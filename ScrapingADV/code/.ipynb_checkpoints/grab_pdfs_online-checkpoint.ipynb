# %%
import urllib.request 
import zipfile
import os
import PyPDF2

# %%
cwd = os.getcwd()

# %%
data_direc = cwd.split('\\')
temp_direc = os.path.join('\\'.join(data_direc[0:-1]),'data','temp')
pdf_direc = os.path.join('\\'.join(data_direc[0:-1]),'data','pdf')
txt_direc = os.path.join('\\'.join(data_direc[0:-1]),'data','text_files')
data_direc = os.path.join('\\'.join(data_direc[0:-1]),'data')

# %%
base_link = 'https://www.sec.gov/foia/docs/adv/formadv_part2_' 
zip_ending = '.zip'

# %%
def download_url(url, save_path, pdf_direc):
    with urllib.request.urlopen(url) as dl_file:
        with open(save_path, 'wb') as out_file:
            out_file.write(dl_file.read())
        with zipfile.ZipFile(save_path,"r") as zip_ref:
            zip_ref.extractall(pdf_direc)

# %%
i = 1
while i <= 112:
    zip_location = base_link + str(i) + zip_ending
    name = 'formadv_part2_'+ str(i) + zip_ending
    download_url(zip_location, os.path.join(temp_direc, name), pdf_direc)
    i = i + 1

# %%
_, _, filenames = next(os.walk(pdf_direc))
error = []
filenames = ['146902_37445_1_20110316.pdf']
for f in filenames:
    try:
        pdf_file = open(os.path.join(pdf_direc, f), 'rb', encoding = 'UTF-8')
        pdfReader = PyPDF2.PdfFileReader(pdf_file)
        count = pdfReader.numPages
        text_string = ''
        for i in range(count):
            page = pdfReader.getPage(i)
            text_string = text_string + page.extractText()
        resultFile = open(os.path.join(txt_direc, f.replace('pdf','txt')),'w')
        resultFile.write(text_string)
        resultFile.close()
    except:
        error.append(f)

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import HTMLConverter,TextConverter,XMLConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
import io

def convert(case,fname, pages=None):
    if not pages: pagenums = set();
    else:         pagenums = set(pages);      
    manager = PDFResourceManager() 
    codec = 'utf-8'
    caching = True

    output = io.StringIO()
    converter = TextConverter(manager, output, codec=codec, laparams=LAParams())     

    interpreter = PDFPageInterpreter(manager, converter)   
    infile = open(fname, 'rb')

    for page in PDFPage.get_pages(infile, pagenums,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    convertedPDF = output.getvalue()  

    infile.close(); converter.close(); output.close()
    return convertedPDF

# %%
x  = convert('text', os.path.join(pdf_direc, '146902_37445_1_20110316.pdf'), pages = [0,1])
print(x)
# Out:
#   Inc.
#
#   2000
#
#   95128
#
#   244-­‐3800
#
# www.sienawealth.com
#
#   2011
#
#   of
#   this
#   clientservice@sienawealth.com.
#   States
#   authority.
#
#   of
#   training.
#
#   SEC’s
#   www.adviserinfo.sec.gov.
#
# i
#
#   Changes
#
#   II
#
#   new
#   clients.
#
#   last
#   2010.
#
#   published
#   narrative
#   new
#   rules.
#
#   interest
#   best
#   regarding
#   providers
#   brochure.
#
#   investment
#   of
#   brochure.
#
#   $189,455,909
#   brochure.
#
#   of
#   custodian,
#   this
# brochure.
#
#   each
#   the
#   Part
#   brochure.
#
#   delivered
#   annual
#   remains
#
# ii

# %% [markdown]
# ## Scrap One File

# %%
txt_fil = open(os.path.join(txt_direc, '146902_37445_1_20110316.txt'), 'rb')
txt_fil = txt_fil.readlines()

# %%
print(txt_fil)
