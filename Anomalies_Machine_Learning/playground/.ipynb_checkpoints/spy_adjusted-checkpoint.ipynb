# %%
from regime_module import *
from statsmodels.iolib.summary2 import summary_col
import csv
import os
import matplotlib.backends.backend_pdf

cur_wd = os.getcwd()
print(cur_wd)
image_wd = os.path.join(cur_wd, 'backtest_images')
backtest_wd = os.path.join(cur_wd, 'backtests_spy')
import matplotlib.pyplot as plt
# Out:
# D:\janko_machine_learning\playground

# %%
def write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns, backtest_write, image_write, cur_wd, data_type ):
    
    outname = 'output_results_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    outnamelatex = 'output_results_latex_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    
    output_reg = []
    output_capm = []
    output_umd = []
    output_qfactor = []
    output_tm = []
    
    names = ['KNN L/S', 'KNN L', 'KNN S', 'Neural Net L/S', 'Neural Net L', 'Neural Net S', 'RF L/S', 'RF L', 'RF S']

    print("KNN")
    print("Long and Short")
    backtest, weights = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Nearest Neighbors"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN' '_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_KNN' '_' + 'ls' + '.pdf'))


    print("Long Only")
    backtest, weights = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Nearest Neighbors"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    
    backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN' '_' + 'l' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_KNN' '_' + 'l' + '.pdf'))

    print("Short Only")
    backtest, weights = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Nearest Neighbors"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    
    
    backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN' '_' + 's' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_KNN' '_' + 's' + '.pdf'))


    print("Neural Net")
    print("Long and Short")
    backtest, weights = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Neural Net"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    backtest.to_csv(os.path.join(backtest_write, data_type + '_NN' '_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_NN' '_' + 'ls' + '.pdf'))

    print("Long Only")

    backtest, weights = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Neural Net"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    backtest.to_csv(os.path.join(backtest_write, data_type + '_NN' '_' + 'l' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_NN' '_' + 'l' + '.pdf'))
 

    print("Short Only")

    backtest, weights = bt.run_backtest(returns,lookback_backtest, input_classifiers= ["Neural Net"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    backtest.to_csv(os.path.join(backtest_write, data_type + '_NN' '_' + 's' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_NN' '_' + 's' + '.pdf'))


    print("Random Forest")
    print("Long and Short")
    backtest, weights = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Random Forest"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    backtest.to_csv(os.path.join(backtest_write, data_type + '_RF' '_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_RF' '_' + 'ls' + '.pdf'))


    print("Long Only")

    backtest, weights = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Random Forest"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    
    backtest.to_csv(os.path.join(backtest_write, data_type + '_RF' '_' + 'l' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_RF' '_' + 'l' + '.pdf'))


    print("Short Only")

    backtest, weights = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Random Forest"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    backtest.to_csv(os.path.join(backtest_write, data_type + '_RF' '_' + 's' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_RF' '_' + 's' + '.pdf'))

    """
    print("Ensemble System")
    try:
        backtest, weights = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Nearest Neighbors", "Random Forest"], inputs = feature_set, outputs = binary_returns,  ensemble = 'yes')  
        results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
        results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
        results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
        results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)

        output_reg.append(results)
        output_capm.append(results_capm)
        output_umd.append(results_umd)
        output_qfactor.append(results_q)
        backtest.to_csv(os.path.join(backtest_write, data_type + '_ensemble' '_' + 'ls' + '.csv'))
        plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
        plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
        plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
        ax = plot_df.plot()
        ax.figure.savefig(os.path.join(image_write, data_type + '_ensemble' '_' + 'ls' + '.pdf'))
    except:
        names.remove('Ensemble')
    """
    
    factor_results = summary_col(output_reg,stars=True,float_format='%0.3f',model_names=names)
    factor_results.title = data_type
    factor_results_capm = summary_col(output_capm,stars=True,float_format='%0.3f',model_names=names)
    factor_results_capm.title = data_type + ' capm'
    
    factor_results_umd = summary_col(output_umd,stars=True,float_format='%0.3f',model_names=names)
    factor_results_umd.title = data_type + ' umd'
    
    factor_results_q = summary_col(output_qfactor,stars=True,float_format='%0.3f',model_names=names)
    factor_results_q.title = data_type + ' q factor'
    
    factor_results_tm = summary_col(output_tm,stars=True,float_format='%0.3f',model_names=names)
    factor_results_tm.title = data_type + ' Treynor and Mazuy'
    
    resultFile = open(os.path.join(backtest_wd,'outputs' ,outname),'a')
    resultFile.write(factor_results.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_capm.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_umd.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_q.as_text())
    resultFile.write('\n')    
    resultFile.write(factor_results_tm.as_text())
    resultFile.write('\n')
    resultFile.close()
    
    resultFile = open(os.path.join(backtest_wd,'outputs' ,outnamelatex),'a')
    resultFile.write(factor_results.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_capm.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_umd.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_q.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_tm.as_latex())
    resultFile.write('\n')
    resultFile.close()
    
    add_factor = pd.DataFrame(factor_results.tables[0]).T['intercept']
    add_factor.columns = [data_type + '_' +  str(lookback) + '_' + str(lookback_backtest) ]
    add_factor.name = data_type + '_' +  str(lookback) + '_' + str(lookback_backtest) 
    add_factor_capm = pd.DataFrame(factor_results_capm.tables[0]).T['intercept']
    add_factor_capm.columns = [data_type + '_' + str(lookback) + '_' + str(lookback_backtest) ]
    add_factor_capm.name = data_type + '_' + str(lookback) + '_' + str(lookback_backtest)
    
    return add_factor, add_factor_capm, factor_results

# %%
alpha_ff5 = pd.DataFrame()
alpha_capm = pd.DataFrame()
treynor_mazuy = pd.DataFrame()

# %%
#get the famma french factors

# %%
ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
ff_factors = ff_factors / 100.0
ff_factors[ff_factors == -999] = np.NaN
ff_factors[ff_factors == -99.9] = np.NaN
ff_factors = ff_factors.dropna(how = 'any', axis = 0)
ff_factors = ff_factors[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
ff_factors_compare = ff_factors.copy()

# %%
#get the momentum model
mom = pd.read_csv('Mom.csv', index_col = 0)
mom.index = pd.to_datetime(mom.index, format= '%Y%m')
mom = mom / 100.0
mom[mom == -999] = np.NaN
mom[mom == -99.9] = np.NaN
mom = mom.dropna(how = 'any', axis = 0)
umd = pd.concat([ff_factors[['Mkt-RF', 'SMB', 'HML']], mom], axis = 1)
umd = umd.dropna()
cols_add = []
for c in umd.columns:
    cols_add.append(c.replace(' ', ''))
umd.columns  = cols_add
print(umd.head(5))
print(umd.columns)
# Out:
#             Mkt-RF     SMB     HML     Mom
# 1963-07-01 -0.0039 -0.0047 -0.0083  0.0100
# 1963-08-01  0.0507 -0.0079  0.0167  0.0103
# 1963-09-01 -0.0157 -0.0048  0.0018  0.0016
# 1963-10-01  0.0253 -0.0129 -0.0010  0.0314
# 1963-11-01 -0.0085 -0.0084  0.0171 -0.0075
# Index(['Mkt-RF', 'SMB', 'HML', 'Mom'], dtype='object')

# %%
q_factor = pd.read_csv('q5_factors.csv', index_col = 0)
q_factor.index = pd.to_datetime(q_factor.index, format= '%Y%m')
q_factor = q_factor[['R_MKT', 'R_ME', 'R_IA', 'R_ROE', 'R_EG']]
q_factor = q_factor / 100.0
print(q_factor.head(5))
# Out:
#                R_MKT      R_ME      R_IA     R_ROE      R_EG
# 1967-01-01  0.081603  0.067282 -0.029434  0.018866 -0.022469
# 1967-02-01  0.007202  0.016918 -0.002064  0.035317  0.025812
# 1967-03-01  0.039691  0.019517 -0.016933  0.018876 -0.014789
# 1967-04-01  0.038265 -0.007446 -0.029519  0.010983 -0.022351
# 1967-05-01 -0.042419  0.029132  0.024686  0.005234  0.002749

# %%
industry = pd.read_csv('48_Industry_Portfolios.csv', index_col = 0)
industry.index = pd.to_datetime(industry.index, format= '%Y%m')
industry[industry <= -99.] = np.nan
industry = industry / 100.0

ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
ff_factors = ff_factors / 100.0
ff_factors[ff_factors == -999] = np.NaN
ff_factors[ff_factors == -99.9] = np.NaN
ff_factors = ff_factors.dropna(how = 'any', axis = 0)

factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
rf = factor_model[['RF']]
rf_subtract = rf.copy()
factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
ff_factors_compare = factor_model.copy()

rf_subtract.index = pd.to_datetime(rf_subtract.index, format = 'Y%-%m-%d')

# %%
lookback_list = [24,12]
lookback_backtest_list = [12]

for lookback in lookback_list:
    for lookback_backtest in lookback_backtest_list:

        if not os.path.exists(os.path.join(image_wd, str(lookback) + '_' + str(lookback_backtest))):
            os.makedirs(os.path.join(image_wd, str(lookback) + '_' + str(lookback_backtest)))

        image_write = os.path.join(image_wd, str(lookback) + '_' + str(lookback_backtest))

        if not os.path.exists(os.path.join(backtest_wd, str(lookback) + '_' + str(lookback_backtest))):
            os.makedirs(os.path.join(backtest_wd, str(lookback) + '_' + str(lookback_backtest)))
        if not os.path.exists(os.path.join(backtest_wd, 'outputs')):
            os.makedirs(os.path.join(backtest_wd, 'outputs'))

        outname = 'output_results_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
        outnamelatex = 'output_results_latex_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    
        backtest_write = os.path.join(backtest_wd, str(lookback) + '_' + str(lookback_backtest))

        resultFile = open(os.path.join(backtest_wd,'outputs' ,outname),'w')
        resultFile.close()
        
        resultFile = open(os.path.join(backtest_wd,'outputs' ,outnamelatex),'w')
        resultFile.close()
        
        
        ################    ETF             ######################################
        """
        etf = pd.read_csv('etf.csv', index_col = 0)
        etf.index = pd.to_datetime(etf.index, format= '%Y%m%d')
        etf.index = etf.index.to_period('M').astype(str)
        etf.index = pd.to_datetime(etf.index, format= '%Y-%m')

        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)

        factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
        rf = factor_model[['RF']]
        factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
        ff_factors_compare = factor_model.copy()
        rf_subtract = factor_model[['Mkt-RF']].copy()
        rf_subtract.index = pd.to_datetime(rf_subtract.index, format = 'Y%-%m-%d')

        union_index = etf.index.intersection(rf_subtract.index)
        etf = etf.loc[union_index,:]
        rf_subtract = rf_subtract.loc[union_index, :]
        for e in etf.columns:
            etf.loc[:,e] = etf.loc[:,e] - rf_subtract['Mkt-RF']

        index_symbol = 'Mkt-RF'
        
        print(etf.head(5))

        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'


        #control the leverage
        lev = 1.
        stk_symbols  = etf.columns
        returns = etf.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [ binary_mean_12]

        feature_set = data.get_features(feature_list)

        data_type = 'etf_universe'

        factor_results, factor_results_capm, factor_reg = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )

        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)

        """
            
        ################    Sector_ETF Sectors           ######################################
        etf = pd.read_csv('Sector_ETF.csv', index_col = 0)
        etf.index = pd.to_datetime(etf.index, format= '%Y%m%d')
        etf.index = etf.index.to_period('M').astype(str)
        etf.index = pd.to_datetime(etf.index, format= '%Y-%m')

        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)

        factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
        rf = factor_model[['RF']]
        factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
        ff_factors_compare = factor_model.copy()
        rf_subtract = rf.copy()
        rf_subtract.index = pd.to_datetime(rf_subtract.index, format = 'Y%-%m-%d')

        union_index = etf.index.intersection(rf_subtract.index)
        etf = etf.loc[union_index,:]
        rf_subtract = rf_subtract.loc[union_index, :]
        for e in etf.columns:
            etf.loc[:,e] = etf.loc[:,e] - rf_subtract['RF']

        index_symbol = 'Mkt-RF'
        
        print(etf.head(5))

        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'


        #control the leverage
        lev = 1.
        stk_symbols  = etf.columns
        returns = etf.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        p = data.get_probability(returns, factor_model, rf)
        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [ binary_mean_12, p]

        feature_set = data.get_features(feature_list)

        data_type = 'sector_etf_universe'

        factor_results, factor_results_capm, factor_reg = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )

        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)
        ######################################################
        ######################################################
        ######################################################
        ############## Factor Model ETF   ####################
        ######################################################
        ######################################################
        ######################################################
        
        etf = pd.read_csv('Three_Factor_ETF.csv', index_col = 0)
        etf.index = pd.to_datetime(etf.index, format= '%Y%m%d')
        etf.index = etf.index.to_period('M').astype(str)
        etf.index = pd.to_datetime(etf.index, format= '%Y-%m')

        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)

        factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
        rf = factor_model[['RF']]
        factor_model = factor_model[['Mkt-RF', 'SMB', 'HML']]
        ff_factors_compare = factor_model.copy()
        rf_subtract = rf.copy()
        rf_subtract.index = pd.to_datetime(rf_subtract.index, format = 'Y%-%m-%d')

        union_index = etf.index.intersection(rf_subtract.index)
        etf = etf.loc[union_index,:]
        rf_subtract = rf_subtract.loc[union_index, :]
        for e in etf.columns:
            if e == 'SPY':
                etf.loc[:,e] = etf.loc[:,e] - rf_subtract['RF']

        index_symbol = 'Mkt-RF'
        
        print(etf.head(5))

        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'


        #control the leverage
        lev = 1.
        stk_symbols  = etf.columns
        returns = etf.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        p = data.get_probability(returns, factor_model, rf)
        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [ binary_mean_12, p]

        feature_set = data.get_features(feature_list)

        data_type = 'three_factor_etf'

        factor_results, factor_results_capm, factor_reg = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )

        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)
        

        ######################################################
        #write the alphas to a csv
        #annualize the alphas
        
        
        alpha_ff5.to_csv('alphaff5.csv')
        alpha_capm.to_csv('alphacapm.csv')
        
        plt.close('all')
# Out:
#                  SPY       XLB  XLC       XLE       XLF       XLI       XLK  \
# 2001-01-01  0.039059 -0.032096  NaN -0.037264 -0.007773 -0.001560  0.185818
# 2001-02-01 -0.099188  0.009150  NaN -0.015938 -0.071078 -0.063730 -0.252862
# 2001-03-01 -0.060226 -0.054178  NaN -0.033923 -0.034176 -0.099853 -0.118802
# 2001-04-01  0.066543  0.102760  NaN  0.099357  0.032272  0.110429  0.157794
# 2001-05-01  0.005126  0.035262  NaN -0.012648  0.040800  0.038650 -0.044158
#
#                  XLP       XLU       XLV       XLY  XME
# 2001-01-01 -0.078310 -0.061671  0.066894  0.110888  NaN
# 2001-02-01  0.002242  0.016954 -0.022965 -0.075204  NaN
# 2001-03-01 -0.073552 -0.018753 -0.068223 -0.018782  NaN
# 2001-04-01  0.015518  0.044358  0.069925  0.042478  NaN
# 2001-05-01  0.011482  0.003812  0.034994  0.020610  NaN
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#                  SPY       XLB  XLC       XLE       XLF       XLI       XLK  \
# 2003-02-01 -0.001905  0.002513  NaN -0.019111 -0.003421 -0.006276  0.017409
# 2003-03-01 -0.002896  0.002540  NaN -0.015460 -0.001548 -0.006037  0.012375
# 2003-04-01 -0.002600  0.002544  NaN -0.011975 -0.002202 -0.005383  0.013227
# 2003-05-01 -0.002922  0.002019  NaN -0.013719 -0.002830 -0.004928  0.010155
# 2003-06-01 -0.002125 -0.001098  NaN -0.020616  0.001753 -0.005199  0.008290
#
#                  XLP       XLU       XLV       XLY  XME
# 2003-02-01 -0.013185 -0.021626  0.005252  0.005847  NaN
# 2003-03-01 -0.010715 -0.018718  0.004206  0.001387  NaN
# 2003-04-01 -0.011332 -0.019476  0.003918  0.002421  NaN
# 2003-05-01 -0.009879 -0.017603  0.005083  0.001205  NaN
# 2003-06-01 -0.009038 -0.017006  0.002752  0.005671  NaN
#                  SPY       XLB  XLC       XLE       XLF       XLI       XLK  \
# 2003-02-01  0.004900  0.030141  NaN  0.039730  0.016531  0.028285  0.030593
# 2003-03-01  0.003760  0.030259  NaN  0.038998  0.016367  0.028257  0.027963
# 2003-04-01  0.003336  0.028859  NaN  0.040202  0.015795  0.027500  0.027916
# 2003-05-01  0.003275  0.028987  NaN  0.039862  0.015880  0.027350  0.028149
# 2003-06-01  0.002844  0.028452  NaN  0.039423  0.016875  0.027241  0.030042
#
#                  XLP       XLU       XLV       XLY  XME
# 2003-02-01  0.021041  0.033882  0.026512  0.027942  NaN
# 2003-03-01  0.019911  0.033731  0.025971  0.024650  NaN
# 2003-04-01  0.019434  0.033768  0.025130  0.024589  NaN
# 2003-05-01  0.018080  0.036604  0.025040  0.023694  NaN
# 2003-06-01  0.017922  0.037013  0.026663  0.021393  NaN
# KNN
# Long and Short
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.775
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):              0.120
# Time:                        09:54:19   Log-Likelihood:                 462.37
# No. Observations:                 199   AIC:                            -912.7
# Df Residuals:                     193   BIC:                            -893.0
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0301      0.086      0.348      0.727      -0.139       0.200
# SMB            0.0603      0.080      0.754      0.451      -0.096       0.217
# HML           -0.0808      0.079     -1.020      0.308      -0.236       0.074
# RMW            0.3069      0.109      2.825      0.005       0.094       0.520
# CMA            0.0521      0.149      0.351      0.726      -0.239       0.344
# intercept      0.0021      0.002      1.229      0.219      -0.001       0.006
# ==============================================================================
# Omnibus:                       24.592   Durbin-Watson:                   2.276
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.724
# Skew:                           0.358   Prob(JB):                     5.42e-20
# Kurtosis:                       6.192   Cond. No.                         86.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                 0.0008288
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):              0.977
# Time:                        09:54:19   Log-Likelihood:                 458.39
# No. Observations:                 199   AIC:                            -912.8
# Df Residuals:                     197   BIC:                            -906.2
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0024      0.085     -0.029      0.977      -0.169       0.164
# intercept      0.0035      0.002      1.930      0.054   -5.39e-05       0.007
# ==============================================================================
# Omnibus:                       26.912   Durbin-Watson:                   2.289
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               97.319
# Skew:                           0.422   Prob(JB):                     7.37e-22
# Kurtosis:                       6.320   Cond. No.                         23.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                    0.5521
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):              0.698
# Time:                        09:54:19   Log-Likelihood:                 461.49
# No. Observations:                 199   AIC:                            -913.0
# Df Residuals:                     194   BIC:                            -896.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0304      0.090      0.336      0.737      -0.147       0.207
# SMB            0.0129      0.082      0.157      0.875      -0.148       0.174
# HML            0.0026      0.088      0.030      0.976      -0.169       0.174
# Mom            0.1038      0.090      1.150      0.250      -0.073       0.281
# intercept      0.0031      0.002      1.657      0.097      -0.001       0.007
# ==============================================================================
# Omnibus:                       38.784   Durbin-Watson:                   2.261
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              157.441
# Skew:                           0.662   Prob(JB):                     6.49e-35
# Kurtosis:                       7.151   Cond. No.                         50.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.103
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     3.546
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):            0.00438
# Time:                        09:54:19   Log-Likelihood:                 451.21
# No. Observations:                 191   AIC:                            -890.4
# Df Residuals:                     185   BIC:                            -870.9
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT          0.0703      0.095      0.739      0.460      -0.116       0.257
# R_ME           0.1175      0.089      1.324      0.185      -0.056       0.291
# R_IA           0.1336      0.136      0.985      0.325      -0.132       0.399
# R_ROE          0.0531      0.163      0.325      0.745      -0.267       0.373
# R_EG           0.5223      0.167      3.132      0.002       0.195       0.849
# intercept      0.0009      0.002      0.523      0.601      -0.002       0.004
# ==============================================================================
# Omnibus:                       18.940   Durbin-Watson:                   2.293
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.716
# Skew:                           0.217   Prob(JB):                     1.46e-14
# Kurtosis:                       5.796   Cond. No.                         83.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                   0.09235
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):              0.912
# Time:                        09:54:19   Log-Likelihood:                 459.09
# No. Observations:                 199   AIC:                            -912.2
# Df Residuals:                     196   BIC:                            -902.3
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF             0.0057      0.078      0.073      0.942      -0.148       0.159
# market_squared     0.5934      1.410      0.421      0.674      -2.170       3.356
# intercept          0.0023      0.002      1.006      0.315      -0.002       0.007
# ==============================================================================
# Omnibus:                       16.458   Durbin-Watson:                   2.276
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.650
# Skew:                           0.019   Prob(JB):                     1.36e-12
# Kurtosis:                       5.567   Cond. No.                         294.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Long Only
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     144.3
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           3.19e-63
# Time:                        09:54:28   Log-Likelihood:                 543.28
# No. Observations:                 199   AIC:                            -1075.
# Df Residuals:                     193   BIC:                            -1055.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.9661      0.039     24.613      0.000       0.889       1.043
# SMB           -0.0697      0.058     -1.198      0.231      -0.184       0.044
# HML            0.1204      0.065      1.862      0.063      -0.006       0.247
# RMW            0.2375      0.086      2.763      0.006       0.069       0.406
# CMA            0.0224      0.124      0.180      0.857      -0.222       0.266
# intercept      0.0004      0.001      0.344      0.731      -0.002       0.003
# ==============================================================================
# Omnibus:                       83.427   Durbin-Watson:                   2.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              844.403
# Skew:                           1.272   Prob(JB):                    4.37e-184
# Kurtosis:                      12.765   Cond. No.                         86.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     413.4
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           2.90e-50
# Time:                        09:54:28   Log-Likelihood:                 533.37
# No. Observations:                 199   AIC:                            -1063.
# Df Residuals:                     197   BIC:                            -1056.
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.9426      0.046     20.331      0.000       0.852       1.033
# intercept      0.0010      0.001      0.737      0.461      -0.002       0.003
# ==============================================================================
# Omnibus:                       92.492   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1086.698
# Skew:                           1.410   Prob(JB):                    1.06e-236
# Kurtosis:                      14.095   Cond. No.                         23.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     139.6
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           5.74e-56
# Time:                        09:54:28   Log-Likelihood:                 538.95
# No. Observations:                 199   AIC:                            -1068.
# Df Residuals:                     194   BIC:                            -1051.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.9396      0.041     22.952      0.000       0.859       1.020
# SMB           -0.1058      0.058     -1.832      0.067      -0.219       0.007
# HML            0.1162      0.060      1.929      0.054      -0.002       0.234
# Mom           -0.0290      0.059     -0.489      0.624      -0.145       0.087
# intercept      0.0013      0.001      1.023      0.306      -0.001       0.004
# ==============================================================================
# Omnibus:                       80.170   Durbin-Watson:                   2.125
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              750.067
# Skew:                           1.233   Prob(JB):                    1.33e-163
# Kurtosis:                      12.186   Cond. No.                         50.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     100.0
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           1.07e-50
# Time:                        09:54:28   Log-Likelihood:                 525.58
# No. Observations:                 191   AIC:                            -1039.
# Df Residuals:                     185   BIC:                            -1020.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT          1.0133      0.048     21.000      0.000       0.919       1.108
# R_ME          -0.0484      0.059     -0.827      0.408      -0.163       0.066
# R_IA           0.2455      0.114      2.158      0.031       0.023       0.468
# R_ROE          0.0387      0.115      0.336      0.737      -0.187       0.265
# R_EG           0.2320      0.117      1.978      0.048       0.002       0.462
# intercept      0.0005      0.001      0.390      0.697      -0.002       0.003
# ==============================================================================
# Omnibus:                       66.921   Durbin-Watson:                   2.199
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              639.581
# Skew:                           0.991   Prob(JB):                    1.31e-139
# Kurtosis:                      11.743   Cond. No.                         83.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.854
# Method:                 Least Squares   F-statistic:                     230.5
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           3.30e-52
# Time:                        09:54:28   Log-Likelihood:                 533.84
# No. Observations:                 199   AIC:                            -1062.
# Df Residuals:                     196   BIC:                            -1052.
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF             0.9472      0.044     21.341      0.000       0.860       1.034
# market_squared     0.3352      0.568      0.591      0.555      -0.777       1.447
# intercept          0.0003      0.001      0.226      0.821      -0.002       0.003
# ==============================================================================
# Omnibus:                       87.543   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1101.927
# Skew:                           1.279   Prob(JB):                    5.24e-240
# Kurtosis:                      14.240   Cond. No.                         294.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Short Only
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.762
# Model:                            OLS   Adj. R-squared:                  0.755
# Method:                 Least Squares   F-statistic:                     124.1
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           1.45e-56
# Time:                        09:54:37   Log-Likelihood:                 423.96
# No. Observations:                 187   AIC:                            -835.9
# Df Residuals:                     181   BIC:                            -816.5
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -1.0064      0.051    -19.796      0.000      -1.106      -0.907
# SMB           -0.0515      0.103     -0.502      0.616      -0.252       0.150
# HML           -0.1248      0.068     -1.846      0.065      -0.257       0.008
# RMW           -0.0578      0.131     -0.441      0.659      -0.315       0.199
# CMA           -0.2256      0.146     -1.543      0.123      -0.512       0.061
# intercept      0.0027      0.002      1.381      0.167      -0.001       0.006
# ==============================================================================
# Omnibus:                       24.648   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.316
# Skew:                           0.439   Prob(JB):                     5.98e-18
# Kurtosis:                       6.067   Cond. No.                         85.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.746
# Method:                 Least Squares   F-statistic:                     566.9
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           3.14e-58
# Time:                        09:54:37   Log-Likelihood:                 418.69
# No. Observations:                 187   AIC:                            -833.4
# Df Residuals:                     185   BIC:                            -826.9
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -1.0250      0.043    -23.810      0.000      -1.109      -0.941
# intercept      0.0031      0.002      1.625      0.104      -0.001       0.007
# ==============================================================================
# Omnibus:                       27.157   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.845
# Skew:                           0.442   Prob(JB):                     7.67e-23
# Kurtosis:                       6.505   Cond. No.                         23.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.761
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                     156.4
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           9.05e-58
# Time:                        09:54:37   Log-Likelihood:                 423.83
# No. Observations:                 187   AIC:                            -837.7
# Df Residuals:                     182   BIC:                            -821.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.9657      0.049    -19.657      0.000      -1.062      -0.869
# SMB           -0.0387      0.098     -0.394      0.694      -0.231       0.154
# HML           -0.1470      0.068     -2.172      0.030      -0.280      -0.014
# Mom            0.0700      0.082      0.857      0.392      -0.090       0.230
# intercept      0.0022      0.002      1.122      0.262      -0.002       0.006
# ==============================================================================
# Omnibus:                       26.836   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              102.528
# Skew:                           0.425   Prob(JB):                     5.45e-23
# Kurtosis:                       6.526   Cond. No.                         51.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.746
# Method:                 Least Squares   F-statistic:                     113.6
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           9.47e-53
# Time:                        09:54:37   Log-Likelihood:                 415.20
# No. Observations:                 179   AIC:                            -818.4
# Df Residuals:                     173   BIC:                            -799.3
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT         -0.9776      0.057    -17.245      0.000      -1.089      -0.866
# R_ME           0.0638      0.103      0.618      0.536      -0.138       0.266
# R_IA          -0.1258      0.120     -1.049      0.294      -0.361       0.109
# R_ROE         -0.1393      0.122     -1.140      0.254      -0.379       0.100
# R_EG           0.3690      0.129      2.853      0.004       0.115       0.623
# intercept  -3.861e-06      0.002     -0.002      0.999      -0.004       0.004
# ==============================================================================
# Omnibus:                       27.050   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               86.847
# Skew:                           0.526   Prob(JB):                     1.39e-19
# Kurtosis:                       6.246   Cond. No.                         82.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.745
# Method:                 Least Squares   F-statistic:                     303.9
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           4.87e-59
# Time:                        09:54:37   Log-Likelihood:                 418.78
# No. Observations:                 187   AIC:                            -831.6
# Df Residuals:                     184   BIC:                            -821.9
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF            -1.0215      0.045    -22.585      0.000      -1.110      -0.933
# market_squared     0.2319      0.410      0.566      0.572      -0.572       1.035
# intercept          0.0027      0.002      1.152      0.249      -0.002       0.007
# ==============================================================================
# Omnibus:                       27.798   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              104.937
# Skew:                           0.457   Prob(JB):                     1.63e-23
# Kurtosis:                       6.554   Cond. No.                         287.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Neural Net
# Long and Short
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.142
# Model:                            OLS   Adj. R-squared:                  0.120
# Method:                 Least Squares   F-statistic:                     6.213
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           2.29e-05
# Time:                        09:57:14   Log-Likelihood:                 449.87
# No. Observations:                 199   AIC:                            -887.7
# Df Residuals:                     193   BIC:                            -868.0
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.2429      0.102      2.372      0.018       0.042       0.444
# SMB            0.0496      0.079      0.630      0.528      -0.105       0.204
# HML           -0.1845      0.098     -1.879      0.060      -0.377       0.008
# RMW            0.3791      0.111      3.415      0.001       0.161       0.597
# CMA            0.2922      0.179      1.637      0.102      -0.058       0.642
# intercept      0.0011      0.002      0.531      0.596      -0.003       0.005
# ==============================================================================
# Omnibus:                       54.064   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              477.191
# Skew:                           0.702   Prob(JB):                    2.40e-104
# Kurtosis:                      10.455   Cond. No.                         86.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     2.516
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):              0.114
# Time:                        09:57:14   Log-Likelihood:                 442.51
# No. Observations:                 199   AIC:                            -881.0
# Df Residuals:                     197   BIC:                            -874.4
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1756      0.111      1.586      0.113      -0.041       0.393
# intercept      0.0031      0.002      1.345      0.179      -0.001       0.008
# ==============================================================================
# Omnibus:                       56.680   Durbin-Watson:                   1.957
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              487.834
# Skew:                           0.769   Prob(JB):                    1.17e-106
# Kurtosis:                      10.515   Cond. No.                         23.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.219
# Model:                            OLS   Adj. R-squared:                  0.203
# Method:                 Least Squares   F-statistic:                     7.685
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           9.08e-06
# Time:                        09:57:14   Log-Likelihood:                 459.28
# No. Observations:                 199   AIC:                            -908.6
# Df Residuals:                     194   BIC:                            -892.1
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.2607      0.110      2.362      0.018       0.044       0.477
# SMB           -0.0120      0.077     -0.155      0.877      -0.164       0.140
# HML            0.0588      0.099      0.592      0.554      -0.136       0.254
# Mom            0.2614      0.056      4.638      0.000       0.151       0.372
# intercept      0.0022      0.002      1.017      0.309      -0.002       0.006
# ==============================================================================
# Omnibus:                       78.397   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              883.980
# Skew:                           1.127   Prob(JB):                    1.11e-192
# Kurtosis:                      13.076   Cond. No.                         50.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     4.922
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           0.000297
# Time:                        09:57:14   Log-Likelihood:                 432.54
# No. Observations:                 191   AIC:                            -853.1
# Df Residuals:                     185   BIC:                            -833.6
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT          0.2455      0.120      2.053      0.040       0.011       0.480
# R_ME           0.0349      0.088      0.394      0.693      -0.138       0.208
# R_IA           0.1549      0.148      1.049      0.294      -0.135       0.444
# R_ROE          0.2792      0.136      2.059      0.039       0.013       0.545
# R_EG           0.2979      0.150      1.988      0.047       0.004       0.592
# intercept      0.0010      0.002      0.483      0.629      -0.003       0.005
# ==============================================================================
# Omnibus:                       41.424   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              313.272
# Skew:                           0.497   Prob(JB):                     9.42e-69
# Kurtosis:                       9.195   Cond. No.                         83.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.092
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     2.786
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):             0.0641
# Time:                        09:57:14   Log-Likelihood:                 444.21
# No. Observations:                 199   AIC:                            -882.4
# Df Residuals:                     196   BIC:                            -872.5
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF             0.1894      0.093      2.026      0.043       0.006       0.373
# market_squared     1.0030      1.764      0.568      0.570      -2.455       4.461
# intercept          0.0011      0.002      0.449      0.654      -0.004       0.006
# ==============================================================================
# Omnibus:                       29.679   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              207.055
# Skew:                          -0.009   Prob(JB):                     1.09e-45
# Kurtosis:                       7.997   Cond. No.                         294.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Long Only
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     255.4
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           8.50e-83
# Time:                        09:59:51   Log-Likelihood:                 619.30
# No. Observations:                 198   AIC:                            -1227.
# Df Residuals:                     192   BIC:                            -1207.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.9876      0.034     29.055      0.000       0.921       1.054
# SMB           -0.0383      0.039     -0.976      0.329      -0.115       0.039
# HML            0.0610      0.045      1.350      0.177      -0.028       0.149
# RMW            0.2281      0.065      3.532      0.000       0.102       0.355
# CMA            0.0387      0.054      0.716      0.474      -0.067       0.145
# intercept     -0.0017      0.001     -2.107      0.035      -0.003      -0.000
# ==============================================================================
# Omnibus:                       85.191   Durbin-Watson:                   2.176
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              607.577
# Skew:                          -1.449   Prob(JB):                    1.16e-132
# Kurtosis:                      11.077   Cond. No.                         86.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# ...
# Mom            0.0487      0.061      0.793      0.428      -0.072       0.169
# intercept      0.0004      0.002      0.236      0.814      -0.003       0.004
# ==============================================================================
# Omnibus:                        7.977   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):               15.114
# Skew:                           0.039   Prob(JB):                     0.000522
# Kurtosis:                       4.459   Cond. No.                         51.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.435
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     11.07
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           3.67e-09
# Time:                        10:18:24   Log-Likelihood:                 425.53
# No. Observations:                 165   AIC:                            -839.1
# Df Residuals:                     159   BIC:                            -820.4
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT          0.3112      0.082      3.804      0.000       0.151       0.472
# R_ME           0.2472      0.091      2.710      0.007       0.068       0.426
# R_IA           0.2207      0.103      2.136      0.033       0.018       0.423
# R_ROE          0.0873      0.123      0.709      0.478      -0.154       0.328
# R_EG          -0.1053      0.142     -0.740      0.459      -0.384       0.173
# intercept      0.0009      0.002      0.534      0.593      -0.002       0.004
# ==============================================================================
# Omnibus:                        9.610   Durbin-Watson:                   1.809
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               20.740
# Skew:                          -0.070   Prob(JB):                     3.14e-05
# Kurtosis:                       4.731   Cond. No.                         88.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.424
# Model:                            OLS   Adj. R-squared:                  0.417
# Method:                 Least Squares   F-statistic:                     19.87
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           1.82e-08
# Time:                        10:18:24   Log-Likelihood:                 425.10
# No. Observations:                 170   AIC:                            -844.2
# Df Residuals:                     167   BIC:                            -834.8
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF             0.4228      0.069      6.122      0.000       0.287       0.558
# market_squared    -0.4801      1.388     -0.346      0.729      -3.201       2.241
# intercept       3.675e-05      0.002      0.021      0.983      -0.003       0.003
# ==============================================================================
# Omnibus:                       13.384   Durbin-Watson:                   1.815
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               38.184
# Skew:                           0.069   Prob(JB):                     5.11e-09
# Kurtosis:                       5.318   Cond. No.                         333.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Short Only
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.643
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     70.04
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           2.63e-30
# Time:                        10:18:27   Log-Likelihood:                 511.27
# No. Observations:                 189   AIC:                            -1015.
# Df Residuals:                     185   BIC:                            -1002.
# Df Model:                           3
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2556      0.068     -3.784      0.000      -0.388      -0.123
# SMB           -0.3645      0.069     -5.276      0.000      -0.500      -0.229
# HML           -0.2968      0.041     -7.207      0.000      -0.377      -0.216
# intercept      0.0007      0.001      0.524      0.600      -0.002       0.004
# ==============================================================================
# Omnibus:                       85.744   Durbin-Watson:                   1.723
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              642.152
# Skew:                           1.512   Prob(JB):                    3.62e-140
# Kurtosis:                      11.509   Cond. No.                         50.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.423
# Model:                            OLS   Adj. R-squared:                  0.420
# Method:                 Least Squares   F-statistic:                     45.84
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           1.61e-10
# Time:                        10:18:27   Log-Likelihood:                 465.82
# No. Observations:                 189   AIC:                            -927.6
# Df Residuals:                     187   BIC:                            -921.2
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.4000      0.059     -6.771      0.000      -0.516      -0.284
# intercept      0.0023      0.002      1.318      0.187      -0.001       0.006
# ==============================================================================
# Omnibus:                       47.381   Durbin-Watson:                   1.572
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              131.706
# Skew:                           1.035   Prob(JB):                     2.51e-29
# Kurtosis:                       6.527   Cond. No.                         22.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.644
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     53.76
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           5.93e-30
# Time:                        10:18:27   Log-Likelihood:                 511.62
# No. Observations:                 189   AIC:                            -1013.
# Df Residuals:                     184   BIC:                            -997.0
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2487      0.067     -3.699      0.000      -0.381      -0.117
# SMB           -0.3649      0.069     -5.287      0.000      -0.500      -0.230
# HML           -0.2821      0.042     -6.673      0.000      -0.365      -0.199
# Mom            0.0247      0.027      0.926      0.355      -0.028       0.077
# intercept      0.0007      0.001      0.515      0.607      -0.002       0.003
# ==============================================================================
# Omnibus:                       84.198   Durbin-Watson:                   1.731
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              625.266
# Skew:                           1.480   Prob(JB):                    1.68e-136
# Kurtosis:                      11.405   Cond. No.                         51.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.607
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     28.93
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           2.49e-21
# Time:                        10:18:27   Log-Likelihood:                 490.15
# No. Observations:                 181   AIC:                            -968.3
# Df Residuals:                     175   BIC:                            -949.1
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT         -0.2943      0.061     -4.809      0.000      -0.414      -0.174
# R_ME          -0.3256      0.070     -4.654      0.000      -0.463      -0.188
# R_IA          -0.1300      0.081     -1.610      0.107      -0.288       0.028
# R_ROE          0.0269      0.057      0.469      0.639      -0.086       0.139
# R_EG           0.1597      0.114      1.398      0.162      -0.064       0.384
# intercept   2.102e-05      0.001      0.016      0.987      -0.003       0.003
# ==============================================================================
# Omnibus:                       41.199   Durbin-Watson:                   1.843
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              155.524
# Skew:                           0.807   Prob(JB):                     1.69e-34
# Kurtosis:                       7.244   Cond. No.                         80.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.466
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     40.49
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           2.52e-15
# Time:                        10:18:27   Log-Likelihood:                 473.13
# No. Observations:                 189   AIC:                            -940.3
# Df Residuals:                     186   BIC:                            -930.5
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF            -0.3795      0.044     -8.566      0.000      -0.466      -0.293
# market_squared     1.6074      0.707      2.273      0.023       0.222       2.993
# intercept         -0.0011      0.002     -0.687      0.492      -0.004       0.002
# ==============================================================================
# Omnibus:                       16.877   Durbin-Watson:                   1.640
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.097
# Skew:                           0.470   Prob(JB):                     4.80e-07
# Kurtosis:                       4.676   Cond. No.                         286.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %% [markdown]
# Lets clean up the input of the alpha parameters

# %%
alpha_ff5 = pd.read_csv('alphaff5.csv', index_col = 0).T
alpha_capm = pd.read_csv('alphacapm.csv', index_col = 0).T

alpha_ff5_clean  = alpha_ff5.copy()
alpha_capm_clean = alpha_capm.copy()

alpha_ff5_clean.loc[:, 'lookback feature'] = ''
alpha_ff5_clean.loc[:, 'lookback ml model'] = ''
alpha_ff5_clean.loc[:, 'new index'] = ''

alpha_capm_clean.loc[:, 'lookback feature'] = ''
alpha_capm_clean.loc[:, 'lookback ml model'] = ''
alpha_capm_clean.loc[:, 'new index'] = ''

for count, row in alpha_ff5.iterrows():
    alpha_ff5_clean.loc[count, 'lookback feature'] = count.split('_')[-2]
    alpha_ff5_clean.loc[count, 'lookback ml model'] = count.split('_')[-1]
    alpha_ff5_clean.loc[count, 'new index'] = "_".join(count.split('_')[0:-2])
   
for count, row in alpha_capm.iterrows():
    alpha_capm_clean.loc[count, 'lookback feature'] = count.split('_')[-2]
    alpha_capm_clean.loc[count, 'lookback ml model'] = count.split('_')[-1]
    alpha_capm_clean.loc[count, 'new index'] = "_".join(count.split('_')[0:-2])
    
alpha_capm_clean.index = alpha_capm_clean.loc[:, 'new index']
alpha_ff5_clean.index = alpha_ff5_clean.loc[:, 'new index']

alpha_capm_clean.drop('new index', axis = 1, inplace = True)
alpha_capm.index.name = 'strategy'
alpha_ff5_clean.drop('new index', axis = 1, inplace = True)
alpha_ff5_clean.index.name = 'strategy'

alpha_ff5_clean.to_csv('alphaff5_cleaned.csv')
alpha_capm_clean.to_csv('alphacapm_cleaned.csv')
alpha_ff5_clean.to_latex('alphaff5_latex.txt')
alpha_capm_clean.to_latex('alphacapm_latex.txt')

# %%
#get the alphas for a backtest across individual portfolios

# %%
alpha_capm
# Out:
#                           KNN L/S   KNN L   KNN S Neural Net L/S Neural Net L  \
# strategy
# sector_etf_universe_24_12  0.004*   0.001   0.003          0.003       -0.001
# three_factor_etf_24_12     0.002*   0.001   0.003        0.003**        0.002
# sector_etf_universe_12_12   0.002  -0.000   0.002          0.002      -0.002*
# three_factor_etf_12_12      0.002   0.000  0.004*         0.002*        0.001
#
#                           Neural Net S    RF L/S    RF L      RF S
# strategy
# sector_etf_universe_24_12      0.005**     0.002   0.001     0.001
# three_factor_etf_24_12        0.005***     0.001  -0.001     0.003
# sector_etf_universe_12_12      0.005**  0.004***   0.001  0.003***
# three_factor_etf_12_12        0.005***     0.001  -0.001     0.002
