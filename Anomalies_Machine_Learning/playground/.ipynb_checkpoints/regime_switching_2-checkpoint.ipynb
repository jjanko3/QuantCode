# %%
from regime_module import *
from statsmodels.iolib.summary2 import summary_col
import csv
import os

cur_wd = os.getcwd()
print(cur_wd)
# Out:
# D:\janko_machine_learning\playground

# %%
ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
ff_factors = ff_factors / 100.0
ff_factors[ff_factors == -999] = np.NaN
ff_factors[ff_factors == -99.9] = np.NaN
ff_factors = ff_factors.dropna(how = 'any', axis = 0)
ff_factors = ff_factors[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
ff_factors_compare = ff_factors.copy()

# %% [markdown]
# # hoe zue zhang

# %%
q_factor = pd.read_csv('q5_factors.csv', index_col = 0)
q_factor.index = pd.to_datetime(q_factor.index, format= '%Y%m')
q_factor = q_factor / 100.0

factor_model = q_factor.copy()
factor_model = factor_model[['R_MKT', 'R_ME', 'R_IA', 'R_ROE', 'R_EG']]
rf = q_factor[['R_F']]

index_symbol = 'R_MKT'

print(q_factor.head(5))
# Out:
#                  R_F     R_MKT      R_ME      R_IA     R_ROE      R_EG
# 1967-01-01  0.003927  0.081603  0.067282 -0.029434  0.018866 -0.022469
# 1967-02-01  0.003743  0.007202  0.016918 -0.002064  0.035317  0.025812
# 1967-03-01  0.003693  0.039691  0.019517 -0.016933  0.018876 -0.014789
# 1967-04-01  0.003344  0.038265 -0.007446 -0.029519  0.010983 -0.022351
# 1967-05-01  0.003126 -0.042419  0.029132  0.024686  0.005234  0.002749

# %%
#start date for data
start = '2004-01-01'
#end date for data
end = '2020-01-01'

#the lookback for alpha feature
lookback = 60
#control the leverage
lev = 1.
stk_symbols  = factor_model.columns
returns = factor_model.copy()


#set the backtest parameters
bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
bt = Backtest(bp, returns, mode = 'insample')
data = Data(bp)

df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns = data.get_rolling_features(returns, 0.0)


#creates a dictionary of different features for analysis based on ticker keys
feature_list = [binary_alpha]

feature_set = data.get_features(feature_list)
# Out:
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#                R_MKT      R_ME      R_IA     R_ROE      R_EG
# 1972-02-01 -0.006003 -0.000718 -0.000272  0.006437  0.005032
# 1972-03-01 -0.005190  0.000011 -0.000285  0.005517  0.005497
# 1972-04-01 -0.005061 -0.000321 -0.000492  0.005074  0.005028
# 1972-05-01 -0.005651  0.000034  0.000432  0.005457  0.005369
# 1972-06-01 -0.003984 -0.000320 -0.000824  0.006204  0.005462
#                R_MKT      R_ME      R_IA     R_ROE      R_EG
# 1972-02-01  0.044118  0.026733  0.020240  0.018881  0.019336
# 1972-03-01  0.044233  0.027048  0.020240  0.020261  0.019037
# 1972-04-01  0.044164  0.027120  0.020062  0.020322  0.019038
# 1972-05-01  0.043933  0.026998  0.019858  0.020589  0.018904
# 1972-06-01  0.043656  0.026960  0.019462  0.020558  0.018900

# %%
output_reg = []
output_capm = []
names = ['KNN L/S', 'KNN L', 'KNN S', 'Neural Net L/S', 'Neural Net L', 'Neural Net S', 'RF L/S', 'RF L', 'RF S', 'Ensemble', 'Binary']

data_type = 'q_factor'

print("KNN")
print("Long and Short")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 'ls' + '.csv'))
#backtest.mean(axis = 1).cumsum().plot()

print("Long Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 'l' + '.csv'))
#backtest.mean(axis = 1).cumsum().plot()

print("Short Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 's' + '.csv'))
#backtest.mean(axis = 1).cumsum().plot()

print("Neural Net")
print("Long and Short")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 'ls' + '.csv'))

print("Long Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 'l' + '.csv'))

print("Short Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 's' + '.csv'))

print("Random Forest")
print("Long and Short")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 'ls' + '.csv'))

print("Long Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 'l' + '.csv'))

print("Short Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 's' + '.csv'))

print("Ensemble System")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors", "Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'yes')  
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_ensemble' '_' + 'ls' + '.csv'))
    
print("Simple Binary Decision")
df_alpha_shift = df_alpha.shift(1).dropna(axis = 0)
backtest = returns.loc[df_alpha_shift.index]
weights = returns.loc[df_alpha_shift.index]
for count, row in  backtest.iterrows(): 
    for j in backtest.columns:
        if df_alpha_shift.loc[count, j] >= 0:
            backtest.loc[count, j] = backtest.loc[count, j]
            weights.loc[count, j] = 1.0
        else:
            backtest.loc[count, j] = -backtest.loc[count, j]
            weights.loc[count, j] = -1.0
            
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_simp_binary' '_' + 'ls' + '.csv'))


print(summary_col(output_reg,stars=True,float_format='%0.4f',model_names=names))
# Out:
# KNN
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -62371.315
# Model:                            OLS   Adj. R-squared:             -62931.210
# Method:                 Least Squares   F-statistic:                    -111.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:31:57   Log-Likelihood:                -1563.2
# No. Observations:                 563   AIC:                             3138.
# Df Residuals:                     557   BIC:                             3164.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0282      4.154      0.007      0.995      -8.131       8.187
# SMB           -0.0515      6.053     -0.009      0.993     -11.941      11.838
# HML           -0.0795      7.939     -0.010      0.992     -15.674      15.515
# RMW           -0.0457      8.032     -0.006      0.995     -15.822      15.731
# CMA            0.1694     12.328      0.014      0.989     -24.046      24.384
# intercept      3.8900      0.173     22.517      0.000       3.551       4.229
# ==============================================================================
# Omnibus:                       91.292   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              446.635
# Skew:                          -0.611   Prob(JB):                     1.03e-97
# Kurtosis:                       7.189   Cond. No.                         83.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                    mean  std_error     tstat
# intercept  3.434481e-03   0.000646  5.318678
# Mkt-RF     4.157651e-05   0.000057  0.730647
# SMB       -1.945527e-05   0.000035 -0.555322
# HML       -7.985740e-07   0.000034 -0.023605
# RMW       -9.797554e-06   0.000029 -0.337161
# CMA        3.399973e-05   0.000022  1.537508
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -67941.962
# Model:                            OLS   Adj. R-squared:             -68063.072
# Method:                 Least Squares   F-statistic:                    -561.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:31:57   Log-Likelihood:                -1587.3
# No. Observations:                 563   AIC:                             3179.
# Df Residuals:                     561   BIC:                             3187.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0106      3.794      0.003      0.998      -7.442       7.463
# intercept      4.0600      0.173     23.518      0.000       3.721       4.399
# ==============================================================================
# Omnibus:                      110.543   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              688.451
# Skew:                          -0.694   Prob(JB):                    3.20e-150
# Kurtosis:                       8.236   Cond. No.                         22.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.003442   0.000651  5.284239
# Mkt-RF     0.000041   0.000058  0.718602
# Long Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -98317.698
# Model:                            OLS   Adj. R-squared:             -99200.271
# Method:                 Least Squares   F-statistic:                    -111.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:32:08   Log-Likelihood:                -1762.2
# No. Observations:                 563   AIC:                             3536.
# Df Residuals:                     557   BIC:                             3562.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1565      5.916      0.026      0.979     -11.463      11.776
# SMB            0.0592      8.621      0.007      0.995     -16.874      16.992
# HML           -0.0744     11.307     -0.007      0.995     -22.284      22.135
# RMW            0.0860     11.439      0.008      0.994     -22.382      22.554
# CMA            0.2951     17.557      0.017      0.987     -34.191      34.781
# intercept      5.5400      0.246     22.517      0.000       5.057       6.023
# ==============================================================================
# Omnibus:                      140.964   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              840.154
# Skew:                          -0.956   Prob(JB):                    3.65e-183
# Kurtosis:                       8.671   Cond. No.                         83.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.006501   0.000735  8.848094
# Mkt-RF     0.000275   0.000061  4.481878
# SMB        0.000089   0.000035  2.528889
# HML        0.000024   0.000032  0.746887
# RMW        0.000010   0.000027  0.371959
# CMA        0.000050   0.000023  2.148400
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -157865.339
# Model:                            OLS   Adj. R-squared:            -158146.741
# Method:                 Least Squares   F-statistic:                    -561.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:32:08   Log-Likelihood:                -1895.5
# No. Observations:                 563   AIC:                             3795.
# Df Residuals:                     561   BIC:                             3804.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1182      6.560      0.018      0.986     -12.768      13.004
# intercept      7.0200      0.298     23.518      0.000       6.434       7.606
# ==============================================================================
# Omnibus:                      113.565   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              751.685
# Skew:                          -0.699   Prob(JB):                    5.94e-164
# Kurtosis:                       8.485   Cond. No.                         22.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.006519   0.000739  8.817835
# Mkt-RF     0.000276   0.000062  4.452342
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -3260.945
# Model:                            OLS   Adj. R-squared:              -3293.370
# Method:                 Least Squares   F-statistic:                    -100.6
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:32:19   Log-Likelihood:                -885.81
# No. Observations:                 509   AIC:                             1784.
# Df Residuals:                     503   BIC:                             1809.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2070      1.553     -0.133      0.894      -3.259       2.844
# SMB           -0.2677      2.299     -0.116      0.907      -4.785       4.250
# HML           -0.0608      2.975     -0.020      0.984      -5.905       5.783
# RMW           -0.3152      2.996     -0.105      0.916      -6.202       5.571
# CMA           -0.0466      4.600     -0.010      0.992      -9.084       8.990
# intercept      1.3800      0.064     21.440      0.000       1.254       1.506
# ==============================================================================
# Omnibus:                       26.999   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.041
# Skew:                           0.149   Prob(JB):                     3.08e-17
# Kurtosis:                       4.870   Cond. No.                         83.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.001556   0.001056 -1.473472
# Mkt-RF    -0.000394   0.000083 -4.769024
# SMB       -0.000226   0.000054 -4.156039
# HML       -0.000028   0.000051 -0.543165
# RMW       -0.000054   0.000044 -1.228981
# CMA        0.000018   0.000031  0.591377
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -1015.189
# Model:                            OLS   Adj. R-squared:              -1017.193
# Method:                 Least Squares   F-statistic:                    -506.5
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:32:19   Log-Likelihood:                -589.00
# No. Observations:                 509   AIC:                             1182.
# Df Residuals:                     507   BIC:                             1190.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.1922      0.756     -0.254      0.799      -1.678       1.293
# intercept     -0.7700      0.034    -22.400      0.000      -0.838      -0.702
# ==============================================================================
# Omnibus:                       48.162   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.544
# Skew:                          -0.248   Prob(JB):                     1.57e-47
# Kurtosis:                       6.149   Cond. No.                         22.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.001562   0.001064 -1.467177
# Mkt-RF    -0.000396   0.000084 -4.738894
# Neural Net
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -117823.085
# Model:                            OLS   Adj. R-squared:            -118880.752
# Method:                 Least Squares   F-statistic:                    -111.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:34:59   Log-Likelihood:                -1680.4
# No. Observations:                 563   AIC:                             3373.
# Df Residuals:                     557   BIC:                             3399.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0345      5.115      0.007      0.995     -10.012      10.081
# SMB            0.0630      7.454      0.008      0.993     -14.578      14.704
# HML           -0.0881      9.776     -0.009      0.993     -19.291      19.115
# RMW            0.1143      9.890      0.012      0.991     -19.312      19.541
# CMA            0.2468     15.180      0.016      0.987     -29.571      30.064
# intercept      4.7900      0.213     22.517      0.000       4.372       5.208
# ==============================================================================
# Omnibus:                       65.946   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              267.318
# Skew:                          -0.446   Prob(JB):                     8.97e-59
# Kurtosis:                       6.256   Cond. No.                         83.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.005071   0.000580  8.736898
# Mkt-RF     0.000039   0.000047  0.828026
# SMB        0.000044   0.000030  1.465170
# HML        0.000035   0.000026  1.360632
# RMW        0.000047   0.000024  1.928327
# CMA        0.000064   0.000017  3.697326
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -190456.041
# Model:                            OLS   Adj. R-squared:            -190795.536
# Method:                 Least Squares   F-statistic:                    -561.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:35:00   Log-Likelihood:                -1815.5
# No. Observations:                 563   AIC:                             3635.
# Df Residuals:                     561   BIC:                             3644.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0041      5.691      0.001      0.999     -11.175      11.183
# intercept      6.0900      0.259     23.518      0.000       5.581       6.599
# ==============================================================================
# Omnibus:                       53.877   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.489
# Skew:                          -0.414   Prob(JB):                     5.78e-38
# Kurtosis:                       5.574   Cond. No.                         22.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.005088   0.000584  8.706328
# Mkt-RF     0.000038   0.000047  0.802837
# Long Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -138408.813
# Model:                            OLS   Adj. R-squared:            -139651.271
# Method:                 Least Squares   F-statistic:                    -111.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:37:39   Log-Likelihood:                -1690.8
# No. Observations:                 563   AIC:                             3394.
# Df Residuals:                     557   BIC:                             3420.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1223      5.211      0.023      0.981     -10.113      10.358
# SMB            0.1028      7.594      0.014      0.989     -14.813      15.018
# HML           -0.0724      9.960     -0.007      0.994     -19.636      19.491
# RMW            0.1613     10.076      0.016      0.987     -19.630      19.953
# CMA            0.2798     15.465      0.018      0.986     -30.098      30.657
# intercept      4.8800      0.217     22.517      0.000       4.454       5.306
# ==============================================================================
# Omnibus:                       79.847   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              409.286
# Skew:                          -0.492   Prob(JB):                     1.33e-89
# Kurtosis:                       7.059   Cond. No.                         83.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept  0.006000   0.000547  10.975173
# Mkt-RF     0.000204   0.000040   5.077867
# SMB        0.000096   0.000026   3.766683
# HML        0.000035   0.000023   1.548261
# RMW        0.000044   0.000021   2.070457
# CMA        0.000055   0.000016   3.377674
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -257794.424
# Model:                            OLS   Adj. R-squared:            -258253.953
# Method:                 Least Squares   F-statistic:                    -561.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:37:40   Log-Likelihood:                -1865.9
# No. Observations:                 563   AIC:                             3736.
# Df Residuals:                     561   BIC:                             3744.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0841      6.224      0.014      0.989     -12.141      12.309
# intercept      6.6600      0.283     23.518      0.000       6.104       7.216
# ==============================================================================
# Omnibus:                       48.516   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              185.020
# Skew:                          -0.280   Prob(JB):                     6.66e-41
# Kurtosis:                       5.752   Cond. No.                         22.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept  0.006020   0.000550  10.947698
# Mkt-RF     0.000204   0.000041   5.039503
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -23022.943
# Model:                            OLS   Adj. R-squared:             -23378.251
# Method:                 Least Squares   F-statistic:                    -64.80
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:40:20   Log-Likelihood:                -1025.7
# No. Observations:                 330   AIC:                             2063.
# Df Residuals:                     324   BIC:                             2086.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.4299      7.024     -0.061      0.951     -14.248      13.388
# SMB           -0.2003     11.044     -0.018      0.986     -21.927      21.527
# HML           -0.0813     13.735     -0.006      0.995     -27.102      26.939
# RMW           -0.2288     15.447     -0.015      0.988     -30.617      30.159
# CMA           -0.0130     21.762     -0.001      1.000     -42.827      42.801
# intercept      5.4200      0.313     17.334      0.000       4.805       6.035
# ==============================================================================
# Omnibus:                       14.193   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               25.736
# Skew:                          -0.232   Prob(JB):                     2.58e-06
# Kurtosis:                       4.287   Cond. No.                         80.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.001494   0.001935  0.772358
# Mkt-RF    -0.001017   0.000185 -5.485975
# SMB       -0.000286   0.000099 -2.887604
# HML        0.000067   0.000094  0.711459
# RMW        0.000041   0.000066  0.619369
# CMA        0.000145   0.000048  3.010269
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -15311.020
# Model:                            OLS   Adj. R-squared:             -15357.703
# Method:                 Least Squares   F-statistic:                    -328.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:40:20   Log-Likelihood:                -958.41
# No. Observations:                 330   AIC:                             1921.
# Df Residuals:                     328   BIC:                             1928.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.4272      4.928     -0.087      0.931     -10.122       9.268
# intercept      4.4200      0.245     18.032      0.000       3.938       4.902
# ==============================================================================
# Omnibus:                        5.933   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.051   Jarque-Bera (JB):                8.445
# Skew:                          -0.064   Prob(JB):                       0.0147
# Kurtosis:                       3.773   Cond. No.                         20.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.001501   0.001948  0.770528
# Mkt-RF    -0.001024   0.000187 -5.476763
# Random Forest
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -54779.576
# Model:                            OLS   Adj. R-squared:             -55271.323
# Method:                 Least Squares   F-statistic:                    -111.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:40:31   Log-Likelihood:                -1525.8
# No. Observations:                 563   AIC:                             3064.
# Df Residuals:                     557   BIC:                             3090.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0046      3.887      0.001      0.999      -7.630       7.639
# SMB            0.0377      5.664      0.007      0.995     -11.088      11.163
# HML           -0.1046      7.429     -0.014      0.989     -14.697      14.488
# RMW            0.0682      7.516      0.009      0.993     -14.694      14.831
# CMA            0.2795     11.536      0.024      0.981     -22.379      22.938
# intercept      3.6400      0.162     22.517      0.000       3.322       3.958
# ==============================================================================
# Omnibus:                       37.838   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              107.806
# Skew:                          -0.278   Prob(JB):                     3.89e-24
# Kurtosis:                       5.071   Cond. No.                         83.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.003812   0.000646  5.901414
# Mkt-RF    -0.000031   0.000051 -0.598210
# SMB        0.000021   0.000032  0.649423
# HML        0.000037   0.000034  1.078696
# RMW        0.000032   0.000031  1.045587
# CMA        0.000075   0.000022  3.351530
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -94860.916
# Model:                            OLS   Adj. R-squared:             -95030.010
# Method:                 Least Squares   F-statistic:                    -561.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:40:32   Log-Likelihood:                -1680.4
# No. Observations:                 563   AIC:                             3365.
# Df Residuals:                     561   BIC:                             3373.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0269      4.476     -0.006      0.995      -8.820       8.766
# intercept      4.7900      0.204     23.518      0.000       4.390       5.190
# ==============================================================================
# Omnibus:                       38.511   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              150.030
# Skew:                          -0.087   Prob(JB):                     2.64e-33
# Kurtosis:                       5.523   Cond. No.                         22.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.003832   0.000651  5.882403
# Mkt-RF    -0.000032   0.000052 -0.618131
# Long Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -98681.222
# Model:                            OLS   Adj. R-squared:             -99568.652
# Method:                 Least Squares   F-statistic:                    -111.2
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:40:43   Log-Likelihood:                -1748.9
# No. Observations:                 562   AIC:                             3510.
# Df Residuals:                     556   BIC:                             3536.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1221      5.809      0.021      0.983     -11.289      11.533
# SMB            0.1347      8.475      0.016      0.987     -16.511      16.781
# HML           -0.1042     11.105     -0.009      0.993     -21.918      21.710
# RMW            0.1626     11.233      0.014      0.988     -21.901      22.226
# CMA            0.3833     17.247      0.022      0.982     -33.494      34.261
# intercept      5.4400      0.242     22.499      0.000       4.965       5.915
# ==============================================================================
# Omnibus:                      102.429   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              579.755
# Skew:                          -0.659   Prob(JB):                    1.28e-126
# Kurtosis:                       7.798   Cond. No.                         83.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.006728   0.000721  9.335044
# Mkt-RF     0.000195   0.000054  3.583365
# SMB        0.000123   0.000036  3.467677
# HML        0.000050   0.000037  1.351360
# RMW        0.000038   0.000034  1.101414
# CMA        0.000083   0.000024  3.420407
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -192603.666
# Model:                            OLS   Adj. R-squared:            -192947.603
# Method:                 Least Squares   F-statistic:                    -560.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:40:44   Log-Likelihood:                -1936.8
# No. Observations:                 562   AIC:                             3878.
# Df Residuals:                     560   BIC:                             3886.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0768      7.103      0.011      0.991     -13.874      14.028
# intercept      7.6000      0.323     23.498      0.000       6.965       8.235
# ==============================================================================
# Omnibus:                       67.774   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              514.547
# Skew:                          -0.137   Prob(JB):                    1.85e-112
# Kurtosis:                       7.680   Cond. No.                         22.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.006757   0.000726  9.300623
# Mkt-RF     0.000194   0.000055  3.535339
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                    -106.050
# Model:                            OLS   Adj. R-squared:               -107.118
# Method:                 Least Squares   F-statistic:                    -99.26
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:40:56   Log-Likelihood:                -37.788
# No. Observations:                 507   AIC:                             87.58
# Df Residuals:                     501   BIC:                             112.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2385      0.288     -0.829      0.408      -0.804       0.327
# SMB           -0.1329      0.422     -0.315      0.753      -0.962       0.697
# HML           -0.0518      0.549     -0.094      0.925      -1.131       1.027
# RMW           -0.1507      0.557     -0.270      0.787      -1.246       0.944
# CMA            0.1452      0.861      0.169      0.866      -1.546       1.836
# intercept      0.2600      0.012     21.257      0.000       0.236       0.284
# ==============================================================================
# Omnibus:                       68.832   Durbin-Watson:                   0.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              551.074
# Skew:                          -0.231   Prob(JB):                    2.17e-120
# Kurtosis:                       8.087   Cond. No.                         82.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.001349   0.001102 -1.224343
# Mkt-RF    -0.000541   0.000100 -5.395441
# SMB       -0.000167   0.000056 -2.999998
# HML        0.000073   0.000059  1.253574
# RMW        0.000012   0.000042  0.292301
# CMA        0.000108   0.000035  3.070567
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                     -12.518
# Model:                            OLS   Adj. R-squared:                -12.544
# Method:                 Least Squares   F-statistic:                    -467.6
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:40:56   Log-Likelihood:                 486.78
# No. Observations:                 507   AIC:                            -969.6
# Df Residuals:                     505   BIC:                            -961.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2563      0.089     -2.870      0.004      -0.432      -0.081
# intercept     -0.0900      0.004    -21.709      0.000      -0.098      -0.082
# ==============================================================================
# Omnibus:                       61.697   Durbin-Watson:                   0.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              484.762
# Skew:                          -0.061   Prob(JB):                    5.44e-106
# Kurtosis:                       7.789   Cond. No.                         21.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.001342   0.001110 -1.209161
# Mkt-RF    -0.000545   0.000101 -5.376825
# Ensemble System
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -119185.630
# Model:                            OLS   Adj. R-squared:            -120255.528
# Method:                 Least Squares   F-statistic:                    -111.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:41:12   Log-Likelihood:                -1700.0
# No. Observations:                 563   AIC:                             3412.
# Df Residuals:                     557   BIC:                             3438.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0673      5.296      0.013      0.990     -10.336      10.471
# SMB            0.0397      7.718      0.005      0.996     -15.121      15.200
# HML           -0.0705     10.123     -0.007      0.994     -19.955      19.814
# RMW            0.0735     10.241      0.007      0.994     -20.042      20.189
# CMA            0.2493     15.719      0.016      0.987     -30.626      31.125
# intercept      4.9600      0.220     22.517      0.000       4.527       5.393
# ==============================================================================
# Omnibus:                       66.031   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              453.585
# Skew:                          -0.189   Prob(JB):                     3.20e-99
# Kurtosis:                       7.381   Cond. No.                         83.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.005294   0.000597  8.863305
# Mkt-RF     0.000102   0.000048  2.104652
# SMB        0.000044   0.000031  1.457568
# HML        0.000036   0.000030  1.221261
# RMW        0.000026   0.000026  0.985713
# CMA        0.000060   0.000020  2.976634
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -183832.365
# Model:                            OLS   Adj. R-squared:            -184160.054
# Method:                 Least Squares   F-statistic:                    -561.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:41:12   Log-Likelihood:                -1822.0
# No. Observations:                 563   AIC:                             3648.
# Df Residuals:                     561   BIC:                             3657.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0345      5.757      0.006      0.995     -11.273      11.342
# intercept      6.1600      0.262     23.518      0.000       5.646       6.674
# ==============================================================================
# Omnibus:                       58.872   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              387.350
# Skew:                          -0.006   Prob(JB):                     7.73e-85
# Kurtosis:                       7.064   Cond. No.                         22.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.005319   0.000602  8.839686
# Mkt-RF     0.000101   0.000049  2.072720
# Simple Binary Decision
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -18289.858
# Model:                            OLS   Adj. R-squared:             -18450.869
# Method:                 Least Squares   F-statistic:                    -113.6
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:41:14   Log-Likelihood:                -1173.3
# No. Observations:                 574   AIC:                             2359.
# Df Residuals:                     568   BIC:                             2385.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0629      1.987      0.032      0.975      -3.839       3.965
# SMB           -0.1487      2.888     -0.051      0.959      -5.821       5.524
# HML            0.0081      3.793      0.002      0.998      -7.441       7.457
# RMW            0.0572      3.838      0.015      0.988      -7.481       7.596
# CMA           -0.0929      5.883     -0.016      0.987     -11.648      11.462
# intercept      1.8700      0.082     22.766      0.000       1.709       2.031
# ==============================================================================
# Omnibus:                      140.762   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              923.426
# Skew:                          -0.904   Prob(JB):                    3.02e-201
# Kurtosis:                       8.945   Cond. No.                         83.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.001608   0.000569  2.827324
# Mkt-RF     0.000101   0.000045  2.257469
# SMB       -0.000119   0.000036 -3.300710
# HML       -0.000034   0.000024 -1.424772
# RMW        0.000053   0.000024  2.212164
# CMA       -0.000043   0.000013 -3.241196
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -13389.693
# Model:                            OLS   Adj. R-squared:             -13413.103
# Method:                 Least Squares   F-statistic:                    -572.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:41:14   Log-Likelihood:                -1083.8
# No. Observations:                 574   AIC:                             2172.
# Df Residuals:                     572   BIC:                             2180.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0461      1.492      0.031      0.975      -2.884       2.976
# intercept      1.6000      0.067     23.747      0.000       1.468       1.732
# ==============================================================================
# Omnibus:                      167.497   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1288.551
# Skew:                          -1.064   Prob(JB):                    1.57e-280
# Kurtosis:                      10.025   Cond. No.                         22.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.001598   0.000574  2.786269
# Mkt-RF     0.000101   0.000045  2.232663
#
# =====================================================================================================================================
#            KNN L/S    KNN L     KNN S    Neural Net L/S Neural Net L Neural Net S   RF L/S     RF L      RF S     Ensemble   Binary
# -------------------------------------------------------------------------------------------------------------------------------------
# Mkt-RF    0.0282    0.1565*** -0.2070*** 0.0345         0.1223***    -0.4299***   0.0046    0.1221*** -0.2385*** 0.0673**  0.0629**
#           (0.0001)  (0.0001)  (0.0001)   (0.0000)       (0.0000)     (0.0002)     (0.0001)  (0.0001)  (0.0001)   (0.0000)  (0.0000)
# SMB       -0.0515   0.0592**  -0.2677*** 0.0630         0.1028***    -0.2003***   0.0377    0.1347*** -0.1329*** 0.0397    -0.1487***
#           (0.0000)  (0.0000)  (0.0001)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0000)  (0.0001)   (0.0000)  (0.0000)
# HML       -0.0795   -0.0744   -0.0608    -0.0881        -0.0724      -0.0813      -0.1046   -0.1042   -0.0518    -0.0705   0.0081
#           (0.0000)  (0.0000)  (0.0001)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0000)  (0.0001)   (0.0000)  (0.0000)
# RMW       -0.0457   0.0860    -0.3152    0.1143*        0.1613**     -0.2288      0.0682    0.1626    -0.1507    0.0735    0.0572**
#           (0.0000)  (0.0000)  (0.0000)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0000)  (0.0000)   (0.0000)  (0.0000)
# CMA       0.1694    0.2951**  -0.0466    0.2468***      0.2798***    -0.0130***   0.2795*** 0.3833*** 0.1452***  0.2493*** -0.0929***
#           (0.0000)  (0.0000)  (0.0000)   (0.0000)       (0.0000)     (0.0000)     (0.0000)  (0.0000)  (0.0000)   (0.0000)  (0.0000)
# intercept 3.8900*** 5.5400*** 1.3800     4.7900***      4.8800***    5.4200       3.6400*** 5.4400*** 0.2600     4.9600*** 1.8700***
#           (0.0006)  (0.0007)  (0.0011)   (0.0006)       (0.0005)     (0.0019)     (0.0006)  (0.0007)  (0.0011)   (0.0006)  (0.0006)
# =====================================================================================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %%
resultFile = open("output.txt",'w')
resultFile.close()
q_factor_results = summary_col(output_reg,stars=True,float_format='%0.4f',model_names=names)
q_factor_results.title = 'q factor'
q_factor_results_capm = summary_col(output_capm,stars=True,float_format='%0.4f',model_names=names)
q_factor_results_capm.title = 'q factor capm'
resultFile = open("output.txt",'a')
resultFile.write(q_factor_results.as_text())
resultFile.write('\n')
resultFile.write(q_factor_results_capm.as_text())
resultFile.write('\n')
resultFile.close()

# %% [markdown]
# # Fama French 5 Factor

# %%
ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
ff_factors = ff_factors / 100.0
ff_factors[ff_factors == -999] = np.NaN
ff_factors[ff_factors == -99.9] = np.NaN
ff_factors = ff_factors.dropna(how = 'any', axis = 0)

factor_model = ff_factors.copy()
factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
rf = ff_factors[['RF']]

index_symbol = 'Mkt-RF'

print(ff_factors.head(5))

#start date for data
start = '2004-01-01'
#end date for data
end = '2020-01-01'

#the lookback for alpha feature
lookback = 60
#control the leverage
lev = 1.
stk_symbols  = factor_model.columns
returns = factor_model.copy()


#set the backtest parameters
bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
bt = Backtest(bp, returns, mode = 'insample')
data = Data(bp)

df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns = data.get_rolling_features(returns, 0.0)


#creates a dictionary of different features for analysis based on ticker keys
feature_list = [binary_alpha]

feature_set = data.get_features(feature_list)
# Out:
#             Mkt-RF     SMB     HML     RMW     CMA      RF
# 1963-07-01 -0.0039 -0.0047 -0.0083  0.0066 -0.0115  0.0027
# 1963-08-01  0.0507 -0.0079  0.0167  0.0040 -0.0040  0.0025
# 1963-09-01 -0.0157 -0.0048  0.0018 -0.0076  0.0024  0.0027
# 1963-10-01  0.0253 -0.0129 -0.0010  0.0275 -0.0224  0.0029
# 1963-11-01 -0.0085 -0.0084  0.0171 -0.0045  0.0222  0.0027
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#               Mkt-RF       SMB       HML       RMW       CMA
# 1968-08-01  0.004686  0.006016 -0.000766 -0.002048 -0.006084
# 1968-09-01  0.003146  0.006134 -0.000267 -0.002788 -0.005145
# 1968-10-01  0.003727  0.006555 -0.000347 -0.002577 -0.005342
# 1968-11-01  0.003766  0.007209 -0.000303 -0.003457 -0.004763
# 1968-12-01  0.004546  0.007290 -0.000566 -0.003387 -0.004722
#               Mkt-RF       SMB       HML       RMW       CMA
# 1968-08-01  0.029955  0.027251  0.017452  0.014173  0.019689
# 1968-09-01  0.029701  0.027173  0.018432  0.014811  0.020400
# 1968-10-01  0.029452  0.027096  0.018422  0.014703  0.020372
# 1968-11-01  0.029710  0.027022  0.018420  0.014432  0.020215
# 1968-12-01  0.029435  0.026727  0.018434  0.014492  0.020312

# %%
output_reg = []
output_capm = []
names = ['KNN L/S', 'KNN L', 'KNN S', 'Neural Net L/S', 'Neural Net L', 'Neural Net S', 'RF L/S', 'RF L', 'RF S', 'Ensemble', 'Binary']

data_type = 'ff5'

print("KNN")
print("Long and Short")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 'ls' + '.csv'))
#backtest.mean(axis = 1).cumsum().plot()

print("Long Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 'l' + '.csv'))
#backtest.mean(axis = 1).cumsum().plot()

print("Short Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 's' + '.csv'))
#backtest.mean(axis = 1).cumsum().plot()

print("Neural Net")
print("Long and Short")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 'ls' + '.csv'))

print("Long Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 'l' + '.csv'))

print("Short Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 's' + '.csv'))

print("Random Forest")
print("Long and Short")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 'ls' + '.csv'))

print("Long Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 'l' + '.csv'))

print("Short Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 's' + '.csv'))

print("Ensemble System")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors", "Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'yes')  
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_ensemble' '_' + 'ls' + '.csv'))
    
print("Simple Binary Decision")
df_alpha_shift = df_alpha.shift(1).dropna(axis = 0)
backtest = returns.loc[df_alpha_shift.index]
weights = returns.loc[df_alpha_shift.index]
for count, row in  backtest.iterrows(): 
    for j in backtest.columns:
        if df_alpha_shift.loc[count, j] >= 0:
            backtest.loc[count, j] = backtest.loc[count, j]
            weights.loc[count, j] = 1.0
        else:
            backtest.loc[count, j] = -backtest.loc[count, j]
            weights.loc[count, j] = -1.0
            
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_simp_binary' '_' + 'ls' + '.csv'))


print(summary_col(output_reg,stars=True,float_format='%0.4f',model_names=names))
# Out:
# KNN
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -20158.587
# Model:                            OLS   Adj. R-squared:             -20324.647
# Method:                 Least Squares   F-statistic:                    -121.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:41:41   Log-Likelihood:                -1366.4
# No. Observations:                 613   AIC:                             2745.
# Df Residuals:                     607   BIC:                             2771.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0272      2.271      0.012      0.990      -4.434       4.488
# SMB           -0.0281      3.319     -0.008      0.993      -6.547       6.490
# HML           -0.0125      4.307     -0.003      0.998      -8.472       8.447
# RMW           -0.0042      4.492     -0.001      0.999      -8.825       8.817
# CMA            0.0741      6.774      0.011      0.991     -13.230      13.378
# intercept      2.2500      0.096     23.539      0.000       2.062       2.438
# ==============================================================================
# Omnibus:                       65.274   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              382.019
# Skew:                          -0.215   Prob(JB):                     1.11e-83
# Kurtosis:                       6.843   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.002152   0.000631  3.410725
# Mkt-RF     0.000038   0.000050  0.751775
# SMB       -0.000015   0.000025 -0.585579
# HML        0.000016   0.000035  0.464745
# RMW        0.000005   0.000029  0.176154
# CMA        0.000022   0.000024  0.895324
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -25086.635
# Model:                            OLS   Adj. R-squared:             -25127.695
# Method:                 Least Squares   F-statistic:                    -611.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:41:41   Log-Likelihood:                -1433.4
# No. Observations:                 613   AIC:                             2871.
# Df Residuals:                     611   BIC:                             2880.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0121      2.221      0.005      0.996      -4.349       4.373
# intercept      2.5100      0.102     24.546      0.000       2.309       2.711
# ==============================================================================
# Omnibus:                       58.543   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              334.781
# Skew:                          -0.106   Prob(JB):                     2.01e-73
# Kurtosis:                       6.614   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.002154   0.000636  3.386991
# Mkt-RF     0.000037   0.000051  0.738279
# Long Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -20179.256
# Model:                            OLS   Adj. R-squared:             -20346.866
# Method:                 Least Squares   F-statistic:                    -120.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:41:53   Log-Likelihood:                -1479.5
# No. Observations:                 608   AIC:                             2971.
# Df Residuals:                     602   BIC:                             2997.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1922      2.789      0.069      0.945      -5.285       5.670
# SMB            0.1497      4.073      0.037      0.971      -7.849       8.149
# HML            0.1431      5.318      0.027      0.979     -10.300      10.586
# RMW            0.1582      5.541      0.029      0.977     -10.724      11.040
# CMA            0.2269      8.340      0.027      0.978     -16.152      16.605
# intercept      2.7600      0.118     23.457      0.000       2.529       2.991
# ==============================================================================
# Omnibus:                       84.087   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              748.628
# Skew:                          -0.219   Prob(JB):                    2.74e-163
# Kurtosis:                       8.418   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.004986   0.000776  6.424911
# Mkt-RF     0.000324   0.000069  4.702940
# SMB        0.000158   0.000033  4.740331
# HML        0.000171   0.000041  4.131366
# RMW        0.000026   0.000028  0.906799
# CMA        0.000088   0.000026  3.397058
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -66491.936
# Model:                            OLS   Adj. R-squared:             -66601.660
# Method:                 Least Squares   F-statistic:                    -606.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:41:53   Log-Likelihood:                -1842.0
# No. Observations:                 608   AIC:                             3688.
# Df Residuals:                     606   BIC:                             3697.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1424      4.436      0.032      0.974      -8.570       8.855
# intercept      5.0100      0.205     24.441      0.000       4.607       5.413
# ==============================================================================
# Omnibus:                       78.119   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              600.210
# Skew:                           0.230   Prob(JB):                    4.64e-131
# Kurtosis:                       7.846   Cond. No.                         21.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.004999   0.000782  6.396303
# Mkt-RF     0.000325   0.000070  4.668032
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -5407.662
# Model:                            OLS   Adj. R-squared:              -5454.612
# Method:                 Least Squares   F-statistic:                    -115.2
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:42:05   Log-Likelihood:                -1127.3
# No. Observations:                 582   AIC:                             2267.
# Df Residuals:                     576   BIC:                             2293.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.1816      1.751     -0.104      0.917      -3.620       3.257
# SMB           -0.2565      2.598     -0.099      0.921      -5.359       4.846
# HML           -0.1873      3.368     -0.056      0.956      -6.802       6.427
# RMW           -0.1721      3.648     -0.047      0.962      -7.338       6.994
# CMA           -0.1403      5.292     -0.027      0.979     -10.534      10.253
# intercept      1.6800      0.073     22.914      0.000       1.536       1.824
# ==============================================================================
# Omnibus:                       39.942   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              162.473
# Skew:                           0.002   Prob(JB):                     5.24e-36
# Kurtosis:                       5.588   Cond. No.                         84.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.001180   0.000933 -1.263906
# Mkt-RF    -0.000333   0.000072 -4.615524
# SMB       -0.000251   0.000046 -5.449829
# HML       -0.000169   0.000051 -3.317717
# RMW       -0.000002   0.000037 -0.045264
# CMA       -0.000058   0.000030 -1.919219
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                    -423.164
# Model:                            OLS   Adj. R-squared:               -423.895
# Method:                 Least Squares   F-statistic:                    -578.6
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:42:05   Log-Likelihood:                -386.53
# No. Observations:                 582   AIC:                             777.1
# Df Residuals:                     580   BIC:                             785.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.1558      0.422     -0.369      0.712      -0.985       0.673
# intercept     -0.4700      0.020    -23.933      0.000      -0.509      -0.431
# ==============================================================================
# Omnibus:                       91.551   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              414.483
# Skew:                          -0.617   Prob(JB):                     9.91e-91
# Kurtosis:                       6.946   Cond. No.                         21.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.001192   0.000941 -1.267097
# Mkt-RF    -0.000335   0.000073 -4.585075
# Neural Net
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -53530.261
# Model:                            OLS   Adj. R-squared:             -53971.211
# Method:                 Least Squares   F-statistic:                    -121.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:44:43   Log-Likelihood:                -1673.0
# No. Observations:                 613   AIC:                             3358.
# Df Residuals:                     607   BIC:                             3384.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0482      3.745      0.013      0.990      -7.307       7.403
# SMB            0.1030      5.473      0.019      0.985     -10.645      10.851
# HML            0.0054      7.102      0.001      0.999     -13.943      13.953
# RMW           -0.0191      7.406     -0.003      0.998     -14.564      14.526
# CMA            0.2197     11.170      0.020      0.984     -21.717      22.156
# intercept      3.7100      0.158     23.540      0.000       3.400       4.020
# ==============================================================================
# Omnibus:                       60.212   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              369.885
# Skew:                          -0.043   Prob(JB):                     4.79e-81
# Kurtosis:                       6.805   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.004047   0.000637  6.356820
# Mkt-RF     0.000088   0.000049  1.809739
# SMB        0.000107   0.000040  2.663674
# HML        0.000083   0.000036  2.295039
# RMW       -0.000028   0.000037 -0.751354
# CMA        0.000077   0.000022  3.549532
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -85545.807
# Model:                            OLS   Adj. R-squared:             -85685.818
# Method:                 Least Squares   F-statistic:                    -611.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:44:44   Log-Likelihood:                -1816.7
# No. Observations:                 613   AIC:                             3637.
# Df Residuals:                     611   BIC:                             3646.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0307      4.149      0.007      0.994      -8.117       8.179
# intercept      4.6900      0.191     24.546      0.000       4.315       5.065
# ==============================================================================
# Omnibus:                       70.657   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              546.965
# Skew:                          -0.005   Prob(JB):                    1.69e-119
# Kurtosis:                       7.628   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.004071   0.000644  6.321634
# Mkt-RF     0.000088   0.000049  1.788260
# Long Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -31886.354
# Model:                            OLS   Adj. R-squared:             -32149.018
# Method:                 Least Squares   F-statistic:                    -121.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:47:22   Log-Likelihood:                -1513.5
# No. Observations:                 613   AIC:                             3039.
# Df Residuals:                     607   BIC:                             3065.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1488      2.887      0.052      0.959      -5.521       5.819
# SMB            0.1940      4.219      0.046      0.963      -8.092       8.480
# HML            0.1405      5.475      0.026      0.980     -10.612      10.893
# RMW            0.0611      5.709      0.011      0.991     -11.151      11.273
# CMA            0.2311      8.611      0.027      0.979     -16.680      17.142
# intercept      2.8600      0.121     23.540      0.000       2.621       3.099
# ==============================================================================
# Omnibus:                       94.515   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1047.457
# Skew:                          -0.213   Prob(JB):                    3.53e-228
# Kurtosis:                       9.390   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.004625   0.000636  7.266724
# Mkt-RF     0.000267   0.000050  5.358235
# SMB        0.000202   0.000037  5.493151
# HML        0.000176   0.000038  4.654750
# RMW       -0.000020   0.000029 -0.704802
# CMA        0.000100   0.000021  4.727070
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -89443.791
# Model:                            OLS   Adj. R-squared:             -89590.181
# Method:                 Least Squares   F-statistic:                    -611.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:47:23   Log-Likelihood:                -1829.6
# No. Observations:                 613   AIC:                             3663.
# Df Residuals:                     611   BIC:                             3672.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1163      4.237      0.027      0.978      -8.206       8.438
# intercept      4.7900      0.195     24.546      0.000       4.407       5.173
# ==============================================================================
# Omnibus:                       76.629   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              592.865
# Skew:                          -0.194   Prob(JB):                    1.82e-129
# Kurtosis:                       7.802   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.004648   0.000643  7.231120
# Mkt-RF     0.000267   0.000050  5.306326
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -32541.728
# Model:                            OLS   Adj. R-squared:             -32891.650
# Method:                 Least Squares   F-statistic:                    -93.00
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:50:01   Log-Likelihood:                -1493.4
# No. Observations:                 471   AIC:                             2999.
# Df Residuals:                     465   BIC:                             3024.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.3283      6.539     -0.050      0.960     -13.178      12.521
# SMB           -0.1750      9.633     -0.018      0.986     -19.105      18.755
# HML           -0.3594     12.031     -0.030      0.976     -24.001      23.282
# RMW           -0.2410     13.514     -0.018      0.986     -26.796      26.314
# CMA           -0.0271     19.652     -0.001      0.999     -38.644      38.590
# intercept      5.7700      0.278     20.774      0.000       5.224       6.316
# ==============================================================================
# Omnibus:                       24.271   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               72.746
# Skew:                          -0.024   Prob(JB):                     1.60e-16
# Kurtosis:                       4.925   Cond. No.                         81.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.002147   0.001450  1.480357
# Mkt-RF    -0.000571   0.000123 -4.646784
# SMB       -0.000189   0.000084 -2.254432
# HML       -0.000207   0.000072 -2.893270
# RMW       -0.000026   0.000070 -0.366575
# CMA        0.000002   0.000040  0.051507
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -16752.865
# Model:                            OLS   Adj. R-squared:             -16788.587
# Method:                 Least Squares   F-statistic:                    -469.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:50:01   Log-Likelihood:                -1337.1
# No. Observations:                 471   AIC:                             2678.
# Df Residuals:                     469   BIC:                             2686.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2637      4.027     -0.065      0.948      -8.178       7.650
# intercept      4.1400      0.192     21.566      0.000       3.763       4.517
# ==============================================================================
# Omnibus:                       34.304   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              107.857
# Skew:                           0.254   Prob(JB):                     3.79e-24
# Kurtosis:                       5.289   Cond. No.                         21.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.002168   0.001463  1.481798
# Mkt-RF    -0.000574   0.000124 -4.638934
# Random Forest
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -26506.280
# Model:                            OLS   Adj. R-squared:             -26724.627
# Method:                 Least Squares   F-statistic:                    -121.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:50:14   Log-Likelihood:                -1511.3
# No. Observations:                 613   AIC:                             3035.
# Df Residuals:                     607   BIC:                             3061.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0099      2.877     -0.003      0.997      -5.660       5.640
# SMB            0.0708      4.204      0.017      0.987      -8.186       8.328
# HML           -0.1378      5.456     -0.025      0.980     -10.853      10.577
# RMW            0.0002      5.689   3.55e-05      1.000     -11.173      11.173
# CMA            0.2693      8.581      0.031      0.975     -16.582      17.121
# intercept      2.8500      0.121     23.539      0.000       2.612       3.088
# ==============================================================================
# Omnibus:                       51.443   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              190.422
# Skew:                           0.287   Prob(JB):                     4.47e-42
# Kurtosis:                       5.669   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.002811   0.000694  4.052632
# Mkt-RF    -0.000027   0.000057 -0.465652
# SMB        0.000054   0.000043  1.255644
# HML       -0.000004   0.000045 -0.090333
# RMW       -0.000012   0.000041 -0.302893
# CMA        0.000057   0.000025  2.256033
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -41357.969
# Model:                            OLS   Adj. R-squared:             -41425.660
# Method:                 Least Squares   F-statistic:                    -611.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:50:14   Log-Likelihood:                -1647.7
# No. Observations:                 613   AIC:                             3299.
# Df Residuals:                     611   BIC:                             3308.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0215      3.149     -0.007      0.995      -6.206       6.163
# intercept      3.5600      0.145     24.546      0.000       3.275       3.845
# ==============================================================================
# Omnibus:                       79.650   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              408.917
# Skew:                           0.436   Prob(JB):                     1.60e-89
# Kurtosis:                       6.905   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.002837   0.000702  4.040315
# Mkt-RF    -0.000028   0.000058 -0.484871
# Long Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -21021.938
# Model:                            OLS   Adj. R-squared:             -21197.422
# Method:                 Least Squares   F-statistic:                    -119.8
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:50:27   Log-Likelihood:                -1528.6
# No. Observations:                 605   AIC:                             3069.
# Df Residuals:                     599   BIC:                             3096.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1568      3.078      0.051      0.959      -5.889       6.202
# SMB            0.2365      4.506      0.052      0.958      -8.614       9.087
# HML            0.0550      6.058      0.009      0.993     -11.842      11.952
# RMW            0.1084      6.073      0.018      0.986     -11.819      12.035
# CMA            0.3490      9.287      0.038      0.970     -17.891      18.589
# intercept      3.0300      0.129     23.398      0.000       2.776       3.284
# ==============================================================================
# Omnibus:                       58.209   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              323.712
# Skew:                           0.143   Prob(JB):                     5.09e-71
# Kurtosis:                       6.572   Cond. No.                         84.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.005149   0.000836  6.159207
# Mkt-RF     0.000271   0.000062  4.374399
# SMB        0.000224   0.000046  4.871930
# HML        0.000141   0.000048  2.924862
# RMW       -0.000014   0.000047 -0.302738
# CMA        0.000110   0.000031  3.538175
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -67017.443
# Model:                            OLS   Adj. R-squared:             -67128.584
# Method:                 Least Squares   F-statistic:                    -603.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:50:28   Log-Likelihood:                -1879.3
# No. Observations:                 605   AIC:                             3763.
# Df Residuals:                     603   BIC:                             3772.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1166      4.831      0.024      0.981      -9.371       9.604
# intercept      5.4100      0.222     24.375      0.000       4.974       5.846
# ==============================================================================
# Omnibus:                       97.298   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              796.009
# Skew:                           0.421   Prob(JB):                    1.41e-173
# Kurtosis:                       8.556   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.005184   0.000845  6.135317
# Mkt-RF     0.000271   0.000063  4.314078
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -18157.997
# Model:                            OLS   Adj. R-squared:             -18313.202
# Method:                 Least Squares   F-statistic:                    -117.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:50:40   Log-Likelihood:                -1534.7
# No. Observations:                 591   AIC:                             3081.
# Df Residuals:                     585   BIC:                             3108.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2451      3.394     -0.072      0.942      -6.911       6.421
# SMB           -0.1074      4.879     -0.022      0.982      -9.690       9.475
# HML           -0.3070      6.353     -0.048      0.961     -12.785      12.171
# RMW           -0.0992      6.587     -0.015      0.988     -13.036      12.838
# CMA            0.0542     10.082      0.005      0.996     -19.747      19.856
# intercept      3.2500      0.141     22.971      0.000       2.972       3.528
# ==============================================================================
# Omnibus:                       77.539   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              522.358
# Skew:                           0.321   Prob(JB):                    3.73e-114
# Kurtosis:                       7.561   Cond. No.                         84.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.000247   0.000977  0.252363
# Mkt-RF    -0.000421   0.000083 -5.060709
# SMB       -0.000148   0.000051 -2.904386
# HML       -0.000173   0.000049 -3.538525
# RMW        0.000008   0.000042  0.203514
# CMA       -0.000016   0.000027 -0.584684
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -6403.408
# Model:                            OLS   Adj. R-squared:              -6414.281
# Method:                 Least Squares   F-statistic:                    -588.9
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:50:41   Log-Likelihood:                -1226.7
# No. Observations:                 591   AIC:                             2457.
# Df Residuals:                     589   BIC:                             2466.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2137      1.770     -0.121      0.904      -3.690       3.263
# intercept      1.9300      0.080     24.055      0.000       1.772       2.088
# ==============================================================================
# Omnibus:                       77.682   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              382.886
# Skew:                           0.456   Prob(JB):                     7.20e-84
# Kurtosis:                       6.836   Cond. No.                         22.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.000259   0.000985  0.263097
# Mkt-RF    -0.000424   0.000084 -5.054464
# Ensemble System
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -41978.566
# Model:                            OLS   Adj. R-squared:             -42324.361
# Method:                 Least Squares   F-statistic:                    -121.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:50:58   Log-Likelihood:                -1556.9
# No. Observations:                 613   AIC:                             3126.
# Df Residuals:                     607   BIC:                             3152.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0778      3.099      0.025      0.980      -6.008       6.164
# SMB            0.0654      4.529      0.014      0.988      -8.829       8.959
# HML            0.0164      5.877      0.003      0.998     -11.526      11.558
# RMW            0.0876      6.129      0.014      0.989     -11.948      12.123
# CMA            0.2387      9.243      0.026      0.979     -17.914      18.391
# intercept      3.0700      0.130     23.540      0.000       2.814       3.326
# ==============================================================================
# Omnibus:                       62.689   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              385.920
# Skew:                           0.126   Prob(JB):                     1.58e-84
# Kurtosis:                       6.879   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.004028   0.000596  6.753632
# Mkt-RF     0.000102   0.000050  2.038914
# SMB        0.000060   0.000027  2.211583
# HML        0.000099   0.000033  2.960296
# RMW        0.000026   0.000023  1.132884
# CMA        0.000082   0.000022  3.722915
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -95068.686
# Model:                            OLS   Adj. R-squared:             -95224.283
# Method:                 Least Squares   F-statistic:                    -611.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:50:59   Log-Likelihood:                -1807.4
# No. Observations:                 613   AIC:                             3619.
# Df Residuals:                     611   BIC:                             3628.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0375      4.087      0.009      0.993      -7.989       8.064
# intercept      4.6200      0.188     24.546      0.000       4.250       4.990
# ==============================================================================
# Omnibus:                       75.668   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              427.702
# Skew:                           0.358   Prob(JB):                     1.34e-93
# Kurtosis:                       7.029   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.004050   0.000601  6.737712
# Mkt-RF     0.000101   0.000050  2.003193
# Simple Binary Decision
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -3883.682
# Model:                            OLS   Adj. R-squared:              -3915.112
# Method:                 Least Squares   F-statistic:                    -123.6
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:51:00   Log-Likelihood:                -872.35
# No. Observations:                 624   AIC:                             1757.
# Df Residuals:                     618   BIC:                             1783.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0328      0.983      0.033      0.973      -1.898       1.964
# SMB           -0.0836      1.439     -0.058      0.954      -2.910       2.743
# HML           -0.1217      1.874     -0.065      0.948      -3.802       3.559
# RMW           -0.1506      1.949     -0.077      0.938      -3.979       3.678
# CMA           -0.1963      2.937     -0.067      0.947      -5.965       5.572
# intercept      0.9800      0.041     23.773      0.000       0.899       1.061
# ==============================================================================
# Omnibus:                       65.991   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              334.986
# Skew:                          -0.292   Prob(JB):                     1.81e-73
# Kurtosis:                       6.542   Cond. No.                         83.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.000371   0.000620 -0.597921
# Mkt-RF     0.000173   0.000047  3.715123
# SMB       -0.000014   0.000025 -0.537326
# HML       -0.000201   0.000035 -5.812490
# RMW       -0.000071   0.000029 -2.408336
# CMA       -0.000134   0.000024 -5.542286
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -4290.362
# Model:                            OLS   Adj. R-squared:              -4297.261
# Method:                 Least Squares   F-statistic:                    -621.9
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:51:01   Log-Likelihood:                -903.41
# No. Observations:                 624   AIC:                             1811.
# Df Residuals:                     622   BIC:                             1820.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0852      0.903      0.094      0.925      -1.689       1.859
# intercept     -1.0300      0.042    -24.782      0.000      -1.112      -0.948
# ==============================================================================
# Omnibus:                       82.596   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              331.451
# Skew:                          -0.539   Prob(JB):                     1.06e-72
# Kurtosis:                       6.404   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.000385   0.000626 -0.614782
# Mkt-RF     0.000174   0.000047  3.700239
#
# =====================================================================================================================================
#            KNN L/S    KNN L     KNN S    Neural Net L/S Neural Net L Neural Net S   RF L/S     RF L      RF S     Ensemble   Binary
# -------------------------------------------------------------------------------------------------------------------------------------
# Mkt-RF    0.0272    0.1922*** -0.1816*** 0.0482*        0.1488***    -0.3283***   -0.0099   0.1568*** -0.2451*** 0.0778**  0.0328***
#           (0.0001)  (0.0001)  (0.0001)   (0.0000)       (0.0000)     (0.0001)     (0.0001)  (0.0001)  (0.0001)   (0.0000)  (0.0000)
# SMB       -0.0281   0.1497*** -0.2565*** 0.1030***      0.1940***    -0.1750**    0.0708    0.2365*** -0.1074*** 0.0654**  -0.0836
#           (0.0000)  (0.0000)  (0.0000)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0000)  (0.0001)   (0.0000)  (0.0000)
# HML       -0.0125   0.1431*** -0.1873*** 0.0054**       0.1405***    -0.3594***   -0.1378   0.0550*** -0.3070*** 0.0164*** -0.1217***
#           (0.0000)  (0.0000)  (0.0001)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0000)  (0.0000)   (0.0000)  (0.0000)
# RMW       -0.0042   0.1582    -0.1721    -0.0191        0.0611       -0.2410      0.0002    0.1084    -0.0992    0.0876    -0.1506**
#           (0.0000)  (0.0000)  (0.0000)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0000)  (0.0000)   (0.0000)  (0.0000)
# CMA       0.0741    0.2269*** -0.1403*   0.2197***      0.2311***    -0.0271      0.2693**  0.3490*** 0.0542     0.2387*** -0.1963***
#           (0.0000)  (0.0000)  (0.0000)   (0.0000)       (0.0000)     (0.0000)     (0.0000)  (0.0000)  (0.0000)   (0.0000)  (0.0000)
# intercept 2.2500*** 2.7600*** 1.6800     3.7100***      2.8600***    5.7700       2.8500*** 3.0300*** 3.2500     3.0700*** 0.9800
#           (0.0006)  (0.0008)  (0.0009)   (0.0006)       (0.0006)     (0.0015)     (0.0007)  (0.0008)  (0.0010)   (0.0006)  (0.0006)
# =====================================================================================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %%
five_factor_factor_results = summary_col(output_reg,stars=True,float_format='%0.4f',model_names=names)
five_factor_factor_results.title = 'Fama French 5 Factor Model'
five_factor_results_capm = summary_col(output_capm,stars=True,float_format='%0.4f',model_names=names)
five_factor_results_capm.title = 'Famma French capm'
resultFile = open("output.txt",'a')
resultFile.write(five_factor_factor_results.as_text())
resultFile.write('\n')
resultFile.write(five_factor_results_capm.as_text())
resultFile.write('\n')
resultFile.close()

# %% [markdown]
# # Industry

# %%
industry = pd.read_csv('48_Industry_Portfolios.csv', index_col = 0)
industry.index = pd.to_datetime(industry.index, format= '%Y%m')
industry[industry <= -99.] = np.nan
industry = industry / 100.0

ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
ff_factors = ff_factors / 100.0
ff_factors[ff_factors == -999] = np.NaN
ff_factors[ff_factors == -99.9] = np.NaN
ff_factors = ff_factors.dropna(how = 'any', axis = 0)

factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
rf = factor_model[['RF']]
factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
ff_factors_compare = factor_model.copy()

industry = industry.loc[rf.index,:]
index_symbol = 'Mkt-RF'

print(ff_factors.head(5))

print(industry.head(5))


#start date for data
start = '2004-01-01'
#end date for data
end = '2020-01-01'

#the lookback for alpha feature
lookback = 60
#control the leverage
lev = 1.
stk_symbols  = industry.columns
returns = industry.copy()


#set the backtest parameters
bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
bt = Backtest(bp, returns, mode = 'insample')
data = Data(bp)

df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns = data.get_rolling_features(returns, 0.0)


#creates a dictionary of different features for analysis based on ticker keys
feature_list = [binary_alpha]

feature_set = data.get_features(feature_list)
# Out:
#             Mkt-RF     SMB     HML     RMW     CMA      RF
# 1963-07-01 -0.0039 -0.0047 -0.0083  0.0066 -0.0115  0.0027
# 1963-08-01  0.0507 -0.0079  0.0167  0.0040 -0.0040  0.0025
# 1963-09-01 -0.0157 -0.0048  0.0018 -0.0076  0.0024  0.0027
# 1963-10-01  0.0253 -0.0129 -0.0010  0.0275 -0.0224  0.0029
# 1963-11-01 -0.0085 -0.0084  0.0171 -0.0045  0.0222  0.0027
#              Agric   Food    Soda    Beer    Smoke   Toys    Fun     Books  \
# 1963-07-01  0.0304 -0.0046  0.0257 -0.0219 -0.0254 -0.0507 -0.0070 -0.0007
#
# [5 rows x 48 columns]
#                Agric     Food      Soda      Beer      Smoke     Toys   \
# 1968-08-01  0.058645  0.030482  0.037982  0.037796  0.047189  0.076798
# 1968-09-01  0.058546  0.030556  0.038912  0.037795  0.046533  0.076881
# 1968-10-01  0.058558  0.030261  0.038907  0.038745  0.046708  0.076031
# 1968-11-01  0.059404  0.030786  0.039050  0.038889  0.046670  0.074288
# 1968-12-01  0.059134  0.030611  0.038917  0.039414  0.046293  0.074042
#
#                Fun       Books     Hshld     Clths  ...     Boxes     Trans  \
# 1968-08-01  0.061407  0.044491  0.039129  0.042895  ...  0.037120  0.047701
# 1968-09-01  0.061389  0.045441  0.039631  0.043019  ...  0.037233  0.047575
# 1968-10-01  0.061969  0.045426  0.039275  0.042025  ...  0.037428  0.046413
# 1968-11-01  0.064487  0.045429  0.039142  0.042065  ...  0.037284  0.048344
# 1968-12-01  0.063516  0.044633  0.038859  0.041253  ...  0.037264  0.048327
#
#                Whlsl     Rtail     Meals     Banks     Insur     RlEst  \
# 1968-08-01  0.054341  0.036270  0.054136  0.043099  0.048404  0.056493
# 1968-09-01  0.055412  0.036318  0.055101  0.043185  0.048799  0.056504
# 1968-10-01  0.054792  0.036315  0.055914  0.043039  0.051021  0.057089
# 1968-11-01  0.055558  0.037255  0.056379  0.043801  0.059909  0.058860
# 1968-12-01  0.053855  0.037057  0.055237  0.043540  0.059284  0.057347
#
#                Fin       Other
# 1968-08-01  0.039093  0.066648
# 1968-09-01  0.038806  0.065970
# 1968-10-01  0.038459  0.065949
# 1968-11-01  0.038869  0.068468
# 1968-12-01  0.038919  0.068629
#
# [5 rows x 48 columns]

# %%
output_reg = []
output_capm = []
names = ['KNN L/S', 'KNN L', 'KNN S', 'Neural Net L/S', 'Neural Net L', 'Neural Net S', 'RF L/S', 'RF L', 'RF S', 'Ensemble', 'Binary']

data_type = 'industry'

print("KNN")
print("Long and Short")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 'ls' + '.csv'))
#backtest.mean(axis = 1).cumsum().plot()

print("Long Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 'l' + '.csv'))
#backtest.mean(axis = 1).cumsum().plot()

print("Short Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 's' + '.csv'))
#backtest.mean(axis = 1).cumsum().plot()

print("Neural Net")
print("Long and Short")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 'ls' + '.csv'))

print("Long Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 'l' + '.csv'))

print("Short Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 's' + '.csv'))

print("Random Forest")
print("Long and Short")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 'ls' + '.csv'))

print("Long Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 'l' + '.csv'))

print("Short Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 's' + '.csv'))

print("Ensemble System")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors", "Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'yes')  
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_ensemble' '_' + 'ls' + '.csv'))
    
print("Simple Binary Decision")
df_alpha_shift = df_alpha.shift(1).dropna(axis = 0)
backtest = returns.loc[df_alpha_shift.index]
weights = returns.loc[df_alpha_shift.index]
for count, row in  backtest.iterrows(): 
    for j in backtest.columns:
        if df_alpha_shift.loc[count, j] >= 0:
            backtest.loc[count, j] = backtest.loc[count, j]
            weights.loc[count, j] = 1.0
        else:
            backtest.loc[count, j] = -backtest.loc[count, j]
            weights.loc[count, j] = -1.0
            
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_simp_binary' '_' + 'ls' + '.csv'))


print(summary_col(output_reg,stars=True,float_format='%0.4f',model_names=names))
# Out:
# KNN
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -6287.764
# Model:                            OLS   Adj. R-squared:              -6339.566
# Method:                 Least Squares   F-statistic:                    -121.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:55:00   Log-Likelihood:                -1406.0
# No. Observations:                 613   AIC:                             2824.
# Df Residuals:                     607   BIC:                             2851.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1800      2.423      0.074      0.941      -4.578       4.938
# SMB           -0.0760      3.541     -0.021      0.983      -7.030       6.877
# HML           -0.0466      4.595     -0.010      0.992      -9.070       8.977
# RMW            0.0130      4.791      0.003      0.998      -9.397       9.423
# CMA            0.0991      7.226      0.014      0.989     -14.093      14.291
# intercept      2.4000      0.102     23.538      0.000       2.200       2.600
# ==============================================================================
# Omnibus:                       88.035   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              857.104
# Skew:                           0.206   Prob(JB):                    7.63e-187
# Kurtosis:                       8.778   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.003142   0.001205  2.606976
# Mkt-RF     0.000339   0.000115  2.958084
# SMB       -0.000004   0.000056 -0.072131
# HML       -0.000047   0.000051 -0.915419
# RMW       -0.000008   0.000025 -0.321107
# CMA       -0.000030   0.000027 -1.103783
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -7957.988
# Model:                            OLS   Adj. R-squared:              -7971.015
# Method:                 Least Squares   F-statistic:                    -610.9
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:55:01   Log-Likelihood:                -1478.2
# No. Observations:                 613   AIC:                             2960.
# Df Residuals:                     611   BIC:                             2969.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1556      2.389      0.065      0.948      -4.535       4.847
# intercept      2.7000      0.110     24.545      0.000       2.484       2.916
# ==============================================================================
# Omnibus:                       91.742   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              970.967
# Skew:                           0.203   Prob(JB):                    1.44e-211
# Kurtosis:                       9.152   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.003138   0.001211  2.590571
# Mkt-RF     0.000340   0.000115  2.942595
# Long Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -7410.458
# Model:                            OLS   Adj. R-squared:              -7471.508
# Method:                 Least Squares   F-statistic:                    -121.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:56:45   Log-Likelihood:                -1744.6
# No. Observations:                 613   AIC:                             3501.
# Df Residuals:                     607   BIC:                             3528.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         1.0156      4.210      0.241      0.809      -7.251       9.283
# SMB            0.2097      6.151      0.034      0.973     -11.871      12.290
# HML            0.0578      7.983      0.007      0.994     -15.620      15.735
# RMW            0.2054      8.324      0.025      0.980     -16.143      16.553
# CMA            0.0960     12.555      0.008      0.994     -24.560      24.752
# intercept      4.1700      0.177     23.540      0.000       3.822       4.518
# ==============================================================================
# Omnibus:                       97.601   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1330.647
# Skew:                           0.006   Prob(JB):                    1.13e-289
# Kurtosis:                      10.218   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept  0.010576   0.001927   5.487782
# Mkt-RF     0.002130   0.000169  12.577584
# SMB        0.000518   0.000087   5.947742
# HML       -0.000202   0.000085  -2.376051
# RMW       -0.000133   0.000049  -2.750859
# CMA       -0.000268   0.000045  -5.981673
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -14188.969
# Model:                            OLS   Adj. R-squared:             -14212.193
# Method:                 Least Squares   F-statistic:                    -611.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:56:45   Log-Likelihood:                -1943.7
# No. Observations:                 613   AIC:                             3891.
# Df Residuals:                     611   BIC:                             3900.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         1.0061      5.104      0.197      0.844      -9.018      11.030
# intercept      5.7700      0.235     24.546      0.000       5.308       6.232
# ==============================================================================
# Omnibus:                       71.231   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              389.423
# Skew:                           0.326   Prob(JB):                     2.74e-85
# Kurtosis:                       6.850   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept  0.010588   0.001937   5.465594
# Mkt-RF     0.002140   0.000171  12.530186
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                     -13.974
# Model:                            OLS   Adj. R-squared:                -14.098
# Method:                 Least Squares   F-statistic:                    -112.5
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:58:30   Log-Likelihood:                 113.12
# No. Observations:                 609   AIC:                            -214.2
# Df Residuals:                     603   BIC:                            -187.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -1.0278      0.203     -5.061      0.000      -1.427      -0.629
# SMB           -0.2889      0.297     -0.972      0.331      -0.872       0.295
# HML           -0.1860      0.385     -0.483      0.630      -0.943       0.571
# RMW           -0.2576      0.402     -0.641      0.522      -1.047       0.532
# CMA           -0.1033      0.606     -0.170      0.865      -1.294       1.087
# intercept     -0.2000      0.009    -23.320      0.000      -0.217      -0.183
# ==============================================================================
# Omnibus:                       54.174   Durbin-Watson:                   0.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              242.741
# Skew:                           0.226   Prob(JB):                     1.95e-53
# Kurtosis:                       6.060   Cond. No.                         83.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept -0.008065   0.002077  -3.882238
# Mkt-RF    -0.002127   0.000173 -12.273889
# SMB       -0.000575   0.000092  -6.246314
# HML        0.000097   0.000089   1.092725
# RMW        0.000129   0.000047   2.726882
# CMA        0.000229   0.000048   4.802871
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -2521.040
# Model:                            OLS   Adj. R-squared:              -2525.194
# Method:                 Least Squares   F-statistic:                    -606.8
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        07:58:30   Log-Likelihood:                -1447.9
# No. Observations:                 609   AIC:                             2900.
# Df Residuals:                     607   BIC:                             2909.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -1.0059      2.310     -0.435      0.663      -5.543       3.532
# intercept     -2.6100      0.107    -24.458      0.000      -2.820      -2.400
# ==============================================================================
# Omnibus:                       66.055   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              379.517
# Skew:                           0.242   Prob(JB):                     3.88e-83
# Kurtosis:                       6.837   Cond. No.                         21.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept -0.008071   0.002088  -3.866150
# Mkt-RF    -0.002138   0.000175 -12.232119
# Neural Net
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -14896.821
# Model:                            OLS   Adj. R-squared:             -15019.537
# Method:                 Least Squares   F-statistic:                    -121.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        08:21:06   Log-Likelihood:                -1789.9
# No. Observations:                 613   AIC:                             3592.
# Df Residuals:                     607   BIC:                             3618.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.5001      4.533      0.110      0.912      -8.401       9.402
# SMB            0.0962      6.624      0.015      0.988     -12.912      13.104
# HML           -0.1436      8.596     -0.017      0.987     -17.024      16.737
# RMW            0.1548      8.963      0.017      0.986     -17.448      17.758
# CMA            0.3824     13.519      0.028      0.977     -26.167      26.931
# intercept      4.4900      0.191     23.539      0.000       4.115       4.865
# ==============================================================================
# Omnibus:                      273.925   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5685.621
# Skew:                          -1.468   Prob(JB):                         0.00
# Kurtosis:                      17.628   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.007944   0.001463  5.427899
# Mkt-RF     0.000992   0.000141  7.036378
# SMB        0.000230   0.000071  3.258584
# HML       -0.000103   0.000062 -1.679646
# RMW       -0.000039   0.000029 -1.344539
# CMA       -0.000062   0.000032 -1.977336
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -29889.667
# Model:                            OLS   Adj. R-squared:             -29938.588
# Method:                 Least Squares   F-statistic:                    -611.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        08:21:06   Log-Likelihood:                -2003.4
# No. Observations:                 613   AIC:                             4011.
# Df Residuals:                     611   BIC:                             4020.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.4586      5.626      0.082      0.935     -10.591      11.508
# intercept      6.3600      0.259     24.546      0.000       5.851       6.869
# ==============================================================================
# Omnibus:                      261.380   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4581.603
# Skew:                          -1.426   Prob(JB):                         0.00
# Kurtosis:                      16.086   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.007942   0.001471  5.400252
# Mkt-RF     0.000994   0.000142  6.994434
# Long Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -6368.136
# Model:                            OLS   Adj. R-squared:              -6420.600
# Method:                 Least Squares   F-statistic:                    -121.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        08:43:36   Log-Likelihood:                -1682.8
# No. Observations:                 613   AIC:                             3378.
# Df Residuals:                     607   BIC:                             3404.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         1.0093      3.806      0.265      0.791      -6.465       8.483
# SMB            0.1948      5.561      0.035      0.972     -10.727      11.117
# HML            0.0379      7.217      0.005      0.996     -14.136      14.212
# RMW            0.2529      7.526      0.034      0.973     -14.527      15.033
# CMA            0.1570     11.351      0.014      0.989     -22.134      22.448
# intercept      3.7700      0.160     23.540      0.000       3.455       4.085
# ==============================================================================
# Omnibus:                      124.710   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1691.240
# Skew:                           0.454   Prob(JB):                         0.00
# Kurtosis:                      11.086   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept  0.010448   0.001879   5.559075
# Mkt-RF     0.002086   0.000168  12.400279
# SMB        0.000489   0.000082   5.953840
# HML       -0.000189   0.000083  -2.262105
# RMW       -0.000107   0.000042  -2.529415
# CMA       -0.000250   0.000043  -5.784710
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -14918.276
# Model:                            OLS   Adj. R-squared:             -14942.693
# Method:                 Least Squares   F-statistic:                    -611.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        08:43:37   Log-Likelihood:                -1943.7
# No. Observations:                 613   AIC:                             3891.
# Df Residuals:                     611   BIC:                             3900.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.9850      5.104      0.193      0.847      -9.039      11.009
# intercept      5.7700      0.235     24.546      0.000       5.308       6.232
# ==============================================================================
# Omnibus:                       90.046   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              562.805
# Skew:                           0.453   Prob(JB):                    6.14e-123
# Kurtosis:                       7.606   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept  0.010461   0.001889   5.538865
# Mkt-RF     0.002096   0.000170  12.353517
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -3422.331
# Model:                            OLS   Adj. R-squared:              -3454.997
# Method:                 Least Squares   F-statistic:                    -104.8
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:06:06   Log-Likelihood:                -1466.1
# No. Observations:                 530   AIC:                             2944.
# Df Residuals:                     524   BIC:                             2970.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -1.0400      4.072     -0.255      0.799      -9.040       6.960
# SMB           -0.3154      6.002     -0.053      0.958     -12.107      11.476
# HML           -0.3931      7.683     -0.051      0.959     -15.486      14.700
# RMW           -0.1073      7.990     -0.013      0.989     -15.804      15.589
# CMA            0.0207     12.089      0.002      0.999     -23.728      23.769
# intercept      3.8500      0.176     21.852      0.000       3.504       4.196
# ==============================================================================
# Omnibus:                       72.163   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              502.022
# Skew:                           0.323   Prob(JB):                    9.71e-110
# Kurtosis:                       7.724   Cond. No.                         80.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept -0.005207   0.002828  -1.841449
# Mkt-RF    -0.002285   0.000201 -11.373192
# SMB       -0.000647   0.000115  -5.634400
# HML        0.000003   0.000120   0.022137
# RMW        0.000219   0.000065   3.383879
# CMA        0.000246   0.000064   3.843812
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                    -824.356
# Model:                            OLS   Adj. R-squared:               -825.919
# Method:                 Least Squares   F-statistic:                    -527.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:06:06   Log-Likelihood:                -1089.1
# No. Observations:                 530   AIC:                             2182.
# Df Residuals:                     528   BIC:                             2191.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -1.0232      1.740     -0.588      0.557      -4.441       2.395
# intercept      1.8900      0.083     22.769      0.000       1.727       2.053
# ==============================================================================
# Omnibus:                       71.430   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              405.743
# Skew:                           0.407   Prob(JB):                     7.84e-89
# Kurtosis:                       7.209   Cond. No.                         21.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept -0.005208   0.002841  -1.833408
# Mkt-RF    -0.002297   0.000203 -11.337056
# Random Forest
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -9950.618
# Model:                            OLS   Adj. R-squared:             -10032.592
# Method:                 Least Squares   F-statistic:                    -121.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:08:03   Log-Likelihood:                -1554.9
# No. Observations:                 613   AIC:                             3122.
# Df Residuals:                     607   BIC:                             3148.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0562      3.089      0.018      0.985      -6.010       6.123
# SMB            0.0460      4.514      0.010      0.992      -8.819       8.911
# HML           -0.2478      5.858     -0.042      0.966     -11.753      11.257
# RMW            0.0558      6.109      0.009      0.993     -11.941      12.053
# CMA            0.4233      9.213      0.046      0.963     -17.671      18.517
# intercept      3.0600      0.130     23.539      0.000       2.805       3.315
# ==============================================================================
# Omnibus:                      106.257   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              808.413
# Skew:                          -0.520   Prob(JB):                    2.85e-176
# Kurtosis:                       8.529   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.003701   0.001219  3.036545
# Mkt-RF     0.000076   0.000123  0.620861
# SMB        0.000042   0.000065  0.640928
# HML       -0.000051   0.000057 -0.890576
# RMW        0.000002   0.000031  0.079398
# CMA        0.000054   0.000027  1.975012
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -19376.017
# Model:                            OLS   Adj. R-squared:             -19407.731
# Method:                 Least Squares   F-statistic:                    -611.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:08:04   Log-Likelihood:                -1759.2
# No. Observations:                 613   AIC:                             3522.
# Df Residuals:                     611   BIC:                             3531.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0254      3.778      0.007      0.995      -7.393       7.444
# intercept      4.2700      0.174     24.546      0.000       3.928       4.612
# ==============================================================================
# Omnibus:                      113.700   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              910.732
# Skew:                          -0.564   Prob(JB):                    1.73e-198
# Kurtosis:                       8.864   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.003708   0.001226  3.023162
# Mkt-RF     0.000074   0.000124  0.600830
# Long Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -10357.649
# Model:                            OLS   Adj. R-squared:             -10442.976
# Method:                 Least Squares   F-statistic:                    -121.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:10:01   Log-Likelihood:                -1841.0
# No. Observations:                 613   AIC:                             3694.
# Df Residuals:                     607   BIC:                             3721.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.9915      4.926      0.201      0.841      -8.683      10.666
# SMB            0.2635      7.199      0.037      0.971     -13.874      14.401
# HML            0.0349      9.342      0.004      0.997     -18.312      18.382
# RMW            0.2374      9.742      0.024      0.981     -18.894      19.369
# CMA            0.1891     14.693      0.013      0.990     -28.665      29.044
# intercept      4.8800      0.207     23.540      0.000       4.473       5.287
# ==============================================================================
# Omnibus:                      304.396   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3738.680
# Skew:                           1.889   Prob(JB):                         0.00
# Kurtosis:                      14.494   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept  0.011380   0.001908   5.964713
# Mkt-RF     0.002073   0.000170  12.223505
# SMB        0.000546   0.000088   6.200274
# HML       -0.000174   0.000084  -2.070339
# RMW       -0.000123   0.000042  -2.884881
# CMA       -0.000233   0.000043  -5.383622
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -21130.358
# Model:                            OLS   Adj. R-squared:             -21164.943
# Method:                 Least Squares   F-statistic:                    -611.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:10:01   Log-Likelihood:                -2059.5
# No. Observations:                 613   AIC:                             4123.
# Df Residuals:                     611   BIC:                             4132.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.9760      6.166      0.158      0.874     -11.133      13.085
# intercept      6.9700      0.284     24.546      0.000       6.412       7.528
# ==============================================================================
# Omnibus:                      262.760   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2840.649
# Skew:                           1.597   Prob(JB):                         0.00
# Kurtosis:                      13.051   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept  0.011406   0.001917   5.948582
# Mkt-RF     0.002083   0.000171  12.176202
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                      -2.547
# Model:                            OLS   Adj. R-squared:                 -2.576
# Method:                 Least Squares   F-statistic:                    -86.74
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:11:58   Log-Likelihood:                 521.77
# No. Observations:                 610   AIC:                            -1032.
# Df Residuals:                     604   BIC:                            -1005.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -1.0493      0.104    -10.082      0.000      -1.254      -0.845
# SMB           -0.2893      0.153     -1.893      0.059      -0.589       0.011
# HML           -0.1834      0.197     -0.930      0.353      -0.571       0.204
# RMW           -0.2250      0.206     -1.093      0.275      -0.629       0.179
# CMA           -0.0365      0.310     -0.118      0.906      -0.646       0.573
# intercept     -0.1000      0.004    -22.807      0.000      -0.109      -0.091
# ==============================================================================
# Omnibus:                      221.253   Durbin-Watson:                   0.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5760.488
# Skew:                           1.006   Prob(JB):                         0.00
# Kurtosis:                      17.919   Cond. No.                         83.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept -0.007620   0.002185  -3.487603
# Mkt-RF    -0.002196   0.000174 -12.626988
# SMB       -0.000592   0.000094  -6.280567
# HML        0.000133   0.000094   1.410789
# RMW        0.000152   0.000051   2.974773
# CMA        0.000263   0.000050   5.297011
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -1297.894
# Model:                            OLS   Adj. R-squared:              -1300.031
# Method:                 Least Squares   F-statistic:                    -607.5
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:11:59   Log-Likelihood:                -1278.7
# No. Observations:                 610   AIC:                             2561.
# Df Residuals:                     608   BIC:                             2570.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -1.0429      1.744     -0.598      0.550      -4.468       2.383
# intercept     -1.9700      0.080    -24.485      0.000      -2.128      -1.812
# ==============================================================================
# Omnibus:                      238.434   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5228.497
# Skew:                           1.190   Prob(JB):                         0.00
# Kurtosis:                      17.144   Cond. No.                         21.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept -0.007621   0.002196  -3.471092
# Mkt-RF    -0.002207   0.000175 -12.585418
# Ensemble System
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -13357.855
# Model:                            OLS   Adj. R-squared:             -13467.895
# Method:                 Least Squares   F-statistic:                    -121.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:14:37   Log-Likelihood:                -1700.4
# No. Observations:                 613   AIC:                             3413.
# Df Residuals:                     607   BIC:                             3439.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.4809      3.917      0.123      0.902      -7.211       8.173
# SMB            0.0656      5.724      0.011      0.991     -11.175      11.306
# HML           -0.0938      7.428     -0.013      0.990     -14.681      14.494
# RMW            0.1532      7.746      0.020      0.984     -15.058      15.365
# CMA            0.2745     11.682      0.023      0.981     -22.668      23.217
# intercept      3.8800      0.165     23.539      0.000       3.556       4.204
# ==============================================================================
# Omnibus:                      148.039   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5755.368
# Skew:                           0.098   Prob(JB):                         0.00
# Kurtosis:                      18.010   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.007071   0.001336  5.292500
# Mkt-RF     0.000958   0.000127  7.541941
# SMB        0.000199   0.000064  3.124477
# HML       -0.000099   0.000054 -1.825530
# RMW       -0.000029   0.000028 -1.016504
# CMA       -0.000079   0.000028 -2.814777
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -26162.474
# Model:                            OLS   Adj. R-squared:             -26205.295
# Method:                 Least Squares   F-statistic:                    -611.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:14:38   Log-Likelihood:                -1906.5
# No. Observations:                 613   AIC:                             3817.
# Df Residuals:                     611   BIC:                             3826.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.4446      4.804      0.093      0.926      -8.989       9.878
# intercept      5.4300      0.221     24.546      0.000       4.996       5.864
# ==============================================================================
# Omnibus:                      138.141   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4439.363
# Skew:                          -0.027   Prob(JB):                         0.00
# Kurtosis:                      16.184   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.007074   0.001342  5.269943
# Mkt-RF     0.000961   0.000128  7.502834
# Simple Binary Decision
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -7126.084
# Model:                            OLS   Adj. R-squared:              -7184.985
# Method:                 Least Squares   F-statistic:                    -121.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:14:47   Log-Likelihood:                -1561.7
# No. Observations:                 611   AIC:                             3135.
# Df Residuals:                     605   BIC:                             3162.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.5236      3.152      0.166      0.868      -5.666       6.713
# SMB            0.0163      4.608      0.004      0.997      -9.033       9.066
# HML            0.0521      5.981      0.009      0.993     -11.694      11.798
# RMW            0.0975      6.244      0.016      0.988     -12.165      12.361
# CMA           -0.0672      9.412     -0.007      0.994     -18.552      18.418
# intercept      3.1200      0.133     23.497      0.000       2.859       3.381
# ==============================================================================
# Omnibus:                      180.527   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3741.669
# Skew:                          -0.768   Prob(JB):                         0.00
# Kurtosis:                      15.026   Cond. No.                         83.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.005873   0.001472  3.990551
# Mkt-RF     0.001103   0.000146  7.566726
# SMB        0.000192   0.000067  2.875147
# HML       -0.000127   0.000061 -2.075768
# RMW       -0.000050   0.000032 -1.543599
# CMA       -0.000168   0.000034 -5.024771
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -8612.620
# Model:                            OLS   Adj. R-squared:              -8626.763
# Method:                 Least Squares   F-statistic:                    -608.9
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:14:48   Log-Likelihood:                -1619.6
# No. Observations:                 611   AIC:                             3243.
# Df Residuals:                     609   BIC:                             3252.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.5195      3.038      0.171      0.864      -5.447       6.486
# intercept      3.4300      0.140     24.506      0.000       3.155       3.705
# ==============================================================================
# Omnibus:                      180.206   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3248.252
# Skew:                          -0.812   Prob(JB):                         0.00
# Kurtosis:                      14.178   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.005859   0.001479  3.961542
# Mkt-RF     0.001107   0.000147  7.533195
#
# =====================================================================================================================================
#            KNN L/S    KNN L     KNN S    Neural Net L/S Neural Net L Neural Net S   RF L/S     RF L      RF S     Ensemble   Binary
# -------------------------------------------------------------------------------------------------------------------------------------
# Mkt-RF    0.1800*** 1.0156*** -1.0278*** 0.5001***      1.0093***    -1.0400***   0.0562    0.9915*** -1.0493*** 0.4809*** 0.5236***
#           (0.0001)  (0.0002)  (0.0002)   (0.0001)       (0.0002)     (0.0002)     (0.0001)  (0.0002)  (0.0002)   (0.0001)  (0.0001)
# SMB       -0.0760   0.2097*** -0.2889*** 0.0962***      0.1948***    -0.3154***   0.0460    0.2635*** -0.2893*** 0.0656*** 0.0163***
#           (0.0001)  (0.0001)  (0.0001)   (0.0001)       (0.0001)     (0.0001)     (0.0001)  (0.0001)  (0.0001)   (0.0001)  (0.0001)
# HML       -0.0466   0.0578**  -0.1860    -0.1436*       0.0379**     -0.3931      -0.2478   0.0349**  -0.1834    -0.0938*  0.0521**
#           (0.0001)  (0.0001)  (0.0001)   (0.0001)       (0.0001)     (0.0001)     (0.0001)  (0.0001)  (0.0001)   (0.0001)  (0.0001)
# RMW       0.0130    0.2054*** -0.2576*** 0.1548         0.2529**     -0.1073***   0.0558    0.2374*** -0.2250*** 0.1532    0.0975
#           (0.0000)  (0.0000)  (0.0000)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0000)  (0.0001)   (0.0000)  (0.0000)
# CMA       0.0991    0.0960*** -0.1033*** 0.3824**       0.1570***    0.0207***    0.4233**  0.1891*** -0.0365*** 0.2745*** -0.0672***
#           (0.0000)  (0.0000)  (0.0000)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0000)  (0.0000)   (0.0000)  (0.0000)
# intercept 2.4000*** 4.1700*** -0.2000*** 4.4900***      3.7700***    3.8500*      3.0600*** 4.8800*** -0.1000*** 3.8800*** 3.1200***
#           (0.0012)  (0.0019)  (0.0021)   (0.0015)       (0.0019)     (0.0028)     (0.0012)  (0.0019)  (0.0022)   (0.0013)  (0.0015)
# =====================================================================================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %%
industry_factor_results = summary_col(output_reg,stars=True,float_format='%0.4f',model_names=names)
industry_factor_results.title = 'Industry Returns'
industry_factor_results_capm = summary_col(output_capm,stars=True,float_format='%0.4f',model_names=names)
industry_factor_results_capm.title = 'Industry Returns capm'
resultFile = open("output.txt",'a')
resultFile.write(industry_factor_results.as_text())
resultFile.write('\n')
resultFile.write(industry_factor_results_capm.as_text())
resultFile.write('\n')
resultFile.close()

# %% [markdown]
# # Stambaugh and Yuan "Mispricing Factors"

# %%
m4 = pd.read_csv('M4-1.csv', index_col = 0)
m4.index = pd.to_datetime(m4.index, format= '%Y%m')

factor_model = m4.copy()
factor_model = factor_model[['MKTRF','SMB','MGMT','PERF']]
rf = m4[['RF']]

index_symbol = 'MKTRF'

print(m4.head(5))

#start date for data
start = '2004-01-01'
#end date for data
end = '2020-01-01'

#the lookback for alpha feature
lookback = 60
#control the leverage
lev = 1.
stk_symbols  = factor_model.columns
returns = factor_model.copy()


#set the backtest parameters
bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
bt = Backtest(bp, returns, mode = 'insample')
data = Data(bp)

df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns = data.get_rolling_features(returns, 0.0)


#creates a dictionary of different features for analysis based on ticker keys
feature_list = [binary_alpha]

feature_set = data.get_features(feature_list)
# Out:
#              MKTRF       SMB      MGMT      PERF      RF
# YYYYMM
# 1963-01-01  0.0493  0.024818  0.021349 -0.022751  0.0025
# 1963-02-01 -0.0238  0.018096  0.010961  0.000874  0.0023
# 1963-03-01  0.0308 -0.008183  0.005890  0.023281  0.0023
# 1963-04-01  0.0451 -0.037328  0.000190  0.005077  0.0025
# 1963-05-01  0.0176  0.021518  0.017593  0.002848  0.0024
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#                MKTRF       SMB      MGMT      PERF
# YYYYMM
# 1968-02-01  0.005765  0.007119 -0.005921  0.005407
# 1968-03-01  0.005814  0.007359 -0.005636  0.005246
# 1968-04-01  0.004788  0.007196 -0.004694  0.004625
# 1968-05-01  0.004102  0.007359 -0.005246  0.005616
# 1968-06-01  0.005354  0.007753 -0.007145  0.007251
#                MKTRF       SMB      MGMT      PERF
# YYYYMM
# 1968-02-01  0.027592  0.026434  0.021556  0.024572
# 1968-03-01  0.028094  0.026578  0.023250  0.025837
# 1968-04-01  0.028262  0.026593  0.023866  0.025988
# 1968-05-01  0.027668  0.025969  0.023951  0.026408
# 1968-06-01  0.029633  0.026750  0.024786  0.027249

# %%
output_reg = []
output_capm = []
names = ['KNN L/S', 'KNN L', 'KNN S', 'Neural Net L/S', 'Neural Net L', 'Neural Net S', 'RF L/S', 'RF L', 'RF S', 'Ensemble', 'Binary']

data_type = 'stambaugh_yuan'

print("KNN")
print("Long and Short")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 'ls' + '.csv'))
#backtest.mean(axis = 1).cumsum().plot()

print("Long Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 'l' + '.csv'))
#backtest.mean(axis = 1).cumsum().plot()

print("Short Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 's' + '.csv'))
#backtest.mean(axis = 1).cumsum().plot()

print("Neural Net")
print("Long and Short")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 'ls' + '.csv'))

print("Long Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 'l' + '.csv'))

print("Short Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 's' + '.csv'))

print("Random Forest")
print("Long and Short")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 'ls' + '.csv'))

print("Long Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 'l' + '.csv'))

print("Short Only")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 's' + '.csv'))

print("Ensemble System")
backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors", "Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'yes')  
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_ensemble' '_' + 'ls' + '.csv'))
    
print("Simple Binary Decision")
df_alpha_shift = df_alpha.shift(1).dropna(axis = 0)
backtest = returns.loc[df_alpha_shift.index]
weights = returns.loc[df_alpha_shift.index]
for count, row in  backtest.iterrows(): 
    for j in backtest.columns:
        if df_alpha_shift.loc[count, j] >= 0:
            backtest.loc[count, j] = backtest.loc[count, j]
            weights.loc[count, j] = 1.0
        else:
            backtest.loc[count, j] = -backtest.loc[count, j]
            weights.loc[count, j] = -1.0
            
results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
output_reg.append(results)
output_capm.append(results_capm)
#backtest.mean(axis = 1).cumsum().plot()
backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_simp_binary' '_' + 'ls' + '.csv'))


print(summary_col(output_reg,stars=True,float_format='%0.4f',model_names=names))
# Out:
# KNN
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -19151.647
# Model:                            OLS   Adj. R-squared:             -19319.948
# Method:                 Least Squares   F-statistic:                    -113.8
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:15:08   Log-Likelihood:                -1378.0
# No. Observations:                 575   AIC:                             2768.
# Df Residuals:                     569   BIC:                             2794.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0121      2.798     -0.004      0.997      -5.507       5.483
# SMB           -0.0037      4.025     -0.001      0.999      -7.909       7.902
# HML           -0.1049      5.472     -0.019      0.985     -10.854      10.644
# RMW            0.0348      5.417      0.006      0.995     -10.605      10.675
# CMA            0.2224      8.324      0.027      0.979     -16.127      16.572
# intercept      2.6600      0.117     22.695      0.000       2.430       2.890
# ==============================================================================
# Omnibus:                       27.656   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.344
# Skew:                          -0.087   Prob(JB):                     5.90e-18
# Kurtosis:                       4.812   Cond. No.                         84.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.002609   0.000793  3.290841
# Mkt-RF    -0.000062   0.000062 -0.990426
# SMB       -0.000016   0.000033 -0.486109
# HML        0.000020   0.000033  0.608162
# RMW        0.000025   0.000020  1.281576
# CMA        0.000059   0.000022  2.665973
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -30557.684
# Model:                            OLS   Adj. R-squared:             -30611.015
# Method:                 Least Squares   F-statistic:                    -573.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:15:08   Log-Likelihood:                -1512.3
# No. Observations:                 575   AIC:                             3029.
# Df Residuals:                     573   BIC:                             3037.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0366      3.078     -0.012      0.991      -6.083       6.010
# intercept      3.3600      0.141     23.819      0.000       3.083       3.637
# ==============================================================================
# Omnibus:                       27.309   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.896
# Skew:                          -0.042   Prob(JB):                     4.47e-18
# Kurtosis:                       4.824   Cond. No.                         22.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.002615   0.000797  3.282509
# Mkt-RF    -0.000062   0.000062 -0.997629
# Long Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -65150.665
# Model:                            OLS   Adj. R-squared:             -65728.251
# Method:                 Least Squares   F-statistic:                    -112.8
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:15:17   Log-Likelihood:                -1809.3
# No. Observations:                 570   AIC:                             3631.
# Df Residuals:                     564   BIC:                             3657.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.1026      6.099      0.017      0.987     -11.877      12.082
# SMB            0.1445      8.765      0.016      0.987     -17.072      17.361
# HML           -0.1796     11.963     -0.015      0.988     -23.677      23.317
# RMW            0.2266     11.806      0.019      0.985     -22.962      23.416
# CMA            0.4599     18.207      0.025      0.980     -35.301      36.221
# intercept      5.7900      0.256     22.600      0.000       5.287       6.293
# ==============================================================================
# Omnibus:                       56.487   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              268.077
# Skew:                           0.267   Prob(JB):                     6.14e-59
# Kurtosis:                       6.317   Cond. No.                         84.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.007109   0.000938  7.578568
# Mkt-RF     0.000144   0.000073  1.977003
# SMB        0.000113   0.000040  2.828581
# HML        0.000032   0.000049  0.663260
# RMW        0.000067   0.000035  1.889786
# CMA        0.000092   0.000035  2.643426
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -133236.697
# Model:                            OLS   Adj. R-squared:            -133471.270
# Method:                 Least Squares   F-statistic:                    -568.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:15:17   Log-Likelihood:                -2013.2
# No. Observations:                 570   AIC:                             4030.
# Df Residuals:                     568   BIC:                             4039.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0527      7.593      0.007      0.994     -14.861      14.967
# intercept      8.2800      0.349     23.718      0.000       7.594       8.966
# ==============================================================================
# Omnibus:                       83.591   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              573.250
# Skew:                           0.406   Prob(JB):                    3.31e-125
# Kurtosis:                       7.845   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.007141   0.000945  7.560679
# Mkt-RF     0.000144   0.000074  1.948198
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -1821.615
# Model:                            OLS   Adj. R-squared:              -1839.661
# Method:                 Least Squares   F-statistic:                    -100.9
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:15:26   Log-Likelihood:                -842.86
# No. Observations:                 511   AIC:                             1698.
# Df Residuals:                     505   BIC:                             1723.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2303      1.393     -0.165      0.869      -2.967       2.507
# SMB           -0.2859      2.014     -0.142      0.887      -4.242       3.670
# HML            0.0368      2.768      0.013      0.989      -5.401       5.474
# RMW           -0.2459      2.804     -0.088      0.930      -5.755       5.263
# CMA           -0.1896      4.302     -0.044      0.965      -8.641       8.262
# intercept     -1.2600      0.059    -21.413      0.000      -1.376      -1.144
# ==============================================================================
# Omnibus:                       35.627   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               91.251
# Skew:                          -0.330   Prob(JB):                     1.53e-20
# Kurtosis:                       4.962   Cond. No.                         85.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.003692   0.001288 -2.867143
# Mkt-RF    -0.000497   0.000104 -4.794265
# SMB       -0.000285   0.000063 -4.511626
# HML        0.000034   0.000063  0.541836
# RMW       -0.000014   0.000052 -0.265190
# CMA        0.000030   0.000038  0.792826
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -13109.884
# Model:                            OLS   Adj. R-squared:             -13135.642
# Method:                 Least Squares   F-statistic:                    -509.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:15:26   Log-Likelihood:                -1347.0
# No. Observations:                 511   AIC:                             2698.
# Df Residuals:                     509   BIC:                             2706.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2267      3.220     -0.070      0.944      -6.552       6.099
# intercept     -3.3800      0.150    -22.495      0.000      -3.675      -3.085
# ==============================================================================
# Omnibus:                       54.238   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              159.518
# Skew:                          -0.492   Prob(JB):                     2.30e-35
# Kurtosis:                       5.554   Cond. No.                         21.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.003726   0.001297 -2.872363
# Mkt-RF    -0.000499   0.000105 -4.769498
# Neural Net
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -54651.731
# Model:                            OLS   Adj. R-squared:             -55131.983
# Method:                 Least Squares   F-statistic:                    -113.8
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:17:17   Log-Likelihood:                -1690.4
# No. Observations:                 575   AIC:                             3393.
# Df Residuals:                     569   BIC:                             3419.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0206      4.817      0.004      0.997      -9.441       9.482
# SMB            0.0825      6.930      0.012      0.991     -13.529      13.694
# HML           -0.1515      9.422     -0.016      0.987     -18.658      18.355
# RMW            0.1731      9.327      0.019      0.985     -18.147      18.493
# CMA            0.3791     14.332      0.026      0.979     -27.770      28.529
# intercept      4.5800      0.202     22.695      0.000       4.184       4.976
# ==============================================================================
# Omnibus:                       44.694   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.990
# Skew:                          -0.197   Prob(JB):                     6.08e-39
# Kurtosis:                       5.681   Cond. No.                         84.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.005271   0.000806  6.541229
# Mkt-RF    -0.000023   0.000068 -0.336366
# SMB        0.000038   0.000038  0.991297
# HML        0.000046   0.000039  1.174601
# RMW        0.000072   0.000029  2.474538
# CMA        0.000096   0.000027  3.604603
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -110416.968
# Model:                            OLS   Adj. R-squared:            -110609.669
# Method:                 Least Squares   F-statistic:                    -573.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:17:18   Log-Likelihood:                -1892.6
# No. Observations:                 575   AIC:                             3789.
# Df Residuals:                     573   BIC:                             3798.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0244      5.964     -0.004      0.997     -11.739      11.690
# intercept      6.5100      0.273     23.819      0.000       5.973       7.047
# ==============================================================================
# Omnibus:                       41.455   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              132.989
# Skew:                          -0.262   Prob(JB):                     1.32e-29
# Kurtosis:                       5.297   Cond. No.                         22.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.005295   0.000811  6.526511
# Mkt-RF    -0.000024   0.000069 -0.351670
# Long Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -87717.756
# Model:                            OLS   Adj. R-squared:             -88488.571
# Method:                 Least Squares   F-statistic:                    -113.8
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:19:08   Log-Likelihood:                -1790.4
# No. Observations:                 575   AIC:                             3593.
# Df Residuals:                     569   BIC:                             3619.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0902      5.732      0.016      0.987     -11.169      11.349
# SMB            0.1266      8.246      0.015      0.988     -16.071      16.324
# HML           -0.1561     11.212     -0.014      0.989     -22.178      21.866
# RMW            0.2226     11.099      0.020      0.984     -21.578      22.023
# CMA            0.3951     17.054      0.023      0.982     -33.102      33.892
# intercept      5.4500      0.240     22.695      0.000       4.978       5.922
# ==============================================================================
# Omnibus:                       57.912   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              348.529
# Skew:                          -0.110   Prob(JB):                     2.08e-76
# Kurtosis:                       6.808   Cond. No.                         84.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.006589   0.000758  8.691784
# Mkt-RF     0.000125   0.000059  2.115908
# SMB        0.000093   0.000035  2.674542
# HML        0.000028   0.000035  0.805312
# RMW        0.000072   0.000028  2.614796
# CMA        0.000079   0.000026  3.084322
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -174641.659
# Model:                            OLS   Adj. R-squared:            -174946.446
# Method:                 Least Squares   F-statistic:                    -573.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:19:09   Log-Likelihood:                -1988.4
# No. Observations:                 575   AIC:                             3981.
# Df Residuals:                     573   BIC:                             3989.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0449      7.046      0.006      0.995     -13.793      13.883
# intercept      7.6900      0.323     23.819      0.000       7.056       8.324
# ==============================================================================
# Omnibus:                       48.153   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              220.823
# Skew:                          -0.150   Prob(JB):                     1.12e-48
# Kurtosis:                       6.021   Cond. No.                         22.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.006615   0.000763  8.671781
# Mkt-RF     0.000125   0.000060  2.090663
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -3484.513
# Model:                            OLS   Adj. R-squared:              -3539.839
# Method:                 Least Squares   F-statistic:                    -62.98
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:21:00   Log-Likelihood:                -722.60
# No. Observations:                 321   AIC:                             1457.
# Df Residuals:                     315   BIC:                             1480.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.4472      3.359     -0.133      0.894      -7.057       6.163
# SMB           -0.2723      4.792     -0.057      0.955      -9.700       9.155
# HML            0.0155      6.358      0.002      0.998     -12.494      12.525
# RMW            0.1137      7.773      0.015      0.988     -15.180      15.407
# CMA           -0.0332      9.809     -0.003      0.997     -19.332      19.266
# intercept      2.3000      0.136     16.871      0.000       2.032       2.568
# ==============================================================================
# Omnibus:                        8.186   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):               10.589
# Skew:                          -0.216   Prob(JB):                      0.00502
# Kurtosis:                       3.777   Cond. No.                         84.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.000300   0.002146 -0.139584
# Mkt-RF    -0.001053   0.000185 -5.689665
# SMB       -0.000372   0.000095 -3.897208
# HML        0.000146   0.000101  1.449856
# RMW        0.000127   0.000054  2.352323
# CMA        0.000199   0.000056  3.558364
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -3889.648
# Model:                            OLS   Adj. R-squared:              -3901.844
# Method:                 Least Squares   F-statistic:                    -318.9
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:21:00   Log-Likelihood:                -740.25
# No. Observations:                 321   AIC:                             1485.
# Df Residuals:                     319   BIC:                             1492.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.4902      2.910     -0.168      0.866      -6.215       5.235
# intercept      2.4300      0.137     17.783      0.000       2.161       2.699
# ==============================================================================
# Omnibus:                        6.215   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.045   Jarque-Bera (JB):                8.525
# Skew:                          -0.113   Prob(JB):                       0.0141
# Kurtosis:                       3.766   Cond. No.                         21.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.000303   0.002158 -0.140594
# Mkt-RF    -0.001059   0.000187 -5.679126
# Random Forest
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -6744.712
# Model:                            OLS   Adj. R-squared:              -6803.989
# Method:                 Least Squares   F-statistic:                    -113.8
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:21:09   Log-Likelihood:                -1133.9
# No. Observations:                 575   AIC:                             2280.
# Df Residuals:                     569   BIC:                             2306.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0244      1.830     -0.013      0.989      -3.619       3.570
# SMB            0.0568      2.633      0.022      0.983      -5.115       5.228
# HML           -0.1295      3.580     -0.036      0.971      -7.161       6.902
# RMW            0.1915      3.544      0.054      0.957      -6.769       7.152
# CMA            0.3482      5.445      0.064      0.949     -10.347      11.043
# intercept      1.7400      0.077     22.694      0.000       1.589       1.891
# ==============================================================================
# Omnibus:                       24.116   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.050
# Skew:                           0.000   Prob(JB):                     7.49e-15
# Kurtosis:                       4.648   Cond. No.                         84.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.002686   0.000871  3.085031
# Mkt-RF    -0.000139   0.000073 -1.908665
# SMB       -0.000010   0.000041 -0.256105
# HML        0.000061   0.000046  1.328717
# RMW        0.000092   0.000035  2.647170
# CMA        0.000101   0.000031  3.282738
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -30333.513
# Model:                            OLS   Adj. R-squared:             -30386.453
# Method:                 Least Squares   F-statistic:                    -573.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:21:10   Log-Likelihood:                -1566.2
# No. Observations:                 575   AIC:                             3136.
# Df Residuals:                     573   BIC:                             3145.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0750      3.381     -0.022      0.982      -6.715       6.565
# intercept      3.6900      0.155     23.819      0.000       3.386       3.994
# ==============================================================================
# Omnibus:                       34.165   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              111.138
# Skew:                           0.137   Prob(JB):                     7.36e-25
# Kurtosis:                       5.136   Cond. No.                         22.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.002703   0.000877  3.080529
# Mkt-RF    -0.000141   0.000074 -1.916453
# Long Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -41598.702
# Model:                            OLS   Adj. R-squared:             -41966.841
# Method:                 Least Squares   F-statistic:                    -113.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:21:19   Log-Likelihood:                -1720.7
# No. Observations:                 571   AIC:                             3453.
# Df Residuals:                     565   BIC:                             3479.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0832      5.190      0.016      0.987     -10.110      10.277
# SMB            0.1700      7.472      0.023      0.982     -14.507      14.847
# HML           -0.1750     10.160     -0.017      0.986     -20.132      19.782
# RMW            0.3006     10.042      0.030      0.976     -19.424      20.026
# CMA            0.4919     15.477      0.032      0.975     -29.907      30.891
# intercept      4.9300      0.218     22.618      0.000       4.502       5.358
# ==============================================================================
# Omnibus:                       55.642   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              250.351
# Skew:                           0.282   Prob(JB):                     4.33e-55
# Kurtosis:                       6.194   Cond. No.                         84.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.006687   0.000997  6.708159
# Mkt-RF     0.000082   0.000076  1.081368
# SMB        0.000108   0.000042  2.541838
# HML        0.000056   0.000058  0.973161
# RMW        0.000102   0.000048  2.108582
# CMA        0.000111   0.000041  2.664833
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -108173.805
# Model:                            OLS   Adj. R-squared:            -108363.918
# Method:                 Least Squares   F-statistic:                    -569.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:21:20   Log-Likelihood:                -1993.5
# No. Observations:                 571   AIC:                             3991.
# Df Residuals:                     569   BIC:                             4000.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0229      7.295      0.003      0.998     -14.305      14.351
# intercept      7.9500      0.335     23.732      0.000       7.292       8.608
# ==============================================================================
# Omnibus:                      112.075   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              809.782
# Skew:                           0.645   Prob(JB):                    1.44e-176
# Kurtosis:                       8.690   Cond. No.                         21.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.006726   0.001006  6.687217
# Mkt-RF     0.000080   0.000077  1.044817
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -4240.865
# Model:                            OLS   Adj. R-squared:              -4282.780
# Method:                 Least Squares   F-statistic:                    -101.2
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:21:30   Log-Likelihood:                -1086.1
# No. Observations:                 512   AIC:                             2184.
# Df Residuals:                     506   BIC:                             2210.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2913      2.315     -0.126      0.900      -4.840       4.257
# SMB           -0.1491      3.198     -0.047      0.963      -6.433       6.134
# HML           -0.0374      4.382     -0.009      0.993      -8.647       8.572
# RMW           -0.0002      4.316   -5.3e-05      1.000      -8.479       8.478
# CMA            0.0674      6.789      0.010      0.992     -13.271      13.405
# intercept     -2.0200      0.094    -21.405      0.000      -2.205      -1.835
# ==============================================================================
# Omnibus:                       45.231   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              198.093
# Skew:                           0.209   Prob(JB):                     9.65e-44
# Kurtosis:                       6.018   Cond. No.                         84.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.003231   0.001352 -2.389637
# Mkt-RF    -0.000649   0.000114 -5.714486
# SMB       -0.000234   0.000063 -3.683848
# HML        0.000104   0.000065  1.609486
# RMW        0.000091   0.000044  2.076913
# CMA        0.000120   0.000035  3.396248
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -3831.386
# Model:                            OLS   Adj. R-squared:              -3838.901
# Method:                 Least Squares   F-statistic:                    -509.9
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:21:30   Log-Likelihood:                -1060.1
# No. Observations:                 512   AIC:                             2124.
# Df Residuals:                     510   BIC:                             2133.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.3213      1.898     -0.169      0.866      -4.050       3.408
# intercept     -1.9200      0.086    -22.454      0.000      -2.088      -1.752
# ==============================================================================
# Omnibus:                       40.252   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              136.157
# Skew:                           0.272   Prob(JB):                     2.72e-30
# Kurtosis:                       5.467   Cond. No.                         22.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept -0.003241   0.001361 -2.381491
# Mkt-RF    -0.000653   0.000114 -5.705160
# Ensemble System
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -62588.743
# Model:                            OLS   Adj. R-squared:             -63138.741
# Method:                 Least Squares   F-statistic:                    -113.8
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:21:43   Log-Likelihood:                -1704.0
# No. Observations:                 575   AIC:                             3420.
# Df Residuals:                     569   BIC:                             3446.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0305      4.933      0.006      0.995      -9.658       9.719
# SMB            0.0650      7.096      0.009      0.993     -13.873      14.003
# HML           -0.1292      9.649     -0.013      0.989     -19.080      18.822
# RMW            0.1608      9.551      0.017      0.987     -18.599      18.921
# CMA            0.3655     14.676      0.025      0.980     -28.460      29.191
# intercept      4.6900      0.207     22.695      0.000       4.284       5.096
# ==============================================================================
# Omnibus:                       47.056   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              228.219
# Skew:                          -0.040   Prob(JB):                     2.77e-50
# Kurtosis:                       6.085   Cond. No.                         84.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.005381   0.000771  6.981430
# Mkt-RF    -0.000009   0.000067 -0.128782
# SMB        0.000028   0.000034  0.830090
# HML        0.000056   0.000040  1.397136
# RMW        0.000069   0.000027  2.544128
# CMA        0.000097   0.000028  3.526398
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                 -124323.967
# Model:                            OLS   Adj. R-squared:            -124540.939
# Method:                 Least Squares   F-statistic:                    -573.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:21:43   Log-Likelihood:                -1901.3
# No. Observations:                 575   AIC:                             3807.
# Df Residuals:                     573   BIC:                             3815.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0178      6.056     -0.003      0.998     -11.913      11.877
# intercept      6.6100      0.278     23.819      0.000       6.065       7.155
# ==============================================================================
# Omnibus:                       48.724   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              238.179
# Skew:                           0.098   Prob(JB):                     1.91e-52
# Kurtosis:                       6.147   Cond. No.                         22.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.005405   0.000776  6.965289
# Mkt-RF    -0.000010   0.000068 -0.149327
# Simple Binary Decision
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -5273.152
# Model:                            OLS   Adj. R-squared:              -5318.619
# Method:                 Least Squares   F-statistic:                    -116.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:21:45   Log-Likelihood:                -1006.9
# No. Observations:                 586   AIC:                             2026.
# Df Residuals:                     580   BIC:                             2052.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0049      1.415     -0.003      0.997      -2.784       2.774
# SMB           -0.0684      2.018     -0.034      0.973      -4.032       3.895
# HML           -0.0564      2.762     -0.020      0.984      -5.482       5.369
# RMW            0.1755      2.724      0.064      0.949      -5.175       5.526
# CMA            0.0336      4.183      0.008      0.994      -8.182       8.249
# intercept      1.3500      0.059     22.889      0.000       1.234       1.466
# ==============================================================================
# Omnibus:                       53.698   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              180.406
# Skew:                          -0.374   Prob(JB):                     6.69e-40
# Kurtosis:                       5.614   Cond. No.                         84.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.001375   0.000759  1.812469
# Mkt-RF    -0.000062   0.000057 -1.083986
# SMB       -0.000102   0.000037 -2.733377
# HML       -0.000010   0.000035 -0.282115
# RMW        0.000107   0.000025  4.245036
# CMA        0.000001   0.000020  0.067398
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -10010.000
# Model:                            OLS   Adj. R-squared:             -10027.142
# Method:                 Least Squares   F-statistic:                    -583.9
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:21:45   Log-Likelihood:                -1194.7
# No. Observations:                 586   AIC:                             2393.
# Df Residuals:                     584   BIC:                             2402.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0346      1.694     -0.020      0.984      -3.361       3.292
# intercept      1.8600      0.077     24.034      0.000       1.708       2.012
# ==============================================================================
# Omnibus:                       50.971   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              161.987
# Skew:                          -0.367   Prob(JB):                     6.68e-36
# Kurtosis:                       5.469   Cond. No.                         22.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.001375   0.000764  1.801007
# Mkt-RF    -0.000064   0.000058 -1.104070
#
# =====================================================================================================================================
#            KNN L/S    KNN L     KNN S    Neural Net L/S Neural Net L Neural Net S   RF L/S     RF L      RF S     Ensemble   Binary
# -------------------------------------------------------------------------------------------------------------------------------------
# Mkt-RF    -0.0121   0.1026**  -0.2303*** 0.0206         0.0902**     -0.4472***   -0.0244*  0.0832    -0.2913*** 0.0305    -0.0049
#           (0.0001)  (0.0001)  (0.0001)   (0.0001)       (0.0001)     (0.0002)     (0.0001)  (0.0001)  (0.0001)   (0.0001)  (0.0001)
# SMB       -0.0037   0.1445*** -0.2859*** 0.0825         0.1266***    -0.2723***   0.0568    0.1700**  -0.1491*** 0.0650    -0.0684***
#           (0.0000)  (0.0000)  (0.0001)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0000)  (0.0001)   (0.0000)  (0.0000)
# HML       -0.1049   -0.1796   0.0368     -0.1515        -0.1561      0.0155       -0.1295   -0.1750   -0.0374    -0.1292   -0.0564
#           (0.0000)  (0.0000)  (0.0001)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0001)  (0.0001)   (0.0000)  (0.0000)
# RMW       0.0348    0.2266*   -0.2459    0.1731**       0.2226***    0.1137**     0.1915*** 0.3006**  -0.0002**  0.1608**  0.1755***
#           (0.0000)  (0.0000)  (0.0001)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0000)  (0.0000)   (0.0000)  (0.0000)
# CMA       0.2224*** 0.4599*** -0.1896    0.3791***      0.3951***    -0.0332***   0.3482*** 0.4919*** 0.0674***  0.3655*** 0.0336
#           (0.0000)  (0.0000)  (0.0000)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0000)  (0.0000)   (0.0000)  (0.0000)
# intercept 2.6600*** 5.7900*** -1.2600*** 4.5800***      5.4500***    2.3000       1.7400*** 4.9300*** -2.0200**  4.6900*** 1.3500*
#           (0.0008)  (0.0009)  (0.0013)   (0.0008)       (0.0008)     (0.0021)     (0.0009)  (0.0010)  (0.0014)   (0.0008)  (0.0008)
# =====================================================================================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %%
m4_factor_results = summary_col(output_reg,stars=True,float_format='%0.4f',model_names=names)
m4_factor_results.title = 'RF Stambaugh, Y Yuan 4 Factor Model'
m4_factor_results_capm = summary_col(output_capm,stars=True,float_format='%0.4f',model_names=names)
m4_factor_results_capm.title = 'RF Stambaugh, Y Yuan 4 Factor Model capm'
resultFile = open("output.txt",'a')
resultFile.write(m4_factor_results.as_text())
resultFile.write('\n')
resultFile.write(m4_factor_results_capm.as_text())
resultFile.write('\n')
resultFile.close()

# %% [markdown]
# # Testing Portfolios- Hou, Kewei, Chen Xue, and Lu Zhang

# %% [markdown]
# http://global-q.org/testingportfolios.html

# %%
data_dir = os.path.join(os.getcwd(), 'zhang_anomalies')
_, _, filenames = next(os.walk(data_dir))
print("Testing Portfolio files")
print('Show the first 5...')
print(filenames[0:5])

for three_sort in range(1,4):

    for five_sort in range(1,6):

        anomalies = pd.DataFrame()

        for fil in filenames:
            file_path = os.path.join(data_dir, fil)
            df = pd.read_csv(file_path)
            df["month"] = df["month"].astype(str)
            for i in range(9):
                df.loc[df["month"] == str(i), 'month'] = "0" + df.loc[df["month"] == str(i), 'month']
            df.loc[:, 'ret_vw'] = df.loc[:, 'ret_vw'] / 100.0
            df['date'] = 0.0
            df['date'] = df["year"].astype(str) + df["month"].astype(str) 
            df.index = pd.to_datetime(df.date, format= '%Y%m')

            three_sort_name = ''
            five_sort_name = ''
            col_names = df.columns
            for i in col_names:
                if 'rank' in i and 5 in df[i].unique():
                    five_sort_name = i
                if 'rank' in i and 5 not in df[i].unique():
                    three_sort_name = i
            df_add = df.loc[df[three_sort_name] == three_sort]
            df_add = df_add.loc[df_add[five_sort_name] == five_sort]
            df_add = pd.DataFrame(df_add['ret_vw'])
            df_add.columns = [fil.replace('_monthly_2019a.csv', '')]
            if anomalies.empty:
                anomalies = df_add.copy()
            else:
                anomalies = pd.concat([anomalies, df_add], axis = 1)
                
        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)
        ff_factors = ff_factors.dropna(axis = 0, how = 'any')
        ff_factors = ff_factors.loc[anomalies.index].dropna(axis = 0)
        
        factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
        rf = factor_model[['RF']]
        factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
        print(factor_model)
        print(rf)

        ff_factors_compare = factor_model.copy()
        
        anomalies = anomalies.loc[:, anomalies.columns[0:30]]
        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'

        #the lookback for alpha feature
        lookback = 60
        #control the leverage
        lev = 1.
        stk_symbols  = anomalies.columns
        returns = anomalies.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [binary_alpha]
        #feature_list = [df_alpha]

        feature_set = data.get_features(feature_list)


        output_reg = []
        output_capm = []
        names = ['KNN L/S', 'KNN L', 'KNN S', 'Neural Net L/S', 'Neural Net L', 'Neural Net S', 'RF L/S', 'RF L', 'RF S', 'Ensemble', 'Binary']

        data_type = 'anomaly_port' + '_' + str(three_sort) + '_' + str(five_sort)

        print("KNN")
        print("Long and Short")
        backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
        results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
        results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
        output_reg.append(results)
        output_capm.append(results_capm)
        backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 'ls' + '.csv'))
        #backtest.mean(axis = 1).cumsum().plot()

        print("Long Only")
        backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
        results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
        results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
        output_reg.append(results)
        output_capm.append(results_capm)
        backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 'l' + '.csv'))
        #backtest.mean(axis = 1).cumsum().plot()

        print("Short Only")
        backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
        results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
        results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
        output_reg.append(results)
        output_capm.append(results_capm)
        backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_KNN' '_' + 's' + '.csv'))
        #backtest.mean(axis = 1).cumsum().plot()

        print("Neural Net")
        print("Long and Short")
        backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
        results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
        results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
        output_reg.append(results)
        output_capm.append(results_capm)
        #backtest.mean(axis = 1).cumsum().plot()
        backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 'ls' + '.csv'))

        print("Long Only")
        backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
        results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
        results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
        output_reg.append(results)
        output_capm.append(results_capm)
        #backtest.mean(axis = 1).cumsum().plot()
        backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 'l' + '.csv'))

        print("Short Only")
        backtest, weights = bt.run_backtest(returns, input_classifiers= ["Neural Net"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
        results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
        results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
        output_reg.append(results)
        output_capm.append(results_capm)
        #backtest.mean(axis = 1).cumsum().plot()
        backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_NN' '_' + 's' + '.csv'))

        print("Random Forest")
        print("Long and Short")
        backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
        results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
        results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
        output_reg.append(results)
        output_capm.append(results_capm)
        #backtest.mean(axis = 1).cumsum().plot()
        backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 'ls' + '.csv'))

        print("Long Only")
        backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
        results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
        results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
        output_reg.append(results)
        output_capm.append(results_capm)
        #backtest.mean(axis = 1).cumsum().plot()
        backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 'l' + '.csv'))

        print("Short Only")
        backtest, weights = bt.run_backtest(returns, input_classifiers= ["Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
        results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
        results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
        output_reg.append(results)
        output_capm.append(results_capm)
        #backtest.mean(axis = 1).cumsum().plot()
        backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_RF' '_' + 's' + '.csv'))

        print("Ensemble System")
        backtest, weights = bt.run_backtest(returns, input_classifiers= ["Nearest Neighbors", "Random Forest"], lookback_backtest = 12, inputs = feature_set, outputs = binary_returns,  ensemble = 'yes')  
        results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
        results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
        output_reg.append(results)
        output_capm.append(results_capm)
        #backtest.mean(axis = 1).cumsum().plot()
        backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_ensemble' '_' + 'ls' + '.csv'))

        print("Simple Binary Decision")
        df_alpha_shift = df_alpha.shift(1).dropna(axis = 0)
        backtest = returns.loc[df_alpha_shift.index]
        weights = returns.loc[df_alpha_shift.index]
        for count, row in  backtest.iterrows(): 
            for j in backtest.columns:
                if df_alpha_shift.loc[count, j] >= 0:
                    backtest.loc[count, j] = backtest.loc[count, j]
                    weights.loc[count, j] = 1.0
                else:
                    backtest.loc[count, j] = -backtest.loc[count, j]
                    weights.loc[count, j] = -1.0

        results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
        results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
        output_reg.append(results)
        output_capm.append(results_capm)
        #backtest.mean(axis = 1).cumsum().plot()
        backtest.to_csv(os.path.join(cur_wd, 'backtests', data_type + '_simp_binary' '_' + 'ls' + '.csv'))


        print(summary_col(output_reg,stars=True,float_format='%0.4f',model_names=names))

        tp_factor_results = summary_col(output_reg,stars=True,float_format='%0.4f',model_names=names)
        tp_factor_results.title = 'Testing Portfolios- Hou, Kewei, Chen Xue, and Lu Zhang' + ' ' + str(three_sort) + ' ' + str(five_sort)
        tp_factor_results_capm = summary_col(output_capm,stars=True,float_format='%0.4f',model_names=names)
        tp_factor_results_capm.title = 'Testing Portfolios- Hou, Kewei, Chen Xue, and Lu Zhang' + ' ' + str(three_sort) + ' ' + str(five_sort) + ' ' + 'capm'
        resultFile = open("output.txt",'a')
        resultFile.write(tp_factor_results.as_text())
        resultFile.write('\n')
# 2018-10-01  0.0019
# 2018-11-01  0.0018
# 2018-12-01  0.0019
# 2019-01-01  0.0021
# 2019-02-01  0.0018
# 2019-03-01  0.0019
# 2019-04-01  0.0021
# 2019-05-01  0.0021
# 2019-06-01  0.0018
# 2019-07-01  0.0019
# 2019-08-01  0.0016
# 2019-09-01  0.0018
# 2019-10-01  0.0015
# 2019-11-01  0.0012
# 2019-12-01  0.0014
#
# [636 rows x 1 columns]
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#             mom_portf_me_abr_1_monthly_2019a(1).csv  \
# date
# 1972-02-01                                      NaN
# 1972-03-01                                 0.116478
# 1972-04-01                                 0.057935
# 1972-05-01                                -0.054002
# 1972-06-01                                 0.026850
#
#             portf_me_abr_12_monthly_2019a(1).csv  portf_me_abr_12  \
# date
# 1972-02-01                                   NaN              NaN
# 1972-03-01                              0.116478         0.116478
# 1972-04-01                              0.056445         0.056445
# 1972-05-01                             -0.051114        -0.051114
# 1972-06-01                              0.028260         0.028260
#
#             portf_me_abr_1_monthly_2019a(1).csv  portf_me_abr_1  \
# date
# 1972-02-01                                  NaN             NaN
# 1972-03-01                             0.116478        0.116478
# 1972-04-01                             0.057935        0.057935
# 1972-05-01                            -0.054002       -0.054002
# 1972-06-01                             0.026850        0.026850
#
#             portf_me_abr_6_monthly_2019a(1).csv  portf_me_abr_6  portf_me_aci  \
# date
# 1972-02-01                                  NaN             NaN     -0.005694
# 1972-03-01                             0.116478        0.116478     -0.003465
# 1972-04-01                             0.056445        0.056445     -0.003642
# 1972-05-01                            -0.051114       -0.051114     -0.003774
# 1972-06-01                             0.028260        0.028260     -0.002903
#
#             portf_me_adm  portf_me_almq_12  ...  portf_me_cei  \
# date                                        ...
# 1972-02-01           NaN               NaN  ...     -0.001851
# 1972-03-01           NaN               NaN  ...     -0.000290
# 1972-04-01           NaN               NaN  ...     -0.000578
# 1972-05-01           NaN               NaN  ...     -0.000620
# 1972-06-01           NaN               NaN  ...      0.000591
#
#             portf_me_cim_12  portf_me_cim_1  portf_me_cim_6  portf_me_claq_12  \
# date
# 1972-02-01        -0.007963       -0.009816       -0.009978               NaN
# 1972-03-01        -0.005439       -0.007731       -0.007053               NaN
# 1972-04-01        -0.005601       -0.007574       -0.007194               NaN
# 1972-05-01        -0.005567       -0.007711       -0.007134               NaN
# 1972-06-01        -0.005010       -0.007291       -0.006545               NaN
#
#             portf_me_claq_1  portf_me_claq_6  portf_me_cla  portf_me_cm_12  \
# date
# 1972-02-01              NaN              NaN     -0.012114             NaN
# 1972-03-01              NaN              NaN     -0.009172             NaN
# 1972-04-01              NaN              NaN     -0.009276             NaN
# 1972-05-01              NaN              NaN     -0.009614             NaN
# 1972-06-01              NaN              NaN     -0.008767             NaN
#
#             portf_me_cm_1
# date
# 1972-02-01            NaN
# 1972-03-01            NaN
# 1972-04-01            NaN
# 1972-05-01            NaN
# 1972-06-01            NaN
#
# [5 rows x 30 columns]
#             mom_portf_me_abr_1_monthly_2019a(1).csv  \
# date
# 1972-02-01                                      NaN
# 1972-03-01                                      NaN
# 1975-04-01              NaN              NaN     -0.020052             NaN
# 1975-05-01              NaN              NaN     -0.078766             NaN
# 1975-06-01              NaN              NaN     -0.081829             NaN
# 1975-07-01              NaN              NaN      0.009448             NaN
# ...                     ...              ...           ...             ...
# 2017-07-01        -0.026890        -0.019794     -0.022237       -0.002805
# 2017-08-01        -0.018385        -0.010546     -0.031165       -0.010795
# 2017-09-01         0.089932         0.088924      0.120777        0.109506
# 2017-10-01        -0.009629        -0.012129     -0.002215       -0.010744
# 2017-11-01         0.034866         0.044178      0.049496        0.014234
# 2017-12-01         0.015073         0.013058     -0.030879       -0.006195
# 2018-01-01         0.031697         0.030618     -0.031414        0.023561
# 2018-02-01        -0.040239        -0.042616      0.052974       -0.056164
# 2018-03-01         0.007472         0.004376     -0.017078        0.016024
# 2018-04-01        -0.021271        -0.014599     -0.024403        0.005479
# 2018-05-01        -0.088448        -0.084428     -0.080873       -0.086439
# 2018-06-01        -0.028118        -0.025433     -0.006465       -0.008120
# 2018-07-01         0.001494         0.003900      0.000563       -0.001380
# 2018-08-01         0.030512         0.044382      0.028593        0.054925
# 2018-09-01        -0.038329        -0.038659     -0.032991        0.034878
# 2018-10-01        -0.124893        -0.120927     -0.119858       -0.121864
# 2018-11-01        -0.032477        -0.022892     -0.032574        0.015557
# 2018-12-01        -0.146611        -0.138917      0.148485       -0.139493
# 2019-01-01         0.241607         0.147442     -0.117637       -0.146549
# 2019-02-01         0.067880         0.048446      0.064891        0.039607
# 2019-03-01        -0.018621        -0.015338     -0.015603       -0.040750
# 2019-04-01        -0.000794         0.005475      0.015218       -0.000459
# 2019-05-01        -0.092431        -0.083288     -0.082743       -0.120277
# 2019-06-01        -0.056181         0.051822      0.054932        0.060300
# 2019-07-01         0.032768        -0.030491     -0.030277        0.036827
# 2019-08-01        -0.069185        -0.070822     -0.065595        0.097442
# 2019-09-01        -0.032922        -0.014471     -0.030194       -0.038219
# 2019-10-01        -0.002252         0.000366     -0.013955        0.023380
# 2019-11-01         0.052095         0.055677      0.031119        0.021072
# 2019-12-01         0.071489         0.092465      0.043115        0.065315
#
#             portf_me_cm_1
# 1973-02-01            NaN
# 1973-03-01            NaN
# 1973-04-01            NaN
# 1973-05-01            NaN
# 1973-06-01            NaN
# 1973-07-01            NaN
# 1973-08-01            NaN
# 1973-09-01            NaN
# 1973-10-01            NaN
# 1973-11-01            NaN
# 1973-12-01            NaN
# 1974-01-01            NaN
# 1974-02-01            NaN
# 1974-03-01            NaN
# 1974-04-01            NaN
# 1974-05-01            NaN
# 1974-06-01            NaN
# 1974-07-01            NaN
# 1974-08-01            NaN
# 1974-09-01            NaN
# 1974-10-01            NaN
# 1974-11-01            NaN
# 1974-12-01            NaN
# 1975-01-01            NaN
# 1975-02-01            NaN
# 1975-03-01            NaN
# 1975-04-01            NaN
# 1975-05-01            NaN
# 1975-06-01            NaN
# 1975-07-01            NaN
# ...                   ...
# 2017-07-01       0.026631
# 2017-08-01      -0.020580
# 2017-09-01       0.126813
# 2017-10-01       0.014993
# 2017-11-01      -0.007920
# 2017-12-01       0.000819
# 2018-01-01      -0.033270
# 2018-02-01       0.077276
# 2018-03-01      -0.012561
# 2018-04-01      -0.023597
# 2018-05-01       0.090597
# 2018-06-01       0.016612
# 2018-07-01       0.034692
# 2018-08-01       0.047164
# 2018-09-01      -0.037821
# 2018-10-01      -0.123714
# 2018-11-01       0.000351
# 2018-12-01      -0.146379
# 2019-01-01      -0.199956
# 2019-02-01       0.046003
# 2019-03-01      -0.029901
# 2019-04-01      -0.022119
# 2019-05-01      -0.078721
# 2019-06-01       0.037751
# 2019-07-01       0.079922
# 2019-08-01       0.149083
# 2019-09-01      -0.061638
# 2019-10-01       0.026508
# 2019-11-01       0.083095
# 2019-12-01       0.095336
#
# [563 rows x 30 columns]
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                    -198.050
# Model:                            OLS   Adj. R-squared:               -199.837
# Method:                 Least Squares   F-statistic:                    -110.8
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:24:11   Log-Likelihood:                -652.64
# No. Observations:                 563   AIC:                             1317.
# Df Residuals:                     557   BIC:                             1343.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0127      0.824     -0.015      0.988      -1.632       1.606
# SMB            0.0657      1.201      0.055      0.956      -2.294       2.425
# HML           -0.2569      1.575     -0.163      0.871      -3.351       2.838
# RMW           -0.0302      1.594     -0.019      0.985      -3.161       3.100
# CMA            0.3973      2.446      0.162      0.871      -4.408       5.202
# intercept      0.7700      0.034     22.462      0.000       0.703       0.837
# ==============================================================================
# Omnibus:                       74.658   Durbin-Watson:                   0.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              335.472
# Skew:                          -0.492   Prob(JB):                     1.42e-73
# Kurtosis:                       6.652   Cond. No.                         83.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.001016   0.002274  0.446669
# Mkt-RF    -0.000029   0.000190 -0.152036
# SMB        0.000067   0.000127  0.528060
# HML       -0.000057   0.000099 -0.572368
# RMW       -0.000039   0.000073 -0.531244
# CMA        0.000054   0.000064  0.850742
# KNN
# Long and Short
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                    -198.050
# Model:                            OLS   Adj. R-squared:               -199.837
# Method:                 Least Squares   F-statistic:                    -110.8
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        09:25:09   Log-Likelihood:                -652.64
# ...
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept  0.011817   0.002055   5.750190
# Mkt-RF     0.002014   0.000171  11.799537
# Short Only
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -9619.323
# Model:                            OLS   Adj. R-squared:              -9734.675
# Method:                 Least Squares   F-statistic:                    -83.39
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        21:42:34   Log-Likelihood:                -1280.7
# No. Observations:                 423   AIC:                             2573.
# Df Residuals:                     417   BIC:                             2598.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -1.0400      6.136     -0.169      0.865     -13.101      11.021
# SMB           -0.0220      8.654     -0.003      0.998     -17.032      16.988
# HML            0.0359     11.448      0.003      0.998     -22.468      22.539
# RMW           -0.0251     11.316     -0.002      0.998     -22.268      22.218
# CMA           -0.0695     17.981     -0.004      0.997     -35.415      35.276
# intercept     -5.0000      0.258    -19.409      0.000      -5.506      -4.494
# ==============================================================================
# Omnibus:                       78.804   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              653.282
# Skew:                          -0.504   Prob(JB):                    1.39e-142
# Kurtosis:                       9.004   Cond. No.                         82.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept -0.009887   0.002448  -4.038417
# Mkt-RF    -0.002248   0.000179 -12.573945
# SMB       -0.000405   0.000100  -4.051656
# HML        0.000349   0.000106   3.304129
# RMW        0.000299   0.000081   3.700739
# CMA        0.000356   0.000065   5.469517
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -10890.118
# Model:                            OLS   Adj. R-squared:             -10915.988
# Method:                 Least Squares   F-statistic:                    -421.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        21:42:35   Log-Likelihood:                -1306.9
# No. Observations:                 423   AIC:                             2618.
# Df Residuals:                     421   BIC:                             2626.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -1.0334      5.583     -0.185      0.853     -12.008       9.941
# intercept     -5.3200      0.261    -20.402      0.000      -5.833      -4.807
# ==============================================================================
# Omnibus:                       83.694   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              684.185
# Skew:                          -0.568   Prob(JB):                    2.70e-149
# Kurtosis:                       9.126   Cond. No.                         21.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept -0.009906   0.002461  -4.024499
# Mkt-RF    -0.002260   0.000180 -12.533389
# Ensemble System
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -31375.848
# Model:                            OLS   Adj. R-squared:             -31657.507
# Method:                 Least Squares   F-statistic:                    -111.4
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        21:44:03   Log-Likelihood:                -1903.5
# No. Observations:                 563   AIC:                             3819.
# Df Residuals:                     557   BIC:                             3845.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.4920      7.603      0.065      0.948     -14.442      15.426
# SMB           -0.0036     11.079     -0.000      1.000     -21.766      21.759
# HML           -0.2726     14.532     -0.019      0.985     -28.816      28.271
# RMW            0.0417     14.701      0.003      0.998     -28.835      28.918
# CMA            0.3046     22.564      0.013      0.989     -44.017      44.626
# intercept      7.1200      0.316     22.517      0.000       6.499       7.741
# ==============================================================================
# Omnibus:                      127.950   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1768.497
# Skew:                          -0.564   Prob(JB):                         0.00
# Kurtosis:                      11.609   Cond. No.                         83.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.008900   0.001669  5.332571
# Mkt-RF     0.001023   0.000155  6.583537
# SMB        0.000166   0.000075  2.207103
# HML       -0.000253   0.000071 -3.547596
# RMW       -0.000092   0.000051 -1.797466
# CMA       -0.000133   0.000046 -2.856413
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -33800.660
# Model:                            OLS   Adj. R-squared:             -33860.912
# Method:                 Least Squares   F-statistic:                    -561.0
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        21:44:04   Log-Likelihood:                -1924.5
# No. Observations:                 563   AIC:                             3853.
# Df Residuals:                     561   BIC:                             3862.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.4827      6.906      0.070      0.944     -13.082      14.048
# intercept      7.3900      0.314     23.518      0.000       6.773       8.007
# ==============================================================================
# Omnibus:                      131.074   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1912.188
# Skew:                          -0.572   Prob(JB):                         0.00
# Kurtosis:                      11.956   Cond. No.                         22.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error     tstat
# intercept  0.008916   0.001678  5.312929
# Mkt-RF     0.001026   0.000157  6.547591
# Simple Binary Decision
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                  -13456.562
# Model:                            OLS   Adj. R-squared:             -13597.627
# Method:                 Least Squares   F-statistic:                    -95.39
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        21:44:08   Log-Likelihood:                -1472.8
# No. Observations:                 483   AIC:                             2958.
# Df Residuals:                     477   BIC:                             2983.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.8858      6.049      0.146      0.884     -11.000      12.772
# SMB            0.0343      9.047      0.004      0.997     -17.744      17.812
# HML           -0.0435     11.373     -0.004      0.997     -22.391      22.304
# RMW            0.0120     11.453      0.001      0.999     -22.493      22.517
# CMA           -0.1596     17.207     -0.009      0.993     -33.970      33.651
# intercept      5.1100      0.247     20.688      0.000       4.625       5.595
# ==============================================================================
# Omnibus:                      309.829   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5402.759
# Skew:                          -2.468   Prob(JB):                         0.00
# Kurtosis:                      18.624   Cond. No.                         82.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept  0.009797   0.001977   4.955633
# Mkt-RF     0.001834   0.000165  11.089666
# SMB        0.000288   0.000076   3.816720
# HML       -0.000385   0.000077  -4.983382
# RMW       -0.000256   0.000065  -3.961832
# CMA       -0.000355   0.000054  -6.529169
# First Step
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                   -9395.846
# Model:                            OLS   Adj. R-squared:              -9415.382
# Method:                 Least Squares   F-statistic:                    -480.9
# Date:                Tue, 26 Jan 2021   Prob (F-statistic):               1.00
# Time:                        21:44:09   Log-Likelihood:                -1386.1
# No. Observations:                 483   AIC:                             2776.
# Df Residuals:                     481   BIC:                             2785.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.9251      4.417      0.209      0.834      -7.754       9.605
# intercept      4.2700      0.197     21.698      0.000       3.883       4.657
# ==============================================================================
# Omnibus:                      289.210   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4484.629
# Skew:                          -2.280   Prob(JB):                         0.00
# Kurtosis:                      17.214   Cond. No.                         22.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Second Stage Fama Macbeth
#                mean  std_error      tstat
# intercept  0.009804   0.001987   4.934246
# Mkt-RF     0.001843   0.000167  11.063803
#
# =======================================================================================================================================
#            KNN L/S    KNN L      KNN S    Neural Net L/S Neural Net L Neural Net S   RF L/S     RF L      RF S     Ensemble    Binary
# ---------------------------------------------------------------------------------------------------------------------------------------
# Mkt-RF    0.2254*** 0.9930***  -1.0484*** 0.4904***      0.9951***    -1.1129***   0.1525*   1.0224*** -1.0400*** 0.4920***  0.8858***
#           (0.0002)  (0.0002)   (0.0002)   (0.0002)       (0.0002)     (0.0003)     (0.0002)  (0.0002)  (0.0002)   (0.0002)   (0.0002)
# SMB       -0.0743   0.0317***  -0.0709*** 0.0619***      0.0179***    0.0466       0.1137    0.0981*** -0.0220*** -0.0036**  0.0343***
#           (0.0001)  (0.0001)   (0.0001)   (0.0001)       (0.0001)     (0.0002)     (0.0001)  (0.0001)  (0.0001)   (0.0001)   (0.0001)
# HML       -0.2154** -0.0811*** -0.0524*** -0.2496***     -0.0652***   -0.0182**    -0.1629   0.0014*** 0.0359***  -0.2726*** -0.0435***
#           (0.0001)  (0.0001)   (0.0001)   (0.0001)       (0.0001)     (0.0002)     (0.0001)  (0.0001)  (0.0001)   (0.0001)   (0.0001)
# RMW       -0.0354   -0.0433*** -0.0934*** 0.0721*        -0.0649***   -0.2421**    0.2817    0.0548*** -0.0251*** 0.0417*    0.0120***
#           (0.0000)  (0.0001)   (0.0001)   (0.0001)       (0.0001)     (0.0001)     (0.0000)  (0.0001)  (0.0001)   (0.0001)   (0.0001)
# CMA       0.1857*   0.0416***  -0.0103*** 0.2838***      0.0424***    -0.0808***   0.2418    0.0382*** -0.0695*** 0.3046***  -0.1596***
#           (0.0000)  (0.0001)   (0.0001)   (0.0000)       (0.0000)     (0.0001)     (0.0000)  (0.0000)  (0.0001)   (0.0000)   (0.0001)
# intercept 3.8700**  6.8200***  -5.1400*** 7.4000***      7.0400***    -1.0600      4.1000*** 6.8700*** -5.0000*** 7.1200***  5.1100***
#           (0.0017)  (0.0020)   (0.0024)   (0.0017)       (0.0019)     (0.0038)     (0.0016)  (0.0020)  (0.0024)   (0.0017)   (0.0020)
# =======================================================================================================================================
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01
