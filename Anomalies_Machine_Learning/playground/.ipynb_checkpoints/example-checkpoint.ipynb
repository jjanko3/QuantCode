# %%
from regime_module import *
from statsmodels.iolib.summary2 import summary_col
import csv
import os
import matplotlib.backends.backend_pdf

cur_wd = os.getcwd()
print(cur_wd)
image_wd = os.path.join(cur_wd, 'backtest_images_market_timing')
backtest_wd = os.path.join(cur_wd, 'backtests_market_timing')
import matplotlib.pyplot as plt
# Out:
# D:\janko_machine_learning\playground

# %%
def write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns, backtest_write, image_write, cur_wd, data_type ):
    
    outname = 'output_results_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    outnamelatex = 'output_results_latex_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    
    outname_scaled = 'output_results_scaled_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    outnamelatex_scaled = 'output_results_latex_scaled_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    
    
    output_reg = []
    output_capm = []
    output_umd = []
    output_qfactor = []
    output_tm = []
    output_hm = []
    
    output_reg_scaled = []
    output_capm_scaled = []
    output_umd_scaled = []
    output_qfactor_scaled = []
    output_tm_scaled = []
    output_hm_scaled = []
    
    names = ['KNN L/S', 'KNN L', 'KNN S',  'Binary']

    
    print("KNN")
    print("Long and Short")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Nearest Neighbors"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN_' + 'ls' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN_scaled_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_KNN_' + 'ls' + '.pdf'))

    

    print("Long Only")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Nearest Neighbors"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN_' + 'l' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN_scaled_' + 'l' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_KNN_' + 'l' + '.pdf'))


    print("Short Only")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Nearest Neighbors"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)



    print("Simple Binary Decision")
    scaled_backtest = returns.dropna(axis = 1, how = 'all').dropna(axis = 0, how = 'all')
    weights = returns.dropna(axis = 1, how = 'all').dropna(axis = 0, how = 'all')
    backtest.values[:] = 0
    scaled_backtest.values[:] = 0
    weights.values[:] = 0
    signal = returns.rolling(lookback_backtest).mean().shift(1).dropna(axis = 1, how = 'all').dropna(axis = 0, how = 'all')
    std = returns.rolling(lookback_backtest).std().shift(1).dropna(axis = 1, how = 'all').dropna(axis = 0, how = 'all')
    std = .05/std
    signal[signal >= 0] = 1.0
    signal[signal < 0] = -1.0
    backtest = (signal * returns).dropna()
    weights = signal
    scaled_backtest = (signal * returns * std).dropna()



    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)


    backtest.to_csv(os.path.join(backtest_write, data_type + '_simp_binary_' + 'ls' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_simp_binary_scaled_' '_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_sim_binary_scaled_' + 'ls' + '.pdf'))

    plt.close('all')
    
    factor_results = summary_col(output_reg,stars=True,float_format='%0.3f',model_names=names)
    factor_results.title = data_type
    factor_results_capm = summary_col(output_capm,stars=True,float_format='%0.3f',model_names=names)
    factor_results_capm.title = data_type + ' capm'
    
    factor_results_umd = summary_col(output_umd,stars=True,float_format='%0.3f',model_names=names)
    factor_results_umd.title = data_type + ' umd'
    
    factor_results_q = summary_col(output_qfactor,stars=True,float_format='%0.3f',model_names=names)
    factor_results_q.title = data_type + ' q factor'
                                                        
    factor_results_tm = summary_col(output_tm,stars=True,float_format='%0.3f',model_names=names)
    factor_results_tm.title = data_type + ' Treynor and Mazuy'
                               
    factor_results_hm = summary_col(output_hm,stars=True,float_format='%0.3f',model_names=names)
    factor_results_hm.title = data_type + ' Henriksson and Merton'
    
    resultFile = open(os.path.join(backtest_wd,'outputs' ,outname),'a')
    resultFile.write(factor_results.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_capm.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_umd.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_q.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_tm.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_hm.as_text())
    resultFile.write('\n')
    resultFile.close()
    
    resultFile = open(os.path.join(backtest_wd,'outputs' ,outnamelatex),'a')
    resultFile.write(factor_results.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_capm.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_umd.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_q.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_tm.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_hm.as_latex())
    resultFile.write('\n')
    resultFile.close()
    
    add_factor = pd.DataFrame(factor_results.tables[0]).T['intercept']
    add_factor.columns = [data_type + '_' +  str(lookback) + '_' + str(lookback_backtest) ]
    add_factor.name = data_type + '_' +  str(lookback) + '_' + str(lookback_backtest) 
    add_factor_capm = pd.DataFrame(factor_results_capm.tables[0]).T['intercept']
    add_factor_capm.columns = [data_type + '_' + str(lookback) + '_' + str(lookback_backtest) ]
    add_factor_capm.name = data_type + '_' + str(lookback) + '_' + str(lookback_backtest)
                               
    factor_results_scaled = summary_col(output_reg_scaled,stars=True,float_format='%0.3f',model_names=names)
    factor_results_scaled.title = data_type
                               
    factor_results_capm_scaled = summary_col(output_capm_scaled,stars=True,float_format='%0.3f',model_names=names)
    factor_results_capm_scaled.title = data_type + ' capm'
    
    factor_results_umd_scaled = summary_col(output_umd_scaled,stars=True,float_format='%0.3f',model_names=names)
    factor_results_umd_scaled.title = data_type + ' umd'
    
    factor_results_q_scaled = summary_col(output_qfactor_scaled,stars=True,float_format='%0.3f',model_names=names)
    factor_results_q_scaled.title = data_type + ' q factor'
                                                        
    factor_results_tm_scaled = summary_col(output_tm_scaled,stars=True,float_format='%0.3f',model_names=names)
    factor_results_tm_scaled.title = data_type + ' Treynor and Mazuy'
                    
    factor_results_hm_scaled = summary_col(output_hm_scaled,stars=True,float_format='%0.3f',model_names=names)
    factor_results_hm_scaled.title = data_type + ' Henriksson and Merton'
    
    resultFile = open(os.path.join(backtest_wd,'outputs' ,outname_scaled),'a')
    resultFile.write(factor_results_scaled.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_capm_scaled.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_umd_scaled.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_q_scaled.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_tm_scaled.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_hm_scaled.as_text())
    resultFile.write('\n')
    resultFile.close()
    
    resultFile = open(os.path.join(backtest_wd,'outputs' ,outnamelatex_scaled),'a')
    resultFile.write(factor_results_scaled.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_capm_scaled.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_umd_scaled.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_q_scaled.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_tm_scaled.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_hm_scaled.as_latex())
    resultFile.write('\n')
    resultFile.close()
    
    add_factor_scaled = pd.DataFrame(factor_results_scaled.tables[0]).T['intercept']
    add_factor_scaled.columns = [data_type + '_' +  str(lookback) + '_' + str(lookback_backtest) ]
    add_factor_scaled.name = data_type + '_' +  str(lookback) + '_' + str(lookback_backtest) 
    add_factor_capm_scaled = pd.DataFrame(factor_results_capm_scaled.tables[0]).T['intercept']
    add_factor_capm_scaled.columns = [data_type + '_' + str(lookback) + '_' + str(lookback_backtest) ]
    add_factor_capm_scaled.name = data_type + '_' + str(lookback) + '_' + str(lookback_backtest)
       
                    
    
    return add_factor, add_factor_capm, factor_results, add_factor_scaled, add_factor_capm_scaled

# %%
alpha_ff5 = pd.DataFrame()
alpha_capm = pd.DataFrame()

alpha_ff5_scaled = pd.DataFrame()
alpha_capm_scaled = pd.DataFrame()

# %%
#get the famma french factors

# %%
ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
ff_factors = ff_factors / 100.0
ff_factors[ff_factors == -999] = np.NaN
ff_factors[ff_factors == -99.9] = np.NaN
ff_factors = ff_factors.dropna(how = 'any', axis = 0)
ff_factors = ff_factors[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
ff_factors_compare = ff_factors.copy()

# %%
#get the momentum model
mom = pd.read_csv('Mom.csv', index_col = 0)
mom.index = pd.to_datetime(mom.index, format= '%Y%m')
mom = mom / 100.0
mom[mom == -999] = np.NaN
mom[mom == -99.9] = np.NaN
mom = mom.dropna(how = 'any', axis = 0)
umd = pd.concat([ff_factors[['Mkt-RF', 'SMB', 'HML']], mom], axis = 1)
umd = umd.dropna()
cols_add = []
for c in umd.columns:
    cols_add.append(c.replace(' ', ''))
umd.columns  = cols_add
print(umd.head(5))
print(umd.columns)
# Out:
#             Mkt-RF     SMB     HML     Mom
# 1963-07-01 -0.0039 -0.0047 -0.0083  0.0100
# 1963-08-01  0.0507 -0.0079  0.0167  0.0103
# 1963-09-01 -0.0157 -0.0048  0.0018  0.0016
# 1963-10-01  0.0253 -0.0129 -0.0010  0.0314
# 1963-11-01 -0.0085 -0.0084  0.0171 -0.0075
# Index(['Mkt-RF', 'SMB', 'HML', 'Mom'], dtype='object')

# %%
q_factor = pd.read_csv('q5_factors.csv', index_col = 0)
q_factor.index = pd.to_datetime(q_factor.index, format= '%Y%m')
q_factor = q_factor / 100.0
q_factor = q_factor[['R_MKT', 'R_ME', 'R_IA', 'R_ROE', 'R_EG']]
print(q_factor.head(5))
# Out:
#                R_MKT      R_ME      R_IA     R_ROE      R_EG
# 1967-01-01  0.081603  0.067282 -0.029434  0.018866 -0.022469
# 1967-02-01  0.007202  0.016918 -0.002064  0.035317  0.025812
# 1967-03-01  0.039691  0.019517 -0.016933  0.018876 -0.014789
# 1967-04-01  0.038265 -0.007446 -0.029519  0.010983 -0.022351
# 1967-05-01 -0.042419  0.029132  0.024686  0.005234  0.002749

# %%
industry = pd.read_csv('48_Industry_Portfolios.csv', index_col = 0)
industry.index = pd.to_datetime(industry.index, format= '%Y%m')
industry[industry <= -99.] = np.nan
industry = industry / 100.0

ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
ff_factors = ff_factors / 100.0
ff_factors[ff_factors == -999] = np.NaN
ff_factors[ff_factors == -99.9] = np.NaN
ff_factors = ff_factors.dropna(how = 'any', axis = 0)

factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
rf = factor_model[['RF']]
rf_subtract = rf.copy()
factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
ff_factors_compare = factor_model.copy()

rf_subtract.index = pd.to_datetime(rf_subtract.index, format = 'Y%-%m-%d')



policy_uncertainty = pd.read_csv('US_Policy_Uncertainty_Data.csv', index_col = 0)
policy_uncertainty.index = pd.to_datetime(policy_uncertainty.index, format= '%Y%m')

goyal_welch = pd.read_csv('goyal_welch_data.csv', index_col = 0)
goyal_welch.index = pd.to_datetime(goyal_welch.index, format= '%Y')
goyal_welch = goyal_welch.dropna(axis = 0, how = 'all').dropna(axis = 1, how = 'all')
for x in goyal_welch.columns:
    goyal_welch[x] =  pd.to_numeric(goyal_welch[x], errors='coerce')

# %%
lookback_list = [24,12]
lookback_backtest_list = [12,24]

for lookback in lookback_list:
    for lookback_backtest in lookback_backtest_list:

        if not os.path.exists(os.path.join(image_wd, str(lookback) + '_' + str(lookback_backtest))):
            os.makedirs(os.path.join(image_wd, str(lookback) + '_' + str(lookback_backtest)))

        image_write = os.path.join(image_wd, str(lookback) + '_' + str(lookback_backtest))

        if not os.path.exists(os.path.join(backtest_wd, str(lookback) + '_' + str(lookback_backtest))):
            os.makedirs(os.path.join(backtest_wd, str(lookback) + '_' + str(lookback_backtest)))
        if not os.path.exists(os.path.join(backtest_wd, 'outputs')):
            os.makedirs(os.path.join(backtest_wd, 'outputs'))

        outname = 'output_results_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
        outnamelatex = 'output_results_latex_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    
        backtest_write = os.path.join(backtest_wd, str(lookback) + '_' + str(lookback_backtest))

        resultFile = open(os.path.join(backtest_wd,'outputs' ,outname),'w')
        resultFile.close()
        
        resultFile = open(os.path.join(backtest_wd,'outputs' ,outnamelatex),'w')
        resultFile.close()
        
        outname = 'output_results_scaled_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
        outnamelatex = 'output_results_latex_scaled_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    
        backtest_write = os.path.join(backtest_wd, str(lookback) + '_' + str(lookback_backtest))

        resultFile = open(os.path.join(backtest_wd,'outputs' ,outname),'w')
        resultFile.close()
        
        resultFile = open(os.path.join(backtest_wd,'outputs' ,outnamelatex),'w')
        resultFile.close()
        
        ####################################################
        ####################################################    
        #get the ff5 results
        ####################################################
        ####################################################
        ####################################################

        
        
        
        
        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)

        factor_model = ff_factors.copy()
        factor_model = factor_model[['Mkt-RF']]
        rf = ff_factors[['RF']]

        index_symbol = 'Mkt-RF'

        print(ff_factors.head(5))

        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'

        #control the leverage
        lev = 1.
        stk_symbols  = factor_model.columns
        returns = factor_model.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns, rolling_sum_12 = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [binary_alpha, binary_returns]
        
        feature_set = data.get_features(feature_list)
        

 
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], policy_uncertainty],axis = 1)
            feature_set[k] = feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
                
        
        
        """
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], goyal_welch],axis = 1)
            # feature_set[k] = feature_set[k][~feature_set[k].bfill().isna()].ffill()
            feature_set[k] = feature_set[k][~feature_set[k].bfill().isna()].ffill()
            feature_set[k] = feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
        
        """


        data_type = 'Market Timing'
        
        factor_results, factor_results_capm, factor_reg,factor_results_scaled, factor_results_capm_scaled = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )
        
        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)
            
        if alpha_ff5_scaled.empty:
            alpha_ff5_scaled = factor_results_scaled.copy()
            alpha_capm_scaled = factor_results_capm_scaled.copy()
        else:
            alpha_ff5_scaled = pd.concat( [alpha_ff5_scaled, factor_results_scaled], axis = 1)
            alpha_capm_scaled = pd.concat( [alpha_capm_scaled, factor_results_capm_scaled], axis = 1)   
            
        alpha_ff5.to_csv('alphaff5_mt.csv')
        alpha_capm.to_csv('alphacapm_mt.csv')
        alpha_ff5_scaled.to_csv('alphaff5_scaled_mt.csv')
        alpha_capm_scaled.to_csv('alphacapm_scaled_mt.csv')
        
        plt.close('all')
# Out:
#             Mkt-RF     SMB     HML     RMW     CMA      RF
# 1963-07-01 -0.0039 -0.0047 -0.0083  0.0066 -0.0115  0.0027
# 1963-08-01  0.0507 -0.0079  0.0167  0.0040 -0.0040  0.0025
# 1963-09-01 -0.0157 -0.0048  0.0018 -0.0076  0.0024  0.0027
# 1963-10-01  0.0253 -0.0129 -0.0010  0.0275 -0.0224  0.0029
# 1963-11-01 -0.0085 -0.0084  0.0171 -0.0045  0.0222  0.0027
#               Mkt-RF
# 1965-08-01  0.004442
# 1965-09-01  0.005183
# 1965-10-01  0.004175
# 1965-11-01  0.006004
# 1965-12-01  0.006025
#               Mkt-RF
# 1965-08-01  0.021657
# 1965-09-01  0.021567
# 1965-10-01  0.019975
# 1965-11-01  0.019827
# 1965-12-01  0.019846
# KNN
# Long and Short
# found
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.136
# Model:                            OLS   Adj. R-squared:                  0.119
# Method:                 Least Squares   F-statistic:                     5.636
# Date:                Sun, 02 May 2021   Prob (F-statistic):           6.04e-05
# Time:                        10:51:25   Log-Likelihood:                 452.20
# No. Observations:                 258   AIC:                            -892.4
# Df Residuals:                     252   BIC:                            -871.1
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2426      0.120     -2.023      0.043      -0.478      -0.008
# SMB           -0.3461      0.124     -2.786      0.005      -0.590      -0.103
# HML           -0.2373      0.156     -1.525      0.127      -0.542       0.068
# RMW           -0.4290      0.219     -1.957      0.050      -0.859       0.001
# CMA            0.0620      0.250      0.248      0.804      -0.428       0.551
# intercept      0.0098      0.003      3.405      0.001       0.004       0.015
# ==============================================================================
# Omnibus:                        2.966   Durbin-Watson:                   2.146
# Prob(Omnibus):                  0.227   Jarque-Bera (JB):                2.755
# Skew:                          -0.160   Prob(JB):                        0.252
# Kurtosis:                       3.393   Cond. No.                         87.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     5.537
# Date:                Sun, 02 May 2021   Prob (F-statistic):             0.0194
# Time:                        10:51:25   Log-Likelihood:                 443.75
# No. Observations:                 258   AIC:                            -883.5
# Df Residuals:                     256   BIC:                            -876.4
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2757      0.117     -2.353      0.019      -0.505      -0.046
# intercept      0.0067      0.003      2.542      0.011       0.002       0.012
# ==============================================================================
# Omnibus:                        3.920   Durbin-Watson:                   2.133
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                4.574
# Skew:                           0.092   Prob(JB):                        0.102
# Kurtosis:                       3.626   Cond. No.                         21.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.112
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     3.865
# Date:                Sun, 02 May 2021   Prob (F-statistic):            0.00457
# Time:                        10:51:25   Log-Likelihood:                 448.62
# No. Observations:                 258   AIC:                            -887.2
# Df Residuals:                     253   BIC:                            -869.5
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2169      0.121     -1.798      0.072      -0.453       0.020
# SMB           -0.3044      0.126     -2.425      0.015      -0.550      -0.058
# HML           -0.0710      0.119     -0.597      0.550      -0.304       0.162
# Mom            0.0145      0.108      0.134      0.893      -0.197       0.226
# intercept      0.0074      0.003      2.430      0.015       0.001       0.013
# ==============================================================================
# Omnibus:                        2.560   Durbin-Watson:                   2.083
# Prob(Omnibus):                  0.278   Jarque-Bera (JB):                2.412
# Skew:                          -0.114   Prob(JB):                        0.299
# Kurtosis:                       3.415   Cond. No.                         40.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.137
# Model:                            OLS   Adj. R-squared:                  0.120
# Method:                 Least Squares   F-statistic:                     5.779
# Date:                Sun, 02 May 2021   Prob (F-statistic):           4.55e-05
# Time:                        10:51:25   Log-Likelihood:                 447.92
# No. Observations:                 256   AIC:                            -883.8
# Df Residuals:                     250   BIC:                            -862.6
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT         -0.2052      0.126     -1.630      0.103      -0.452       0.042
# R_ME          -0.3094      0.122     -2.542      0.011      -0.548      -0.071
# R_IA          -0.2330      0.194     -1.199      0.230      -0.614       0.148
# R_ROE         -0.3882      0.184     -2.106      0.035      -0.749      -0.027
# R_EG           0.2563      0.263      0.973      0.331      -0.260       0.773
# intercept      0.0086      0.004      2.339      0.019       0.001       0.016
# ==============================================================================
# Omnibus:                        1.153   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.562   Jarque-Bera (JB):                0.873
# Skew:                          -0.011   Prob(JB):                        0.646
# Kurtosis:                       3.285   Cond. No.                         93.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.134
# Model:                            OLS   Adj. R-squared:                  0.127
# Method:                 Least Squares   F-statistic:                     9.313
# Date:                Sun, 02 May 2021   Prob (F-statistic):           0.000125
# Time:                        10:51:25   Log-Likelihood:                 451.86
# No. Observations:                 258   AIC:                            -897.7
# Df Residuals:                     255   BIC:                            -887.1
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF            -0.2251      0.112     -2.014      0.044      -0.444      -0.006
# market_squared     3.1748      1.332      2.384      0.017       0.565       5.785
# intercept       1.751e-05      0.002      0.007      0.994      -0.005       0.005
# ==============================================================================
# Omnibus:                       27.858   Durbin-Watson:                   2.165
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.119
# Skew:                          -0.794   Prob(JB):                     3.90e-08
# Kurtosis:                       3.806   Cond. No.                         297.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.114
# Model:                            OLS   Adj. R-squared:                  0.107
# Method:                 Least Squares   F-statistic:                     5.728
# Date:                Sun, 02 May 2021   Prob (F-statistic):            0.00369
# Time:                        10:51:25   Log-Likelihood:                 448.89
# No. Observations:                 258   AIC:                            -891.8
# Df Residuals:                     255   BIC:                            -881.1
# Df Model:                           2
# Covariance Type:                  HAC
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Mkt-RF          -0.5483      0.168     -3.264      0.001      -0.878      -0.219
# market_dummy     0.5975      0.310      1.930      0.054      -0.009       1.204
# intercept       -0.0039      0.004     -0.949      0.343      -0.012       0.004
# ==============================================================================
# Omnibus:                       21.862   Durbin-Watson:                   2.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.599
# Skew:                          -0.671   Prob(JB):                     2.76e-06
# Kurtosis:                       3.761   Cond. No.                         77.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.107
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     4.405
# Date:                Sun, 02 May 2021   Prob (F-statistic):           0.000730
# Time:                        10:51:25   Log-Likelihood:                 385.01
# No. Observations:                 258   AIC:                            -758.0
# Df Residuals:                     252   BIC:                            -736.7
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2673      0.150     -1.783      0.075      -0.561       0.027
# SMB           -0.4299      0.157     -2.742      0.006      -0.737      -0.123
# HML           -0.1757      0.176     -0.996      0.319      -0.521       0.170
# RMW           -0.4342      0.244     -1.781      0.075      -0.912       0.044
# CMA           -0.0202      0.289     -0.070      0.944      -0.586       0.546
# intercept      0.0128      0.004      3.460      0.001       0.006       0.020
# ==============================================================================
# Omnibus:                        5.223   Durbin-Watson:                   2.098
# Prob(Omnibus):                  0.073   Jarque-Bera (JB):                5.244
# Skew:                          -0.247   Prob(JB):                       0.0726
# Kurtosis:                       3.494   Cond. No.                         87.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     4.990
# Date:                Sun, 02 May 2021   Prob (F-statistic):             0.0264
# Time:                        10:51:25   Log-Likelihood:                 378.55
# No. Observations:                 258   AIC:                            -753.1
# Df Residuals:                     256   BIC:                            -746.0
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.3127      0.140     -2.234      0.026      -0.587      -0.038
# intercept      0.0095      0.003      2.782      0.005       0.003       0.016
# ==============================================================================
# Omnibus:                        2.328   Durbin-Watson:                   2.095
# Prob(Omnibus):                  0.312   Jarque-Bera (JB):                2.293
# Skew:                          -0.046   Prob(JB):                        0.318
# Kurtosis:                       3.453   Cond. No.                         21.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.095
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     3.560
# Date:                Sun, 02 May 2021   Prob (F-statistic):            0.00759
# Time:                        10:51:25   Log-Likelihood:                 383.30
# No. Observations:                 258   AIC:                            -756.6
# Df Residuals:                     253   BIC:                            -738.8
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.2271      0.143     -1.587      0.113      -0.507       0.053
# SMB           -0.3786      0.160     -2.367      0.018      -0.692      -0.065
# HML           -0.0321      0.126     -0.254      0.800      -0.280       0.216
# Mom            0.0717      0.126      0.570      0.568      -0.175       0.318
# intercept      0.0096      0.004      2.485      0.013       0.002       0.017
# ==============================================================================
# Omnibus:                        3.531   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.171   Jarque-Bera (JB):                3.241
# Skew:                          -0.211   Prob(JB):                        0.198
# Kurtosis:                       3.352   Cond. No.                         40.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.112
# Model:                            OLS   Adj. R-squared:                  0.094
# Method:                 Least Squares   F-statistic:                     4.457
# Date:                Sun, 02 May 2021   Prob (F-statistic):           0.000659
# Time:                        10:51:25   Log-Likelihood:                 381.80
# No. Observations:                 256   AIC:                            -751.6
# Df Residuals:                     250   BIC:                            -730.3
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT         -0.2256      0.153     -1.470      0.141      -0.526       0.075
# R_ME          -0.3774      0.153     -2.462      0.014      -0.678      -0.077
# R_IA          -0.2597      0.230     -1.128      0.259      -0.711       0.191
# R_ROE         -0.4311      0.209     -2.065      0.039      -0.840      -0.022
# R_EG           0.2993      0.317      0.943      0.346      -0.323       0.921
# intercept      0.0115      0.005      2.505      0.012       0.003       0.021
# ==============================================================================
# Omnibus:                        2.566   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.277   Jarque-Bera (JB):                2.370
# Skew:                          -0.128   Prob(JB):                        0.306
# Kurtosis:                       3.396   Cond. No.                         93.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.099
# Model:                            OLS   Adj. R-squared:                  0.092
# Method:                 Least Squares   F-statistic:                     7.540
# Date:                Sun, 02 May 2021   Prob (F-statistic):           0.000659
# Time:                        10:51:26   Log-Likelihood:                 383.86
# No. Observations:                 258   AIC:                            -761.7
# Df Residuals:                     255   BIC:                            -751.1
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF            -0.2597      0.139     -1.873      0.061      -0.531       0.012
# market_squared     3.3262      1.683      1.976      0.048       0.027       6.625
# intercept          0.0025      0.003      0.746      0.456      -0.004       0.009
# ==============================================================================
# Omnibus:                       24.150   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.025
# Skew:                          -0.685   Prob(JB):                     3.02e-07
# Kurtosis:                       3.957   Cond. No.                         297.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     4.986
# Date:                Sun, 02 May 2021   Prob (F-statistic):            0.00751
# Time:                        10:51:26   Log-Likelihood:                 382.03
# No. Observations:                 258   AIC:                            -758.1
# Df Residuals:                     255   BIC:                            -747.4
# Df Model:                           2
# Covariance Type:                  HAC
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Mkt-RF          -0.6022      0.200     -3.004      0.003      -0.995      -0.209
# market_dummy     0.6346      0.384      1.654      0.098      -0.117       1.386
# intercept       -0.0017      0.005     -0.333      0.739      -0.012       0.009
# ==============================================================================
# Omnibus:                       19.962   Durbin-Watson:                   2.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.516
# Skew:                          -0.616   Prob(JB):                     7.83e-06
# Kurtosis:                       3.820   Cond. No.                         77.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Long Only
# found
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.407
# Model:                            OLS   Adj. R-squared:                  0.395
# Method:                 Least Squares   F-statistic:                     9.408
# Date:                Sun, 02 May 2021   Prob (F-statistic):           3.09e-08
# Time:                        10:51:29   Log-Likelihood:                 631.03
# No. Observations:                 258   AIC:                            -1250.
# Df Residuals:                     252   BIC:                            -1229.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.3787      0.060      6.318      0.000       0.261       0.496
# SMB           -0.1731      0.062     -2.786      0.005      -0.295      -0.051
# HML           -0.1187      0.078     -1.525      0.127      -0.271       0.034
# RMW           -0.2145      0.110     -1.957      0.050      -0.429       0.000
# CMA            0.0310      0.125      0.248      0.804      -0.214       0.276
# intercept      0.0049      0.001      3.405      0.001       0.002       0.008
# ==============================================================================
# Omnibus:                        2.966   Durbin-Watson:                   2.146
# Prob(Omnibus):                  0.227   Jarque-Bera (JB):                2.755
# Skew:                          -0.160   Prob(JB):                        0.252
# Kurtosis:                       3.393   Cond. No.                         87.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.367
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     38.23
# Date:                Sun, 02 May 2021   Prob (F-statistic):           2.47e-09
# Time:                        10:51:29   Log-Likelihood:                 622.58
# No. Observations:                 258   AIC:                            -1241.
# Df Residuals:                     256   BIC:                            -1234.
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.3622      0.059      6.183      0.000       0.247       0.477
# intercept      0.0033      0.001      2.542      0.011       0.001       0.006
# ==============================================================================
# Omnibus:                        3.920   Durbin-Watson:                   2.133
# Prob(Omnibus):                  0.141   Jarque-Bera (JB):                4.574
# Skew:                           0.092   Prob(JB):                        0.102
# Kurtosis:                       3.626   Cond. No.                         21.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.391
# Model:                            OLS   Adj. R-squared:                  0.381
# Method:                 Least Squares   F-statistic:                     11.18
# Date:                Sun, 02 May 2021   Prob (F-statistic):           2.27e-08
# Time:                        10:51:29   Log-Likelihood:                 627.45
# No. Observations:                 258   AIC:                            -1245.
# Df Residuals:                     253   BIC:                            -1227.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.3916      0.060      6.493      0.000       0.273       0.510
# SMB           -0.1522      0.063     -2.425      0.015      -0.275      -0.029
# HML           -0.0355      0.059     -0.597      0.550      -0.152       0.081
# Mom            0.0072      0.054      0.134      0.893      -0.099       0.113
# intercept      0.0037      0.002      2.430      0.015       0.001       0.007
# ==============================================================================
# Omnibus:                        2.560   Durbin-Watson:                   2.083
# Prob(Omnibus):                  0.278   Jarque-Bera (JB):                2.412
# Skew:                          -0.114   Prob(JB):                        0.299
# Kurtosis:                       3.415   Cond. No.                         40.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.385
# Method:                 Least Squares   F-statistic:                     8.587
# Date:                Sun, 02 May 2021   Prob (F-statistic):           1.60e-07
# Time:                        10:51:29   Log-Likelihood:                 623.13
# No. Observations:                 256   AIC:                            -1234.
# Df Residuals:                     250   BIC:                            -1213.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT          0.3958      0.064      6.169      0.000       0.270       0.522
# R_ME          -0.1537      0.062     -2.493      0.013      -0.275      -0.033
# R_IA          -0.1264      0.097     -1.301      0.193      -0.317       0.064
# R_ROE         -0.1929      0.092     -2.093      0.036      -0.374      -0.012
# R_EG           0.1405      0.133      1.054      0.292      -0.121       0.402
# intercept      0.0043      0.002      2.341      0.019       0.001       0.008
# ==============================================================================
# Omnibus:                        1.600   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.449   Jarque-Bera (JB):                1.380
# Skew:                           0.014   Prob(JB):                        0.502
# Kurtosis:                       3.358   Cond. No.                         93.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     24.60
# Date:                Sun, 02 May 2021   Prob (F-statistic):           1.70e-10
# Time:                        10:51:29   Log-Likelihood:                 630.69
# No. Observations:                 258   AIC:                            -1255.
# Df Residuals:                     255   BIC:                            -1245.
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF             0.3874      0.056      6.932      0.000       0.278       0.497
# market_squared     1.5874      0.666      2.384      0.017       0.282       2.893
# intercept       8.754e-06      0.001      0.007      0.994      -0.002       0.002
# ==============================================================================
# Omnibus:                       27.858   Durbin-Watson:                   2.165
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.119
# Skew:                          -0.794   Prob(JB):                     3.90e-08
# Kurtosis:                       3.806   Cond. No.                         297.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.392
# Model:                            OLS   Adj. R-squared:                  0.387
# Method:                 Least Squares   F-statistic:                     23.01
# Date:                Sun, 02 May 2021   Prob (F-statistic):           6.51e-10
# Time:                        10:51:29   Log-Likelihood:                 627.72
# No. Observations:                 258   AIC:                            -1249.
# Df Residuals:                     255   BIC:                            -1239.
# Df Model:                           2
# Covariance Type:                  HAC
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Mkt-RF           0.2259      0.084      2.689      0.007       0.061       0.390
# market_dummy     0.2987      0.155      1.930      0.054      -0.005       0.602
# intercept       -0.0019      0.002     -0.949      0.343      -0.006       0.002
# ==============================================================================
# Omnibus:                       21.862   Durbin-Watson:                   2.150
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.599
# Skew:                          -0.671   Prob(JB):                     2.76e-06
# Kurtosis:                       3.761   Cond. No.                         77.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.375
# Model:                            OLS   Adj. R-squared:                  0.363
# Method:                 Least Squares   F-statistic:                     10.40
# Date:                Sun, 02 May 2021   Prob (F-statistic):           4.35e-09
# Time:                        10:51:29   Log-Likelihood:                 552.78
# No. Observations:                 258   AIC:                            -1094.
# Df Residuals:                     252   BIC:                            -1072.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.5008      0.076      6.599      0.000       0.352       0.650
# SMB           -0.1998      0.081     -2.482      0.013      -0.358      -0.042
# HML           -0.1824      0.096     -1.893      0.058      -0.371       0.006
# RMW           -0.1845      0.120     -1.543      0.123      -0.419       0.050
# CMA            0.1698      0.149      1.136      0.256      -0.123       0.463
# intercept      0.0065      0.002      3.256      0.001       0.003       0.010
# ==============================================================================
# Omnibus:                        2.294   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.318   Jarque-Bera (JB):                2.208
# Skew:                          -0.064   Prob(JB):                        0.332
# Kurtosis:                       3.435   Cond. No.                         87.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.341
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                     41.45
# Date:                Sun, 02 May 2021   Prob (F-statistic):           5.94e-10
# Time:                        10:51:29   Log-Likelihood:                 546.05
# No. Observations:                 258   AIC:                            -1088.
# Df Residuals:                     256   BIC:                            -1081.
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.4607      0.072      6.438      0.000       0.320       0.601
# intercept      0.0051      0.002      2.801      0.005       0.002       0.009
# ==============================================================================
# Omnibus:                        3.378   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.185   Jarque-Bera (JB):                3.330
# Skew:                           0.155   Prob(JB):                        0.189
# Kurtosis:                       3.463   Cond. No.                         21.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.364
# Model:                            OLS   Adj. R-squared:                  0.354
# Method:                 Least Squares   F-statistic:                     12.13
# Date:                Sun, 02 May 2021   Prob (F-statistic):           4.92e-09
# Time:                        10:51:29   Log-Likelihood:                 550.57
# No. Observations:                 258   AIC:                            -1091.
# Df Residuals:                     253   BIC:                            -1073.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.5009      0.075      6.698      0.000       0.354       0.648
# SMB           -0.1818      0.083     -2.199      0.028      -0.344      -0.020
# HML           -0.0309      0.077     -0.402      0.688      -0.182       0.120
# Mom            0.0509      0.065      0.778      0.437      -0.077       0.179
# intercept      0.0051      0.002      2.430      0.015       0.001       0.009
# ==============================================================================
# Omnibus:                        1.686   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.431   Jarque-Bera (JB):                1.488
# Skew:                           0.003   Prob(JB):                        0.475
# Kurtosis:                       3.372   Cond. No.                         40.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     9.226
# Date:                Sun, 02 May 2021   Prob (F-statistic):           4.49e-08
# Time:                        10:51:29   Log-Likelihood:                 544.23
# No. Observations:                 256   AIC:                            -1076.
# Df Residuals:                     250   BIC:                            -1055.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT          0.5133      0.080      6.405      0.000       0.356       0.670
# R_ME          -0.1667      0.083     -2.021      0.043      -0.328      -0.005
# R_IA          -0.0551      0.124     -0.446      0.656      -0.297       0.187
# R_ROE         -0.1661      0.105     -1.581      0.114      -0.372       0.040
# R_EG           0.1821      0.172      1.061      0.289      -0.154       0.518
# intercept      0.0052      0.003      2.040      0.041       0.000       0.010
# ==============================================================================
# Omnibus:                        2.918   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.232   Jarque-Bera (JB):                2.983
# Skew:                           0.095   Prob(JB):                        0.225
# Kurtosis:                       3.494   Cond. No.                         93.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.370
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     26.00
# Date:                Sun, 02 May 2021   Prob (F-statistic):           5.29e-11
# Time:                        10:51:29   Log-Likelihood:                 551.76
# No. Observations:                 258   AIC:                            -1098.
# Df Residuals:                     255   BIC:                            -1087.
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF             0.4894      0.068      7.152      0.000       0.355       0.623
# market_squared     1.8010      0.797      2.261      0.024       0.240       3.362
# intercept          0.0013      0.002      0.734      0.463      -0.002       0.005
# ==============================================================================
# Omnibus:                       11.284   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               12.718
# Skew:                          -0.405   Prob(JB):                      0.00173
# Kurtosis:                       3.727   Cond. No.                         297.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# ...
# Model:                            OLS   Adj. R-squared:                  0.271
# Method:                 Least Squares   F-statistic:                     32.11
# Date:                Sun, 02 May 2021   Prob (F-statistic):           5.32e-14
# Time:                        12:01:24   Log-Likelihood:                 1140.1
# No. Observations:                 626   AIC:                            -2274.
# Df Residuals:                     623   BIC:                            -2261.
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF             0.4462      0.082      5.469      0.000       0.286       0.606
# market_squared    -2.5092      0.845     -2.969      0.003      -4.166      -0.853
# intercept          0.0045      0.002      2.678      0.007       0.001       0.008
# ==============================================================================
# Omnibus:                      100.102   Durbin-Watson:                   1.849
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              848.857
# Skew:                           0.405   Prob(JB):                    4.71e-185
# Kurtosis:                       8.647   Cond. No.                         257.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.253
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     22.70
# Date:                Sun, 02 May 2021   Prob (F-statistic):           3.04e-10
# Time:                        12:01:24   Log-Likelihood:                 1131.7
# No. Observations:                 626   AIC:                            -2257.
# Df Residuals:                     623   BIC:                            -2244.
# Df Model:                           2
# Covariance Type:                  HAC
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Mkt-RF           0.7225      0.124      5.812      0.000       0.479       0.966
# market_dummy    -0.5030      0.222     -2.262      0.024      -0.939      -0.067
# intercept        0.0080      0.003      2.640      0.008       0.002       0.014
# ==============================================================================
# Omnibus:                       88.445   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              906.505
# Skew:                           0.137   Prob(JB):                    1.43e-197
# Kurtosis:                       8.889   Cond. No.                         77.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.293
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     17.50
# Date:                Sun, 02 May 2021   Prob (F-statistic):           3.15e-16
# Time:                        12:01:24   Log-Likelihood:                 1029.0
# No. Observations:                 626   AIC:                            -2046.
# Df Residuals:                     620   BIC:                            -2019.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.5752      0.112      5.115      0.000       0.355       0.796
# SMB           -0.0381      0.107     -0.355      0.723      -0.248       0.172
# HML           -0.0806      0.177     -0.457      0.648      -0.427       0.265
# RMW           -0.0109      0.117     -0.093      0.926      -0.240       0.218
# CMA           -0.3297      0.206     -1.603      0.109      -0.733       0.073
# intercept      0.0004      0.002      0.203      0.839      -0.004       0.005
# ==============================================================================
# Omnibus:                      127.846   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1091.224
# Skew:                          -0.637   Prob(JB):                    1.11e-237
# Kurtosis:                       9.342   Cond. No.                         83.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.273
# Model:                            OLS   Adj. R-squared:                  0.272
# Method:                 Least Squares   F-statistic:                     39.85
# Date:                Sun, 02 May 2021   Prob (F-statistic):           5.20e-10
# Time:                        12:01:24   Log-Likelihood:                 1020.3
# No. Observations:                 626   AIC:                            -2037.
# Df Residuals:                     624   BIC:                            -2028.
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.6372      0.101      6.313      0.000       0.439       0.835
# intercept     -0.0011      0.002     -0.570      0.569      -0.005       0.003
# ==============================================================================
# Omnibus:                      127.058   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1032.754
# Skew:                          -0.647   Prob(JB):                    5.50e-225
# Kurtosis:                       9.158   Cond. No.                         21.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     23.95
# Date:                Sun, 02 May 2021   Prob (F-statistic):           1.92e-18
# Time:                        12:01:24   Log-Likelihood:                 1039.9
# No. Observations:                 626   AIC:                            -2070.
# Df Residuals:                     621   BIC:                            -2048.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.6578      0.103      6.396      0.000       0.456       0.859
# SMB           -0.0264      0.099     -0.267      0.789      -0.220       0.167
# HML           -0.1386      0.122     -1.132      0.258      -0.379       0.101
# Mom            0.2364      0.068      3.472      0.001       0.103       0.370
# intercept     -0.0024      0.002     -1.111      0.267      -0.007       0.002
# ==============================================================================
# Omnibus:                      122.989   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1084.021
# Skew:                          -0.587   Prob(JB):                    4.05e-236
# Kurtosis:                       9.339   Cond. No.                         38.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.281
# Model:                            OLS   Adj. R-squared:                  0.276
# Method:                 Least Squares   F-statistic:                     17.06
# Date:                Sun, 02 May 2021   Prob (F-statistic):           8.28e-16
# Time:                        12:01:24   Log-Likelihood:                 1021.4
# No. Observations:                 618   AIC:                            -2031.
# Df Residuals:                     612   BIC:                            -2004.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT          0.5846      0.112      5.218      0.000       0.365       0.804
# R_ME          -0.0166      0.097     -0.170      0.865      -0.207       0.174
# R_IA          -0.5290      0.123     -4.295      0.000      -0.770      -0.288
# R_ROE          0.0962      0.155      0.621      0.535      -0.208       0.400
# R_EG           0.2365      0.158      1.500      0.134      -0.072       0.545
# intercept     -0.0012      0.002     -0.523      0.601      -0.006       0.003
# ==============================================================================
# Omnibus:                      121.133   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1023.220
# Skew:                          -0.598   Prob(JB):                    6.46e-223
# Kurtosis:                       9.189   Cond. No.                         78.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.320
# Method:                 Least Squares   F-statistic:                     33.75
# Date:                Sun, 02 May 2021   Prob (F-statistic):           1.21e-14
# Time:                        12:01:24   Log-Likelihood:                 1042.0
# No. Observations:                 626   AIC:                            -2078.
# Df Residuals:                     623   BIC:                            -2065.
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF             0.5944      0.094      6.333      0.000       0.410       0.778
# market_squared    -3.1548      0.985     -3.203      0.001      -5.085      -1.225
# intercept          0.0057      0.002      2.959      0.003       0.002       0.010
# ==============================================================================
# Omnibus:                      118.933   Durbin-Watson:                   1.870
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              903.517
# Skew:                           0.607   Prob(JB):                    6.37e-197
# Kurtosis:                       8.759   Cond. No.                         257.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.301
# Model:                            OLS   Adj. R-squared:                  0.299
# Method:                 Least Squares   F-statistic:                     26.02
# Date:                Sun, 02 May 2021   Prob (F-statistic):           1.41e-11
# Time:                        12:01:24   Log-Likelihood:                 1032.5
# No. Observations:                 626   AIC:                            -2059.
# Df Residuals:                     623   BIC:                            -2046.
# Df Model:                           2
# Covariance Type:                  HAC
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Mkt-RF           0.9446      0.154      6.120      0.000       0.642       1.247
# market_dummy    -0.6384      0.258     -2.479      0.013      -1.143      -0.134
# intercept        0.0103      0.003      2.975      0.003       0.004       0.017
# ==============================================================================
# Omnibus:                       97.433   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              899.941
# Skew:                           0.338   Prob(JB):                    3.81e-196
# Kurtosis:                       8.835   Cond. No.                         77.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction

# %% [markdown]
# Lets clean up the input of the alpha parameters

# %%
alpha_ff5 = pd.read_csv('alphaff5_mt.csv', index_col = 0).T
alpha_capm = pd.read_csv('alphacapm_mt.csv', index_col = 0).T

alpha_ff5_clean  = alpha_ff5.copy()
alpha_capm_clean = alpha_capm.copy()

alpha_ff5_clean.loc[:, 'lookback feature'] = ''
alpha_ff5_clean.loc[:, 'lookback ml model'] = ''
alpha_ff5_clean.loc[:, 'new index'] = ''

alpha_capm_clean.loc[:, 'lookback feature'] = ''
alpha_capm_clean.loc[:, 'lookback ml model'] = ''
alpha_capm_clean.loc[:, 'new index'] = ''

for count, row in alpha_ff5.iterrows():
    alpha_ff5_clean.loc[count, 'lookback feature'] = count.split('_')[-2]
    alpha_ff5_clean.loc[count, 'lookback ml model'] = count.split('_')[-1]
    alpha_ff5_clean.loc[count, 'new index'] = "_".join(count.split('_')[0:-2])
   
for count, row in alpha_capm.iterrows():
    alpha_capm_clean.loc[count, 'lookback feature'] = count.split('_')[-2]
    alpha_capm_clean.loc[count, 'lookback ml model'] = count.split('_')[-1]
    alpha_capm_clean.loc[count, 'new index'] = "_".join(count.split('_')[0:-2])
    
alpha_capm_clean.index = alpha_capm_clean.loc[:, 'new index']
alpha_ff5_clean.index = alpha_ff5_clean.loc[:, 'new index']

alpha_capm_clean.drop('new index', axis = 1, inplace = True)
alpha_capm.index.name = 'strategy'
alpha_ff5_clean.drop('new index', axis = 1, inplace = True)
alpha_ff5_clean.index.name = 'strategy'

alpha_ff5_clean.to_csv('alphaff5_cleaned_mt.csv')
alpha_capm_clean.to_csv('alphacapm_cleaned_mt.csv')
alpha_ff5_clean.to_latex('alphaff5_latex_mt.txt')
alpha_capm_clean.to_latex('alphacapm_latex_mt.txt')

# %%
#get the alphas for a backtest across individual portfolios

# %%
alpha_capm
# Out:
#                      KNN L/S    KNN L    KNN S Neural Net L/S Neural Net L  \
# strategy
# Market Timing_24_12  0.007**  0.003**  0.003**        0.006**      0.003**
# Market Timing_24_24   -0.002   -0.001   -0.001          0.001            0
# Market Timing_24_60    0.002    0.001    0.001         -0.001       -0.001
# Market Timing_12_12    0.003    0.001    0.001          0.004        0.002
# Market Timing_12_24   -0.001   -0.001   -0.001          0.001            0
# Market Timing_12_60    0.001    0.000    0.000        -0.003*      -0.002*
#
#                     Neural Net S   RF L/S     RF L     RF S AdaBoost L/S  \
# strategy
# Market Timing_24_12      0.003**  0.005**  0.003**  0.003**        0.002
# Market Timing_24_24            0    0.003    0.002    0.002        0.001
# Market Timing_24_60       -0.001    0.003    0.002    0.002       0.004*
# Market Timing_12_12        0.002    0.003    0.001    0.001       -0.002
# Market Timing_12_24            0    0.002    0.001    0.001           -0
# Market Timing_12_60      -0.002*    0.001    0.000    0.000        0.003
#
#                     AdaBoost L AdaBoost S Ensemble   Binary
# strategy
# Market Timing_24_12      0.001      0.001    0.001  0.004**
# Market Timing_24_24          0          0   -0.002    0.001
# Market Timing_24_60     0.002*     0.002*    0.001   -0.001
# Market Timing_12_12     -0.001     -0.001    0.001  0.004**
# Market Timing_12_24         -0         -0   -0.001    0.001
# Market Timing_12_60      0.001      0.001   -0.001   -0.001

# %%
alpha_ff5
# Out:
#                       KNN L/S     KNN L     KNN S Neural Net L/S Neural Net L  \
# Market Timing_24_12  0.010***  0.005***  0.005***        0.007**      0.004**
# Market Timing_24_24         0         0         0          0.003        0.002
# Market Timing_24_60    0.004*    0.002*    0.002*         -0.000       -0.000
# Market Timing_12_12     0.003     0.001     0.001         0.004*       0.002*
# Market Timing_12_24         0         0         0          0.002        0.001
# Market Timing_12_60     0.002     0.001     0.001         -0.002       -0.001
#
#                     Neural Net S  RF L/S    RF L    RF S AdaBoost L/S  \
# Market Timing_24_12      0.004**  0.005*  0.003*  0.003*        0.005
# Market Timing_24_24        0.002   0.002   0.001   0.001        0.001
# Market Timing_24_60       -0.000  0.004*  0.002*  0.002*        0.004
# Market Timing_12_12       0.002*   0.003   0.002   0.002        0.000
# Market Timing_12_24        0.001   0.002   0.001   0.001       -0.001
# Market Timing_12_60       -0.001      -0      -0      -0        0.002
#
#                     AdaBoost L AdaBoost S Ensemble Binary
# Market Timing_24_12      0.002      0.002    0.001  0.003
# Market Timing_24_24      0.001      0.001   -0.003  0.001
# Market Timing_24_60      0.002      0.002    0.001  0.000
# Market Timing_12_12      0.000      0.000    0.001  0.003
# Market Timing_12_24         -0         -0       -0  0.001
# Market Timing_12_60      0.001      0.001    0.001      0
