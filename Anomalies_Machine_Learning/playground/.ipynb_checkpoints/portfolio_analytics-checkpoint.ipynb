# %%
from regime_module import *
from statsmodels.iolib.summary2 import summary_col
import csv
import os
import math

cur_wd = os.getcwd()
print(cur_wd)

backtest_directory = os.path.join(cur_wd, 'backtests')
# Out:
# D:\janko_machine_learning\playground

# %%
ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
ff_factors = ff_factors / 100.0
ff_factors[ff_factors == -999] = np.NaN
ff_factors[ff_factors == -99.9] = np.NaN
ff_factors = ff_factors.dropna(how = 'any', axis = 0)
ff_factors = ff_factors[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
ff_factors_compare = ff_factors.copy()

# %%
q_factor = pd.read_csv('q5_factors.csv', index_col = 0)
q_factor.index = pd.to_datetime(q_factor.index, format= '%Y%m')
q_factor = q_factor / 100.0

factor_model = q_factor[['R_MKT', 'R_ME', 'R_IA', 'R_ROE', 'R_EG']]

# %%
os.listdir(backtest_directory)
# Out:
# ['12_12', 'outputs']

# %%
all_subdirs = os.listdir(backtest_directory)
out_combined = pd.DataFrame()

for fol_bt in all_subdirs:
    if fol_bt != 'outputs':
        _, _, filenames = next(os.walk(os.path.join(backtest_directory, fol_bt)))
        name = "portfolio" + fol_bt +  "_analytics.csv"
        resultFile = open(os.path.join(backtest_directory, 'outputs', name),'w')
        resultFile.close()        
        out = pd.DataFrame()
        for bt in filenames:
            backtest = pd.read_csv(os.path.join(backtest_directory,fol_bt, bt), index_col = 0)
            eql_weight = backtest.mean(axis = 1)
            
            cumsum_eql_weight = eql_weight.cumsum()[1:]
            
            eql_weight.index = pd.to_datetime(eql_weight.index)
            union_index = eql_weight.index.intersection(ff_factors['Mkt-RF'].index)
            check_mkt = ff_factors['Mkt-RF'].loc[union_index]
            check_eql_weight = eql_weight.loc[union_index]
            downside = check_eql_weight.loc[check_mkt < 0.0].dropna()
            downside_mkt = check_mkt.loc[downside.index].dropna()           
            
            analytics = {}
            analytics['Mean return'] = str(round(eql_weight.mean() * 100,4))
            analytics['Mean return annualized'] = str(round(eql_weight.mean() * 12 * 100.,4))
            analytics['std return'] = str(round(eql_weight.std() * 100.,4))
            analytics['std return annualized'] = str(round(eql_weight.std() * math.sqrt(12) * 100.0,4))
            analytics['yearly window max drawdown'] =  100.0 * (cumsum_eql_weight.rolling(12).max()[12:] - cumsum_eql_weight.rolling(12).min()[12:]).max()
            analytics['sharpe'] = round(eql_weight.mean() * 12 * 100.,4) / round(eql_weight.std() * math.sqrt(12) * 100.0,4)
            analytics['downside mean return annualized'] = str(round(downside.mean() * 100,4))
            analytics['market downside mean return annualized'] = str(round(downside_mkt.mean() * 100,4))
            
            df = pd.DataFrame.from_dict(analytics, orient = 'index')
            df.columns = [bt.replace('.csv', '')]
            if out.empty:
                out = df.copy()
            else:
                out = pd.concat([out, df], axis = 1)
        out.to_csv(os.path.join(backtest_directory, 'outputs', name), mode = 'a')
        combined = out.T
        combined.loc[:, 'lookback for features'] = fol_bt.split('_')[0]
        combined.loc[:, 'lookback for ml model'] = fol_bt.split('_')[1]
        if out_combined.empty:
            out_combined = combined.copy()
        else:
            out_combined = pd.concat([out_combined, combined], axis = 0, sort = False)
            
out_combined.to_csv(os.path.join(backtest_directory, 'outputs', 'combined_analytics.csv'))

# %%
all_subdirs
# Out:
# ['12_12', 'outputs']

# %%
factor_model = q_factor.copy()
fol_bt = '12_12'
_, _, filenames = next(os.walk(os.path.join(backtest_directory, fol_bt)))
name = "portfolio" + fol_bt +  "_analytics.csv"
resultFile = open(os.path.join(backtest_directory, 'outputs', name),'w')
resultFile.close()        
out = pd.DataFrame()
all_alphas = pd.DataFrame()
all_p = pd.DataFrame()
all_mean = pd.DataFrame()
all_downside_mean = pd.DataFrame()
all_market_downside_mean = pd.DataFrame()

for bt in filenames:
    backtest = pd.read_csv(os.path.join(backtest_directory,fol_bt, bt), index_col = 0)
    alphas = {}
    pvalues = {}
    means = {}
    dmeans = {}
    dmeans_mkt = {}
    
    for strgy in backtest.columns:
        port= pd.DataFrame(backtest[strgy])
        port.columns = ['strategy_' + strgy]
        port.index = pd.to_datetime(port.index)
        #1st step. run the regression of factors on the portfolio
        df = pd.concat([port, factor_model], axis = 1).dropna(axis =0 ,how = 'any')
        Y = port.loc[df.index]
        X = factor_model.loc[df.index]
        X['intercept'] = 1.0
        model = sm.OLS(Y,X,missing = 'drop')
        #robust covariance results
        results = model.fit(cov_type='HAC',cov_kwds={'maxlags':1})
        #results.params['intercept'] = round(results.params['intercept'] * 12.*100.0, 2)
        pvalues[strgy] = results.pvalues['intercept']
        alphas[strgy]= results.params['intercept'] * 12.0
        
        check_mkt = X['R_MKT']
        check_strgy = Y.copy()
        downside = check_strgy.loc[check_mkt < 0.0].dropna()
        downside_mkt = check_mkt.loc[downside.index].dropna() 
        mean_mkt = Y.mean()
        means[strgy] = mean_mkt.values[0]
        dmeans[strgy] = downside.mean().values[0]
        dmeans_mkt[strgy] = downside_mkt.mean()
            
    add = pd.DataFrame.from_dict(alphas, orient = 'index')
    add.columns = [bt.replace('.csv', '')]
    
    addp = pd.DataFrame.from_dict(pvalues, orient = 'index')
    addp.columns = [bt.replace('.csv', '')]
    
    addmeans = pd.DataFrame.from_dict(means, orient = 'index')
    addmeans.columns = [bt.replace('.csv', '')]
    
    add_dmeans = pd.DataFrame.from_dict(dmeans, orient = 'index')
    add_dmeans.columns = [bt.replace('.csv', '')]
    
    add_dmeans_mkt = pd.DataFrame.from_dict(dmeans_mkt, orient = 'index')
    add_dmeans_mkt.columns = [bt.replace('.csv', '')]
    
    
    if all_alphas.empty:
        all_alphas = add.copy()
    else:
        all_alphas = pd.concat([all_alphas, add], axis = 1)
        
    if all_p.empty:
        all_p = addp.copy()
    else:
        all_p = pd.concat([all_p, addp], axis = 1)
        
    if all_mean.empty:
        all_mean = addmeans.copy()
    else:
        all_mean = pd.concat([all_mean, add], axis = 1)
        
    if all_downside_mean.empty:
        all_downside_mean = add_dmeans.copy()
    else:
        all_downside_mean = pd.concat([all_downside_mean, add_dmeans], axis = 1)
        
    if all_market_downside_mean.empty:
        all_market_downside_mean = add_dmeans_mkt.copy()
    else:
        all_market_downside_mean = pd.concat([all_market_downside_mean, add_dmeans_mkt], axis = 1)
    
print(all_alphas)
print(all_p)
# Out:
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:66: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:71: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:76: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:81: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
# C:\Users\jjanko\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:86: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                      anomaly_size_control_KNN_l  anomaly_size_control_KNN_ls  \
# Aero                                        NaN                          NaN
# Agric                                       NaN                          NaN
# Autos                                       NaN                          NaN
# Banks                                       NaN                          NaN
# Beer                                        NaN                          NaN
# BldMt                                       NaN                          NaN
# Books                                       NaN                          NaN
# Boxes                                       NaN                          NaN
# BusSv                                       NaN                          NaN
# CMA                                         NaN                          NaN
# Chems                                       NaN                          NaN
# Chips                                       NaN                          NaN
# Clths                                       NaN                          NaN
# Cnstr                                       NaN                          NaN
# Coal                                        NaN                          NaN
# Comps                                       NaN                          NaN
# Drugs                                       NaN                          NaN
# ElcEq                                       NaN                          NaN
# FabPr                                       NaN                          NaN
# Fin                                         NaN                          NaN
# Food                                        NaN                          NaN
# Fun                                         NaN                          NaN
# Gold                                        NaN                          NaN
# Guns                                        NaN                          NaN
# HML                                         NaN                          NaN
# Hlth                                        NaN                          NaN
# Hshld                                       NaN                          NaN
# Insur                                       NaN                          NaN
# LabEq                                       NaN                          NaN
# MGMT                                        NaN                          NaN
# ...                                         ...                          ...
# portf_me_resid11_12                   -0.029589                    -0.014950
# portf_me_resid11_6                    -0.033945                    -0.038129
# portf_me_resid6_12                    -0.044165                    -0.050662
# portf_me_resid6_6                      0.009915                    -0.048551
# portf_me_rev_1                         0.050350                     0.025396
# portf_me_rev_12                       -0.027517                     0.022225
# portf_me_rev_6                        -0.037043                    -0.014981
# portf_me_rnaq_1                        0.076018                     0.044619
# portf_me_rnaq_6                        0.039099                    -0.007643
# portf_me_roa_1                         0.051929                     0.018286
# portf_me_roe_1                         0.024626                    -0.038839
# portf_me_roe_6                         0.042003                     0.107074
# portf_me_rs_1                          0.045610                    -0.047469
# portf_me_sgq_1                         0.025154                    -0.114673
# portf_me_sim_1                         0.246402                     0.205267
# portf_me_sm_1                          0.022849                    -0.008696
# portf_me_sm_12                        -0.006326                    -0.008792
# portf_me_sp                            0.134908                     0.106841
# portf_me_spq_1                         0.057838                    -0.145066
# portf_me_spq_12                        0.065029                     0.010203
# portf_me_spq_6                         0.005410                    -0.098172
# portf_me_srev                         -0.167792                     0.010217
# portf_me_sue_1                         0.036293                     0.023280
# portf_me_sue_6                        -0.026398                     0.127298
# portf_me_sv_1                          0.176524                     0.122473
# portf_me_ta                           -0.037154                    -0.013890
# portf_me_tbiq_12                       0.025661                    -0.027852
# portf_me_tv_1                         -0.164453                     0.240420
# portf_me_vfp                           0.086568                     0.121053
# portf_me_vhp                          -0.031839                    -0.031454
#
#                      anomaly_size_control_KNN_s  ff5_ensemble_ls  ff5_KNN_l  \
# Aero                                        NaN              NaN        NaN
# Agric                                       NaN              NaN        NaN
# Autos                                       NaN              NaN        NaN
# Banks                                       NaN              NaN        NaN
# Beer                                        NaN              NaN        NaN
# BldMt                                       NaN              NaN        NaN
# Books                                       NaN              NaN        NaN
# Boxes                                       NaN              NaN        NaN
# BusSv                                       NaN              NaN        NaN
# CMA                                         NaN        -0.003594    0.00274
# Chems                                       NaN              NaN        NaN
# Chips                                       NaN              NaN        NaN
# Clths                                       NaN              NaN        NaN
# Cnstr                                       NaN              NaN        NaN
# Coal                                        NaN              NaN        NaN
# Comps                                       NaN              NaN        NaN
# Drugs                                       NaN              NaN        NaN
# ElcEq                                       NaN              NaN        NaN
# FabPr                                       NaN              NaN        NaN
# Fin                                         NaN              NaN        NaN
# Food                                        NaN              NaN        NaN
# Fun                                         NaN              NaN        NaN
# Gold                                        NaN              NaN        NaN
# Guns                                        NaN              NaN        NaN
# HML                                         NaN         0.033686    0.03096
# Hlth                                        NaN              NaN        NaN
# Hshld                                       NaN              NaN        NaN
# Insur                                       NaN              NaN        NaN
# LabEq                                       NaN              NaN        NaN
# MGMT                                        NaN              NaN        NaN
# ...                                         ...              ...        ...
# portf_me_resid11_12                    0.049512              NaN        NaN
# portf_me_resid11_6                     0.002096              NaN        NaN
# portf_me_resid6_12                    -0.009228              NaN        NaN
# portf_me_resid6_6                     -0.017596              NaN        NaN
# portf_me_rev_1                         0.041863              NaN        NaN
# portf_me_rev_12                       -0.004876              NaN        NaN
# portf_me_rev_6                        -0.024069              NaN        NaN
# portf_me_rnaq_1                       -0.070873              NaN        NaN
# portf_me_rnaq_6                       -0.072522              NaN        NaN
# portf_me_roa_1                         0.016798              NaN        NaN
# portf_me_roe_1                        -0.080915              NaN        NaN
# portf_me_roe_6                        -0.037703              NaN        NaN
# portf_me_rs_1                         -0.251613              NaN        NaN
# portf_me_sgq_1                        -0.080573              NaN        NaN
# portf_me_sim_1                         0.197082              NaN        NaN
# portf_me_sm_1                          0.111679              NaN        NaN
# portf_me_sm_12                        -0.021487              NaN        NaN
# portf_me_sp                            0.077632              NaN        NaN
# portf_me_spq_1                        -0.291918              NaN        NaN
# portf_me_spq_12                       -0.168328              NaN        NaN
# portf_me_spq_6                        -0.316593              NaN        NaN
# portf_me_srev                          0.138477              NaN        NaN
# portf_me_sue_1                         0.107304              NaN        NaN
# portf_me_sue_6                         0.166947              NaN        NaN
# portf_me_sv_1                          0.091494              NaN        NaN
# portf_me_ta                           -0.003086              NaN        NaN
# portf_me_tbiq_12                      -0.134728              NaN        NaN
# portf_me_tv_1                          0.170458              NaN        NaN
# portf_me_vfp                           0.213471              NaN        NaN
# portf_me_vhp                          -0.033101              NaN        NaN
#
#                      ff5_KNN_ls  ff5_KNN_s  ff5_NN_l  ff5_NN_ls  ff5_NN_s  \
# Aero                        NaN        NaN       NaN        NaN       NaN
# Agric                       NaN        NaN       NaN        NaN       NaN
# Autos                       NaN        NaN       NaN        NaN       NaN
# Banks                       NaN        NaN       NaN        NaN       NaN
# Beer                        NaN        NaN       NaN        NaN       NaN
# BldMt                       NaN        NaN       NaN        NaN       NaN
# Books                       NaN        NaN       NaN        NaN       NaN
# Boxes                       NaN        NaN       NaN        NaN       NaN
# BusSv                       NaN        NaN       NaN        NaN       NaN
# CMA                   -0.000757  -0.001824  0.005285   0.010080  0.000615
# Chems                       NaN        NaN       NaN        NaN       NaN
# Chips                       NaN        NaN       NaN        NaN       NaN
# Clths                       NaN        NaN       NaN        NaN       NaN
# Cnstr                       NaN        NaN       NaN        NaN       NaN
# Coal                        NaN        NaN       NaN        NaN       NaN
# Comps                       NaN        NaN       NaN        NaN       NaN
# Drugs                       NaN        NaN       NaN        NaN       NaN
# ElcEq                       NaN        NaN       NaN        NaN       NaN
# FabPr                       NaN        NaN       NaN        NaN       NaN
# Fin                         NaN        NaN       NaN        NaN       NaN
# Food                        NaN        NaN       NaN        NaN       NaN
# Fun                         NaN        NaN       NaN        NaN       NaN
# Gold                        NaN        NaN       NaN        NaN       NaN
# Guns                        NaN        NaN       NaN        NaN       NaN
# HML                    0.029655   0.044755  0.005631   0.007975  0.039209
# Hlth                        NaN        NaN       NaN        NaN       NaN
# Hshld                       NaN        NaN       NaN        NaN       NaN
# Insur                       NaN        NaN       NaN        NaN       NaN
# LabEq                       NaN        NaN       NaN        NaN       NaN
# MGMT                        NaN        NaN       NaN        NaN       NaN
# ...                         ...        ...       ...        ...       ...
# portf_me_resid11_12         NaN        NaN       NaN        NaN       NaN
# portf_me_resid11_6          NaN        NaN       NaN        NaN       NaN
# portf_me_resid6_12          NaN        NaN       NaN        NaN       NaN
# portf_me_resid6_6           NaN        NaN       NaN        NaN       NaN
# portf_me_rev_1              NaN        NaN       NaN        NaN       NaN
# portf_me_rev_12             NaN        NaN       NaN        NaN       NaN
# portf_me_rev_6              NaN        NaN       NaN        NaN       NaN
# portf_me_rnaq_1             NaN        NaN       NaN        NaN       NaN
# portf_me_rnaq_6             NaN        NaN       NaN        NaN       NaN
# portf_me_roa_1              NaN        NaN       NaN        NaN       NaN
# portf_me_roe_1              NaN        NaN       NaN        NaN       NaN
# portf_me_roe_6              NaN        NaN       NaN        NaN       NaN
# portf_me_rs_1               NaN        NaN       NaN        NaN       NaN
# portf_me_sgq_1              NaN        NaN       NaN        NaN       NaN
# portf_me_sim_1              NaN        NaN       NaN        NaN       NaN
# portf_me_sm_1               NaN        NaN       NaN        NaN       NaN
# portf_me_sm_12              NaN        NaN       NaN        NaN       NaN
# portf_me_sp                 NaN        NaN       NaN        NaN       NaN
# portf_me_spq_1              NaN        NaN       NaN        NaN       NaN
# portf_me_spq_12             NaN        NaN       NaN        NaN       NaN
# portf_me_spq_6              NaN        NaN       NaN        NaN       NaN
# portf_me_srev               NaN        NaN       NaN        NaN       NaN
# portf_me_sue_1              NaN        NaN       NaN        NaN       NaN
# portf_me_sue_6              NaN        NaN       NaN        NaN       NaN
# portf_me_sv_1               NaN        NaN       NaN        NaN       NaN
# portf_me_ta                 NaN        NaN       NaN        NaN       NaN
# portf_me_tbiq_12            NaN        NaN       NaN        NaN       NaN
# portf_me_tv_1               NaN        NaN       NaN        NaN       NaN
# portf_me_vfp                NaN        NaN       NaN        NaN       NaN
# portf_me_vhp                NaN        NaN       NaN        NaN       NaN
#
#                      ...  stambaugh_yuan_KNN_l  stambaugh_yuan_KNN_ls  \
# Aero                 ...                   NaN                    NaN
# Agric                ...                   NaN                    NaN
# Autos                ...                   NaN                    NaN
# Banks                ...                   NaN                    NaN
# Beer                 ...                   NaN                    NaN
# BldMt                ...                   NaN                    NaN
# Books                ...                   NaN                    NaN
# Boxes                ...                   NaN                    NaN
# BusSv                ...                   NaN                    NaN
# CMA                  ...                   NaN                    NaN
# Chems                ...                   NaN                    NaN
# Chips                ...                   NaN                    NaN
# Clths                ...                   NaN                    NaN
# Cnstr                ...                   NaN                    NaN
# Coal                 ...                   NaN                    NaN
# Comps                ...                   NaN                    NaN
# Drugs                ...                   NaN                    NaN
# ElcEq                ...                   NaN                    NaN
# FabPr                ...                   NaN                    NaN
# Fin                  ...                   NaN                    NaN
# Food                 ...                   NaN                    NaN
# Fun                  ...                   NaN                    NaN
# Gold                 ...                   NaN                    NaN
# Guns                 ...                   NaN                    NaN
# HML                  ...                   NaN                    NaN
# Hlth                 ...                   NaN                    NaN
# Hshld                ...                   NaN                    NaN
# Insur                ...                   NaN                    NaN
# LabEq                ...                   NaN                    NaN
# MGMT                 ...              0.029644              -0.001415
# ...                  ...                   ...                    ...
# portf_me_resid11_12  ...                   NaN                    NaN
# portf_me_resid11_6   ...                   NaN                    NaN
# portf_me_resid6_12   ...                   NaN                    NaN
# portf_me_resid6_6    ...                   NaN                    NaN
# portf_me_rev_1       ...                   NaN                    NaN
# portf_me_rev_12      ...                   NaN                    NaN
# portf_me_rev_6       ...                   NaN                    NaN
# portf_me_rnaq_1      ...                   NaN                    NaN
# portf_me_rnaq_6      ...                   NaN                    NaN
# portf_me_roa_1       ...                   NaN                    NaN
# portf_me_roe_1       ...                   NaN                    NaN
# portf_me_roe_6       ...                   NaN                    NaN
# portf_me_rs_1        ...                   NaN                    NaN
# portf_me_sgq_1       ...                   NaN                    NaN
# portf_me_sim_1       ...                   NaN                    NaN
# portf_me_sm_1        ...                   NaN                    NaN
# portf_me_sm_12       ...                   NaN                    NaN
# portf_me_sp          ...                   NaN                    NaN
# portf_me_spq_1       ...                   NaN                    NaN
# portf_me_spq_12      ...                   NaN                    NaN
# portf_me_spq_6       ...                   NaN                    NaN
# portf_me_srev        ...                   NaN                    NaN
# portf_me_sue_1       ...                   NaN                    NaN
# portf_me_sue_6       ...                   NaN                    NaN
# portf_me_sv_1        ...                   NaN                    NaN
# portf_me_ta          ...                   NaN                    NaN
# portf_me_tbiq_12     ...                   NaN                    NaN
# portf_me_tv_1        ...                   NaN                    NaN
# portf_me_vfp         ...                   NaN                    NaN
# portf_me_vhp         ...                   NaN                    NaN
#
#                      stambaugh_yuan_KNN_s  stambaugh_yuan_NN_l  \
# Aero                                  NaN                  NaN
# Agric                                 NaN                  NaN
# Autos                                 NaN                  NaN
# Banks                                 NaN                  NaN
# Beer                                  NaN                  NaN
# BldMt                                 NaN                  NaN
# Books                                 NaN                  NaN
# Boxes                                 NaN                  NaN
# BusSv                                 NaN                  NaN
# CMA                                   NaN                  NaN
# Chems                                 NaN                  NaN
# Chips                                 NaN                  NaN
# Clths                                 NaN                  NaN
# Cnstr                                 NaN                  NaN
# Coal                                  NaN                  NaN
# Comps                                 NaN                  NaN
# Drugs                                 NaN                  NaN
# ElcEq                                 NaN                  NaN
# FabPr                                 NaN                  NaN
# Fin                                   NaN                  NaN
# Food                                  NaN                  NaN
# Fun                                   NaN                  NaN
# Gold                                  NaN                  NaN
# Guns                                  NaN                  NaN
# HML                                   NaN                  NaN
# Hlth                                  NaN                  NaN
# Hshld                                 NaN                  NaN
# Insur                                 NaN                  NaN
# LabEq                                 NaN                  NaN
# MGMT                            -0.007084             0.026407
# ...                                   ...                  ...
# portf_me_resid11_12                   NaN                  NaN
# portf_me_resid11_6                    NaN                  NaN
# portf_me_resid6_12                    NaN                  NaN
# portf_me_resid6_6                     NaN                  NaN
# portf_me_rev_1                        NaN                  NaN
# portf_me_rev_12                       NaN                  NaN
# portf_me_rev_6                        NaN                  NaN
# portf_me_rnaq_1                       NaN                  NaN
# portf_me_rnaq_6                       NaN                  NaN
# portf_me_roa_1                        NaN                  NaN
# portf_me_roe_1                        NaN                  NaN
# portf_me_roe_6                        NaN                  NaN
# portf_me_rs_1                         NaN                  NaN
# portf_me_sgq_1                        NaN                  NaN
# portf_me_sim_1                        NaN                  NaN
# portf_me_sm_1                         NaN                  NaN
# portf_me_sm_12                        NaN                  NaN
# portf_me_sp                           NaN                  NaN
# portf_me_spq_1                        NaN                  NaN
# portf_me_spq_12                       NaN                  NaN
# portf_me_spq_6                        NaN                  NaN
# portf_me_srev                         NaN                  NaN
# portf_me_sue_1                        NaN                  NaN
# portf_me_sue_6                        NaN                  NaN
# portf_me_sv_1                         NaN                  NaN
# portf_me_ta                           NaN                  NaN
# portf_me_tbiq_12                      NaN                  NaN
# portf_me_tv_1                         NaN                  NaN
# portf_me_vfp                          NaN                  NaN
# portf_me_vhp                          NaN                  NaN
#
#                      stambaugh_yuan_NN_ls  stambaugh_yuan_NN_s  \
# Aero                                  NaN                  NaN
# Agric                                 NaN                  NaN
# Autos                                 NaN                  NaN
# Banks                                 NaN                  NaN
# Beer                                  NaN                  NaN
# BldMt                                 NaN                  NaN
# Books                                 NaN                  NaN
# Boxes                                 NaN                  NaN
# BusSv                                 NaN                  NaN
# CMA                                   NaN                  NaN
# Chems                                 NaN                  NaN
# Chips                                 NaN                  NaN
# Clths                                 NaN                  NaN
# Cnstr                                 NaN                  NaN
# Coal                                  NaN                  NaN
# Comps                                 NaN                  NaN
# Drugs                                 NaN                  NaN
# ElcEq                                 NaN                  NaN
# FabPr                                 NaN                  NaN
# Fin                                   NaN                  NaN
# Food                                  NaN                  NaN
# Fun                                   NaN                  NaN
# Gold                                  NaN                  NaN
# Guns                                  NaN                  NaN
# HML                                   NaN                  NaN
# Hlth                                  NaN                  NaN
# Hshld                                 NaN                  NaN
# Insur                                 NaN                  NaN
# LabEq                                 NaN                  NaN
# MGMT                             0.034134             -0.01023
# ...                                   ...                  ...
# portf_me_resid11_12                   NaN                  NaN
# portf_me_resid11_6                    NaN                  NaN
# portf_me_resid6_12                    NaN                  NaN
# portf_me_resid6_6                     NaN                  NaN
# portf_me_rev_1                        NaN                  NaN
# portf_me_rev_12                       NaN                  NaN
# portf_me_rev_6                        NaN                  NaN
# portf_me_rnaq_1                       NaN                  NaN
# portf_me_rnaq_6                       NaN                  NaN
# portf_me_roa_1                        NaN                  NaN
# portf_me_roe_1                        NaN                  NaN
# portf_me_roe_6                        NaN                  NaN
# portf_me_rs_1                         NaN                  NaN
# portf_me_sgq_1                        NaN                  NaN
# portf_me_sim_1                        NaN                  NaN
# portf_me_sm_1                         NaN                  NaN
# portf_me_sm_12                        NaN                  NaN
# portf_me_sp                           NaN                  NaN
# portf_me_spq_1                        NaN                  NaN
# portf_me_spq_12                       NaN                  NaN
# portf_me_spq_6                        NaN                  NaN
# portf_me_srev                         NaN                  NaN
# portf_me_sue_1                        NaN                  NaN
# portf_me_sue_6                        NaN                  NaN
# portf_me_sv_1                         NaN                  NaN
# portf_me_ta                           NaN                  NaN
# portf_me_tbiq_12                      NaN                  NaN
# portf_me_tv_1                         NaN                  NaN
# portf_me_vfp                          NaN                  NaN
# portf_me_vhp                          NaN                  NaN
#
#                      stambaugh_yuan_RF_l  stambaugh_yuan_RF_ls  \
# Aero                                 NaN                   NaN
# Agric                                NaN                   NaN
# Autos                                NaN                   NaN
# Banks                                NaN                   NaN
# Beer                                 NaN                   NaN
# BldMt                                NaN                   NaN
# Books                                NaN                   NaN
# Boxes                                NaN                   NaN
# BusSv                                NaN                   NaN
# CMA                                  NaN                   NaN
# Chems                                NaN                   NaN
# Chips                                NaN                   NaN
# Clths                                NaN                   NaN
# Cnstr                                NaN                   NaN
# Coal                                 NaN                   NaN
# Comps                                NaN                   NaN
# Drugs                                NaN                   NaN
# ElcEq                                NaN                   NaN
# FabPr                                NaN                   NaN
# Fin                                  NaN                   NaN
# Food                                 NaN                   NaN
# Fun                                  NaN                   NaN
# Gold                                 NaN                   NaN
# Guns                                 NaN                   NaN
# HML                                  NaN                   NaN
# Hlth                                 NaN                   NaN
# Hshld                                NaN                   NaN
# Insur                                NaN                   NaN
# LabEq                                NaN                   NaN
# MGMT                             0.02155             -0.004436
# ...                                  ...                   ...
# portf_me_resid11_12                  NaN                   NaN
# portf_me_resid11_6                   NaN                   NaN
# portf_me_resid6_12                   NaN                   NaN
# portf_me_resid6_6                    NaN                   NaN
# portf_me_rev_1                       NaN                   NaN
# portf_me_rev_12                      NaN                   NaN
# portf_me_rev_6                       NaN                   NaN
# portf_me_rnaq_1                      NaN                   NaN
# portf_me_rnaq_6                      NaN                   NaN
# portf_me_roa_1                       NaN                   NaN
# portf_me_roe_1                       NaN                   NaN
# portf_me_roe_6                       NaN                   NaN
# portf_me_rs_1                        NaN                   NaN
# portf_me_sgq_1                       NaN                   NaN
# portf_me_sim_1                       NaN                   NaN
# portf_me_sm_1                        NaN                   NaN
# portf_me_sm_12                       NaN                   NaN
# portf_me_sp                          NaN                   NaN
# portf_me_spq_1                       NaN                   NaN
# portf_me_spq_12                      NaN                   NaN
# portf_me_spq_6                       NaN                   NaN
# portf_me_srev                        NaN                   NaN
# portf_me_sue_1                       NaN                   NaN
# portf_me_sue_6                       NaN                   NaN
# portf_me_sv_1                        NaN                   NaN
# portf_me_ta                          NaN                   NaN
# portf_me_tbiq_12                     NaN                   NaN
# portf_me_tv_1                        NaN                   NaN
# portf_me_vfp                         NaN                   NaN
# portf_me_vhp                         NaN                   NaN
#
#                      stambaugh_yuan_RF_s  stambaugh_yuan_simp_binary_ls
# Aero                                 NaN                            NaN
# Agric                                NaN                            NaN
# Autos                                NaN                            NaN
# Banks                                NaN                            NaN
# Beer                                 NaN                            NaN
# BldMt                                NaN                            NaN
# Books                                NaN                            NaN
# Boxes                                NaN                            NaN
# BusSv                                NaN                            NaN
# CMA                                  NaN                            NaN
# Chems                                NaN                            NaN
# Chips                                NaN                            NaN
# Clths                                NaN                            NaN
# Cnstr                                NaN                            NaN
# Coal                                 NaN                            NaN
# Comps                                NaN                            NaN
# Drugs                                NaN                            NaN
# ElcEq                                NaN                            NaN
# FabPr                                NaN                            NaN
# Fin                                  NaN                            NaN
# Food                                 NaN                            NaN
# Fun                                  NaN                            NaN
# Gold                                 NaN                            NaN
# Guns                                 NaN                            NaN
# HML                                  NaN                            NaN
# Hlth                                 NaN                            NaN
# Hshld                                NaN                            NaN
# Insur                                NaN                            NaN
# LabEq                                NaN                            NaN
# MGMT                           -0.023601                      -0.028504
# ...                                  ...                            ...
# portf_me_resid11_12                  NaN                            NaN
# portf_me_resid11_6                   NaN                            NaN
# portf_me_resid6_12                   NaN                            NaN
# portf_me_resid6_6                    NaN                            NaN
# portf_me_rev_1                       NaN                            NaN
# portf_me_rev_12                      NaN                            NaN
# portf_me_rev_6                       NaN                            NaN
# portf_me_rnaq_1                      NaN                            NaN
# portf_me_rnaq_6                      NaN                            NaN
# portf_me_roa_1                       NaN                            NaN
# portf_me_roe_1                       NaN                            NaN
# portf_me_roe_6                       NaN                            NaN
# portf_me_rs_1                        NaN                            NaN
# portf_me_sgq_1                       NaN                            NaN
# portf_me_sim_1                       NaN                            NaN
# portf_me_sm_1                        NaN                            NaN
# portf_me_sm_12                       NaN                            NaN
# portf_me_sp                          NaN                            NaN
# portf_me_spq_1                       NaN                            NaN
# portf_me_spq_12                      NaN                            NaN
# portf_me_spq_6                       NaN                            NaN
# portf_me_srev                        NaN                            NaN
# portf_me_sue_1                       NaN                            NaN
# portf_me_sue_6                       NaN                            NaN
# portf_me_sv_1                        NaN                            NaN
# portf_me_ta                          NaN                            NaN
# portf_me_tbiq_12                     NaN                            NaN
# portf_me_tv_1                        NaN                            NaN
# portf_me_vfp                         NaN                            NaN
# portf_me_vhp                         NaN                            NaN
#
# [250 rows x 47 columns]
#                      anomaly_size_control_KNN_l  anomaly_size_control_KNN_ls  \
# Aero                                        NaN                          NaN
# Agric                                       NaN                          NaN
# Autos                                       NaN                          NaN
# Banks                                       NaN                          NaN
# Beer                                        NaN                          NaN
# BldMt                                       NaN                          NaN
# Books                                       NaN                          NaN
# Boxes                                       NaN                          NaN
# BusSv                                       NaN                          NaN
# CMA                                         NaN                          NaN
# Chems                                       NaN                          NaN
# Chips                                       NaN                          NaN
# Clths                                       NaN                          NaN
# Cnstr                                       NaN                          NaN
# Coal                                        NaN                          NaN
# Comps                                       NaN                          NaN
# Drugs                                       NaN                          NaN
# ElcEq                                       NaN                          NaN
# FabPr                                       NaN                          NaN
# Fin                                         NaN                          NaN
# Food                                        NaN                          NaN
# Fun                                         NaN                          NaN
# Gold                                        NaN                          NaN
# Guns                                        NaN                          NaN
# HML                                         NaN                          NaN
# Hlth                                        NaN                          NaN
# Hshld                                       NaN                          NaN
# Insur                                       NaN                          NaN
# LabEq                                       NaN                          NaN
# MGMT                                        NaN                          NaN
# ...                                         ...                          ...
# portf_me_resid11_12                    0.579250                     0.745346
# portf_me_resid11_6                     0.670586                     0.503382
# portf_me_resid6_12                     0.393388                     0.242847
# portf_me_resid6_6                      0.873343                     0.394457
# portf_me_rev_1                         0.536183                     0.732341
# portf_me_rev_12                        0.695381                     0.704832
# portf_me_rev_6                         0.605877                     0.827322
# portf_me_rnaq_1                        0.104827                     0.517775
# portf_me_rnaq_6                        0.467745                     0.916968
# portf_me_roa_1                         0.273152                     0.824673
# portf_me_roe_1                         0.551487                     0.614110
# portf_me_roe_6                         0.373152                     0.132331
# portf_me_rs_1                          0.364215                     0.435406
# portf_me_sgq_1                         0.721556                     0.076684
# portf_me_sim_1                         0.016580                     0.032498
# portf_me_sm_1                          0.806319                     0.905805
# portf_me_sm_12                         0.831144                     0.745476
# portf_me_sp                            0.145698                     0.204323
# portf_me_spq_1                         0.569323                     0.142665
# portf_me_spq_12                        0.482480                     0.904390
# portf_me_spq_6                         0.958304                     0.282474
# portf_me_srev                          0.246681                     0.908892
# portf_me_sue_1                         0.437149                     0.613240
# portf_me_sue_6                         0.457052                     0.009054
# portf_me_sv_1                          0.022014                     0.074247
# portf_me_ta                            0.403207                     0.758556
# portf_me_tbiq_12                       0.537043                     0.409949
# portf_me_tv_1                          0.099847                     0.092551
# portf_me_vfp                           0.385067                     0.087698
# portf_me_vhp                           0.726484                     0.617374
#
#                      anomaly_size_control_KNN_s  ff5_ensemble_ls  ff5_KNN_l  \
# Aero                                        NaN              NaN        NaN
# Agric                                       NaN              NaN        NaN
# Autos                                       NaN              NaN        NaN
# Banks                                       NaN              NaN        NaN
# Beer                                        NaN              NaN        NaN
# BldMt                                       NaN              NaN        NaN
# Books                                       NaN              NaN        NaN
# Boxes                                       NaN              NaN        NaN
# BusSv                                       NaN              NaN        NaN
# CMA                                         NaN         0.787683   0.758639
# Chems                                       NaN              NaN        NaN
# Chips                                       NaN              NaN        NaN
# Clths                                       NaN              NaN        NaN
# Cnstr                                       NaN              NaN        NaN
# Coal                                        NaN              NaN        NaN
# Comps                                       NaN              NaN        NaN
# Drugs                                       NaN              NaN        NaN
# ElcEq                                       NaN              NaN        NaN
# FabPr                                       NaN              NaN        NaN
# Fin                                         NaN              NaN        NaN
# Food                                        NaN              NaN        NaN
# Fun                                         NaN              NaN        NaN
# Gold                                        NaN              NaN        NaN
# Guns                                        NaN              NaN        NaN
# HML                                         NaN         0.159333   0.229670
# Hlth                                        NaN              NaN        NaN
# Hshld                                       NaN              NaN        NaN
# Insur                                       NaN              NaN        NaN
# LabEq                                       NaN              NaN        NaN
# MGMT                                        NaN              NaN        NaN
# ...                                         ...              ...        ...
# portf_me_resid11_12                    0.379200              NaN        NaN
# portf_me_resid11_6                     0.972306              NaN        NaN
# portf_me_resid6_12                     0.849146              NaN        NaN
# portf_me_resid6_6                      0.812161              NaN        NaN
# portf_me_rev_1                         0.561063              NaN        NaN
# portf_me_rev_12                        0.936501              NaN        NaN
# portf_me_rev_6                         0.725590              NaN        NaN
# portf_me_rnaq_1                        0.180760              NaN        NaN
# portf_me_rnaq_6                        0.118138              NaN        NaN
# portf_me_roa_1                         0.726277              NaN        NaN
# portf_me_roe_1                         0.049138              NaN        NaN
# portf_me_roe_6                         0.467621              NaN        NaN
# portf_me_rs_1                          0.000139              NaN        NaN
# portf_me_sgq_1                         0.258900              NaN        NaN
# portf_me_sim_1                         0.235013              NaN        NaN
# portf_me_sm_1                          0.266049              NaN        NaN
# portf_me_sm_12                         0.658533              NaN        NaN
# portf_me_sp                            0.498123              NaN        NaN
# portf_me_spq_1                         0.044952              NaN        NaN
# portf_me_spq_12                        0.173209              NaN        NaN
# portf_me_spq_6                         0.005573              NaN        NaN
# portf_me_srev                          0.175870              NaN        NaN
# portf_me_sue_1                         0.163778              NaN        NaN
# portf_me_sue_6                         0.004618              NaN        NaN
# portf_me_sv_1                          0.311865              NaN        NaN
# portf_me_ta                            0.943119              NaN        NaN
# portf_me_tbiq_12                       0.005029              NaN        NaN
# portf_me_tv_1                          0.080715              NaN        NaN
# portf_me_vfp                           0.025256              NaN        NaN
# portf_me_vhp                           0.653225              NaN        NaN
#
#                      ff5_KNN_ls  ff5_KNN_s  ff5_NN_l  ff5_NN_ls  ff5_NN_s  \
# Aero                        NaN        NaN       NaN        NaN       NaN
# Agric                       NaN        NaN       NaN        NaN       NaN
# Autos                       NaN        NaN       NaN        NaN       NaN
# ...
# Cnstr                                 NaN                  NaN
# Coal                                  NaN                  NaN
# Comps                                 NaN                  NaN
# Drugs                                 NaN                  NaN
# ElcEq                                 NaN                  NaN
# FabPr                                 NaN                  NaN
# Fin                                   NaN                  NaN
# Food                                  NaN                  NaN
# Fun                                   NaN                  NaN
# Gold                                  NaN                  NaN
# Guns                                  NaN                  NaN
# HML                                   NaN                  NaN
# Hlth                                  NaN                  NaN
# Hshld                                 NaN                  NaN
# Insur                                 NaN                  NaN
# LabEq                                 NaN                  NaN
# MGMT                             0.801898             0.082608
# ...                                   ...                  ...
# portf_me_resid11_12                   NaN                  NaN
# portf_me_resid11_6                    NaN                  NaN
# portf_me_resid6_12                    NaN                  NaN
# portf_me_resid6_6                     NaN                  NaN
# portf_me_rev_1                        NaN                  NaN
# portf_me_rev_12                       NaN                  NaN
# portf_me_rev_6                        NaN                  NaN
# portf_me_rnaq_1                       NaN                  NaN
# portf_me_rnaq_6                       NaN                  NaN
# portf_me_roa_1                        NaN                  NaN
# portf_me_roe_1                        NaN                  NaN
# portf_me_roe_6                        NaN                  NaN
# portf_me_rs_1                         NaN                  NaN
# portf_me_sgq_1                        NaN                  NaN
# portf_me_sim_1                        NaN                  NaN
# portf_me_sm_1                         NaN                  NaN
# portf_me_sm_12                        NaN                  NaN
# portf_me_sp                           NaN                  NaN
# portf_me_spq_1                        NaN                  NaN
# portf_me_spq_12                       NaN                  NaN
# portf_me_spq_6                        NaN                  NaN
# portf_me_srev                         NaN                  NaN
# portf_me_sue_1                        NaN                  NaN
# portf_me_sue_6                        NaN                  NaN
# portf_me_sv_1                         NaN                  NaN
# portf_me_ta                           NaN                  NaN
# portf_me_tbiq_12                      NaN                  NaN
# portf_me_tv_1                         NaN                  NaN
# portf_me_vfp                          NaN                  NaN
# portf_me_vhp                          NaN                  NaN
#
#                      stambaugh_yuan_NN_ls  stambaugh_yuan_NN_s  \
# Aero                                  NaN                  NaN
# Agric                                 NaN                  NaN
# Autos                                 NaN                  NaN
# Banks                                 NaN                  NaN
# Beer                                  NaN                  NaN
# BldMt                                 NaN                  NaN
# Books                                 NaN                  NaN
# Boxes                                 NaN                  NaN
# BusSv                                 NaN                  NaN
# CMA                                   NaN                  NaN
# Chems                                 NaN                  NaN
# Chips                                 NaN                  NaN
# Clths                                 NaN                  NaN
# Cnstr                                 NaN                  NaN
# Coal                                  NaN                  NaN
# Comps                                 NaN                  NaN
# Drugs                                 NaN                  NaN
# ElcEq                                 NaN                  NaN
# FabPr                                 NaN                  NaN
# Fin                                   NaN                  NaN
# Food                                  NaN                  NaN
# Fun                                   NaN                  NaN
# Gold                                  NaN                  NaN
# Guns                                  NaN                  NaN
# HML                                   NaN                  NaN
# Hlth                                  NaN                  NaN
# Hshld                                 NaN                  NaN
# Insur                                 NaN                  NaN
# LabEq                                 NaN                  NaN
# MGMT                             0.078983             0.821461
# ...                                   ...                  ...
# portf_me_resid11_12                   NaN                  NaN
# portf_me_resid11_6                    NaN                  NaN
# portf_me_resid6_12                    NaN                  NaN
# portf_me_resid6_6                     NaN                  NaN
# portf_me_rev_1                        NaN                  NaN
# portf_me_rev_12                       NaN                  NaN
# portf_me_rev_6                        NaN                  NaN
# portf_me_rnaq_1                       NaN                  NaN
# portf_me_rnaq_6                       NaN                  NaN
# portf_me_roa_1                        NaN                  NaN
# portf_me_roe_1                        NaN                  NaN
# portf_me_roe_6                        NaN                  NaN
# portf_me_rs_1                         NaN                  NaN
# portf_me_sgq_1                        NaN                  NaN
# portf_me_sim_1                        NaN                  NaN
# portf_me_sm_1                         NaN                  NaN
# portf_me_sm_12                        NaN                  NaN
# portf_me_sp                           NaN                  NaN
# portf_me_spq_1                        NaN                  NaN
# portf_me_spq_12                       NaN                  NaN
# portf_me_spq_6                        NaN                  NaN
# portf_me_srev                         NaN                  NaN
# portf_me_sue_1                        NaN                  NaN
# portf_me_sue_6                        NaN                  NaN
# portf_me_sv_1                         NaN                  NaN
# portf_me_ta                           NaN                  NaN
# portf_me_tbiq_12                      NaN                  NaN
# portf_me_tv_1                         NaN                  NaN
# portf_me_vfp                          NaN                  NaN
# portf_me_vhp                          NaN                  NaN
#
#                      stambaugh_yuan_RF_l  stambaugh_yuan_RF_ls  \
# Aero                                 NaN                   NaN
# Agric                                NaN                   NaN
# Autos                                NaN                   NaN
# Banks                                NaN                   NaN
# Beer                                 NaN                   NaN
# BldMt                                NaN                   NaN
# Books                                NaN                   NaN
# Boxes                                NaN                   NaN
# BusSv                                NaN                   NaN
# CMA                                  NaN                   NaN
# Chems                                NaN                   NaN
# Chips                                NaN                   NaN
# Clths                                NaN                   NaN
# Cnstr                                NaN                   NaN
# Coal                                 NaN                   NaN
# Comps                                NaN                   NaN
# Drugs                                NaN                   NaN
# ElcEq                                NaN                   NaN
# FabPr                                NaN                   NaN
# Fin                                  NaN                   NaN
# Food                                 NaN                   NaN
# Fun                                  NaN                   NaN
# Gold                                 NaN                   NaN
# Guns                                 NaN                   NaN
# HML                                  NaN                   NaN
# Hlth                                 NaN                   NaN
# Hshld                                NaN                   NaN
# Insur                                NaN                   NaN
# LabEq                                NaN                   NaN
# MGMT                            0.299846              0.841129
# ...                                  ...                   ...
# portf_me_resid11_12                  NaN                   NaN
# portf_me_resid11_6                   NaN                   NaN
# portf_me_resid6_12                   NaN                   NaN
# portf_me_resid6_6                    NaN                   NaN
# portf_me_rev_1                       NaN                   NaN
# portf_me_rev_12                      NaN                   NaN
# portf_me_rev_6                       NaN                   NaN
# portf_me_rnaq_1                      NaN                   NaN
# portf_me_rnaq_6                      NaN                   NaN
# portf_me_roa_1                       NaN                   NaN
# portf_me_roe_1                       NaN                   NaN
# portf_me_roe_6                       NaN                   NaN
# portf_me_rs_1                        NaN                   NaN
# portf_me_sgq_1                       NaN                   NaN
# portf_me_sim_1                       NaN                   NaN
# portf_me_sm_1                        NaN                   NaN
# portf_me_sm_12                       NaN                   NaN
# portf_me_sp                          NaN                   NaN
# portf_me_spq_1                       NaN                   NaN
# portf_me_spq_12                      NaN                   NaN
# portf_me_spq_6                       NaN                   NaN
# portf_me_srev                        NaN                   NaN
# portf_me_sue_1                       NaN                   NaN
# portf_me_sue_6                       NaN                   NaN
# portf_me_sv_1                        NaN                   NaN
# portf_me_ta                          NaN                   NaN
# portf_me_tbiq_12                     NaN                   NaN
# portf_me_tv_1                        NaN                   NaN
# portf_me_vfp                         NaN                   NaN
# portf_me_vhp                         NaN                   NaN
#
#                      stambaugh_yuan_RF_s  stambaugh_yuan_simp_binary_ls
# Aero                                 NaN                            NaN
# Agric                                NaN                            NaN
# Autos                                NaN                            NaN
# Banks                                NaN                            NaN
# Beer                                 NaN                            NaN
# BldMt                                NaN                            NaN
# Books                                NaN                            NaN
# Boxes                                NaN                            NaN
# BusSv                                NaN                            NaN
# CMA                                  NaN                            NaN
# Chems                                NaN                            NaN
# Chips                                NaN                            NaN
# Clths                                NaN                            NaN
# Cnstr                                NaN                            NaN
# Coal                                 NaN                            NaN
# Comps                                NaN                            NaN
# Drugs                                NaN                            NaN
# ElcEq                                NaN                            NaN
# FabPr                                NaN                            NaN
# Fin                                  NaN                            NaN
# Food                                 NaN                            NaN
# Fun                                  NaN                            NaN
# Gold                                 NaN                            NaN
# Guns                                 NaN                            NaN
# HML                                  NaN                            NaN
# Hlth                                 NaN                            NaN
# Hshld                                NaN                            NaN
# Insur                                NaN                            NaN
# LabEq                                NaN                            NaN
# MGMT                            0.302137                       0.226552
# ...                                  ...                            ...
# portf_me_resid11_12                  NaN                            NaN
# portf_me_resid11_6                   NaN                            NaN
# portf_me_resid6_12                   NaN                            NaN
# portf_me_resid6_6                    NaN                            NaN
# portf_me_rev_1                       NaN                            NaN
# portf_me_rev_12                      NaN                            NaN
# portf_me_rev_6                       NaN                            NaN
# portf_me_rnaq_1                      NaN                            NaN
# portf_me_rnaq_6                      NaN                            NaN
# portf_me_roa_1                       NaN                            NaN
# portf_me_roe_1                       NaN                            NaN
# portf_me_roe_6                       NaN                            NaN
# portf_me_rs_1                        NaN                            NaN
# portf_me_sgq_1                       NaN                            NaN
# portf_me_sim_1                       NaN                            NaN
# portf_me_sm_1                        NaN                            NaN
# portf_me_sm_12                       NaN                            NaN
# portf_me_sp                          NaN                            NaN
# portf_me_spq_1                       NaN                            NaN
# portf_me_spq_12                      NaN                            NaN
# portf_me_spq_6                       NaN                            NaN
# portf_me_srev                        NaN                            NaN
# portf_me_sue_1                       NaN                            NaN
# portf_me_sue_6                       NaN                            NaN
# portf_me_sv_1                        NaN                            NaN
# portf_me_ta                          NaN                            NaN
# portf_me_tbiq_12                     NaN                            NaN
# portf_me_tv_1                        NaN                            NaN
# portf_me_vfp                         NaN                            NaN
# portf_me_vhp                         NaN                            NaN
#
# [250 rows x 47 columns]

# %%
mean_check = pd.DataFrame()

over_zero_df = {}
for col in all_mean.columns:
    check = all_mean[col].dropna()
    over_zero_df[col] = round(check.mean() * 100.0,2)

over_zero_df = pd.DataFrame.from_dict(over_zero_df, orient = 'index')
over_zero_df.columns = ['mean']
over_zero_df.to_csv(os.path.join(backtest_directory, 'outputs', 'mean_ret.csv'))
mean_check = over_zero_df.copy()

over_zero_df = {}
for col in all_downside_mean.columns:
    check = all_downside_mean[col].dropna()
    over_zero_df[col] = round(check.mean() * 100.0,2)

over_zero_df = pd.DataFrame.from_dict(over_zero_df, orient = 'index')
over_zero_df.columns = ['downside mean']
over_zero_df.to_csv(os.path.join(backtest_directory, 'outputs', 'downside_mean.csv'))
mean_check = pd.concat([mean_check, over_zero_df], axis = 1)

over_zero_df = {}
for col in all_market_downside_mean.columns:
    check = all_market_downside_mean[col].dropna()
    over_zero_df[col] = round(check.mean() * 100.0,2)

over_zero_df = pd.DataFrame.from_dict(over_zero_df, orient = 'index')
over_zero_df.columns = ['downside market mean']
over_zero_df.to_csv(os.path.join(backtest_directory, 'outputs', 'downside_mkt_mean.csv'))
mean_check = pd.concat([mean_check, over_zero_df], axis = 1)


print(mean_check)
# Out:
#                                mean  downside mean  downside market mean
# anomaly_size_control_KNN_l     1.00           1.10                 -3.73
# anomaly_size_control_KNN_ls    1.01           1.02                 -3.73
# anomaly_size_control_KNN_s    -1.92          -0.63                 -3.71
# ff5_ensemble_ls                2.05           0.14                 -3.70
# ff5_KNN_l                      1.64          -0.11                 -3.66
# ff5_KNN_ls                     0.82           0.16                 -3.70
# ff5_KNN_s                      0.56           0.50                 -3.75
# ff5_NN_l                       1.06          -0.11                 -3.68
# ff5_NN_ls                      1.85           0.12                 -3.70
# ff5_NN_s                       0.19           0.77                 -3.74
# ff5_RF_l                       1.82           0.02                 -3.75
# ff5_RF_ls                      1.92           0.26                 -3.70
# ff5_RF_s                       0.79           0.69                 -3.68
# ff5_simp_binary_ls             0.39          -0.09                 -3.70
# industry_ensemble_ls           0.15          -1.35                 -3.70
# industry_KNN_l                 0.58          -3.26                 -3.61
# industry_KNN_ls               -0.78          -0.56                 -3.70
# industry_KNN_s                 0.05           3.59                 -3.86
# industry_NN_l                  0.59          -3.10                 -3.52
# industry_NN_ls                 0.99          -1.54                 -3.70
# industry_NN_s                 -0.09           4.59                 -4.49
# industry_RF_l                 -0.25          -3.00                 -3.47
# industry_RF_ls                 0.14          -0.19                 -3.70
# industry_RF_s                 -1.56           4.01                 -4.07
# industry_simp_binary_ls        2.16          -0.61                 -3.71
# q_factor_ensemble_ls           0.88           0.35                 -3.72
# q_factor_KNN_l                 0.00          -0.09                 -3.66
# q_factor_KNN_ls                0.25           0.29                 -3.72
# q_factor_KNN_s                 0.00           0.18                 -3.77
# q_factor_NN_l                  0.00           0.00                 -3.67
# q_factor_NN_ls                 0.81           0.35                 -3.72
# q_factor_NN_s                 -0.00           0.64                 -3.53
# q_factor_RF_l                 -0.00           0.07                 -3.64
# q_factor_RF_ls                 0.75           0.47                 -3.72
# q_factor_RF_s                 -0.00           0.45                 -3.69
# q_factor_simp_binary_ls        0.17           0.10                 -3.71
# stambaugh_yuan_ensemble_ls     1.52           0.41                 -3.68
# stambaugh_yuan_KNN_l           2.74           0.20                 -3.72
# stambaugh_yuan_KNN_ls          0.69           0.52                 -3.68
# stambaugh_yuan_KNN_s          -1.03           0.52                 -3.56
# stambaugh_yuan_NN_l            2.20           0.10                 -3.71
# stambaugh_yuan_NN_ls           2.48           0.36                 -3.68
# stambaugh_yuan_NN_s           -2.85           0.73                 -3.41
# stambaugh_yuan_RF_l            2.52           0.20                 -3.70
# stambaugh_yuan_RF_ls           1.46           0.41                 -3.68
# stambaugh_yuan_RF_s           -1.64           0.46                 -3.62
# stambaugh_yuan_simp_binary_ls  0.36           0.24                 -3.68

# %%
over_zero_df = {}
for col in all_p.columns:
    check = all_p[col].dropna()
    over_zero_df[col] = check.mean()

over_zero_df = pd.DataFrame.from_dict(over_zero_df, orient = 'index')
over_zero_df.columns = ['mean']
print(over_zero_df)
over_zero_df.to_csv(os.path.join(backtest_directory, 'outputs', 'p_mean.csv'))
# Out:
#                                    mean
# anomaly_size_control_KNN_l     0.364775
# anomaly_size_control_KNN_ls    0.474332
# anomaly_size_control_KNN_s     0.395868
# ff5_ensemble_ls                0.346955
# ff5_KNN_l                      0.303370
# ff5_KNN_ls                     0.606266
# ff5_KNN_s                      0.581728
# ff5_NN_l                       0.348094
# ff5_NN_ls                      0.397980
# ff5_NN_s                       0.676750
# ff5_RF_l                       0.399491
# ff5_RF_ls                      0.186018
# ff5_RF_s                       0.487364
# ff5_simp_binary_ls             0.329227
# industry_ensemble_ls           0.510891
# industry_KNN_l                 0.544735
# industry_KNN_ls                0.503216
# industry_KNN_s                 0.503977
# industry_NN_l                  0.505833
# industry_NN_ls                 0.575043
# industry_NN_s                  0.537053
# industry_RF_l                  0.501350
# industry_RF_ls                 0.532898
# industry_RF_s                  0.456801
# industry_simp_binary_ls        0.495721
# q_factor_ensemble_ls           0.458298
# q_factor_KNN_l                 0.000001
# q_factor_KNN_ls                0.540896
# q_factor_KNN_s                 0.004220
# q_factor_NN_l                  0.182533
# q_factor_NN_ls                 0.565356
# q_factor_NN_s                  0.000785
# q_factor_RF_l                  0.000002
# q_factor_RF_ls                 0.363500
# q_factor_RF_s                  0.000134
# q_factor_simp_binary_ls        0.679813
# stambaugh_yuan_ensemble_ls     0.667625
# stambaugh_yuan_KNN_l           0.130627
# stambaugh_yuan_KNN_ls          0.711315
# stambaugh_yuan_KNN_s           0.572881
# stambaugh_yuan_NN_l            0.179855
# stambaugh_yuan_NN_ls           0.412485
# stambaugh_yuan_NN_s            0.397525
# stambaugh_yuan_RF_l            0.326638
# stambaugh_yuan_RF_ls           0.567528
# stambaugh_yuan_RF_s            0.517670
# stambaugh_yuan_simp_binary_ls  0.536487

# %%
over_zero_df = {}
for col in all_alphas.columns:
    check = all_alphas[col].dropna()
    over_zero_df[col] = round(check.mean() * 100.0,2)

over_zero_df = pd.DataFrame.from_dict(over_zero_df, orient = 'index')
over_zero_df.columns = ['mean']
print(over_zero_df)
over_zero_df.to_csv(os.path.join(backtest_directory, 'outputs', 'alpha_mean.csv'))
# Out:
#                                mean
# anomaly_size_control_KNN_l     3.00
# anomaly_size_control_KNN_ls    1.01
# anomaly_size_control_KNN_s    -1.92
# ff5_ensemble_ls                2.05
# ff5_KNN_l                      1.64
# ff5_KNN_ls                     0.82
# ff5_KNN_s                      0.56
# ff5_NN_l                       1.06
# ff5_NN_ls                      1.85
# ff5_NN_s                       0.19
# ff5_RF_l                       1.82
# ff5_RF_ls                      1.92
# ff5_RF_s                       0.79
# ff5_simp_binary_ls             0.39
# industry_ensemble_ls           0.15
# industry_KNN_l                 0.58
# industry_KNN_ls               -0.78
# industry_KNN_s                 0.05
# industry_NN_l                  0.59
# industry_NN_ls                 0.99
# industry_NN_s                 -0.09
# industry_RF_l                 -0.25
# industry_RF_ls                 0.14
# industry_RF_s                 -1.56
# industry_simp_binary_ls        2.16
# q_factor_ensemble_ls           0.88
# q_factor_KNN_l                 0.00
# q_factor_KNN_ls                0.25
# q_factor_KNN_s                 0.00
# q_factor_NN_l                  0.00
# q_factor_NN_ls                 0.81
# q_factor_NN_s                 -0.00
# q_factor_RF_l                 -0.00
# q_factor_RF_ls                 0.75
# q_factor_RF_s                 -0.00
# q_factor_simp_binary_ls        0.17
# stambaugh_yuan_ensemble_ls     1.52
# stambaugh_yuan_KNN_l           2.74
# stambaugh_yuan_KNN_ls          0.69
# stambaugh_yuan_KNN_s          -1.03
# stambaugh_yuan_NN_l            2.20
# stambaugh_yuan_NN_ls           2.48
# stambaugh_yuan_NN_s           -2.85
# stambaugh_yuan_RF_l            2.52
# stambaugh_yuan_RF_ls           1.46
# stambaugh_yuan_RF_s           -1.64
# stambaugh_yuan_simp_binary_ls  0.36

# %%
over_zero_df = {}
for col in all_p.columns:
    check = all_p[col].dropna()
    over_zero = check[check <0.05 ].count() / len(check.index)
    over_zero_df[col] = round(over_zero * 100.0,0)

over_zero_df = pd.DataFrame.from_dict(over_zero_df, orient = 'index')
over_zero_df.columns = ['percentage']
print(over_zero_df)
over_zero_df.to_csv(os.path.join(backtest_directory, 'outputs', 'p_sign.csv'))
# Out:
#                                percentage
# anomaly_size_control_KNN_l           22.0
# anomaly_size_control_KNN_ls           8.0
# anomaly_size_control_KNN_s           16.0
# ff5_ensemble_ls                       0.0
# ff5_KNN_l                            20.0
# ff5_KNN_ls                            0.0
# ff5_KNN_s                             0.0
# ff5_NN_l                             40.0
# ff5_NN_ls                            20.0
# ff5_NN_s                              0.0
# ff5_RF_l                             20.0
# ff5_RF_ls                            20.0
# ff5_RF_s                             20.0
# ff5_simp_binary_ls                   40.0
# industry_ensemble_ls                  2.0
# industry_KNN_l                        8.0
# industry_KNN_ls                       2.0
# industry_KNN_s                        6.0
# industry_NN_l                         2.0
# industry_NN_ls                        0.0
# industry_NN_s                         4.0
# industry_RF_l                         6.0
# industry_RF_ls                        2.0
# industry_RF_s                         4.0
# industry_simp_binary_ls               0.0
# q_factor_ensemble_ls                 20.0
# q_factor_KNN_l                      100.0
# q_factor_KNN_ls                       0.0
# q_factor_KNN_s                      100.0
# q_factor_NN_l                        80.0
# q_factor_NN_ls                        0.0
# q_factor_NN_s                       100.0
# q_factor_RF_l                       100.0
# q_factor_RF_ls                        0.0
# q_factor_RF_s                       100.0
# q_factor_simp_binary_ls               0.0
# stambaugh_yuan_ensemble_ls            0.0
# stambaugh_yuan_KNN_l                  0.0
# stambaugh_yuan_KNN_ls                 0.0
# stambaugh_yuan_KNN_s                  0.0
# stambaugh_yuan_NN_l                   0.0
# stambaugh_yuan_NN_ls                  0.0
# stambaugh_yuan_NN_s                   0.0
# stambaugh_yuan_RF_l                   0.0
# stambaugh_yuan_RF_ls                 25.0
# stambaugh_yuan_RF_s                  25.0
# stambaugh_yuan_simp_binary_ls         0.0

# %%
over_zero_df = {}
for col in all_alphas.columns:
    check = all_alphas[col].dropna()
    over_zero = check[check >0 ].count() / len(check.index)
    over_zero_df[col] = round(over_zero * 100.0,0)

over_zero_df = pd.DataFrame.from_dict(over_zero_df, orient = 'index')
over_zero_df.columns = ['percentage']
print(over_zero_df)
over_zero_df.to_csv(os.path.join(backtest_directory, 'outputs', 'over_zero_alpha.csv'))
# Out:
#                                percentage
# anomaly_size_control_KNN_l           64.0
# anomaly_size_control_KNN_ls          54.0
# anomaly_size_control_KNN_s           41.0
# ff5_ensemble_ls                      80.0
# ff5_KNN_l                           100.0
# ff5_KNN_ls                           40.0
# ff5_KNN_s                            20.0
# ff5_NN_l                            100.0
# ff5_NN_ls                           100.0
# ff5_NN_s                             80.0
# ff5_RF_l                            100.0
# ff5_RF_ls                            60.0
# ff5_RF_s                             60.0
# ff5_simp_binary_ls                   60.0
# industry_ensemble_ls                 58.0
# industry_KNN_l                       65.0
# industry_KNN_ls                      54.0
# industry_KNN_s                       48.0
# industry_NN_l                        60.0
# industry_NN_ls                       62.0
# industry_NN_s                        50.0
# industry_RF_l                        58.0
# industry_RF_ls                       54.0
# industry_RF_s                        38.0
# industry_simp_binary_ls              75.0
# q_factor_ensemble_ls                 80.0
# q_factor_KNN_l                       40.0
# q_factor_KNN_ls                      80.0
# q_factor_KNN_s                       40.0
# q_factor_NN_l                        80.0
# q_factor_NN_ls                       60.0
# q_factor_NN_s                        20.0
# q_factor_RF_l                        20.0
# q_factor_RF_ls                       40.0
# q_factor_RF_s                        20.0
# q_factor_simp_binary_ls              80.0
# stambaugh_yuan_ensemble_ls           75.0
# stambaugh_yuan_KNN_l                100.0
# stambaugh_yuan_KNN_ls                25.0
# stambaugh_yuan_KNN_s                 25.0
# stambaugh_yuan_NN_l                 100.0
# stambaugh_yuan_NN_ls                100.0
# stambaugh_yuan_NN_s                  25.0
# stambaugh_yuan_RF_l                 100.0
# stambaugh_yuan_RF_ls                 25.0
# stambaugh_yuan_RF_s                  25.0
# stambaugh_yuan_simp_binary_ls        75.0

# %%
out_combined
# Out:
#                               Mean return Mean return annualized std return  \
# anomaly_size_control_KNN_l         1.2165                14.5982     2.9832
# anomaly_size_control_KNN_ls        0.6329                 7.5953     2.2634
# anomaly_size_control_KNN_s         -0.153                -1.8355     2.3567
# ff5_ensemble_ls                    0.3553                 4.2632     1.4913
# ff5_KNN_l                          0.3895                 4.6745     1.8853
# ff5_KNN_ls                         0.1275                 1.5296      1.534
# ff5_KNN_s                          -0.169                -2.0284     2.3729
# ff5_NN_l                           0.4553                 5.4641     1.6414
# ff5_NN_ls                          0.3873                 4.6472      1.639
# ff5_NN_s                           0.1032                 1.2387     3.1281
# ff5_RF_l                           0.5102                 6.1224     2.0217
# ff5_RF_ls                          0.2744                 3.2933     1.6507
# ff5_RF_s                           0.0017                 0.0201     2.3789
# ff5_simp_binary_ls                  0.114                 1.3679     1.5481
# industry_ensemble_ls               0.6336                 7.6035     3.1139
# industry_KNN_l                     1.0774                12.9282      4.847
# industry_KNN_ls                    0.2078                 2.4933     2.7333
# industry_KNN_s                    -0.8229                 -9.875     5.0319
# industry_NN_l                      1.0474                12.5683     4.7262
# industry_NN_ls                     0.7365                 8.8379     3.5741
# industry_NN_s                     -0.5532                 -6.638     6.1444
# industry_RF_l                      1.1162                13.3945     4.8218
# industry_RF_ls                     0.3575                 4.2898     2.7449
# industry_RF_s                     -0.8554               -10.2645     5.2423
# industry_simp_binary_ls            0.3025                 3.6302     3.5241
# q_factor_ensemble_ls               0.4343                  5.211     1.3651
# q_factor_KNN_l                     0.5714                 6.8566     1.5798
# q_factor_KNN_ls                    0.2123                 2.5481     1.4942
# q_factor_KNN_s                     -0.357                -4.2838     2.6052
# q_factor_NN_l                      0.6046                 7.2555     1.3045
# q_factor_NN_ls                     0.4887                  5.864     1.3816
# q_factor_NN_s                     -0.0007                -0.0082     3.4358
# q_factor_RF_l                      0.6799                  8.159     1.5923
# q_factor_RF_ls                     0.3575                 4.2903     1.4566
# q_factor_RF_s                     -0.1491                -1.7891     2.4595
# q_factor_simp_binary_ls            0.1675                 2.0099     1.5282
# stambaugh_yuan_ensemble_ls         0.4336                 5.2028     2.0255
# stambaugh_yuan_KNN_l               0.6872                 8.2466     2.5457
# stambaugh_yuan_KNN_ls              0.3117                 3.7407     2.1004
# stambaugh_yuan_KNN_s              -0.3276                -3.9309      3.107
# stambaugh_yuan_NN_l                0.6476                 7.7718     1.8819
# stambaugh_yuan_NN_ls               0.4864                 5.8371     1.9784
# stambaugh_yuan_NN_s                -0.198                -2.3758     3.8266
# stambaugh_yuan_RF_l                0.6372                 7.6462      2.488
# stambaugh_yuan_RF_ls               0.2476                 2.9709     2.0711
# stambaugh_yuan_RF_s               -0.3173                -3.8072     3.1611
# stambaugh_yuan_simp_binary_ls      0.1992                 2.3905     2.1073
#
#                               std return annualized  \
# anomaly_size_control_KNN_l                  10.3342
# anomaly_size_control_KNN_ls                  7.8407
# anomaly_size_control_KNN_s                    8.164
# ff5_ensemble_ls                              5.1659
# ff5_KNN_l                                    6.5308
# ff5_KNN_ls                                    5.314
# ff5_KNN_s                                      8.22
# ff5_NN_l                                     5.6859
# ff5_NN_ls                                    5.6778
# ff5_NN_s                                    10.8361
# ff5_RF_l                                     7.0035
# ff5_RF_ls                                    5.7181
# ff5_RF_s                                     8.2407
# ff5_simp_binary_ls                           5.3629
# industry_ensemble_ls                        10.7869
# industry_KNN_l                              16.7905
# industry_KNN_ls                              9.4686
# industry_KNN_s                               17.431
# industry_NN_l                               16.3719
# industry_NN_ls                               12.381
# industry_NN_s                               21.2848
# industry_RF_l                               16.7033
# industry_RF_ls                               9.5085
# industry_RF_s                               18.1598
# industry_simp_binary_ls                      12.208
# q_factor_ensemble_ls                         4.7289
# q_factor_KNN_l                               5.4724
# q_factor_KNN_ls                              5.1759
# q_factor_KNN_s                               9.0246
# q_factor_NN_l                                4.5188
# q_factor_NN_ls                               4.7861
# q_factor_NN_s                               11.9019
# q_factor_RF_l                                5.5159
# q_factor_RF_ls                               5.0459
# q_factor_RF_s                                8.5201
# q_factor_simp_binary_ls                      5.2938
# stambaugh_yuan_ensemble_ls                   7.0165
# stambaugh_yuan_KNN_l                         8.8185
# stambaugh_yuan_KNN_ls                        7.2759
# stambaugh_yuan_KNN_s                        10.7628
# stambaugh_yuan_NN_l                           6.519
# stambaugh_yuan_NN_ls                         6.8535
# stambaugh_yuan_NN_s                         13.2556
# stambaugh_yuan_RF_l                          8.6187
# stambaugh_yuan_RF_ls                         7.1744
# stambaugh_yuan_RF_s                         10.9502
# stambaugh_yuan_simp_binary_ls                7.2997
#
#                               yearly window max drawdown       sharpe  \
# anomaly_size_control_KNN_l                        59.777      1.41261
# anomaly_size_control_KNN_ls                      42.1651     0.968702
# anomaly_size_control_KNN_s                       53.1886    -0.224829
# ff5_ensemble_ls                                   23.688     0.825258
# ff5_KNN_l                                          26.71     0.715762
# ff5_KNN_ls                                         25.84     0.287843
# ff5_KNN_s                                        36.6685    -0.246764
# ff5_NN_l                                          32.009     0.960991
# ff5_NN_ls                                         33.776     0.818486
# ff5_NN_s                                         39.6283     0.114312
# ff5_RF_l                                         36.9457     0.874191
# ff5_RF_ls                                         25.316     0.575943
# ff5_RF_s                                         36.0225   0.00243911
# ff5_simp_binary_ls                                19.354     0.255067
# industry_ensemble_ls                              37.219     0.704883
# industry_KNN_l                                   65.9353     0.769971
# industry_KNN_ls                                   39.576     0.263323
# industry_KNN_s                                    64.537    -0.566519
# industry_NN_l                                    60.6828     0.767675
# industry_NN_ls                                   37.8569     0.713828
# industry_NN_s                                    68.4213    -0.311866
# industry_RF_l                                     66.084     0.801907
# industry_RF_ls                                   36.5488     0.451154
# industry_RF_s                                    67.1258    -0.565232
# industry_simp_binary_ls                          58.3496     0.297362
# q_factor_ensemble_ls                             24.7388      1.10195
# q_factor_KNN_l                                   22.1974      1.25294
# q_factor_KNN_ls                                  20.0371     0.492301
# q_factor_KNN_s                                   35.1905     -0.47468
# q_factor_NN_l                                     21.681      1.60563
# q_factor_NN_ls                                   22.6982      1.22521
# q_factor_NN_s                                    45.9886 -0.000688966
# q_factor_RF_l                                     23.691      1.47918
# q_factor_RF_ls                                    24.636     0.850255
# q_factor_RF_s                                     34.421    -0.209986
# q_factor_simp_binary_ls                          17.0247     0.379671
# stambaugh_yuan_ensemble_ls                       36.7254     0.741509
# stambaugh_yuan_KNN_l                             39.9713     0.935148
# stambaugh_yuan_KNN_ls                            30.6776     0.514122
# stambaugh_yuan_KNN_s                             46.5942     -0.36523
# stambaugh_yuan_NN_l                               33.581      1.19218
# stambaugh_yuan_NN_ls                             31.1054     0.851696
# stambaugh_yuan_NN_s                                50.81     -0.17923
# stambaugh_yuan_RF_l                              51.6077     0.887164
# stambaugh_yuan_RF_ls                             31.3826     0.414097
# stambaugh_yuan_RF_s                              44.7236    -0.347683
# stambaugh_yuan_simp_binary_ls                    29.2319     0.327479
#
#                               downside mean return annualized  \
# anomaly_size_control_KNN_l                             1.6053
# anomaly_size_control_KNN_ls                            1.0235
# anomaly_size_control_KNN_s                               0.23
# ff5_ensemble_ls                                        0.1079
# ff5_KNN_l                                              -0.167
# ff5_KNN_ls                                             0.1181
# ff5_KNN_s                                              0.6258
# ff5_NN_l                                              -0.1368
# ff5_NN_ls                                              0.0882
# ff5_NN_s                                               0.8115
# ff5_RF_l                                              -0.0702
# ff5_RF_ls                                              0.2511
# ff5_RF_s                                               0.7222
# ff5_simp_binary_ls                                    -0.0891
# industry_ensemble_ls                                  -1.3842
# industry_KNN_l                                        -3.1682
# industry_KNN_ls                                       -0.6238
# industry_KNN_s                                         3.4445
# industry_NN_l                                         -3.1692
# industry_NN_ls                                        -1.5845
# industry_NN_s                                          3.6202
# industry_RF_l                                         -3.0819
# industry_RF_ls                                         -0.199
# industry_RF_s                                          3.6536
# industry_simp_binary_ls                               -0.6555
# q_factor_ensemble_ls                                   0.3398
# q_factor_KNN_l                                          0.179
# q_factor_KNN_ls                                        0.2801
# q_factor_KNN_s                                          0.625
# q_factor_NN_l                                          0.1814
# q_factor_NN_ls                                         0.3507
# q_factor_NN_s                                          1.4548
# q_factor_RF_l                                          0.3231
# q_factor_RF_ls                                         0.4596
# q_factor_RF_s                                          0.8743
# q_factor_simp_binary_ls                                0.0868
# stambaugh_yuan_ensemble_ls                             0.3694
# stambaugh_yuan_KNN_l                                   0.3508
# stambaugh_yuan_KNN_ls                                  0.4725
# stambaugh_yuan_KNN_s                                   0.7723
# stambaugh_yuan_NN_l                                    0.2715
# stambaugh_yuan_NN_ls                                    0.344
# stambaugh_yuan_NN_s                                    1.1009
# stambaugh_yuan_RF_l                                    0.2461
# stambaugh_yuan_RF_ls                                   0.3842
# stambaugh_yuan_RF_s                                    0.6973
# stambaugh_yuan_simp_binary_ls                          0.2121
#
#                               market downside mean return annualized  \
# anomaly_size_control_KNN_l                                   -3.6744
# anomaly_size_control_KNN_ls                                  -3.6744
# anomaly_size_control_KNN_s                                   -3.6744
# ff5_ensemble_ls                                              -3.6724
# ff5_KNN_l                                                    -3.6673
# ff5_KNN_ls                                                   -3.6724
# ff5_KNN_s                                                    -3.6726
# ff5_NN_l                                                     -3.6724
# ff5_NN_ls                                                    -3.6724
# ff5_NN_s                                                     -3.6805
# ff5_RF_l                                                     -3.6551
# ff5_RF_ls                                                    -3.6724
# ff5_RF_s                                                     -3.6043
# ff5_simp_binary_ls                                           -3.6598
# industry_ensemble_ls                                         -3.6724
# industry_KNN_l                                               -3.6724
# industry_KNN_ls                                              -3.6724
# industry_KNN_s                                               -3.6557
# industry_NN_l                                                -3.6724
# industry_NN_ls                                               -3.6724
# industry_NN_s                                                -3.7202
# industry_RF_l                                                -3.6724
# industry_RF_ls                                               -3.6724
# industry_RF_s                                                -3.6561
# industry_simp_binary_ls                                      -3.7071
# q_factor_ensemble_ls                                         -3.6744
# q_factor_KNN_l                                               -3.6744
# q_factor_KNN_ls                                              -3.6744
# q_factor_KNN_s                                               -3.7768
# q_factor_NN_l                                                -3.6744
# q_factor_NN_ls                                               -3.6744
# q_factor_NN_s                                                -4.0152
# q_factor_RF_l                                                -3.6744
# q_factor_RF_ls                                               -3.6744
# q_factor_RF_s                                                -3.7547
# q_factor_simp_binary_ls                                      -3.6706
# stambaugh_yuan_ensemble_ls                                   -3.5777
# stambaugh_yuan_KNN_l                                         -3.5758
# stambaugh_yuan_KNN_ls                                        -3.5777
# stambaugh_yuan_KNN_s                                         -3.5064
# stambaugh_yuan_NN_l                                          -3.5777
# stambaugh_yuan_NN_ls                                         -3.5777
# stambaugh_yuan_NN_s                                          -3.5514
# stambaugh_yuan_RF_l                                          -3.5889
# stambaugh_yuan_RF_ls                                         -3.5777
# stambaugh_yuan_RF_s                                          -3.5476
# stambaugh_yuan_simp_binary_ls                                -3.5695
#
#                               lookback for features lookback for ml model
# anomaly_size_control_KNN_l                       12                    12
# anomaly_size_control_KNN_ls                      12                    12
# anomaly_size_control_KNN_s                       12                    12
# ff5_ensemble_ls                                  12                    12
# ff5_KNN_l                                        12                    12
# ff5_KNN_ls                                       12                    12
# ff5_KNN_s                                        12                    12
# ff5_NN_l                                         12                    12
# ff5_NN_ls                                        12                    12
# ff5_NN_s                                         12                    12
# ff5_RF_l                                         12                    12
# ff5_RF_ls                                        12                    12
# ff5_RF_s                                         12                    12
# ff5_simp_binary_ls                               12                    12
# industry_ensemble_ls                             12                    12
# industry_KNN_l                                   12                    12
# industry_KNN_ls                                  12                    12
# industry_KNN_s                                   12                    12
# industry_NN_l                                    12                    12
# industry_NN_ls                                   12                    12
# industry_NN_s                                    12                    12
# industry_RF_l                                    12                    12
# industry_RF_ls                                   12                    12
# industry_RF_s                                    12                    12
# industry_simp_binary_ls                          12                    12
# q_factor_ensemble_ls                             12                    12
# q_factor_KNN_l                                   12                    12
# q_factor_KNN_ls                                  12                    12
# q_factor_KNN_s                                   12                    12
# q_factor_NN_l                                    12                    12
# q_factor_NN_ls                                   12                    12
# q_factor_NN_s                                    12                    12
# q_factor_RF_l                                    12                    12
# q_factor_RF_ls                                   12                    12
# q_factor_RF_s                                    12                    12
# q_factor_simp_binary_ls                          12                    12
# stambaugh_yuan_ensemble_ls                       12                    12
# stambaugh_yuan_KNN_l                             12                    12
# stambaugh_yuan_KNN_ls                            12                    12
# stambaugh_yuan_KNN_s                             12                    12
# stambaugh_yuan_NN_l                              12                    12
# stambaugh_yuan_NN_ls                             12                    12
# stambaugh_yuan_NN_s                              12                    12
# stambaugh_yuan_RF_l                              12                    12
# stambaugh_yuan_RF_ls                             12                    12
# stambaugh_yuan_RF_s                              12                    12
# stambaugh_yuan_simp_binary_ls                    12                    12
