# %%
from regime_module import *
from statsmodels.iolib.summary2 import summary_col
import csv
import os
import matplotlib.backends.backend_pdf

cur_wd = os.getcwd()
print(cur_wd)
image_wd = os.path.join(cur_wd, 'backtest_images')
backtest_wd = os.path.join(cur_wd, 'backtests')
import matplotlib.pyplot as plt
# Out:
# D:\janko_machine_learning\playground

# %%
alpha_ff5 = pd.DataFrame()
alpha_capm = pd.DataFrame()

alpha_ff5_scaled = pd.DataFrame()
alpha_capm_scaled = pd.DataFrame()

# %%
def write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns, backtest_write, image_write, cur_wd, data_type ):
    
    outname = 'output_results_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    outnamelatex = 'output_results_latex_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    
    outname_scaled = 'output_results_scaled_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    outnamelatex_scaled = 'output_results_latex_scaled_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    
    
    output_reg = []
    output_capm = []
    output_umd = []
    output_qfactor = []
    output_tm = []
    output_hm = []
    
    output_reg_scaled = []
    output_capm_scaled = []
    output_umd_scaled = []
    output_qfactor_scaled = []
    output_tm_scaled = []
    output_hm_scaled = []
    
    #names = ['Logistic L/S', 'Logistic L', 'Logistic S', 'KNN L/S', 'KNN L', 'KNN S', 'Neural Net L/S', 'Neural Net L', 'Neural Net S', 'RF L/S', 'RF L', 'RF S','AdaBoost L/S', 'AdaBoost L', 'AdaBoost S', 'Ensemble', 'Binary']

    names = ['KNN L/S', 'KNN L', 'KNN S', 'Neural Net L/S', 'Neural Net L', 'Neural Net S', 'RF L/S', 'RF L', 'RF S','AdaBoost L/S', 'AdaBoost L', 'AdaBoost S', 'Ensemble', 'Binary', 'Equal-Weight']
    """
    
    
    print("Logistic")
    print("Long and Short")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Logistic"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_Logistic_' + 'ls' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_Logistic_scaled_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_Logistic_' + 'ls' + '.pdf'))


    print("Long Only")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Logistic"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_Logistic_' + 'l' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_Logistic_scaled_' + 'l' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_Logistic_' + 'l' + '.pdf'))


    print("Short Only")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Logistic"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_Logistic_' + 's' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_Logistic_scaled_' + 's' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_Logistic_' + 's' + '.pdf'))
    
    """
    
    
    
    print("KNN")
    print("Long and Short")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Nearest Neighbors"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN_' + 'ls' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN_scaled_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_KNN_' + 'ls' + '.pdf'))

    

    print("Long Only")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Nearest Neighbors"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN_' + 'l' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN_scaled_' + 'l' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_KNN_' + 'l' + '.pdf'))


    print("Short Only")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Nearest Neighbors"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN_' + 's' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_KNN_scaled_' + 's' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_KNN_' + 's' + '.pdf'))


    print("Neural Net")
    print("Long and Short")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Neural Net"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_NN_' + 'ls' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_NN_scaled_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_NN_' + 'ls' + '.pdf'))


    print("Long Only")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Neural Net"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_NN_' + 'l' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_NN_scaled_' + 'l' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_NN_' + 'l' + '.pdf'))

    print("Short Only")
    backtest, weights, scaled_backtest = bt.run_backtest(returns,lookback_backtest, input_classifiers= ["Neural Net"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_NN_' + 's' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_NN_scaled_' + 's' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_NN_' + 's' + '.pdf'))


    print("Random Forest")
    print("Long and Short")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Random Forest"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_RF_' + 'ls' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_RF_scaled_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_RF_' + 'ls' + '.pdf'))


    print("Long Only")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Random Forest"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_RF_' + 'l' + '.csv'))
    backtest.to_csv(os.path.join(backtest_write, data_type + '_RF_scaled_' + 'l' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_RF_' + 'l' + '.pdf'))


    print("Short Only")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Random Forest"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_RF_' + 's' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_RF_scaled' + 's' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_RF_' + 's' + '.pdf'))

        
        
    print("AdaBooost")
    print("Long and Short")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["AdaBoost"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'both')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_AdaBoost_' + 'ls' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_AdaBoost_scaled_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_AdaBoost_' + 'ls' + '.pdf'))


    print("Long Only")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["AdaBoost"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'long')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_AdaBoost_' + 'l' + '.csv'))
    backtest.to_csv(os.path.join(backtest_write, data_type + '_AdaBoost_scaled_' + 'l' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_AdaBoost_' + 'l' + '.pdf'))


    print("Short Only")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["AdaBoost"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no', trade_type = 'short')
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_AdaBoost_' + 's' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_AdaBoost_scaled' + 's' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_AdaBoost_' + 's' + '.pdf'))


    print("Ensemble System")
    backtest, weights, scaled_backtest = bt.run_backtest(returns, lookback_backtest, input_classifiers= ["Voter"], inputs = feature_set, outputs = binary_returns,  ensemble = 'no')  
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)

    backtest.to_csv(os.path.join(backtest_write, data_type + '_ensemble_' + 'ls' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_ensemble_scaled_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_ensemble_' + 'ls' + '.pdf'))


    print("Simple Binary Decision")
    scaled_backtest = returns.dropna(axis = 1, how = 'all').dropna(axis = 0, how = 'all')
    weights = returns.dropna(axis = 1, how = 'all').dropna(axis = 0, how = 'all')
    backtest.values[:] = 0
    scaled_backtest.values[:] = 0
    weights.values[:] = 0
    signal = returns.rolling(lookback_backtest).mean().shift(1).dropna(axis = 1, how = 'all').dropna(axis = 0, how = 'all')
    std = returns.rolling(lookback_backtest).std().shift(1).dropna(axis = 1, how = 'all').dropna(axis = 0, how = 'all')
    std = .05/std
    signal[signal >= 0] = 1.0
    signal[signal < 0] = -1.0
    backtest = (signal * returns).dropna(axis = 0, how = 'all')
    weights = signal
    scaled_backtest = (signal * returns * std).dropna(axis = 0, how = 'all')


    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)


    backtest.to_csv(os.path.join(backtest_write, data_type + '_simp_binary_' + 'ls' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_simp_binary_scaled_' '_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_sim_binary_scaled_' + 'ls' + '.pdf'))
    
    
    print("Equal Weight")
    scaled_backtest = returns.dropna(axis = 1, how = 'all').dropna(axis = 0, how = 'all')
    weights = returns.dropna(axis = 1, how = 'all').dropna(axis = 0, how = 'all')
    backtest.values[:] = 0
    scaled_backtest.values[:] = 0
    weights.values[:] = 1.0
    std = returns.rolling(lookback_backtest).std().shift(1).dropna(axis = 1, how = 'all').dropna(axis = 0, how = 'all')
    std = .05/std
    backtest = (returns).dropna(axis = 0, how = 'all')
    weights = signal
    scaled_backtest = (returns * std).dropna(axis = 0, how = 'all') 
    
    results, fm_sum = bt.factor_results(backtest, ff_factors_compare)
    results_capm, fm_sum_capm = bt.factor_results_capm(backtest, ff_factors_compare)
    results_umd, fm_sum_umd = bt.factor_results_umd(backtest, umd)
    results_q, fm_sum_q = bt.factor_results_qfactor(backtest, q_factor)
    results_tm = bt.treynor_mazuy(backtest, ff_factors_compare)
    results_hm = bt.henriksson_merton(backtest, ff_factors_compare)

    results_scaled, fm_sum = bt.factor_results(scaled_backtest, ff_factors_compare)
    results_capm_scaled, fm_sum_capm = bt.factor_results_capm(scaled_backtest, ff_factors_compare)
    results_umd_scaled, fm_sum_umd = bt.factor_results_umd(scaled_backtest, umd)
    results_q_scaled, fm_sum_q = bt.factor_results_qfactor(scaled_backtest, q_factor)
    results_tm_scaled = bt.treynor_mazuy(scaled_backtest, ff_factors_compare)
    results_hm_scaled = bt.henriksson_merton(scaled_backtest, ff_factors_compare)

    output_reg.append(results)
    output_capm.append(results_capm)
    output_umd.append(results_umd)
    output_qfactor.append(results_q)
    output_tm.append(results_tm)
    output_hm.append(results_hm)

    output_reg_scaled.append(results_scaled)
    output_capm_scaled.append(results_capm_scaled)
    output_umd_scaled.append(results_umd_scaled)
    output_qfactor_scaled.append(results_q_scaled)
    output_tm_scaled.append(results_tm_scaled)
    output_hm_scaled.append(results_hm_scaled)


    backtest.to_csv(os.path.join(backtest_write, data_type + '_eql_weight_' + 'ls' + '.csv'))
    scaled_backtest.to_csv(os.path.join(backtest_write, data_type + '_eql_weight_scaled_' '_' + 'ls' + '.csv'))
    plot_bf = pd.DataFrame(1.0 + backtest.mean(axis = 1), columns = ['backtest']).cumprod()
    plot_mkt = (1.0 + ff_factors['Mkt-RF'].loc[plot_bf.index]).cumprod()
    plot_df = pd.concat([plot_bf, plot_mkt], axis = 1).dropna()
    ax = plot_df.plot()
    ax.figure.savefig(os.path.join(image_write, data_type + '_eql_weight_scaled_' + 'ls' + '.pdf'))
    
    
    

    plt.close('all')
    
    factor_results = summary_col(output_reg,stars=True,float_format='%0.3f',model_names=names)
    factor_results.title = data_type
    factor_results_capm = summary_col(output_capm,stars=True,float_format='%0.3f',model_names=names)
    factor_results_capm.title = data_type + ' capm'
    
    factor_results_umd = summary_col(output_umd,stars=True,float_format='%0.3f',model_names=names)
    factor_results_umd.title = data_type + ' umd'
    
    factor_results_q = summary_col(output_qfactor,stars=True,float_format='%0.3f',model_names=names)
    factor_results_q.title = data_type + ' q factor'
                                                        
    factor_results_tm = summary_col(output_tm,stars=True,float_format='%0.3f',model_names=names)
    factor_results_tm.title = data_type + ' Treynor and Mazuy'
                               
    factor_results_hm = summary_col(output_hm,stars=True,float_format='%0.3f',model_names=names)
    factor_results_hm.title = data_type + ' Henriksson and Merton'
    
    resultFile = open(os.path.join(backtest_wd,'outputs' ,outname),'a')
    resultFile.write(factor_results.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_capm.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_umd.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_q.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_tm.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_hm.as_text())
    resultFile.write('\n')
    resultFile.close()
    
    resultFile = open(os.path.join(backtest_wd,'outputs' ,outnamelatex),'a')
    resultFile.write(factor_results.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_capm.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_umd.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_q.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_tm.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_hm.as_latex())
    resultFile.write('\n')
    resultFile.close()
    
    add_factor = pd.DataFrame(factor_results.tables[0]).T['intercept']
    add_factor.columns = [data_type + '_' +  str(lookback) + '_' + str(lookback_backtest) ]
    add_factor.name = data_type + '_' +  str(lookback) + '_' + str(lookback_backtest) 
    add_factor_capm = pd.DataFrame(factor_results_capm.tables[0]).T['intercept']
    add_factor_capm.columns = [data_type + '_' + str(lookback) + '_' + str(lookback_backtest) ]
    add_factor_capm.name = data_type + '_' + str(lookback) + '_' + str(lookback_backtest)
                               
    factor_results_scaled = summary_col(output_reg_scaled,stars=True,float_format='%0.3f',model_names=names)
    factor_results_scaled.title = data_type
                               
    factor_results_capm_scaled = summary_col(output_capm_scaled,stars=True,float_format='%0.3f',model_names=names)
    factor_results_capm_scaled.title = data_type + ' capm'
    
    factor_results_umd_scaled = summary_col(output_umd_scaled,stars=True,float_format='%0.3f',model_names=names)
    factor_results_umd_scaled.title = data_type + ' umd'
    
    factor_results_q_scaled = summary_col(output_qfactor_scaled,stars=True,float_format='%0.3f',model_names=names)
    factor_results_q_scaled.title = data_type + ' q factor'
                                                        
    factor_results_tm_scaled = summary_col(output_tm_scaled,stars=True,float_format='%0.3f',model_names=names)
    factor_results_tm_scaled.title = data_type + ' Treynor and Mazuy'
                    
    factor_results_hm_scaled = summary_col(output_hm_scaled,stars=True,float_format='%0.3f',model_names=names)
    factor_results_hm_scaled.title = data_type + ' Henriksson and Merton'
    
    resultFile = open(os.path.join(backtest_wd,'outputs' ,outname_scaled),'a')
    resultFile.write(factor_results_scaled.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_capm_scaled.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_umd_scaled.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_q_scaled.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_tm_scaled.as_text())
    resultFile.write('\n')
    resultFile.write(factor_results_hm_scaled.as_text())
    resultFile.write('\n')
    resultFile.close()
    
    resultFile = open(os.path.join(backtest_wd,'outputs' ,outnamelatex_scaled),'a')
    resultFile.write(factor_results_scaled.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_capm_scaled.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_umd_scaled.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_q_scaled.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_tm_scaled.as_latex())
    resultFile.write('\n')
    resultFile.write(factor_results_hm_scaled.as_latex())
    resultFile.write('\n')
    resultFile.close()
    
    add_factor_scaled = pd.DataFrame(factor_results_scaled.tables[0]).T['intercept']
    add_factor_scaled.columns = [data_type + '_' +  str(lookback) + '_' + str(lookback_backtest) ]
    add_factor_scaled.name = data_type + '_' +  str(lookback) + '_' + str(lookback_backtest) 
    add_factor_capm_scaled = pd.DataFrame(factor_results_capm_scaled.tables[0]).T['intercept']
    add_factor_capm_scaled.columns = [data_type + '_' + str(lookback) + '_' + str(lookback_backtest) ]
    add_factor_capm_scaled.name = data_type + '_' + str(lookback) + '_' + str(lookback_backtest)
       
                    
    
    return add_factor, add_factor_capm, factor_results, add_factor_scaled, add_factor_capm_scaled

# %%
#get the famma french factors

# %%
ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
ff_factors = ff_factors / 100.0
ff_factors[ff_factors == -999] = np.NaN
ff_factors[ff_factors == -99.9] = np.NaN
ff_factors = ff_factors.dropna(how = 'any', axis = 0)
ff_factors = ff_factors[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
ff_factors_compare = ff_factors.copy()

# %%
#get the momentum model
mom = pd.read_csv('Mom.csv', index_col = 0)
mom.index = pd.to_datetime(mom.index, format= '%Y%m')
mom = mom / 100.0
mom[mom == -999] = np.NaN
mom[mom == -99.9] = np.NaN
mom = mom.dropna(how = 'any', axis = 0)
umd = pd.concat([ff_factors[['Mkt-RF', 'SMB', 'HML']], mom], axis = 1)
umd = umd.dropna()
cols_add = []
for c in umd.columns:
    cols_add.append(c.replace(' ', ''))
umd.columns  = cols_add
print(umd.head(5))
print(umd.columns)
# Out:
#             Mkt-RF     SMB     HML     Mom
# 1963-07-01 -0.0039 -0.0047 -0.0083  0.0100
# 1963-08-01  0.0507 -0.0079  0.0167  0.0103
# 1963-09-01 -0.0157 -0.0048  0.0018  0.0016
# 1963-10-01  0.0253 -0.0129 -0.0010  0.0314
# 1963-11-01 -0.0085 -0.0084  0.0171 -0.0075
# Index(['Mkt-RF', 'SMB', 'HML', 'Mom'], dtype='object')

# %%
q_factor = pd.read_csv('q5_factors.csv', index_col = 0)
q_factor.index = pd.to_datetime(q_factor.index, format= '%Y%m')
q_factor = q_factor / 100.0
print(q_factor.head(5))
# Out:
#                  R_F     R_MKT      R_ME      R_IA     R_ROE      R_EG
# 1967-01-01  0.003927  0.081603  0.067282 -0.029434  0.018866 -0.022469
# 1967-02-01  0.003743  0.007202  0.016918 -0.002064  0.035317  0.025812
# 1967-03-01  0.003693  0.039691  0.019517 -0.016933  0.018876 -0.014789
# 1967-04-01  0.003344  0.038265 -0.007446 -0.029519  0.010983 -0.022351
# 1967-05-01  0.003126 -0.042419  0.029132  0.024686  0.005234  0.002749

# %%
industry = pd.read_csv('48_Industry_Portfolios.csv', index_col = 0)
industry.index = pd.to_datetime(industry.index, format= '%Y%m')
industry[industry <= -99.] = np.NaN
industry = industry / 100.0

ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
ff_factors = ff_factors / 100.0
ff_factors[ff_factors == -999] = np.NaN
ff_factors[ff_factors == -99.9] = np.NaN
ff_factors = ff_factors.dropna(how = 'any', axis = 0)

factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
rf = factor_model[['RF']]
rf_subtract = rf.copy()
factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
ff_factors_compare = factor_model.copy()

rf_subtract.index = pd.to_datetime(rf_subtract.index, format = 'Y%-%m-%d')

# %%
policy_uncertainty = pd.read_csv('US_Policy_Uncertainty_Data.csv', index_col = 0)
policy_uncertainty.index = pd.to_datetime(policy_uncertainty.index, format= '%Y%m')

goyal_welch = pd.read_csv('goyal_welch_data.csv', index_col = 0)
goyal_welch = goyal_welch.loc[goyal_welch.index.dropna(),:]
goyal_welch.index = goyal_welch.index.map(lambda x: int(x))
goyal_welch.index = pd.to_datetime(goyal_welch.index, format= '%Y%m')
goyal_welch = goyal_welch.dropna(axis = 0, how = 'all').dropna(axis = 1, how = 'all')
for x in goyal_welch.columns:
    goyal_welch[x] =  pd.to_numeric(goyal_welch[x], errors='coerce')
    
bw = pd.read_csv('b_w_is.csv', index_col = 0)
bw.index = pd.to_datetime(bw.index, format= '%Y%m')

# %%
lookback_list = [24 ]
lookback_backtest_list = [12]


for lookback in lookback_list:
    for lookback_backtest in lookback_backtest_list:

        if not os.path.exists(os.path.join(image_wd, str(lookback) + '_' + str(lookback_backtest))):
            os.makedirs(os.path.join(image_wd, str(lookback) + '_' + str(lookback_backtest)))

        image_write = os.path.join(image_wd, str(lookback) + '_' + str(lookback_backtest))

        if not os.path.exists(os.path.join(backtest_wd, str(lookback) + '_' + str(lookback_backtest))):
            os.makedirs(os.path.join(backtest_wd, str(lookback) + '_' + str(lookback_backtest)))
        if not os.path.exists(os.path.join(backtest_wd, 'outputs')):
            os.makedirs(os.path.join(backtest_wd, 'outputs'))

        outname = 'output_results_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
        outnamelatex = 'output_results_latex_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    
        backtest_write = os.path.join(backtest_wd, str(lookback) + '_' + str(lookback_backtest))

        resultFile = open(os.path.join(backtest_wd,'outputs' ,outname),'w')
        resultFile.close()
        
        resultFile = open(os.path.join(backtest_wd,'outputs' ,outnamelatex),'w')
        resultFile.close()
        
        outname = 'output_results_scaled_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
        outnamelatex = 'output_results_latex_scaled_' + str(lookback) + '_' + str(lookback_backtest) +  '.txt'
    
        backtest_write = os.path.join(backtest_wd, str(lookback) + '_' + str(lookback_backtest))

        resultFile = open(os.path.join(backtest_wd,'outputs' ,outname),'w')
        resultFile.close()
        
        resultFile = open(os.path.join(backtest_wd,'outputs' ,outnamelatex),'w')
        resultFile.close()
        
        
        
        ####################################################
        ####################################################
        ####################################################
        #get the q factor model
        ####################################################
        ####################################################
        ####################################################
        
        
        
        
        
        q_factor = pd.read_csv('q5_factors.csv', index_col = 0)
        q_factor.index = pd.to_datetime(q_factor.index, format= '%Y%m')
        q_factor = q_factor / 100.0

        factor_model = q_factor.copy()
        factor_model = factor_model[['R_MKT', 'R_ME', 'R_IA', 'R_ROE', 'R_EG']]
        rf = q_factor[['R_F']]
        q_factor = factor_model.copy()

        index_symbol = 'R_MKT'

        print(q_factor.head(5))
        
        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'


        #control the leverage
        lev = 1.
        stk_symbols  = factor_model.columns
        returns = factor_model.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns, rolling_sum_12s = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [binary_returns, rolling_std_12]

        feature_set = data.get_features(feature_list)
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], bw],axis = 1)
            feature_set[k] =  feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
        
        data_type = 'q_factor'

        factor_results, factor_results_capm, factor_reg,factor_results_scaled, factor_results_capm_scaled = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )
        
        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)
            
        if alpha_ff5_scaled.empty:
            alpha_ff5_scaled = factor_results_scaled.copy()
            alpha_capm_scaled = factor_results_capm_scaled.copy()
        else:
            alpha_ff5_scaled = pd.concat( [alpha_ff5_scaled, factor_results_scaled], axis = 1)
            alpha_capm_scaled = pd.concat( [alpha_capm_scaled, factor_results_capm_scaled], axis = 1)      

        ####################################################
        ####################################################    
        #get the ff5 results
        ####################################################
        ####################################################
        ####################################################

        
        
        
        
        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)

        factor_model = ff_factors.copy()
        factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
        rf = ff_factors[['RF']]

        index_symbol = 'Mkt-RF'

        print(ff_factors.head(5))

        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'

        #control the leverage
        lev = 1.
        stk_symbols  = factor_model.columns
        returns = factor_model.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns, rolling_sum_12s = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [binary_returns]
        
        feature_set = data.get_features(feature_list)
        

 
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], policy_uncertainty],axis = 1)
            feature_set[k] = feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
               
                
        data_type = 'ff5'
        
        factor_results, factor_results_capm, factor_reg,factor_results_scaled, factor_results_capm_scaled = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )
        
        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)
            
        if alpha_ff5_scaled.empty:
            alpha_ff5_scaled = factor_results_scaled.copy()
            alpha_capm_scaled = factor_results_capm_scaled.copy()
        else:
            alpha_ff5_scaled = pd.concat( [alpha_ff5_scaled, factor_results_scaled], axis = 1)
            alpha_capm_scaled = pd.concat( [alpha_capm_scaled, factor_results_capm_scaled], axis = 1)  
            
 
        ####################################################
        ####################################################
        #Industry
        ####################################################
        ####################################################
        ####################################################


        industry = pd.read_csv('48_Industry_Portfolios.csv', index_col = 0)
        industry.index = pd.to_datetime(industry.index, format= '%Y%m')
        industry[industry <= -99.] = np.nan
        industry = industry / 100.0

        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)

        factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
        rf = factor_model[['RF']]
        rf_subtract = rf.copy()
        factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
        ff_factors_compare = factor_model[['Mkt-RF']].copy()

        rf_subtract.index = pd.to_datetime(rf_subtract.index, format = 'Y%-%m-%d')

        union_index = industry.index.intersection(rf_subtract.index)
        industry = industry.loc[union_index,:]
        rf_subtract = rf_subtract.loc[union_index, :]

        for i in industry.columns:
            industry.loc[:,i] = industry.loc[:,i] - rf_subtract['RF']

        index_symbol = 'Mkt-RF'

        print(ff_factors.head(5))

        print(industry.head(5))


        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'

        #control the leverage
        lev = 1.
        stk_symbols  = factor_model.columns
        returns = factor_model.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns, rolling_sum_12s = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [binary_returns]
        
        feature_set = data.get_features(feature_list)
        

 
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], policy_uncertainty],axis = 1)
            feature_set[k] = feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
               

        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [binary_returns]
        
        feature_set = data.get_features(feature_list)
        

 
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], policy_uncertainty],axis = 1)
            feature_set[k] = feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
               
                
        data_type = 'industry'

        factor_results, factor_results_capm, factor_reg,factor_results_scaled, factor_results_capm_scaled = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )
        
        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)
            
        if alpha_ff5_scaled.empty:
            alpha_ff5_scaled = factor_results_scaled.copy()
            alpha_capm_scaled = factor_results_capm_scaled.copy()
        else:
            alpha_ff5_scaled = pd.concat( [alpha_ff5_scaled, factor_results_scaled], axis = 1)
            alpha_capm_scaled = pd.concat( [alpha_capm_scaled, factor_results_capm_scaled], axis = 1)      

        ####################################################    
        ####################################################    
        #stambaugh_yuan model
        ####################################################
        ####################################################
        ####################################################
        
        
        
        
        m4 = pd.read_csv('M4-1.csv', index_col = 0)
        m4.index = pd.to_datetime(m4.index, format= '%Y%m')

        factor_model = m4.copy()
        factor_model = factor_model[['MKTRF','SMB','MGMT','PERF']]
        rf = m4[['RF']]

        index_symbol = 'MKTRF'

        print(m4.head(5))

        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'


        #control the leverage
        lev = 1.
        stk_symbols  = factor_model.columns
        returns = factor_model.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns, rolling_sum_12s = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [binary_returns]
        
        feature_set = data.get_features(feature_list)
        

 
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], policy_uncertainty],axis = 1)
            feature_set[k] = feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
               
                
        data_type = 'stambaugh_yuan'
        
        factor_results, factor_results_capm, factor_reg,factor_results_scaled, factor_results_capm_scaled = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )
        
        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)
            
        if alpha_ff5_scaled.empty:
            alpha_ff5_scaled = factor_results_scaled.copy()
            alpha_capm_scaled = factor_results_capm_scaled.copy()
        else:
            alpha_ff5_scaled = pd.concat( [alpha_ff5_scaled, factor_results_scaled], axis = 1)
            alpha_capm_scaled = pd.concat( [alpha_capm_scaled, factor_results_capm_scaled], axis = 1)      
          
        
        
        ####################################################
        ####################################################   
        #Testing Portfolios- Hou, Kewei, Chen Xue, and Lu Zhang####################################################
        ####################################################
        ####################################################
        ####################################################
        
        
        ###############size control#######################################
        anomaly = pd.read_csv('anomalies_size_control.csv', index_col = 0)
        anomaly.index = pd.to_datetime(anomaly.index, format= '%Y-%m-%d')

        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)

        factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
        rf = factor_model[['RF']]
        factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
        ff_factors_compare = factor_model.copy()

        index_symbol = 'Mkt-RF'

        print(anomaly.head(5))

        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'


        #control the leverage
        lev = 1.
        stk_symbols  = anomaly.columns
        returns = anomaly.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns, rolling_sum_12s = data.get_rolling_features(returns, 0.0)


        feature_list = [binary_returns]
        
        feature_set = data.get_features(feature_list)
        

 
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], policy_uncertainty],axis = 1)
            feature_set[k] = feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
               
        data_type = 'anomaly_size_control'
        
        factor_results, factor_results_capm, factor_reg,factor_results_scaled, factor_results_capm_scaled = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )
        
        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)
            
        if alpha_ff5_scaled.empty:
            alpha_ff5_scaled = factor_results_scaled.copy()
            alpha_capm_scaled = factor_results_capm_scaled.copy()
        else:
            alpha_ff5_scaled = pd.concat( [alpha_ff5_scaled, factor_results_scaled], axis = 1)
            alpha_capm_scaled = pd.concat( [alpha_capm_scaled, factor_results_capm_scaled], axis = 1)      
       
        
        
        
        ##########################################################################
        ##########################################################################
        ##########################################################################
        ###############deciles #######################################
        ##########################################################################
        ##########################################################################
        ##########################################################################
        ##########################################################################
        
        anomaly = pd.read_csv('anomalies_decile.csv', index_col = 0)
        anomaly.index = pd.to_datetime(anomaly.index, format= '%Y-%m-%d')

        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)

        factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
        rf = factor_model[['RF']]
        factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
        ff_factors_compare = factor_model.copy()

        index_symbol = 'Mkt-RF'

        print(anomaly.head(5))

        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'


        #control the leverage
        lev = 1.
        stk_symbols  = anomaly.columns
        returns = anomaly.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns, rolling_sum_12s = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [binary_returns]
        
        feature_set = data.get_features(feature_list)
        

 
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], policy_uncertainty],axis = 1)
            feature_set[k] = feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
               
        data_type = 'anomaly_decile'
        
        factor_results, factor_results_capm, factor_reg,factor_results_scaled, factor_results_capm_scaled = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )
        
        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)
            
        if alpha_ff5_scaled.empty:
            alpha_ff5_scaled = factor_results_scaled.copy()
            alpha_capm_scaled = factor_results_capm_scaled.copy()
        else:
            alpha_ff5_scaled = pd.concat( [alpha_ff5_scaled, factor_results_scaled], axis = 1)
            alpha_capm_scaled = pd.concat( [alpha_capm_scaled, factor_results_capm_scaled], axis = 1)      
   
        
        ################    Sector_ETF Sectors           ######################################
        etf = pd.read_csv('Sector_ETF.csv', index_col = 0)
        etf.index = pd.to_datetime(etf.index, format= '%Y%m%d')
        etf.index = etf.index.to_period('M').astype(str)
        etf.index = pd.to_datetime(etf.index, format= '%Y-%m')

        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)

        factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
        rf = factor_model[['RF']]
        factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
        ff_factors_compare = factor_model.copy()
        rf_subtract = rf.copy()
        rf_subtract.index = pd.to_datetime(rf_subtract.index, format = 'Y%-%m-%d')

        union_index = etf.index.intersection(rf_subtract.index)
        etf = etf.loc[union_index,:]
        rf_subtract = rf_subtract.loc[union_index, :]
        for e in etf.columns:
            etf.loc[:,e] = etf.loc[:,e] - rf_subtract['RF']

        index_symbol = 'Mkt-RF'
        
        print(etf.head(5))

        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'


        #control the leverage
        lev = 1.
        stk_symbols  = etf.columns
        returns = etf.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        p = data.get_probability(returns, factor_model, rf)
        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns, rolling_sum_12s = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [binary_returns]
        
        feature_set = data.get_features(feature_list)
        

 
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], policy_uncertainty],axis = 1)
            feature_set[k] = feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
               
                
        data_type = 'sector_etf_universe'

        factor_results, factor_results_capm, factor_reg,factor_results_scaled, factor_results_capm_scaled = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )
        
        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)
            
        if alpha_ff5_scaled.empty:
            alpha_ff5_scaled = factor_results_scaled.copy()
            alpha_capm_scaled = factor_results_capm_scaled.copy()
        else:
            alpha_ff5_scaled = pd.concat( [alpha_ff5_scaled, factor_results_scaled], axis = 1)
            alpha_capm_scaled = pd.concat( [alpha_capm_scaled, factor_results_capm_scaled], axis = 1)      
   
        ######################################################
        ######################################################
        ######################################################
        ############## Factor Model ETF   ####################
        ######################################################
        ######################################################
        ######################################################
        
        etf = pd.read_csv('Three_Factor_ETF.csv', index_col = 0)
        etf.index = pd.to_datetime(etf.index, format= '%Y%m%d')
        etf.index = etf.index.to_period('M').astype(str)
        etf.index = pd.to_datetime(etf.index, format= '%Y-%m')

        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)

        factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
        rf = factor_model[['RF']]
        factor_model = factor_model[['Mkt-RF', 'SMB', 'HML']]
        ff_factors_compare = factor_model.copy()
        rf_subtract = rf.copy()
        rf_subtract.index = pd.to_datetime(rf_subtract.index, format = 'Y%-%m-%d')

        union_index = etf.index.intersection(rf_subtract.index)
        etf = etf.loc[union_index,:]
        rf_subtract = rf_subtract.loc[union_index, :]
        for e in etf.columns:
            if e == 'SPY':
                etf.loc[:,e] = etf.loc[:,e] - rf_subtract['RF']

        index_symbol = 'Mkt-RF'
        #end date for data
        end = '2020-01-01'


        #control the leverage
        lev = 1.
        stk_symbols  = etf.columns
        returns = etf.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        p = data.get_probability(returns, factor_model, rf)
        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns, rolling_sum_12s = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [binary_returns]
        
        feature_set = data.get_features(feature_list)
        

 
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], policy_uncertainty],axis = 1)
            feature_set[k] = feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
               
        data_type = 'three_factor_etf'

        factor_results, factor_results_capm, factor_reg,factor_results_scaled, factor_results_capm_scaled = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )

        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)     
        print(etf.head(5))

        
        etf = pd.read_csv('Five_Factor_ETF.csv', index_col = 0)
        etf.index = pd.to_datetime(etf.index, format= '%Y%m%d')
        etf.index = etf.index.to_period('M').astype(str)
        etf.index = pd.to_datetime(etf.index, format= '%Y-%m')

        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)

        factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
        rf = factor_model[['RF']]
        factor_model = factor_model[['Mkt-RF', 'SMB', 'HML']]
        ff_factors_compare = factor_model.copy()
        rf_subtract = rf.copy()
        rf_subtract.index = pd.to_datetime(rf_subtract.index, format = 'Y%-%m-%d')

        union_index = etf.index.intersection(rf_subtract.index)
        etf = etf.loc[union_index,:]
        rf_subtract = rf_subtract.loc[union_index, :]
        for e in etf.columns:
            if e == 'SPY':
                etf.loc[:,e] = etf.loc[:,e] - rf_subtract['RF']

        index_symbol = 'Mkt-RF'
        #end date for data
        end = '2020-01-01'


        #control the leverage
        lev = 1.
        stk_symbols  = etf.columns
        returns = etf.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        p = data.get_probability(returns, factor_model, rf)
        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns, rolling_sum_12s = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [binary_returns]
        
        feature_set = data.get_features(feature_list)
        

 
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], policy_uncertainty],axis = 1)
            feature_set[k] = feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
               
                
        data_type = 'five_factor_etf'

        factor_results, factor_results_capm, factor_reg,factor_results_scaled, factor_results_capm_scaled = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )
        
        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)
            
        if alpha_ff5_scaled.empty:
            alpha_ff5_scaled = factor_results_scaled.copy()
            alpha_capm_scaled = factor_results_capm_scaled.copy()
        else:
            alpha_ff5_scaled = pd.concat( [alpha_ff5_scaled, factor_results_scaled], axis = 1)
            alpha_capm_scaled = pd.concat( [alpha_capm_scaled, factor_results_capm_scaled], axis = 1)      
   
        
        plt.close('all')
        
        ################    Sector_ETF Sectors           ######################################
        etf = pd.read_csv('Sector_ETF.csv', index_col = 0)
        etf.index = pd.to_datetime(etf.index, format= '%Y%m%d')
        etf.index = etf.index.to_period('M').astype(str)
        etf.index = pd.to_datetime(etf.index, format= '%Y-%m')

        ff_factors = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', index_col = 0)
        ff_factors.index = pd.to_datetime(ff_factors.index, format= '%Y%m')
        ff_factors = ff_factors / 100.0
        ff_factors[ff_factors == -999] = np.NaN
        ff_factors[ff_factors == -99.9] = np.NaN
        ff_factors = ff_factors.dropna(how = 'any', axis = 0)

        factor_model = ff_factors.copy().dropna(axis = 0, how = 'any')
        rf = factor_model[['RF']]
        factor_model = factor_model[['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']]
        ff_factors_compare = factor_model.copy()
        rf_subtract = rf.copy()
        rf_subtract.index = pd.to_datetime(rf_subtract.index, format = 'Y%-%m-%d')

        union_index = etf.index.intersection(rf_subtract.index)
        etf = etf.loc[union_index,:]
        rf_subtract = rf_subtract.loc[union_index, :]
        for e in etf.columns:
            etf.loc[:,e] = etf.loc[:,e] - rf_subtract['RF']

        index_symbol = 'Mkt-RF'
        
        print(etf.head(5))

        #start date for data
        start = '2004-01-01'
        #end date for data
        end = '2020-01-01'


        #control the leverage
        lev = 1.
        stk_symbols  = etf.columns
        returns = etf.copy()


        #set the backtest parameters
        bp = BacktestParameters(stk_symbols, start, end, lookback, lev  )
        bt = Backtest(bp, returns, mode = 'insample')
        data = Data(bp)

        p = data.get_probability(returns, factor_model, rf)
        df_alpha, idiosyncratic_vol, binary_alpha = data.get_alpha(returns, factor_model, rf)
        rolling_mean_12, rolling_mean_6, rolling_std_12, binary_mean_12,binary_mean_6,binary_returns, rolling_sum_12s = data.get_rolling_features(returns, 0.0)


        #creates a dictionary of different features for analysis based on ticker keys
        feature_list = [binary_returns]
        
        feature_set = data.get_features(feature_list)
        

 
        for k in feature_set.keys():
            feature_set[k] = pd.concat([feature_set[k], policy_uncertainty],axis = 1)
            feature_set[k] = feature_set[k][(feature_set[k].index > binary_alpha.index.min()) & (feature_set[k].index < binary_alpha.index.max())]
               
        data_type = 'sector_etf_universe'

        factor_results, factor_results_capm, factor_reg,factor_results_scaled, factor_results_capm_scaled = write_outputs(bt, ff_factors_compare, umd, q_factor, returns, lookback_backtest, feature_set, binary_returns,backtest_write, image_write, cur_wd, data_type )
        
        if alpha_ff5.empty:
            alpha_ff5 = factor_results.copy()
            alpha_capm = factor_results_capm.copy()
        else:
            alpha_ff5 = pd.concat( [alpha_ff5, factor_results], axis = 1)
            alpha_capm = pd.concat( [alpha_capm, factor_results_capm], axis = 1)
            
        if alpha_ff5_scaled.empty:
            alpha_ff5_scaled = factor_results_scaled.copy()
            alpha_capm_scaled = factor_results_capm_scaled.copy()
        else:
            alpha_ff5_scaled = pd.concat( [alpha_ff5_scaled, factor_results_scaled], axis = 1)
            alpha_capm_scaled = pd.concat( [alpha_capm_scaled, factor_results_capm_scaled], axis = 1)      
   

        plt.close('all')

        ######################################################
        #write the alphas to a csv
        #annualize the alphas
        
        
        alpha_ff5.to_csv('alphaff5.csv')
        alpha_capm.to_csv('alphacapm.csv')
        alpha_ff5_scaled.to_csv('alphaff5_scaled.csv')
        alpha_capm_scaled.to_csv('alphacapm_scaled.csv')
        
        plt.close('all')
# Out:
#                R_MKT      R_ME      R_IA     R_ROE      R_EG
# 1967-01-01  0.081603  0.067282 -0.029434  0.018866 -0.022469
# 1967-02-01  0.007202  0.016918 -0.002064  0.035317  0.025812
# 1967-03-01  0.039691  0.019517 -0.016933  0.018876 -0.014789
# 1967-04-01  0.038265 -0.007446 -0.029519  0.010983 -0.022351
# 1967-05-01 -0.042419  0.029132  0.024686  0.005234  0.002749
#                R_MKT      R_ME      R_IA     R_ROE      R_EG
# 1969-02-01  0.006427  0.014905 -0.001126 -0.000798  0.001941
# 1969-03-01  0.005585  0.013251 -0.000919 -0.000721  0.001369
# 1969-04-01  0.003210  0.011505 -0.001453 -0.000073  0.001297
# 1969-05-01  0.003197  0.012178 -0.001794 -0.000628  0.002195
# 1969-06-01  0.003807  0.015288  0.000646  0.001520  0.003685
#                R_MKT      R_ME      R_IA     R_ROE      R_EG
# 1969-02-01  0.025691  0.023400  0.013505  0.013798  0.011149
# 1969-03-01  0.025335  0.023177  0.013515  0.013790  0.011245
# 1969-04-01  0.026000  0.024030  0.013552  0.012840  0.010532
# 1969-05-01  0.027377  0.023975  0.013570  0.013002  0.010885
# 1969-06-01  0.027505  0.022747  0.013988  0.013584  0.010469
# KNN
# Long and Short
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                    0.8012
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):              0.549
# Time:                        13:13:24   Log-Likelihood:                 1660.4
# No. Observations:                 596   AIC:                            -3309.
# Df Residuals:                     590   BIC:                            -3282.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0270      0.024     -1.127      0.260      -0.074       0.020
# SMB            0.0117      0.035      0.331      0.741      -0.057       0.081
# HML           -0.0375      0.038     -0.979      0.328      -0.113       0.038
# RMW           -0.0177      0.057     -0.310      0.757      -0.130       0.094
# CMA            0.0781      0.055      1.412      0.158      -0.030       0.187
# intercept      0.0030      0.001      4.620      0.000       0.002       0.004
# ==============================================================================
# Omnibus:                       44.141   Durbin-Watson:                   2.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.493
# Skew:                          -0.176   Prob(JB):                     5.76e-38
# Kurtosis:                       5.604   Cond. No.                         84.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.648
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):              0.200
# Time:                        13:13:24   Log-Likelihood:                 1658.2
# No. Observations:                 596   AIC:                            -3312.
# Df Residuals:                     594   BIC:                            -3304.
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0297      0.023     -1.284      0.199      -0.075       0.016
# intercept      0.0031      0.001      4.754      0.000       0.002       0.004
# ==============================================================================
# Omnibus:                       43.186   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              169.592
# Skew:                          -0.150   Prob(JB):                     1.49e-37
# Kurtosis:                       5.596   Cond. No.                         22.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     1.070
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):              0.371
# Time:                        13:13:24   Log-Likelihood:                 1665.8
# No. Observations:                 596   AIC:                            -3322.
# Df Residuals:                     591   BIC:                            -3300.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0217      0.023     -0.950      0.342      -0.067       0.023
# SMB            0.0197      0.033      0.601      0.548      -0.044       0.084
# HML            0.0159      0.036      0.444      0.657      -0.054       0.086
# Mom            0.0555      0.031      1.791      0.073      -0.005       0.116
# intercept      0.0026      0.001      3.758      0.000       0.001       0.004
# ==============================================================================
# Omnibus:                       51.556   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              270.209
# Skew:                          -0.016   Prob(JB):                     2.11e-59
# Kurtosis:                       6.298   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     5.770
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           3.27e-05
# Time:                        13:13:24   Log-Likelihood:                 1682.5
# No. Observations:                 596   AIC:                            -3353.
# Df Residuals:                     590   BIC:                            -3327.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT          0.0046      0.023      0.196      0.844      -0.041       0.050
# R_ME           0.0648      0.035      1.835      0.067      -0.004       0.134
# R_IA           0.0120      0.053      0.227      0.821      -0.092       0.116
# R_ROE         -0.0467      0.046     -1.026      0.305      -0.136       0.043
# R_EG           0.2674      0.050      5.311      0.000       0.169       0.366
# intercept      0.0007      0.001      0.966      0.334      -0.001       0.002
# ==============================================================================
# Omnibus:                       60.281   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              197.899
# Skew:                          -0.439   Prob(JB):                     1.06e-43
# Kurtosis:                       5.683   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                    0.8571
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):              0.425
# Time:                        13:13:24   Log-Likelihood:                 1658.2
# No. Observations:                 596   AIC:                            -3310.
# Df Residuals:                     593   BIC:                            -3297.
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF            -0.0298      0.023     -1.309      0.191      -0.074       0.015
# market_squared    -0.0030      0.294     -0.010      0.992      -0.580       0.574
# intercept          0.0031      0.001      4.583      0.000       0.002       0.004
# ==============================================================================
# Omnibus:                       43.132   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              169.601
# Skew:                          -0.148   Prob(JB):                     1.48e-37
# Kurtosis:                       5.596   Cond. No.                         259.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                    0.9431
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):              0.390
# Time:                        13:13:24   Log-Likelihood:                 1658.3
# No. Observations:                 596   AIC:                            -3311.
# Df Residuals:                     593   BIC:                            -3297.
# Df Model:                           2
# Covariance Type:                  HAC
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Mkt-RF          -0.0248      0.046     -0.544      0.587      -0.114       0.065
# market_dummy    -0.0102      0.070     -0.146      0.884      -0.147       0.127
# intercept        0.0032      0.001      3.282      0.001       0.001       0.005
# ==============================================================================
# Omnibus:                       42.440   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              169.197
# Skew:                          -0.121   Prob(JB):                     1.82e-37
# Kurtosis:                       5.599   Cond. No.                         77.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.5001
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):              0.776
# Time:                        13:13:24   Log-Likelihood:                 1519.8
# No. Observations:                 596   AIC:                            -3028.
# Df Residuals:                     590   BIC:                            -3001.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0257      0.029     -0.898      0.369      -0.082       0.030
# SMB            0.0119      0.041      0.288      0.773      -0.069       0.093
# HML           -0.0491      0.043     -1.140      0.254      -0.133       0.035
# RMW           -0.0015      0.062     -0.024      0.981      -0.122       0.119
# CMA            0.0556      0.061      0.905      0.365      -0.065       0.176
# intercept      0.0042      0.001      4.987      0.000       0.003       0.006
# ==============================================================================
# Omnibus:                       23.781   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.518
# Skew:                          -0.146   Prob(JB):                     8.80e-13
# Kurtosis:                       4.467   Cond. No.                         84.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                    0.8339
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):              0.362
# Time:                        13:13:24   Log-Likelihood:                 1518.8
# No. Observations:                 596   AIC:                            -3034.
# Df Residuals:                     594   BIC:                            -3025.
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0244      0.027     -0.913      0.361      -0.077       0.028
# intercept      0.0042      0.001      5.203      0.000       0.003       0.006
# ==============================================================================
# Omnibus:                       25.394   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               60.455
# Skew:                          -0.164   Prob(JB):                     7.45e-14
# Kurtosis:                       4.526   Cond. No.                         22.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     2.038
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):             0.0877
# Time:                        13:13:24   Log-Likelihood:                 1529.7
# No. Observations:                 596   AIC:                            -3049.
# Df Residuals:                     591   BIC:                            -3027.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0133      0.027     -0.490      0.624      -0.066       0.040
# SMB            0.0168      0.038      0.439      0.661      -0.058       0.092
# HML            0.0054      0.039      0.138      0.890      -0.071       0.082
# Mom            0.0837      0.030      2.753      0.006       0.024       0.143
# intercept      0.0036      0.001      4.260      0.000       0.002       0.005
# ==============================================================================
# Omnibus:                       24.067   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               62.020
# Skew:                          -0.069   Prob(JB):                     3.41e-14
# Kurtosis:                       4.574   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.094
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     7.217
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           1.43e-06
# Time:                        13:13:24   Log-Likelihood:                 1547.4
# No. Observations:                 596   AIC:                            -3083.
# Df Residuals:                     590   BIC:                            -3056.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT          0.0169      0.028      0.606      0.545      -0.038       0.072
# R_ME           0.0818      0.041      2.000      0.045       0.002       0.162
# R_IA          -0.0505      0.060     -0.836      0.403      -0.169       0.068
# R_ROE         -0.0509      0.049     -1.047      0.295      -0.146       0.044
# R_EG           0.3765      0.065      5.761      0.000       0.248       0.505
# intercept      0.0012      0.001      1.254      0.210      -0.001       0.003
# ==============================================================================
# Omnibus:                       25.348   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.793
# Skew:                          -0.292   Prob(JB):                     1.88e-10
# Kurtosis:                       4.209   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                    0.6141
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):              0.541
# Time:                        13:13:24   Log-Likelihood:                 1519.0
# No. Observations:                 596   AIC:                            -3032.
# Df Residuals:                     593   BIC:                            -3019.
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF            -0.0261      0.026     -1.006      0.314      -0.077       0.025
# market_squared    -0.1229      0.350     -0.351      0.726      -0.809       0.563
# intercept          0.0045      0.001      5.074      0.000       0.003       0.006
# ==============================================================================
# Omnibus:                       23.806   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               58.057
# Skew:                          -0.116   Prob(JB):                     2.47e-13
# Kurtosis:                       4.511   Cond. No.                         259.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                    0.9749
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):              0.378
# Time:                        13:13:24   Log-Likelihood:                 1519.4
# No. Observations:                 596   AIC:                            -3033.
# Df Residuals:                     593   BIC:                            -3020.
# Df Model:                           2
# Covariance Type:                  HAC
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Mkt-RF           0.0022      0.054      0.041      0.968      -0.103       0.108
# market_dummy    -0.0550      0.080     -0.691      0.490      -0.211       0.101
# intercept        0.0052      0.001      4.284      0.000       0.003       0.008
# ==============================================================================
# Omnibus:                       22.431   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               54.986
# Skew:                          -0.072   Prob(JB):                     1.15e-12
# Kurtosis:                       4.481   Cond. No.                         77.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Long Only
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.169
# Method:                 Least Squares   F-statistic:                     12.31
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           2.24e-11
# Time:                        13:13:39   Log-Likelihood:                 1979.2
# No. Observations:                 596   AIC:                            -3946.
# Df Residuals:                     590   BIC:                            -3920.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0737      0.014      5.446      0.000       0.047       0.100
# SMB            0.0734      0.020      3.600      0.000       0.033       0.113
# HML           -0.0411      0.022     -1.830      0.067      -0.085       0.003
# RMW            0.0899      0.034      2.625      0.009       0.023       0.157
# CMA            0.1538      0.033      4.688      0.000       0.090       0.218
# intercept      0.0028      0.000      7.173      0.000       0.002       0.004
# ==============================================================================
# Omnibus:                       42.515   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              169.658
# Skew:                          -0.122   Prob(JB):                     1.44e-37
# Kurtosis:                       5.602   Cond. No.                         84.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.068
# Method:                 Least Squares   F-statistic:                     16.33
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           6.03e-05
# Time:                        13:13:39   Log-Likelihood:                 1943.1
# No. Observations:                 596   AIC:                            -3882.
# Df Residuals:                     594   BIC:                            -3873.
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0566      0.014      4.041      0.000       0.029       0.084
# intercept      0.0036      0.000      8.832      0.000       0.003       0.004
# ==============================================================================
# Omnibus:                       77.650   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              647.878
# Skew:                           0.183   Prob(JB):                    2.07e-141
# Kurtosis:                       8.095   Cond. No.                         22.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.214
# Model:                            OLS   Adj. R-squared:                  0.208
# Method:                 Least Squares   F-statistic:                     15.57
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           4.08e-12
# Time:                        13:13:39   Log-Likelihood:                 1993.2
# No. Observations:                 596   AIC:                            -3976.
# Df Residuals:                     591   BIC:                            -3954.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0687      0.013      5.344      0.000       0.044       0.094
# SMB            0.0571      0.016      3.476      0.001       0.025       0.089
# HML            0.0584      0.022      2.704      0.007       0.016       0.101
# Mom            0.0764      0.018      4.229      0.000       0.041       0.112
# intercept      0.0028      0.000      6.879      0.000       0.002       0.004
# ==============================================================================
# Omnibus:                      102.047   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              872.371
# Skew:                           0.460   Prob(JB):                    3.69e-190
# Kurtosis:                       8.855   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.442
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     38.72
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           2.10e-34
# Time:                        13:13:39   Log-Likelihood:                 2095.6
# No. Observations:                 596   AIC:                            -4179.
# Df Residuals:                     590   BIC:                            -4153.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT          0.1023      0.012      8.797      0.000       0.079       0.125
# R_ME           0.1324      0.018      7.497      0.000       0.098       0.167
# R_IA           0.1060      0.026      4.000      0.000       0.054       0.158
# R_ROE          0.0766      0.023      3.366      0.001       0.032       0.121
# R_EG           0.2337      0.025      9.283      0.000       0.184       0.283
# intercept      0.0004      0.000      0.966      0.334      -0.000       0.001
# ==============================================================================
# Omnibus:                       60.281   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              197.899
# Skew:                          -0.439   Prob(JB):                     1.06e-43
# Kurtosis:                       5.683   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     8.561
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           0.000216
# Time:                        13:13:39   Log-Likelihood:                 1943.3
# No. Observations:                 596   AIC:                            -3881.
# Df Residuals:                     593   BIC:                            -3867.
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF             0.0557      0.014      4.128      0.000       0.029       0.082
# market_squared    -0.0584      0.158     -0.369      0.712      -0.368       0.251
# intercept          0.0038      0.000      9.625      0.000       0.003       0.005
# ==============================================================================
# Omnibus:                       80.500   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              663.107
# Skew:                           0.239   Prob(JB):                    1.02e-144
# Kurtosis:                       8.145   Cond. No.                         259.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     8.880
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           0.000159
# Time:                        13:13:39   Log-Likelihood:                 1943.3
# No. Observations:                 596   AIC:                            -3881.
# Df Residuals:                     593   BIC:                            -3867.
# Df Model:                           2
# Covariance Type:                  HAC
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Mkt-RF           0.0643      0.028      2.262      0.024       0.009       0.120
# market_dummy    -0.0160      0.041     -0.387      0.699      -0.097       0.065
# intercept        0.0039      0.001      6.591      0.000       0.003       0.005
# ==============================================================================
# Omnibus:                       81.078   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              666.350
# Skew:                           0.248   Prob(JB):                    2.01e-145
# Kurtosis:                       8.156   Cond. No.                         77.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.150
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     11.54
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           1.19e-10
# Time:                        13:13:39   Log-Likelihood:                 1794.2
# No. Observations:                 596   AIC:                            -3576.
# Df Residuals:                     590   BIC:                            -3550.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0965      0.017      5.739      0.000       0.064       0.129
# SMB            0.0864      0.025      3.466      0.001       0.038       0.135
# HML           -0.0569      0.026     -2.174      0.030      -0.108      -0.006
# RMW            0.1087      0.037      2.942      0.003       0.036       0.181
# CMA            0.1601      0.038      4.240      0.000       0.086       0.234
# intercept      0.0040      0.001      7.365      0.000       0.003       0.005
# ==============================================================================
# Omnibus:                       33.468   Durbin-Watson:                   1.907
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.013
# Skew:                           0.172   Prob(JB):                     3.16e-22
# Kurtosis:                       4.967   Cond. No.                         84.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.078
# Method:                 Least Squares   F-statistic:                     23.20
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           1.86e-06
# Time:                        13:13:39   Log-Likelihood:                 1770.3
# No. Observations:                 596   AIC:                            -3537.
# Df Residuals:                     594   BIC:                            -3528.
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0811      0.017      4.816      0.000       0.048       0.114
# intercept      0.0049      0.001      8.917      0.000       0.004       0.006
# ==============================================================================
# Omnibus:                       47.801   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              204.873
# Skew:                           0.170   Prob(JB):                     3.25e-45
# Kurtosis:                       5.852   Cond. No.                         22.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.209
# Model:                            OLS   Adj. R-squared:                  0.203
# Method:                 Least Squares   F-statistic:                     18.51
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           2.43e-14
# Time:                        13:13:39   Log-Likelihood:                 1815.4
# No. Observations:                 596   AIC:                            -3621.
# Df Residuals:                     591   BIC:                            -3599.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF         0.0950      0.016      5.941      0.000       0.064       0.126
# SMB            0.0667      0.020      3.269      0.001       0.027       0.107
# HML            0.0555      0.024      2.350      0.019       0.009       0.102
# Mom            0.1019      0.017      5.880      0.000       0.068       0.136
# intercept      0.0039      0.001      7.209      0.000       0.003       0.005
# ==============================================================================
# Omnibus:                       66.458   Durbin-Watson:                   1.824
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              289.133
# Skew:                           0.392   Prob(JB):                     1.64e-63
# Kurtosis:                       6.321   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.401
# Model:                            OLS   Adj. R-squared:                  0.396
# Method:                 Least Squares   F-statistic:                     37.26
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           3.18e-33
# Time:                        13:13:39   Log-Likelihood:                 1898.4
# No. Observations:                 596   AIC:                            -3785.
# Df Residuals:                     590   BIC:                            -3758.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT          0.1345      0.015      8.939      0.000       0.105       0.164
# R_ME           0.1664      0.022      7.658      0.000       0.124       0.209
# R_IA           0.0867      0.031      2.768      0.006       0.025       0.148
# R_ROE          0.1013      0.025      4.008      0.000       0.052       0.151
# R_EG           0.3090      0.036      8.556      0.000       0.238       0.380
# intercept      0.0008      0.000      1.622      0.105      -0.000       0.002
# ==============================================================================
# Omnibus:                       27.779   Durbin-Watson:                   1.862
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.420
# Skew:                           0.010   Prob(JB):                     2.09e-18
# Kurtosis:                       4.811   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     11.81
# Date:                Tue, 01 Jun 2021   Prob (F-statistic):           9.31e-06
# Time:                        13:13:39   Log-Likelihood:                 1771.4
# No. Observations:                 596   AIC:                            -3537.
# Df Residuals:                     593   BIC:                            -3524.
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF             0.0784      0.016      4.857      0.000       0.047       0.110
# market_squared    -0.1919      0.201     -0.953      0.340      -0.586       0.203
# intercept          0.0053      0.001      9.418      0.000       0.004       0.006
# ==============================================================================
# Omnibus:                       51.621   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              208.349
# ...
# Method:                 Least Squares   F-statistic:                     1.868
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):              0.155
# Time:                        09:16:17   Log-Likelihood:                 2167.3
# No. Observations:                 597   AIC:                            -4329.
# Df Residuals:                     594   BIC:                            -4316.
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF            -0.0139      0.009     -1.485      0.138      -0.032       0.004
# market_squared    -0.0079      0.099     -0.080      0.936      -0.201       0.185
# intercept         -0.0001      0.000     -0.555      0.579      -0.001       0.000
# ==============================================================================
# Omnibus:                      301.394   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6946.854
# Skew:                           1.709   Prob(JB):                         0.00
# Kurtosis:                      19.358   Cond. No.                         260.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.748
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):              0.175
# Time:                        09:16:17   Log-Likelihood:                 2167.3
# No. Observations:                 597   AIC:                            -4329.
# Df Residuals:                     594   BIC:                            -4316.
# Df Model:                           2
# Covariance Type:                  HAC
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Mkt-RF          -0.0140      0.011     -1.235      0.217      -0.036       0.008
# market_dummy     0.0005      0.026      0.018      0.986      -0.051       0.052
# intercept       -0.0002      0.000     -0.410      0.682      -0.001       0.001
# ==============================================================================
# Omnibus:                      299.878   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6875.133
# Skew:                           1.698   Prob(JB):                         0.00
# Kurtosis:                      19.274   Cond. No.                         77.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.092
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     7.600
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):           6.22e-07
# Time:                        09:16:17   Log-Likelihood:                 2081.9
# No. Observations:                 597   AIC:                            -4152.
# Df Residuals:                     591   BIC:                            -4126.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0137      0.008     -1.730      0.084      -0.029       0.002
# SMB           -0.0049      0.013     -0.372      0.710      -0.031       0.021
# HML            0.0152      0.017      0.894      0.371      -0.018       0.049
# RMW           -0.0608      0.017     -3.489      0.000      -0.095      -0.027
# CMA            0.0737      0.025      2.964      0.003       0.025       0.122
# intercept     -0.0004      0.000     -1.294      0.196      -0.001       0.000
# ==============================================================================
# Omnibus:                      422.162   Durbin-Watson:                   1.836
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20527.486
# Skew:                           2.523   Prob(JB):                         0.00
# Kurtosis:                      31.280   Cond. No.                         84.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     8.344
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):            0.00401
# Time:                        09:16:17   Log-Likelihood:                 2058.3
# No. Observations:                 597   AIC:                            -4113.
# Df Residuals:                     595   BIC:                            -4104.
# Df Model:                           1
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0228      0.008     -2.889      0.004      -0.038      -0.007
# intercept     -0.0003      0.000     -0.856      0.392      -0.001       0.000
# ==============================================================================
# Omnibus:                      428.268   Durbin-Watson:                   1.838
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20852.205
# Skew:                           2.581   Prob(JB):                         0.00
# Kurtosis:                      31.489   Cond. No.                         22.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.044
# Method:                 Least Squares   F-statistic:                     5.310
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):           0.000331
# Time:                        09:16:17   Log-Likelihood:                 2068.3
# No. Observations:                 597   AIC:                            -4127.
# Df Residuals:                     592   BIC:                            -4105.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Mkt-RF        -0.0198      0.008     -2.574      0.010      -0.035      -0.005
# SMB            0.0107      0.015      0.732      0.464      -0.018       0.039
# HML            0.0397      0.013      3.019      0.003       0.014       0.065
# Mom           -0.0135      0.013     -1.023      0.306      -0.039       0.012
# intercept     -0.0003      0.000     -1.018      0.309      -0.001       0.000
# ==============================================================================
# Omnibus:                      413.193   Durbin-Watson:                   1.846
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            18796.449
# Skew:                           2.462   Prob(JB):                         0.00
# Kurtosis:                      30.044   Cond. No.                         38.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.169
# Model:                            OLS   Adj. R-squared:                  0.162
# Method:                 Least Squares   F-statistic:                     9.610
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):           7.84e-09
# Time:                        09:16:17   Log-Likelihood:                 2108.2
# No. Observations:                 597   AIC:                            -4204.
# Df Residuals:                     591   BIC:                            -4178.
# Df Model:                           5
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# R_MKT         -0.0219      0.008     -2.727      0.006      -0.038      -0.006
# R_ME          -0.0270      0.014     -1.863      0.062      -0.055       0.001
# R_IA           0.0844      0.022      3.853      0.000       0.041       0.127
# R_ROE         -0.1030      0.021     -4.830      0.000      -0.145      -0.061
# R_EG          -0.0270      0.034     -0.795      0.427      -0.094       0.040
# intercept      0.0002      0.001      0.464      0.642      -0.001       0.001
# ==============================================================================
# Omnibus:                      362.371   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14514.311
# Skew:                           2.043   Prob(JB):                         0.00
# Kurtosis:                      26.807   Cond. No.                         77.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     4.370
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):             0.0131
# Time:                        09:16:17   Log-Likelihood:                 2058.6
# No. Observations:                 597   AIC:                            -4111.
# Df Residuals:                     594   BIC:                            -4098.
# Df Model:                           2
# Covariance Type:                  HAC
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Mkt-RF            -0.0237      0.008     -2.807      0.005      -0.040      -0.007
# market_squared    -0.0629      0.087     -0.720      0.471      -0.234       0.108
# intercept         -0.0001      0.000     -0.394      0.694      -0.001       0.001
# ==============================================================================
# Omnibus:                      429.801   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20837.447
# Skew:                           2.598   Prob(JB):                         0.00
# Kurtosis:                      31.473   Cond. No.                         260.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portfolio   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     4.224
# Date:                Thu, 03 Jun 2021   Prob (F-statistic):             0.0151
# Time:                        09:16:17   Log-Likelihood:                 2058.5
# No. Observations:                 597   AIC:                            -4111.
# Df Residuals:                     594   BIC:                            -4098.
# Df Model:                           2
# Covariance Type:                  HAC
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Mkt-RF          -0.0157      0.012     -1.306      0.192      -0.039       0.008
# market_dummy    -0.0147      0.024     -0.608      0.543      -0.062       0.033
# intercept    -1.802e-05      0.001     -0.035      0.972      -0.001       0.001
# ==============================================================================
# Omnibus:                      428.885   Durbin-Watson:                   1.836
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20703.096
# Skew:                           2.590   Prob(JB):                         0.00
# Kurtosis:                      31.380   Cond. No.                         77.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 1 lags and without small sample correction
# Ensemble System

# %% [markdown]
# Lets clean up the input of the alpha parameters

# %%
alpha_ff5 = pd.read_csv('alphaff5.csv', index_col = 0).T
alpha_capm = pd.read_csv('alphacapm.csv', index_col = 0).T

alpha_ff5_clean  = alpha_ff5.copy()
alpha_capm_clean = alpha_capm.copy()

alpha_ff5_clean.loc[:, 'lookback feature'] = ''
alpha_ff5_clean.loc[:, 'lookback ml model'] = ''
alpha_ff5_clean.loc[:, 'new index'] = ''

alpha_capm_clean.loc[:, 'lookback feature'] = ''
alpha_capm_clean.loc[:, 'lookback ml model'] = ''
alpha_capm_clean.loc[:, 'new index'] = ''

for count, row in alpha_ff5.iterrows():
    alpha_ff5_clean.loc[count, 'lookback feature'] = count.split('_')[-2]
    alpha_ff5_clean.loc[count, 'lookback ml model'] = count.split('_')[-1]
    alpha_ff5_clean.loc[count, 'new index'] = "_".join(count.split('_')[0:-2])
   
for count, row in alpha_capm.iterrows():
    alpha_capm_clean.loc[count, 'lookback feature'] = count.split('_')[-2]
    alpha_capm_clean.loc[count, 'lookback ml model'] = count.split('_')[-1]
    alpha_capm_clean.loc[count, 'new index'] = "_".join(count.split('_')[0:-2])
    
alpha_capm_clean.index = alpha_capm_clean.loc[:, 'new index']
alpha_ff5_clean.index = alpha_ff5_clean.loc[:, 'new index']

alpha_capm_clean.drop('new index', axis = 1, inplace = True)
alpha_capm.index.name = 'strategy'
alpha_ff5_clean.drop('new index', axis = 1, inplace = True)
alpha_ff5_clean.index.name = 'strategy'

alpha_ff5_clean.to_csv('alphaff5_cleaned.csv')
alpha_capm_clean.to_csv('alphacapm_cleaned.csv')
alpha_ff5_clean.to_latex('alphaff5_latex.txt')
alpha_capm_clean.to_latex('alphacapm_latex.txt')

# %%
#get the alphas for a backtest across individual portfolios

# %%
alpha_ff5_scaled
