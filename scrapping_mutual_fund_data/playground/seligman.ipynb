# %%
import os
import pandas as pd
from lxml import html
import requests
import re
import sys
from datetime import datetime

from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import time
import pickle
import string

# %%
fund_name = 'seligman'


CIK_LIST = ['316411']

# %%
cur_wd = os.getcwd()
if 'trunk' in cur_wd:
    output_directory = os.path.join("\\".join(cur_wd.split('\\')[0:-1]),'output')
else:
    output_directory = os.path.join("\\".join(cur_wd.split('\\')[0:-1]),'output','working')
    
cached_wd = os.path.join("\\".join(cur_wd.split('\\')[0:-1]),'cached_data')
cur_wd = os.path.join("\\".join(cur_wd.split('\\')[0:-1]),'data')
print('data directory')
print(cur_wd)
print('output directory')
print(output_directory)

print('cached data')
print(cached_wd)
# Out:
# data directory
# C:\Users\jjanko\Desktop\wei_mutual_fund_project\data
# output directory
# C:\Users\jjanko\Desktop\wei_mutual_fund_project\output\working
# cached data
# C:\Users\jjanko\Desktop\wei_mutual_fund_project\cached_data

# %%
weblink = {}
txt = []

for CIK in CIK_LIST:
    weblink[CIK]  = []
    txt_files = os.listdir(os.path.join(cur_wd, CIK, 'n-q'))
    for i in txt_files:
        txt.append(i)
        weblink[CIK].append(r"https://www.sec.gov/Archives/edgar/data/" + str(CIK)+r"/"  + i)

# %%
with open(os.path.join(cached_wd, 'errors_dict.pickle'), 'rb') as handle:
    errors = pickle.load(handle)
    
print(errors)
# Out:
# {'867297': ['0001193125-04-202597.txt', '0001193125-05-115532.txt', '0001193125-05-232633.txt'], '1091439': ['0000950152-04-008622.txt', '0000950152-05-004867.txt', '0000950152-05-009599.txt'], '1301708': ['0000950152-05-009600.txt'], '1423227': [], '1098605': ['0000950136-05-006141.txt', '0000950136-04-003174.txt', '0000950136-05-001871.txt'], '1378240': ['0001104659-07-029038.txt', '0001104659-07-077264.txt', '0001104659-08-027201.txt', '0001104659-08-064591.txt'], '726735': ['0000950129-04-009378.txt', '0000950129-05-005810.txt', '0000950129-05-011455.txt'], '844779': ['0001193125-05-039836.txt', '0001193125-05-175146.txt', '0001193125-05-175147.txt', '0001193125-05-175620.txt'], '1398078': [], '774013': ['0001193805-05-000319.txt', '0001193805-05-001781.txt', '0001193805-05-002628.txt', '0001193805-05-002636.txt', '0001193805-05-002638.txt'], '1062806': ['0000900092-04-000310.txt', '0000900092-05-000103.txt', '0000900092-05-000135.txt', '0000900092-05-000453.txt', '0001193805-04-001626.txt', '0001193805-05-002132.txt'], '1026144': ['0001193805-04-001796.txt', '0001193805-04-001803.txt', '0001193805-04-001824.txt', '0001193805-04-001836.txt', '0001193805-05-000898.txt', '0001193805-05-001187.txt', '0001193805-05-001197.txt', '0001193805-05-001217.txt', '0001193805-05-001228.txt', '0001193805-05-002368.txt', '0001193805-05-002374.txt', '0001193805-05-002382.txt', '0001193805-05-002390.txt'], '1062805': ['0000900092-04-000311.txt', '0000900092-05-000104.txt', '0000900092-05-000136.txt', '0000900092-05-000454.txt', '0001193805-04-001628.txt', '0001193805-05-000900.txt', '0001193805-05-002134.txt'], '276463': ['0000900092-05-000045.txt', '0000900092-05-000047.txt', '0000900092-05-000052.txt', '0000900092-05-000113.txt', '0000900092-05-000374.txt', '0000900092-05-000376.txt', '0000900092-05-000377.txt'], '1097077': ['0001193805-04-001466.txt', '0001193805-04-001490.txt', '0001193805-04-001495.txt', '0001193805-05-000623.txt', '0001193805-05-000639.txt', '0001193805-05-000651.txt', '0001193805-05-001991.txt', '0001193805-05-001995.txt', '0001193805-05-001999.txt'], '1137391': ['0000891092-13-005525.txt', '0000891092-13-010218.txt', '0000891092-14-004773.txt', '0000891092-14-009551.txt', '0000891092-15-005304.txt', '0000930413-04-004580.txt', '0000930413-05-002397.txt', '0000930413-05-006885.txt', '0000930413-06-002593.txt', '0000930413-06-007049.txt', '0000930413-07-002985.txt', '0000930413-07-007633.txt', '0000930413-08-002117.txt', '0000930413-08-007373.txt', '0001171200-09-000395.txt', '0001171200-09-001050.txt', '0001171200-10-000620.txt', '0001171200-10-001195.txt', '0001171200-11-000541.txt', '0001171200-11-001133.txt', '0001171200-12-000586.txt', '0001193125-12-512794.txt', '0001193125-15-410813.txt', '0001193125-16-628998.txt', '0001193125-16-798990.txt', '0001193125-17-210388.txt', '0001193125-17-376378.txt', '0001193125-18-197964.txt', '0001193125-18-356378.txt'], '1160864': ['0000891092-13-000558.txt', '0000891092-13-006494.txt', '0000891092-14-000498.txt', '0000891092-14-005548.txt', '0000891092-15-000459.txt', '0000891092-15-006483.txt', '0000930413-04-004572.txt', '0000930413-05-002392.txt', '0000930413-05-006895.txt', '0000930413-06-002619.txt', '0000930413-06-007033.txt', '0000930413-07-002962.txt', '0000930413-07-007640.txt', '0000930413-08-002102.txt', '0000930413-08-005678.txt', '0000930413-09-000518.txt', '0001171200-09-000501.txt', '0001171200-10-000067.txt', '0001171200-10-000744.txt', '0001171200-11-000053.txt', '0001171200-11-000652.txt', '0001171200-12-000097.txt', '0001171200-12-000716.txt', '0001193125-16-435647.txt', '0001193125-16-658423.txt', '0001193125-17-016352.txt', '0001193125-17-233962.txt', '0001193125-18-016079.txt', '0001193125-18-223365.txt', '0001193125-19-013796.txt'], '1181249': ['0000891092-13-005524.txt', '0000891092-13-010217.txt', '0000891092-14-004774.txt', '0000891092-14-009550.txt', '0000891092-15-005305.txt', '0000930413-04-005417.txt', '0000930413-05-003986.txt', '0000930413-05- ...

# %%
with open(os.path.join(cached_wd, 'panel2.pickle'), 'rb') as handle:
    panel2 = pickle.load(handle)

# %%
panel2 = panel2.loc[panel2['file_read'].isin(txt)]

# %%
print(panel2)
panel2.to_csv(os.path.join(output_directory, fund_name + '_panel2.csv'), sep = ',')
# Out:
#    CLASS-CONTRACT-ID                      CLASS-CONTRACT-NAME  \
# 0         C000026136      SELIGMAN GROWTH FUND, INC., CLASS A
# 1         C000026137      SELIGMAN GROWTH FUND, INC., CLASS B
# 2         C000026138      SELIGMAN GROWTH FUND, INC., CLASS C
# 3         C000026139      SELIGMAN GROWTH FUND, INC., CLASS D
# 4         C000026140      SELIGMAN GROWTH FUND, INC., CLASS I
# 5         C000026141      SELIGMAN GROWTH FUND, INC., CLASS R
# 0         C000026136      SELIGMAN GROWTH FUND, INC., CLASS A
# 1         C000026137      SELIGMAN GROWTH FUND, INC., CLASS B
# 2         C000026138      SELIGMAN GROWTH FUND, INC., CLASS C
# 3         C000026139      SELIGMAN GROWTH FUND, INC., CLASS D
# 4         C000026140      SELIGMAN GROWTH FUND, INC., CLASS I
# 5         C000026141      SELIGMAN GROWTH FUND, INC., CLASS R
# 0         C000026136      SELIGMAN GROWTH FUND, INC., CLASS A
# 1         C000026137      SELIGMAN GROWTH FUND, INC., CLASS B
# 2         C000026138      SELIGMAN GROWTH FUND, INC., CLASS C
# 3         C000026140     SELIGMAN GROWTH FUND, INC., CLASS R5
# 4         C000026141     SELIGMAN GROWTH FUND, INC., CLASS R2
# 5         C000076414  SELIGMAN GROWTH FUND, INC., NEW CLASS I
# 6         C000076415     SELIGMAN GROWTH FUND, INC., CLASS R3
# 7         C000076416     SELIGMAN GROWTH FUND, INC., CLASS R4
# 0         C000026136      SELIGMAN GROWTH FUND, INC., CLASS A
# 1         C000026137      SELIGMAN GROWTH FUND, INC., CLASS B
# 2         C000026138      SELIGMAN GROWTH FUND, INC., CLASS C
# 3         C000026140     SELIGMAN GROWTH FUND, INC., CLASS R5
# 4         C000026141     SELIGMAN GROWTH FUND, INC., CLASS R2
# 5         C000076414  SELIGMAN GROWTH FUND, INC., NEW CLASS I
# 6         C000076415     SELIGMAN GROWTH FUND, INC., CLASS R3
# 7         C000076416     SELIGMAN GROWTH FUND, INC., CLASS R4
# 0         C000026136      SELIGMAN GROWTH FUND, INC., CLASS A
# 1         C000026137      SELIGMAN GROWTH FUND, INC., CLASS B
# ..               ...                                      ...
# 1         C000026137      SELIGMAN GROWTH FUND, INC., CLASS B
# 2         C000026138      SELIGMAN GROWTH FUND, INC., CLASS C
# 3         C000026139      SELIGMAN GROWTH FUND, INC., CLASS D
# 4         C000026140      SELIGMAN GROWTH FUND, INC., CLASS I
# 5         C000026141      SELIGMAN GROWTH FUND, INC., CLASS R
# 0         C000026136      SELIGMAN GROWTH FUND, INC., CLASS A
# 1         C000026137      SELIGMAN GROWTH FUND, INC., CLASS B
# 2         C000026138      SELIGMAN GROWTH FUND, INC., CLASS C
# 3         C000026139      SELIGMAN GROWTH FUND, INC., CLASS D
# 4         C000026140      SELIGMAN GROWTH FUND, INC., CLASS I
# 5         C000026141      SELIGMAN GROWTH FUND, INC., CLASS R
# 0         C000026136      SELIGMAN GROWTH FUND, INC., CLASS A
# 1         C000026137      SELIGMAN GROWTH FUND, INC., CLASS B
# 2         C000026138      SELIGMAN GROWTH FUND, INC., CLASS C
# 3         C000026139      SELIGMAN GROWTH FUND, INC., CLASS D
# 4         C000026140      SELIGMAN GROWTH FUND, INC., CLASS I
# 5         C000026141      SELIGMAN GROWTH FUND, INC., CLASS R
# 0         C000026136      SELIGMAN GROWTH FUND, INC., CLASS A
# 1         C000026137      SELIGMAN GROWTH FUND, INC., CLASS B
# 2         C000026138      SELIGMAN GROWTH FUND, INC., CLASS C
# 3         C000026140      SELIGMAN GROWTH FUND, INC., CLASS I
# 4         C000026141      SELIGMAN GROWTH FUND, INC., CLASS R
# 0         C000026136      SELIGMAN GROWTH FUND, INC., CLASS A
# 1         C000026137      SELIGMAN GROWTH FUND, INC., CLASS B
# 2         C000026138      SELIGMAN GROWTH FUND, INC., CLASS C
# 3         C000026140      SELIGMAN GROWTH FUND, INC., CLASS I
# 4         C000026141      SELIGMAN GROWTH FUND, INC., CLASS R
# 5         C000076414  SELIGMAN GROWTH FUND, INC., NEW CLASS I
# 6         C000076415     SELIGMAN GROWTH FUND, INC., CLASS R3
# 7         C000076416     SELIGMAN GROWTH FUND, INC., CLASS R4
#
#    CLASS-CONTRACT-TICKER-SYMBOL   SERIES-ID   OWNER-CIK  \
# 0                         SGRFX  S000009569  0000316411
# 1                         SGBTX  S000009569  0000316411
# 2                         SGRCX  S000009569  0000316411
# 3                         SGRDX  S000009569  0000316411
# 4                         SGFIX  S000009569  0000316411
# 5                         SGFRX  S000009569  0000316411
# 0                         SGRFX  S000009569  0000316411
# 1                         SGBTX  S000009569  0000316411
# 2                         SGRCX  S000009569  0000316411
# 3                         SGRDX  S000009569  0000316411
# 4                         SGFIX  S000009569  0000316411
# 5                         SGFRX  S000009569  0000316411
# 0                         SGRFX  S000009569  0000316411
# 1                         SGBTX  S000009569  0000316411
# 2                         SGRCX  S000009569  0000316411
# 3                         SGFIX  S000009569  0000316411
# 4                         SGFRX  S000009569  0000316411
# 5                          None  S000009569  0000316411
# 6                          None  S000009569  0000316411
# 7                          None  S000009569  0000316411
# 0                         SGRFX  S000009569  0000316411
# 1                         SGBTX  S000009569  0000316411
# 2                         SGRCX  S000009569  0000316411
# 3                         SGFIX  S000009569  0000316411
# 4                         SGFRX  S000009569  0000316411
# 5                          None  S000009569  0000316411
# 6                          None  S000009569  0000316411
# 7                          None  S000009569  0000316411
# 0                         SGRFX  S000009569  0000316411
# 1                         SGBTX  S000009569  0000316411
# ..                          ...         ...         ...
# 1                         SGBTX  S000009569  0000316411
# 2                         SGRCX  S000009569  0000316411
# 3                         SGRDX  S000009569  0000316411
# 4                         SGFIX  S000009569  0000316411
# 5                         SGFRX  S000009569  0000316411
# 0                         SGRFX  S000009569  0000316411
# 1                         SGBTX  S000009569  0000316411
# 2                         SGRCX  S000009569  0000316411
# 3                         SGRDX  S000009569  0000316411
# 4                         SGFIX  S000009569  0000316411
# 5                         SGFRX  S000009569  0000316411
# 0                         SGRFX  S000009569  0000316411
# 1                         SGBTX  S000009569  0000316411
# 2                         SGRCX  S000009569  0000316411
# 3                         SGRDX  S000009569  0000316411
# 4                         SGFIX  S000009569  0000316411
# 5                         SGFRX  S000009569  0000316411
# 0                         SGRFX  S000009569  0000316411
# 1                         SGBTX  S000009569  0000316411
# 2                         SGRCX  S000009569  0000316411
# 3                         SGFIX  S000009569  0000316411
# 4                         SGFRX  S000009569  0000316411
# 0                         SGRFX  S000009569  0000316411
# 1                         SGBTX  S000009569  0000316411
# 2                         SGRCX  S000009569  0000316411
# 3                         SGFIX  S000009569  0000316411
# 4                         SGFRX  S000009569  0000316411
# 5                          None  S000009569  0000316411
# 6                          None  S000009569  0000316411
# 7                          None  S000009569  0000316411
#
#                    SERIES-NAME                 file_read date_filed  \
# 0   SELIGMAN GROWTH FUND, INC.  0000936329-06-000167.txt   20061127
# 1   SELIGMAN GROWTH FUND, INC.  0000936329-06-000167.txt   20061127
# 2   SELIGMAN GROWTH FUND, INC.  0000936329-06-000167.txt   20061127
# 3   SELIGMAN GROWTH FUND, INC.  0000936329-06-000167.txt   20061127
# 4   SELIGMAN GROWTH FUND, INC.  0000936329-06-000167.txt   20061127
# 5   SELIGMAN GROWTH FUND, INC.  0000936329-06-000167.txt   20061127
# 0   SELIGMAN GROWTH FUND, INC.  0000936329-07-000060.txt   20070525
# 1   SELIGMAN GROWTH FUND, INC.  0000936329-07-000060.txt   20070525
# 2   SELIGMAN GROWTH FUND, INC.  0000936329-07-000060.txt   20070525
# 3   SELIGMAN GROWTH FUND, INC.  0000936329-07-000060.txt   20070525
# 4   SELIGMAN GROWTH FUND, INC.  0000936329-07-000060.txt   20070525
# 5   SELIGMAN GROWTH FUND, INC.  0000936329-07-000060.txt   20070525
# 0   SELIGMAN GROWTH FUND, INC.  0000950123-09-065935.txt   20091125
# 1   SELIGMAN GROWTH FUND, INC.  0000950123-09-065935.txt   20091125
# 2   SELIGMAN GROWTH FUND, INC.  0000950123-09-065935.txt   20091125
# 3   SELIGMAN GROWTH FUND, INC.  0000950123-09-065935.txt   20091125
# 4   SELIGMAN GROWTH FUND, INC.  0000950123-09-065935.txt   20091125
# 5   SELIGMAN GROWTH FUND, INC.  0000950123-09-065935.txt   20091125
# 6   SELIGMAN GROWTH FUND, INC.  0000950123-09-065935.txt   20091125
# 7   SELIGMAN GROWTH FUND, INC.  0000950123-09-065935.txt   20091125
# 0   SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 1   SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 2   SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 3   SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 4   SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 5   SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 6   SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 7   SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 0   SELIGMAN GROWTH FUND, INC.  0000950123-10-109224.txt   20101129
# 1   SELIGMAN GROWTH FUND, INC.  0000950123-10-109224.txt   20101129
# ..                         ...                       ...        ...
# 1   SELIGMAN GROWTH FUND, INC.  0001145443-06-001745.txt   20060526
# 2   SELIGMAN GROWTH FUND, INC.  0001145443-06-001745.txt   20060526
# 3   SELIGMAN GROWTH FUND, INC.  0001145443-06-001745.txt   20060526
# 4   SELIGMAN GROWTH FUND, INC.  0001145443-06-001745.txt   20060526
# 5   SELIGMAN GROWTH FUND, INC.  0001145443-06-001745.txt   20060526
# 0   SELIGMAN GROWTH FUND, INC.  0001169232-07-004458.txt   20071127
# 1   SELIGMAN GROWTH FUND, INC.  0001169232-07-004458.txt   20071127
# 2   SELIGMAN GROWTH FUND, INC.  0001169232-07-004458.txt   20071127
# 3   SELIGMAN GROWTH FUND, INC.  0001169232-07-004458.txt   20071127
# 4   SELIGMAN GROWTH FUND, INC.  0001169232-07-004458.txt   20071127
# 5   SELIGMAN GROWTH FUND, INC.  0001169232-07-004458.txt   20071127
# 0   SELIGMAN GROWTH FUND, INC.  0001169232-08-002193.txt   20080528
# 1   SELIGMAN GROWTH FUND, INC.  0001169232-08-002193.txt   20080528
# 2   SELIGMAN GROWTH FUND, INC.  0001169232-08-002193.txt   20080528
# 3   SELIGMAN GROWTH FUND, INC.  0001169232-08-002193.txt   20080528
# 4   SELIGMAN GROWTH FUND, INC.  0001169232-08-002193.txt   20080528
# 5   SELIGMAN GROWTH FUND, INC.  0001169232-08-002193.txt   20080528
# 0   SELIGMAN GROWTH FUND, INC.  0001169232-08-004392.txt   20081125
# 1   SELIGMAN GROWTH FUND, INC.  0001169232-08-004392.txt   20081125
# 2   SELIGMAN GROWTH FUND, INC.  0001169232-08-004392.txt   20081125
# 3   SELIGMAN GROWTH FUND, INC.  0001169232-08-004392.txt   20081125
# 4   SELIGMAN GROWTH FUND, INC.  0001169232-08-004392.txt   20081125
# 0   SELIGMAN GROWTH FUND, INC.  0001169232-09-002769.txt   20090527
# 1   SELIGMAN GROWTH FUND, INC.  0001169232-09-002769.txt   20090527
# 2   SELIGMAN GROWTH FUND, INC.  0001169232-09-002769.txt   20090527
# 3   SELIGMAN GROWTH FUND, INC.  0001169232-09-002769.txt   20090527
# 4   SELIGMAN GROWTH FUND, INC.  0001169232-09-002769.txt   20090527
# 5   SELIGMAN GROWTH FUND, INC.  0001169232-09-002769.txt   20090527
# 6   SELIGMAN GROWTH FUND, INC.  0001169232-09-002769.txt   20090527
# 7   SELIGMAN GROWTH FUND, INC.  0001169232-09-002769.txt   20090527
#
#       company conformed name reporting_date
# 0   SELIGMAN GROWTH FUND INC       20060930
# 1   SELIGMAN GROWTH FUND INC       20060930
# 2   SELIGMAN GROWTH FUND INC       20060930
# 3   SELIGMAN GROWTH FUND INC       20060930
# 4   SELIGMAN GROWTH FUND INC       20060930
# 5   SELIGMAN GROWTH FUND INC       20060930
# 0   SELIGMAN GROWTH FUND INC       20070331
# 1   SELIGMAN GROWTH FUND INC       20070331
# 2   SELIGMAN GROWTH FUND INC       20070331
# 3   SELIGMAN GROWTH FUND INC       20070331
# 4   SELIGMAN GROWTH FUND INC       20070331
# 5   SELIGMAN GROWTH FUND INC       20070331
# 0   SELIGMAN GROWTH FUND INC       20090930
# 1   SELIGMAN GROWTH FUND INC       20090930
# 2   SELIGMAN GROWTH FUND INC       20090930
# 3   SELIGMAN GROWTH FUND INC       20090930
# 4   SELIGMAN GROWTH FUND INC       20090930
# 5   SELIGMAN GROWTH FUND INC       20090930
# 6   SELIGMAN GROWTH FUND INC       20090930
# 7   SELIGMAN GROWTH FUND INC       20090930
# 0   SELIGMAN GROWTH FUND INC       20100331
# 1   SELIGMAN GROWTH FUND INC       20100331
# 2   SELIGMAN GROWTH FUND INC       20100331
# 3   SELIGMAN GROWTH FUND INC       20100331
# 4   SELIGMAN GROWTH FUND INC       20100331
# 5   SELIGMAN GROWTH FUND INC       20100331
# 6   SELIGMAN GROWTH FUND INC       20100331
# 7   SELIGMAN GROWTH FUND INC       20100331
# 0   SELIGMAN GROWTH FUND INC       20100930
# 1   SELIGMAN GROWTH FUND INC       20100930
# ..                       ...            ...
# 1   SELIGMAN GROWTH FUND INC       20060331
# 2   SELIGMAN GROWTH FUND INC       20060331
# 3   SELIGMAN GROWTH FUND INC       20060331
# 4   SELIGMAN GROWTH FUND INC       20060331
# 5   SELIGMAN GROWTH FUND INC       20060331
# 0   SELIGMAN GROWTH FUND INC       20070930
# 1   SELIGMAN GROWTH FUND INC       20070930
# 2   SELIGMAN GROWTH FUND INC       20070930
# 3   SELIGMAN GROWTH FUND INC       20070930
# 4   SELIGMAN GROWTH FUND INC       20070930
# 5   SELIGMAN GROWTH FUND INC       20070930
# 0   SELIGMAN GROWTH FUND INC       20080331
# 1   SELIGMAN GROWTH FUND INC       20080331
# 2   SELIGMAN GROWTH FUND INC       20080331
# 3   SELIGMAN GROWTH FUND INC       20080331
# 4   SELIGMAN GROWTH FUND INC       20080331
# 5   SELIGMAN GROWTH FUND INC       20080331
# 0   SELIGMAN GROWTH FUND INC       20080930
# 1   SELIGMAN GROWTH FUND INC       20080930
# 2   SELIGMAN GROWTH FUND INC       20080930
# 3   SELIGMAN GROWTH FUND INC       20080930
# 4   SELIGMAN GROWTH FUND INC       20080930
# 0   SELIGMAN GROWTH FUND INC       20090331
# 1   SELIGMAN GROWTH FUND INC       20090331
# 2   SELIGMAN GROWTH FUND INC       20090331
# 3   SELIGMAN GROWTH FUND INC       20090331
# 4   SELIGMAN GROWTH FUND INC       20090331
# 5   SELIGMAN GROWTH FUND INC       20090331
# 6   SELIGMAN GROWTH FUND INC       20090331
# 7   SELIGMAN GROWTH FUND INC       20090331
#
# [73 rows x 10 columns]

# %% [markdown]
# ## Test on One FILE

# %%
CIK  = '316411'
text =  '0000950123-10-053029.txt'

# %%
panel2.loc[panel2['file_read'] == text]
# Out:
#   CLASS-CONTRACT-ID                      CLASS-CONTRACT-NAME  \
# 0        C000026136      SELIGMAN GROWTH FUND, INC., CLASS A
# 1        C000026137      SELIGMAN GROWTH FUND, INC., CLASS B
# 2        C000026138      SELIGMAN GROWTH FUND, INC., CLASS C
# 3        C000026140     SELIGMAN GROWTH FUND, INC., CLASS R5
# 4        C000026141     SELIGMAN GROWTH FUND, INC., CLASS R2
# 5        C000076414  SELIGMAN GROWTH FUND, INC., NEW CLASS I
# 6        C000076415     SELIGMAN GROWTH FUND, INC., CLASS R3
# 7        C000076416     SELIGMAN GROWTH FUND, INC., CLASS R4
#
#   CLASS-CONTRACT-TICKER-SYMBOL   SERIES-ID   OWNER-CIK  \
# 0                        SGRFX  S000009569  0000316411
# 1                        SGBTX  S000009569  0000316411
# 2                        SGRCX  S000009569  0000316411
# 3                        SGFIX  S000009569  0000316411
# 4                        SGFRX  S000009569  0000316411
# 5                         None  S000009569  0000316411
# 6                         None  S000009569  0000316411
# 7                         None  S000009569  0000316411
#
#                   SERIES-NAME                 file_read date_filed  \
# 0  SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 1  SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 2  SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 3  SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 4  SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 5  SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 6  SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
# 7  SELIGMAN GROWTH FUND, INC.  0000950123-10-053029.txt   20100526
#
#      company conformed name reporting_date
# 0  SELIGMAN GROWTH FUND INC       20100331
# 1  SELIGMAN GROWTH FUND INC       20100331
# 2  SELIGMAN GROWTH FUND INC       20100331
# 3  SELIGMAN GROWTH FUND INC       20100331
# 4  SELIGMAN GROWTH FUND INC       20100331
# 5  SELIGMAN GROWTH FUND INC       20100331
# 6  SELIGMAN GROWTH FUND INC       20100331
# 7  SELIGMAN GROWTH FUND INC       20100331

# %%
names = panel2.loc[panel2['file_read'] == text, 'SERIES-NAME']
names = names.unique()
print(names)
# Out:
# ['SELIGMAN GROWTH FUND, INC.']

# %%
url = r'https://www.sec.gov/Archives/edgar/data/' + CIK + r'/' + text.replace('.txt', '').replace('-','')  + r'/' + text
html_table = urlopen(url).read()
soup = BeautifulSoup(html_table, "html.parser")
tags = soup.find_all(['tr','b'])

# %%
tables = []
iterate = 0

for h in tags:
    if 'seligman' in str(h).lower() and 'fund'  in str(h).lower() and '<b>' in str(h).lower():
        print(str(h).lower())
        
    try:
        df = pd.read_html(str(i), flavor="bs4")
        for j in df:
            if len(j.index) > 0 :
                tables.append(j)
                iterate = iterate + 1
    except:
        pass
# Out:
# <b>seligman growth fund, inc.</b>

# %%
def remove_junk(addline):
    addline = re.sub('<[^>]*>', ' ', addline)
    addline = re.sub('&nbsp;', ' ', addline)
    addline = re.sub('&#174;', ' ', addline)
    addline = re.sub('&#8480;', ' ', addline)
    addline = re.sub(r'&reg;',' ',addline)
    addline = re.sub(r'\n', ' ', addline)
    addline = re.sub(r'\t', ' ', addline)
    addline = re.sub('\xa0', ' ', addline)
    return addline

# %%
count = 0
for i in tables:
    s = 'table ' + str(count)
    print(s)
    print(i)
    count = count + 1

# %%
def get_holdings(df):
    filter_names = []
    cleaned_df = pd.DataFrame()
    add =0 
    if len(df.columns) >= 3:
        col_name = 0
        
        df = df.dropna(axis = 0, subset = [df.columns[col_name]])
        df = df.dropna(thresh = 3, axis = 0)

        for count, row in df.iterrows():
            name = str(row[0])
            if name[-1] != r'%' and '(cost' not in name.lower() and 'issuer' not in name.lower() and 'security description' not in name.lower() \
            and 'due' not in name.lower() :
                keys = re.findall(r'\([^()]*\)',name)
                key = ''
                for k in keys:
                    if '-' not in k:
                        key = key + k
                        name = name.replace(k,'')

                strip_punct = '!"#$%&\'()+,-./:;<=>?@[\\]^_`{|}'
                h = re.findall("[^A-Za-z0-9]", name.replace(' ', ''))
                key2 = ''.join(h)
                key2 = key2.strip(strip_punct)
                for c in key2:
                    name = name.replace(c,"")

                
                add = pd.DataFrame(df.loc[count]).dropna()
                add = add[~add.duplicated()]
                add = add.loc[1:]
                if len(add) == 2:
                    add = add.transpose().dropna()
                    add.columns = ['holdings shares', 'holdings value']
                    add['holdings name'] = name
                    add['key'] = key + key2
                    add.loc[0,'holdings shares'] = add.loc[0,'holdings shares'].replace('$','').replace(',','')
                    add.loc[0,'holdings value'] = add.loc[0,'holdings value'].replace('$','').replace(',','')
                    if add.loc[0,'holdings shares'].isdigit() and add.loc[0,'holdings value'].isdigit():
                        cleaned_df = pd.concat([cleaned_df, add], axis = 0, sort=False, ignore_index = True)

                        cleaned_df.index = pd.RangeIndex(len(cleaned_df.index))

    return cleaned_df, add

# %%
def get_legend(df):
    df = df.dropna(axis = 0, how = 'all')
    df = df.dropna(axis = 1, how = 'all')
    legend = pd.DataFrame(columns = ['code', 'symbol', 'restricted'])
    try:
        for count, row in df.iterrows():
            keys = str(row[0])
            code = str(row[1])
            if (keys.strip() != code.strip()) and (code.strip() != ''):
                if (len(keys) == 3 and '(' in keys and ')' in keys) or ((len(keys) == 1) and (keys.isdigit() is False) and (keys.isalpha() is False)):
                    if 'level' not in code.lower():
                        add = pd.DataFrame([code, keys, '']).T
                        add.columns = ['code', 'symbol', 'restricted']
                        if len(legend.index) == 0:
                            legend = add.copy()
                        else:
                            legend = pd.concat([legend, add], axis = 0,ignore_index = True, sort = False)
    except:
        pass

                    
    return legend

# %%
names = panel2.loc[panel2['file_read'] == text, 'SERIES-NAME']
names = names.unique()

holdings = pd.DataFrame()
legend = pd.DataFrame()
fundname = ''

for tr in tags:
    if 'seligman' in str(tr).lower() and 'fund'  in str(tr).lower() and '<b>' in str(tr).lower():
        s = str(tr).replace('&amp','and')
        s = s.replace('  ', '').replace(';','').replace(',','').replace('.','').strip()
        s = remove_junk(s)
        for n in names:
            if n.lower().replace(';','').replace(',','').replace('.','').strip() in str(s).lower().strip():
                fundname = n
                print(fundname)
                
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td]
    row = list(filter(None, row))
    if len(row) == 3:
        add = pd.DataFrame(row).T
        cleaned_df, add1 = get_holdings(add)
        if len(cleaned_df.index) > 0:
            cleaned_df.loc[:, 'fund name'] = fundname
            cleaned_df.loc[:, 'identifier'] = fundname
            if len(holdings.index) > 0:
                holdings = pd.concat([holdings, cleaned_df], axis = 0, sort=False, ignore_index = True)
            else:
                holdings = cleaned_df.copy()
                
    if len(row) == 2:
        add = pd.DataFrame(row).T
        add_legend = get_legend(add)
        if len(add_legend.index) > 0:
            add_legend.loc[:, 'identifier'] = fundname
            if len(legend.index) > 0:
                legend = pd.concat([legend, add_legend], axis = 0 , sort=False, ignore_index = True)
            else:
                legend  = add_legend.copy()
# Out:
# SELIGMAN GROWTH FUND, INC.

# %%
legend
# Out:
#                                                 code symbol restricted  \
# 0  Securities are valued by using policies descri...    (a)
# 1                              Non-income producing.    (b)
# 2  Foreign security values are stated in U.S. dol...    (c)
# 3  At March 31, 2010, security was partially or f...    (d)
# 4  Affiliated Money Market Fund — The Fund may in...    (e)
# 5                      Represents fractional shares.    (f)
# 6  At March 31, 2010, the cost of securities for ...    (h)
# 7  Industry classifications are identified in the...    (a)
# 8  Money market fund that is a sweep investment f...    (b)
# 9  Asset categories for Investments of Cash Colla...    (c)
#
#                    identifier
# 0  SELIGMAN GROWTH FUND, INC.
# 1  SELIGMAN GROWTH FUND, INC.
# 2  SELIGMAN GROWTH FUND, INC.
# 3  SELIGMAN GROWTH FUND, INC.
# 4  SELIGMAN GROWTH FUND, INC.
# 5  SELIGMAN GROWTH FUND, INC.
# 6  SELIGMAN GROWTH FUND, INC.
# 7  SELIGMAN GROWTH FUND, INC.
# 8  SELIGMAN GROWTH FUND, INC.
# 9  SELIGMAN GROWTH FUND, INC.

# %%
holdings.to_csv('check.csv')

# %%
holdings['value multiplier'] = ''
holdings['textfile'] = text
holdings['CIK'] = CIK
holdings['date_filed'] = '' 
holdings['company conformed name'] = ''
holdings['reporting_date'] = ''

try:
    date_filed = panel2.loc[panel2['file_read'] == text, 'date_filed'].unique()[0]
    conformed_name = panel2.loc[panel2['file_read'] == text, 'company conformed name'].unique()[0]
    reporting_date = panel2.loc[panel2['file_read'] == text, 'reporting_date'].unique()[0]
except IndexError:
    date_filed = ''
    conformed_name = ''

holdings.loc[:, 'date_filed'] = date_filed
holdings.loc[:, 'company conformed name'] = conformed_name
holdings.loc[:, 'reporting_date'] = reporting_date

holdings.index = pd.RangeIndex(len(holdings.index))
print(holdings)

for z in weblink[CIK]:
    if text in z:
        matching_link = z

holdings['weblink'] = matching_link
legend['weblink'] = matching_link
legend['textfile'] = text
# Out:
#    holdings shares holdings value                        holdings name key  \
# 0           311757       14113239        Honeywell International, Inc.
# 1           167800       10807998  United Parcel Service, Inc., ClassB
# 2           548000       36255680                        PepsiCo, Inc.
# 3            92400       15766212        The Goldman Sachs Group, Inc.
# 4           206600        6580210              Celanese Corp., SeriesA
# 5           245810       17555750                         Monsanto Co.
# 6           484100       20327359                       QUALCOMM, Inc.
# 7           858000       25851540                      Halliburton Co.
# 8           441300        9558558                       The Kroger Co.
# 9           341500       18987400                Wal-Mart Stores, Inc.
# 10          130700        6983301                          Kellogg Co.
# 11          464000       27004800           Baxter International, Inc.
# 12          559900       25212297                      Medtronic, Inc.
# 13          613900       38841453             The Procter & Gamble Co.
# 14          109687        9166543                               3M Co.
# 15          159248        8645574                          AFLAC, Inc.
# 16          513123       31043941           Prudential Financial, Inc.
# 17          205900       11653940                     Joy Global, Inc.
# 18          559671       29438695                         Target Corp.
# 19           79726        8092189                         Apache Corp.
# 20          767253       13158389                         Pfizer, Inc.
# 21          338200       17214380                            CSX Corp.
# 22          259518       19022669                  Union Pacific Corp.
# 23          764875       17026118                          Intel Corp.
# 24         1313957       33755555                         Oracle Corp.
# 25         1003775       52356904    Philip Morris International, Inc.
#
#                      fund name                  identifier value multiplier  \
# 0   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 1   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 2   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 3   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 4   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 5   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 6   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 7   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 8   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 9   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 10  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 11  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 12  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 13  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 14  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 15  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 16  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 17  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 18  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 19  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 20  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 21  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 22  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 23  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 24  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 25  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
#
#                     textfile     CIK date_filed    company conformed name  \
# 0   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 1   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 2   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 3   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 4   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 5   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 6   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 7   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 8   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 9   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 10  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 11  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 12  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 13  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 14  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 15  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 16  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 17  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 18  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 19  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 20  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 21  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 22  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 23  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 24  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 25  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
#
#    reporting_date
# 0        20100331
# 1        20100331
# 2        20100331
# 3        20100331
# 4        20100331
# 5        20100331
# 6        20100331
# 7        20100331
# 8        20100331
# 9        20100331
# 10       20100331
# 11       20100331
# 12       20100331
# 13       20100331
# 14       20100331
# 15       20100331
# 16       20100331
# 17       20100331
# 18       20100331
# 19       20100331
# 20       20100331
# 21       20100331
# 22       20100331
# 23       20100331
# 24       20100331
# 25       20100331

# %%
legend.loc[:,'restricted'] = 'no'

legend.loc[legend['code'].str.contains("restrict") | legend['code'].str.contains("level 3 security") \
              | legend['code'].str.contains("exempt from registration") |legend['code'].str.contains("private placement") , 'restricted'] = 'yes'

restricted = legend.loc[legend['restricted'].str.contains("yes")]
print(restricted)

holdings.loc[:,'restricted'] = 'no'
# Out:
# Empty DataFrame
# Columns: [code, symbol, restricted, identifier, weblink, textfile]
# Index: []

# %%
legend.loc[:,'restricted'] = 'no'

legend.loc[legend['code'].str.contains("restrict") | legend['code'].str.contains("level 3 security") \
              | legend['code'].str.contains("exempt from registration") | legend['code'].str.contains("private placement transaction"), 'restricted'] = 'yes'

restricted = legend.loc[legend['restricted'].str.contains("yes")]
print(restricted)

holdings.loc[:,'restricted'] = 'no'

for index, row in restricted.iterrows():
    holdings.loc[(holdings['identifier'] == row['identifier']) & (holdings['textfile'] == row.textfile) \
                   & (holdings['key'].str.contains(row['symbol'])), 'restricted'] = 'yes'
    
restricted_holdings = holdings.loc[(holdings['restricted'] == 'yes')]
# Out:
# Empty DataFrame
# Columns: [code, symbol, restricted, identifier, weblink, textfile]
# Index: []

# %%
def getpanel1(CIK, text, panel2):
    names = panel2.loc[panel2['file_read'] == text, 'SERIES-NAME']
    names = names.unique()

    holdings = pd.DataFrame()
    legend = pd.DataFrame()
    fundname = ''

    for tr in tags:
        if 'seligman' in str(tr).lower() and 'fund'  in str(tr).lower() and '<b>' in str(tr).lower():
            s = str(tr).replace('&amp','and')
            s = s.replace('  ', '').replace(';','').replace(',','').replace('.','').strip()
            s = remove_junk(s)
            for n in names:
                if n.lower().replace(';','').replace(',','').replace('.','').strip() in str(s).lower().strip():
                    fundname = n


        td = tr.find_all('td')
        row = [tr.text.strip() for tr in td]
        row = list(filter(None, row))
        if len(row) == 3:
            add = pd.DataFrame(row).T
            cleaned_df, add1 = get_holdings(add)
            if len(cleaned_df.index) > 0:
                cleaned_df.loc[:, 'fund name'] = fundname
                cleaned_df.loc[:, 'identifier'] = fundname
                if len(holdings.index) > 0:
                    holdings = pd.concat([holdings, cleaned_df], axis = 0, sort=False, ignore_index = True)
                else:
                    holdings = cleaned_df.copy()

        if len(row) == 2:
            add = pd.DataFrame(row).T
            add_legend = get_legend(add)
            if len(add_legend.index) > 0:
                add_legend.loc[:, 'identifier'] = fundname
                if len(legend.index) > 0:
                    legend = pd.concat([legend, add_legend], axis = 0 , sort=False, ignore_index = True)
                else:
                    legend  = add_legend.copy()
                    
                    
                    
    holdings['value multiplier'] = ''
    holdings['textfile'] = text
    holdings['CIK'] = CIK
    holdings['date_filed'] = '' 
    holdings['company conformed name'] = ''
    holdings['reporting_date'] = ''

    try:
        date_filed = panel2.loc[panel2['file_read'] == text, 'date_filed'].unique()[0]
        conformed_name = panel2.loc[panel2['file_read'] == text, 'company conformed name'].unique()[0]
        reporting_date = panel2.loc[panel2['file_read'] == text, 'reporting_date'].unique()[0]
    except IndexError:
        date_filed = ''
        conformed_name = ''

    holdings.loc[:, 'date_filed'] = date_filed
    holdings.loc[:, 'company conformed name'] = conformed_name
    holdings.loc[:, 'reporting_date'] = reporting_date

    holdings.index = pd.RangeIndex(len(holdings.index))
    print(holdings)

    for z in weblink[CIK]:
        if text in z:
            matching_link = z

    holdings['weblink'] = matching_link
    legend['weblink'] = matching_link
    legend['textfile'] = text
    
    return holdings, legend

# %%
holdings, legend = getpanel1('316411', '0000950123-10-053029.txt', panel2)
# Out:
#    holdings shares holdings value                        holdings name key  \
# 0           311757       14113239        Honeywell International, Inc.
# 1           167800       10807998  United Parcel Service, Inc., ClassB
# 2           548000       36255680                        PepsiCo, Inc.
# 3            92400       15766212        The Goldman Sachs Group, Inc.
# 4           206600        6580210              Celanese Corp., SeriesA
# 5           245810       17555750                         Monsanto Co.
# 6           484100       20327359                       QUALCOMM, Inc.
# 7           858000       25851540                      Halliburton Co.
# 8           441300        9558558                       The Kroger Co.
# 9           341500       18987400                Wal-Mart Stores, Inc.
# 10          130700        6983301                          Kellogg Co.
# 11          464000       27004800           Baxter International, Inc.
# 12          559900       25212297                      Medtronic, Inc.
# 13          613900       38841453             The Procter & Gamble Co.
# 14          109687        9166543                               3M Co.
# 15          159248        8645574                          AFLAC, Inc.
# 16          513123       31043941           Prudential Financial, Inc.
# 17          205900       11653940                     Joy Global, Inc.
# 18          559671       29438695                         Target Corp.
# 19           79726        8092189                         Apache Corp.
# 20          767253       13158389                         Pfizer, Inc.
# 21          338200       17214380                            CSX Corp.
# 22          259518       19022669                  Union Pacific Corp.
# 23          764875       17026118                          Intel Corp.
# 24         1313957       33755555                         Oracle Corp.
# 25         1003775       52356904    Philip Morris International, Inc.
#
#                      fund name                  identifier value multiplier  \
# 0   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 1   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 2   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 3   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 4   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 5   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 6   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 7   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 8   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 9   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 10  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 11  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 12  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 13  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 14  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 15  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 16  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 17  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 18  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 19  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 20  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 21  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 22  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 23  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 24  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 25  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
#
#                     textfile     CIK date_filed    company conformed name  \
# 0   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 1   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 2   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 3   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 4   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 5   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 6   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 7   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 8   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 9   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 10  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 11  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 12  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 13  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 14  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 15  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 16  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 17  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 18  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 19  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 20  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 21  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 22  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 23  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 24  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 25  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
#
#    reporting_date
# 0        20100331
# 1        20100331
# 2        20100331
# 3        20100331
# 4        20100331
# 5        20100331
# 6        20100331
# 7        20100331
# 8        20100331
# 9        20100331
# 10       20100331
# 11       20100331
# 12       20100331
# 13       20100331
# 14       20100331
# 15       20100331
# 16       20100331
# 17       20100331
# 18       20100331
# 19       20100331
# 20       20100331
# 21       20100331
# 22       20100331
# 23       20100331
# 24       20100331
# 25       20100331

# %%
holdings.to_csv(os.path.join(output_directory, fund_name + '_test_holdings2.csv'), sep = ',')
legend.to_csv(os.path.join(output_directory, fund_name + '_test_legend2.csv'), sep = ',')
print(holdings)
# Out:
#    holdings shares holdings value                        holdings name key  \
# 0           311757       14113239        Honeywell International, Inc.
# 1           167800       10807998  United Parcel Service, Inc., ClassB
# 2           548000       36255680                        PepsiCo, Inc.
# 3            92400       15766212        The Goldman Sachs Group, Inc.
# 4           206600        6580210              Celanese Corp., SeriesA
# 5           245810       17555750                         Monsanto Co.
# 6           484100       20327359                       QUALCOMM, Inc.
# 7           858000       25851540                      Halliburton Co.
# 8           441300        9558558                       The Kroger Co.
# 9           341500       18987400                Wal-Mart Stores, Inc.
# 10          130700        6983301                          Kellogg Co.
# 11          464000       27004800           Baxter International, Inc.
# 12          559900       25212297                      Medtronic, Inc.
# 13          613900       38841453             The Procter & Gamble Co.
# 14          109687        9166543                               3M Co.
# 15          159248        8645574                          AFLAC, Inc.
# 16          513123       31043941           Prudential Financial, Inc.
# 17          205900       11653940                     Joy Global, Inc.
# 18          559671       29438695                         Target Corp.
# 19           79726        8092189                         Apache Corp.
# 20          767253       13158389                         Pfizer, Inc.
# 21          338200       17214380                            CSX Corp.
# 22          259518       19022669                  Union Pacific Corp.
# 23          764875       17026118                          Intel Corp.
# 24         1313957       33755555                         Oracle Corp.
# 25         1003775       52356904    Philip Morris International, Inc.
#
#                      fund name                  identifier value multiplier  \
# 0   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 1   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 2   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 3   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 4   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 5   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 6   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 7   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 8   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 9   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 10  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 11  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 12  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 13  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 14  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 15  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 16  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 17  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 18  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 19  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 20  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 21  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 22  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 23  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 24  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 25  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
#
#                     textfile     CIK date_filed    company conformed name  \
# 0   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 1   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 2   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 3   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 4   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 5   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 6   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 7   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 8   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 9   0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 10  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 11  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 12  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 13  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 14  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 15  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 16  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 17  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 18  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 19  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 20  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 21  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 22  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 23  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 24  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
# 25  0000950123-10-053029.txt  316411   20100526  SELIGMAN GROWTH FUND INC
#
#    reporting_date                                            weblink
# 0        20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 1        20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 2        20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 3        20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 4        20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 5        20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 6        20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 7        20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 8        20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 9        20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 10       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 11       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 12       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 13       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 14       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 15       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 16       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 17       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 18       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 19       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 20       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 21       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 22       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 23       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 24       20100331  https://www.sec.gov/Archives/edgar/data/316411...
# 25       20100331  https://www.sec.gov/Archives/edgar/data/316411...

# %% [markdown]
# # Run on all CIKs

# %%
panel1 = pd.DataFrame()


panel1 = pd.DataFrame()
panel1_legend = pd.DataFrame()
error_panel1 = []
no_holdings = {}

CIK_LIST = ['316411']

for CIK in CIK_LIST:
    no_holdings[CIK] = []
    txt_files = os.listdir(os.path.join(cur_wd, CIK, 'n-q'))
    for i in txt_files:
        if '.csv' not in i and i not in errors[CIK]:
            holdings, legend = getpanel1(str(CIK), str(i), panel2)
            print(holdings)
            if len(holdings) == 0:
                no_holdings[CIK].append(i)

            if panel1.empty:
                panel1 = holdings.copy()
                panel1_legend = legend.copy()
            else:
                panel1 = pd.concat([panel1, holdings], axis = 0, sort = False)
                panel1_legend = pd.concat([panel1_legend , legend], axis = 0, sort = False)

            panel1.index = pd.RangeIndex(len(panel1.index))
# Out:
#    holdings shares holdings value                        holdings name key  \
# 0           311757       14113239        Honeywell International, Inc.
# 1           167800       10807998  United Parcel Service, Inc., ClassB
# 2           548000       36255680                        PepsiCo, Inc.
# 3            92400       15766212        The Goldman Sachs Group, Inc.
# 4           206600        6580210              Celanese Corp., SeriesA
# 5           245810       17555750                         Monsanto Co.
# 6           484100       20327359                       QUALCOMM, Inc.
# 7           858000       25851540                      Halliburton Co.
# 8           441300        9558558                       The Kroger Co.
# 9           341500       18987400                Wal-Mart Stores, Inc.
# 10          130700        6983301                          Kellogg Co.
# 11          464000       27004800           Baxter International, Inc.
# 12          559900       25212297                      Medtronic, Inc.
# 13          613900       38841453             The Procter & Gamble Co.
# 14          109687        9166543                               3M Co.
# 15          159248        8645574                          AFLAC, Inc.
# 16          513123       31043941           Prudential Financial, Inc.
# 17          205900       11653940                     Joy Global, Inc.
# 18          559671       29438695                         Target Corp.
# 19           79726        8092189                         Apache Corp.
# 20          767253       13158389                         Pfizer, Inc.
# 21          338200       17214380                            CSX Corp.
# 22          259518       19022669                  Union Pacific Corp.
# 23          764875       17026118                          Intel Corp.
# 24         1313957       33755555                         Oracle Corp.
# 25         1003775       52356904    Philip Morris International, Inc.
#
#                      fund name                  identifier value multiplier  \
# 0   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 1   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 2   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 3   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 4   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 5   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 6   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 7   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 8   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 9   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 10  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 11  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 12  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 13  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 14  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 15  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 16  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 17  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 18  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 19  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 20  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 21  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 22  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 23  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 24  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 25  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
#
#                     textfile     CIK date_filed    company conformed name  \
# 0   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 1   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 2   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 3   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 4   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 5   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 6   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 7   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 8   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 9   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 10  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 11  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 12  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 13  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 14  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 15  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 16  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 17  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 18  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 19  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 20  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 21  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 22  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 23  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 24  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 25  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
#
#    reporting_date
# 0        20060930
# 1        20060930
# 2        20060930
# 3        20060930
# 4        20060930
# 5        20060930
# 6        20060930
# 7        20060930
# 8        20060930
# 9        20060930
# 10       20060930
# 11       20060930
# 12       20060930
# 13       20060930
# 14       20060930
# 15       20060930
# 16       20060930
# 17       20060930
# 18       20060930
# 19       20060930
# 20       20060930
# 21       20060930
# 22       20060930
# 23       20060930
# 24       20060930
# 25       20060930
#    holdings shares holdings value                        holdings name key  \
# 0           311757       14113239        Honeywell International, Inc.
# 1           167800       10807998  United Parcel Service, Inc., ClassB
# 2           548000       36255680                        PepsiCo, Inc.
# 3            92400       15766212        The Goldman Sachs Group, Inc.
# 4           206600        6580210              Celanese Corp., SeriesA
# 5           245810       17555750                         Monsanto Co.
# 6           484100       20327359                       QUALCOMM, Inc.
# 7           858000       25851540                      Halliburton Co.
# 8           441300        9558558                       The Kroger Co.
# 9           341500       18987400                Wal-Mart Stores, Inc.
# 10          130700        6983301                          Kellogg Co.
# 11          464000       27004800           Baxter International, Inc.
# 12          559900       25212297                      Medtronic, Inc.
# 13          613900       38841453             The Procter & Gamble Co.
# 14          109687        9166543                               3M Co.
# 15          159248        8645574                          AFLAC, Inc.
# 16          513123       31043941           Prudential Financial, Inc.
# 17          205900       11653940                     Joy Global, Inc.
# 18          559671       29438695                         Target Corp.
# 19           79726        8092189                         Apache Corp.
# 20          767253       13158389                         Pfizer, Inc.
# 21          338200       17214380                            CSX Corp.
# 22          259518       19022669                  Union Pacific Corp.
# 23          764875       17026118                          Intel Corp.
# 24         1313957       33755555                         Oracle Corp.
# 25         1003775       52356904    Philip Morris International, Inc.
#
#                      fund name                  identifier value multiplier  \
# 0   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 1   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 2   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 3   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 4   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 5   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 6   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 7   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 8   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 9   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 10  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 11  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 12  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 13  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 14  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 15  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 16  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 17  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 18  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 19  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 20  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 21  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 22  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 23  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 24  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 25  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
#
#                     textfile     CIK date_filed    company conformed name  \
# 0   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 1   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 2   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 3   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 4   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 5   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 6   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 7   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 8   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 9   0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 10  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 11  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 12  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 13  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 14  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 15  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 16  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 17  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 18  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 19  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 20  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 21  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 22  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 23  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 24  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
# 25  0000936329-06-000167.txt  316411   20061127  SELIGMAN GROWTH FUND INC
#
#    reporting_date                                            weblink
# 0        20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 1        20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 2        20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 3        20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 4        20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 5        20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 6        20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 7        20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 8        20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 9        20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 10       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 11       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 12       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 13       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 14       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 15       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 16       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 17       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 18       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 19       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 20       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 21       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 22       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 23       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 24       20060930  https://www.sec.gov/Archives/edgar/data/316411...
# 25       20060930  https://www.sec.gov/Archives/edgar/data/316411...
#    holdings shares holdings value                        holdings name key  \
# 0           311757       14113239        Honeywell International, Inc.
# 1           167800       10807998  United Parcel Service, Inc., ClassB
# 2           548000       36255680                        PepsiCo, Inc.
# 3            92400       15766212        The Goldman Sachs Group, Inc.
# 4           206600        6580210              Celanese Corp., SeriesA
# 5           245810       17555750                         Monsanto Co.
# 6           484100       20327359                       QUALCOMM, Inc.
# 7           858000       25851540                      Halliburton Co.
# 8           441300        9558558                       The Kroger Co.
# 9           341500       18987400                Wal-Mart Stores, Inc.
# 10          130700        6983301                          Kellogg Co.
# 11          464000       27004800           Baxter International, Inc.
# 12          559900       25212297                      Medtronic, Inc.
# 13          613900       38841453             The Procter & Gamble Co.
# 14          109687        9166543                               3M Co.
# 15          159248        8645574                          AFLAC, Inc.
# 16          513123       31043941           Prudential Financial, Inc.
# 17          205900       11653940                     Joy Global, Inc.
# 18          559671       29438695                         Target Corp.
# 19           79726        8092189                         Apache Corp.
# 20          767253       13158389                         Pfizer, Inc.
# 21          338200       17214380                            CSX Corp.
# 22          259518       19022669                  Union Pacific Corp.
# 23          764875       17026118                          Intel Corp.
# 24         1313957       33755555                         Oracle Corp.
# 25         1003775       52356904    Philip Morris International, Inc.
#
#                      fund name                  identifier value multiplier  \
# 0   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 1   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 2   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 3   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 4   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 5   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 6   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 7   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 8   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 9   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 10  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 11  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 12  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 13  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 14  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 15  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 16  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 17  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 18  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 19  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 20  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 21  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 22  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 23  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 24  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 25  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
#
#                     textfile     CIK date_filed    company conformed name  \
# 0   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 1   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 2   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 3   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 4   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 5   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 6   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 7   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 8   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 9   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 10  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 11  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 12  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 13  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 14  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 15  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 16  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 17  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 18  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 19  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 20  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 21  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 22  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 23  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 24  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 25  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
#
#    reporting_date
# 0        20070331
# 1        20070331
# 2        20070331
# 3        20070331
# 4        20070331
# 5        20070331
# 6        20070331
# 7        20070331
# 8        20070331
# 9        20070331
# 10       20070331
# 11       20070331
# 12       20070331
# 13       20070331
# 14       20070331
# 15       20070331
# 16       20070331
# 17       20070331
# 18       20070331
# 19       20070331
# 20       20070331
# 21       20070331
# 22       20070331
# 23       20070331
# 24       20070331
# 25       20070331
#    holdings shares holdings value                        holdings name key  \
# 0           311757       14113239        Honeywell International, Inc.
# 1           167800       10807998  United Parcel Service, Inc., ClassB
# 2           548000       36255680                        PepsiCo, Inc.
# 3            92400       15766212        The Goldman Sachs Group, Inc.
# 4           206600        6580210              Celanese Corp., SeriesA
# 5           245810       17555750                         Monsanto Co.
# 6           484100       20327359                       QUALCOMM, Inc.
# 7           858000       25851540                      Halliburton Co.
# 8           441300        9558558                       The Kroger Co.
# 9           341500       18987400                Wal-Mart Stores, Inc.
# 10          130700        6983301                          Kellogg Co.
# 11          464000       27004800           Baxter International, Inc.
# 12          559900       25212297                      Medtronic, Inc.
# 13          613900       38841453             The Procter & Gamble Co.
# 14          109687        9166543                               3M Co.
# 15          159248        8645574                          AFLAC, Inc.
# 16          513123       31043941           Prudential Financial, Inc.
# 17          205900       11653940                     Joy Global, Inc.
# 18          559671       29438695                         Target Corp.
# 19           79726        8092189                         Apache Corp.
# 20          767253       13158389                         Pfizer, Inc.
# 21          338200       17214380                            CSX Corp.
# 22          259518       19022669                  Union Pacific Corp.
# 23          764875       17026118                          Intel Corp.
# 24         1313957       33755555                         Oracle Corp.
# 25         1003775       52356904    Philip Morris International, Inc.
#
#                      fund name                  identifier value multiplier  \
# 0   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 1   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 2   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 3   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 4   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 5   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 6   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 7   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 8   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 9   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 10  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 11  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 12  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 13  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 14  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 15  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 16  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 17  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 18  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 19  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 20  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 21  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 22  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 23  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 24  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 25  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
#
#                     textfile     CIK date_filed    company conformed name  \
# 0   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 1   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 2   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 3   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 4   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 5   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 6   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 7   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 8   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 9   0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 10  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 11  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 12  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 13  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 14  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 15  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 16  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 17  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 18  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 19  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 20  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 21  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 22  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 23  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 24  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
# 25  0000936329-07-000060.txt  316411   20070525  SELIGMAN GROWTH FUND INC
#
#    reporting_date                                            weblink
# 0        20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 1        20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 2        20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 3        20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 4        20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 5        20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 6        20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 7        20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 8        20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 9        20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 10       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 11       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 12       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 13       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 14       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 15       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 16       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 17       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 18       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 19       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 20       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 21       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 22       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 23       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 24       20070331  https://www.sec.gov/Archives/edgar/data/316411...
# 25       20070331  https://www.sec.gov/Archives/edgar/data/316411...
#    holdings shares holdings value                        holdings name key  \
# 0           311757       14113239        Honeywell International, Inc.
# 1           167800       10807998  United Parcel Service, Inc., ClassB
# 2           548000       36255680                        PepsiCo, Inc.
# 3            92400       15766212        The Goldman Sachs Group, Inc.
# 4           206600        6580210              Celanese Corp., SeriesA
# 5           245810       17555750                         Monsanto Co.
# 6           484100       20327359                       QUALCOMM, Inc.
# 7           858000       25851540                      Halliburton Co.
# 8           441300        9558558                       The Kroger Co.
# 9           341500       18987400                Wal-Mart Stores, Inc.
# 10          130700        6983301                          Kellogg Co.
# 11          464000       27004800           Baxter International, Inc.
# 12          559900       25212297                      Medtronic, Inc.
# 13          613900       38841453             The Procter & Gamble Co.
# 14          109687        9166543                               3M Co.
# 15          159248        8645574                          AFLAC, Inc.
# 16          513123       31043941           Prudential Financial, Inc.
# 17          205900       11653940                     Joy Global, Inc.
# 18          559671       29438695                         Target Corp.
# 19           79726        8092189                         Apache Corp.
# 20          767253       13158389                         Pfizer, Inc.
# 21          338200       17214380                            CSX Corp.
# 22          259518       19022669                  Union Pacific Corp.
# 23          764875       17026118                          Intel Corp.
# 24         1313957       33755555                         Oracle Corp.
# 25         1003775       52356904    Philip Morris International, Inc.
#
#                      fund name                  identifier value multiplier  \
# 0   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 1   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 2   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 3   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 4   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 5   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 6   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 7   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 8   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 9   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 10  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 11  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 12  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 13  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 14  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 15  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 16  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 17  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 18  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 19  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 20  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 21  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 22  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 23  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 24  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 25  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
#
#                     textfile     CIK date_filed    company conformed name  \
# 0   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 1   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 2   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 3   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 4   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 5   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 6   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 7   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 8   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 9   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 10  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 11  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 12  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 13  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 14  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 15  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 16  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 17  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 18  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 19  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 20  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 21  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 22  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 23  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 24  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 25  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
#
#    reporting_date
# 0        20090930
# 1        20090930
# 2        20090930
# 3        20090930
# 4        20090930
# 5        20090930
# 6        20090930
# 7        20090930
# 8        20090930
# 9        20090930
# 10       20090930
# 11       20090930
# 12       20090930
# 13       20090930
# 14       20090930
# 15       20090930
# 16       20090930
# 17       20090930
# 18       20090930
# 19       20090930
# 20       20090930
# 21       20090930
# 22       20090930
# 23       20090930
# 24       20090930
# 25       20090930
#    holdings shares holdings value                        holdings name key  \
# 0           311757       14113239        Honeywell International, Inc.
# 1           167800       10807998  United Parcel Service, Inc., ClassB
# 2           548000       36255680                        PepsiCo, Inc.
# 3            92400       15766212        The Goldman Sachs Group, Inc.
# 4           206600        6580210              Celanese Corp., SeriesA
# 5           245810       17555750                         Monsanto Co.
# 6           484100       20327359                       QUALCOMM, Inc.
# 7           858000       25851540                      Halliburton Co.
# 8           441300        9558558                       The Kroger Co.
# 9           341500       18987400                Wal-Mart Stores, Inc.
# 10          130700        6983301                          Kellogg Co.
# 11          464000       27004800           Baxter International, Inc.
# 12          559900       25212297                      Medtronic, Inc.
# 13          613900       38841453             The Procter & Gamble Co.
# 14          109687        9166543                               3M Co.
# 15          159248        8645574                          AFLAC, Inc.
# 16          513123       31043941           Prudential Financial, Inc.
# 17          205900       11653940                     Joy Global, Inc.
# 18          559671       29438695                         Target Corp.
# 19           79726        8092189                         Apache Corp.
# 20          767253       13158389                         Pfizer, Inc.
# 21          338200       17214380                            CSX Corp.
# 22          259518       19022669                  Union Pacific Corp.
# 23          764875       17026118                          Intel Corp.
# 24         1313957       33755555                         Oracle Corp.
# 25         1003775       52356904    Philip Morris International, Inc.
#
#                      fund name                  identifier value multiplier  \
# 0   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 1   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 2   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 3   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 4   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 5   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 6   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 7   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 8   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 9   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 10  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 11  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 12  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 13  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 14  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 15  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 16  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 17  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 18  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 19  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 20  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 21  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 22  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 23  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 24  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 25  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
#
#                     textfile     CIK date_filed    company conformed name  \
# 0   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 1   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 2   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 3   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 4   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 5   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 6   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 7   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 8   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 9   0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 10  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 11  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 12  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 13  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 14  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 15  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 16  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 17  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 18  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 19  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 20  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 21  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 22  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 23  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 24  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
# 25  0000950123-09-065935.txt  316411   20091125  SELIGMAN GROWTH FUND INC
#
#    reporting_date                                            weblink
# 0        20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 1        20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 2        20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 3        20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 4        20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 5        20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 6        20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 7        20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 8        20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 9        20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 10       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 11       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 12       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 13       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 14       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 15       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 16       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 17       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 18       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 19       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 20       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 21       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 22       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 23       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 24       20090930  https://www.sec.gov/Archives/edgar/data/316411...
# 25       20090930  https://www.sec.gov/Archives/edgar/data/316411...
#    holdings shares holdings value                        holdings name key  \
# 0           311757       14113239        Honeywell International, Inc.
# 1           167800       10807998  United Parcel Service, Inc., ClassB
# 2           548000       36255680                        PepsiCo, Inc.
# 3            92400       15766212        The Goldman Sachs Group, Inc.
# 4           206600        6580210              Celanese Corp., SeriesA
# 5           245810       17555750                         Monsanto Co.
# 6           484100       20327359                       QUALCOMM, Inc.
# 7           858000       25851540                      Halliburton Co.
# 8           441300        9558558                       The Kroger Co.
# 9           341500       18987400                Wal-Mart Stores, Inc.
# 10          130700        6983301                          Kellogg Co.
# 11          464000       27004800           Baxter International, Inc.
# 12          559900       25212297                      Medtronic, Inc.
# 13          613900       38841453             The Procter & Gamble Co.
# 14          109687        9166543                               3M Co.
# 15          159248        8645574                          AFLAC, Inc.
# 16          513123       31043941           Prudential Financial, Inc.
# 17          205900       11653940                     Joy Global, Inc.
# 18          559671       29438695                         Target Corp.
# 19           79726        8092189                         Apache Corp.
# 20          767253       13158389                         Pfizer, Inc.
# 21          338200       17214380                            CSX Corp.
# 22          259518       19022669                  Union Pacific Corp.
# 23          764875       17026118                          Intel Corp.
# 24         1313957       33755555                         Oracle Corp.
# 25         1003775       52356904    Philip Morris International, Inc.
#
#                      fund name                  identifier value multiplier  \
# 0   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 1   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 2   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 3   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 4   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 5   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# ...
# 14       20080930  https://www.sec.gov/Archives/edgar/data/316411...
# 15       20080930  https://www.sec.gov/Archives/edgar/data/316411...
# 16       20080930  https://www.sec.gov/Archives/edgar/data/316411...
# 17       20080930  https://www.sec.gov/Archives/edgar/data/316411...
# 18       20080930  https://www.sec.gov/Archives/edgar/data/316411...
# 19       20080930  https://www.sec.gov/Archives/edgar/data/316411...
# 20       20080930  https://www.sec.gov/Archives/edgar/data/316411...
# 21       20080930  https://www.sec.gov/Archives/edgar/data/316411...
# 22       20080930  https://www.sec.gov/Archives/edgar/data/316411...
# 23       20080930  https://www.sec.gov/Archives/edgar/data/316411...
# 24       20080930  https://www.sec.gov/Archives/edgar/data/316411...
# 25       20080930  https://www.sec.gov/Archives/edgar/data/316411...
#    holdings shares holdings value                        holdings name key  \
# 0           311757       14113239        Honeywell International, Inc.
# 1           167800       10807998  United Parcel Service, Inc., ClassB
# 2           548000       36255680                        PepsiCo, Inc.
# 3            92400       15766212        The Goldman Sachs Group, Inc.
# 4           206600        6580210              Celanese Corp., SeriesA
# 5           245810       17555750                         Monsanto Co.
# 6           484100       20327359                       QUALCOMM, Inc.
# 7           858000       25851540                      Halliburton Co.
# 8           441300        9558558                       The Kroger Co.
# 9           341500       18987400                Wal-Mart Stores, Inc.
# 10          130700        6983301                          Kellogg Co.
# 11          464000       27004800           Baxter International, Inc.
# 12          559900       25212297                      Medtronic, Inc.
# 13          613900       38841453             The Procter & Gamble Co.
# 14          109687        9166543                               3M Co.
# 15          159248        8645574                          AFLAC, Inc.
# 16          513123       31043941           Prudential Financial, Inc.
# 17          205900       11653940                     Joy Global, Inc.
# 18          559671       29438695                         Target Corp.
# 19           79726        8092189                         Apache Corp.
# 20          767253       13158389                         Pfizer, Inc.
# 21          338200       17214380                            CSX Corp.
# 22          259518       19022669                  Union Pacific Corp.
# 23          764875       17026118                          Intel Corp.
# 24         1313957       33755555                         Oracle Corp.
# 25         1003775       52356904    Philip Morris International, Inc.
#
#                      fund name                  identifier value multiplier  \
# 0   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 1   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 2   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 3   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 4   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 5   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 6   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 7   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 8   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 9   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 10  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 11  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 12  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 13  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 14  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 15  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 16  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 17  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 18  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 19  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 20  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 21  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 22  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 23  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 24  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 25  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
#
#                     textfile     CIK date_filed    company conformed name  \
# 0   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 1   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 2   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 3   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 4   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 5   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 6   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 7   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 8   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 9   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 10  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 11  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 12  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 13  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 14  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 15  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 16  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 17  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 18  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 19  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 20  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 21  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 22  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 23  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 24  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 25  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
#
#    reporting_date
# 0        20090331
# 1        20090331
# 2        20090331
# 3        20090331
# 4        20090331
# 5        20090331
# 6        20090331
# 7        20090331
# 8        20090331
# 9        20090331
# 10       20090331
# 11       20090331
# 12       20090331
# 13       20090331
# 14       20090331
# 15       20090331
# 16       20090331
# 17       20090331
# 18       20090331
# 19       20090331
# 20       20090331
# 21       20090331
# 22       20090331
# 23       20090331
# 24       20090331
# 25       20090331
#    holdings shares holdings value                        holdings name key  \
# 0           311757       14113239        Honeywell International, Inc.
# 1           167800       10807998  United Parcel Service, Inc., ClassB
# 2           548000       36255680                        PepsiCo, Inc.
# 3            92400       15766212        The Goldman Sachs Group, Inc.
# 4           206600        6580210              Celanese Corp., SeriesA
# 5           245810       17555750                         Monsanto Co.
# 6           484100       20327359                       QUALCOMM, Inc.
# 7           858000       25851540                      Halliburton Co.
# 8           441300        9558558                       The Kroger Co.
# 9           341500       18987400                Wal-Mart Stores, Inc.
# 10          130700        6983301                          Kellogg Co.
# 11          464000       27004800           Baxter International, Inc.
# 12          559900       25212297                      Medtronic, Inc.
# 13          613900       38841453             The Procter & Gamble Co.
# 14          109687        9166543                               3M Co.
# 15          159248        8645574                          AFLAC, Inc.
# 16          513123       31043941           Prudential Financial, Inc.
# 17          205900       11653940                     Joy Global, Inc.
# 18          559671       29438695                         Target Corp.
# 19           79726        8092189                         Apache Corp.
# 20          767253       13158389                         Pfizer, Inc.
# 21          338200       17214380                            CSX Corp.
# 22          259518       19022669                  Union Pacific Corp.
# 23          764875       17026118                          Intel Corp.
# 24         1313957       33755555                         Oracle Corp.
# 25         1003775       52356904    Philip Morris International, Inc.
#
#                      fund name                  identifier value multiplier  \
# 0   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 1   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 2   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 3   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 4   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 5   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 6   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 7   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 8   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 9   SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 10  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 11  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 12  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 13  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 14  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 15  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 16  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 17  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 18  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 19  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 20  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 21  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 22  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 23  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 24  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
# 25  SELIGMAN GROWTH FUND, INC.  SELIGMAN GROWTH FUND, INC.
#
#                     textfile     CIK date_filed    company conformed name  \
# 0   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 1   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 2   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 3   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 4   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 5   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 6   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 7   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 8   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 9   0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 10  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 11  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 12  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 13  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 14  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 15  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 16  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 17  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 18  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 19  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 20  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 21  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 22  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 23  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 24  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
# 25  0001169232-09-002769.txt  316411   20090527  SELIGMAN GROWTH FUND INC
#
#    reporting_date                                            weblink
# 0        20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 1        20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 2        20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 3        20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 4        20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 5        20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 6        20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 7        20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 8        20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 9        20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 10       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 11       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 12       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 13       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 14       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 15       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 16       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 17       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 18       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 19       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 20       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 21       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 22       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 23       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 24       20090331  https://www.sec.gov/Archives/edgar/data/316411...
# 25       20090331  https://www.sec.gov/Archives/edgar/data/316411...

# %%
panel1.loc[:,'acq name'] = ''
panel1.loc[:,'acq date'] = ''
panel1.loc[:,'acq cost'] = ''
print(output_directory)
panel1.to_csv(os.path.join(output_directory, fund_name + '_panel1.csv'), sep = ',')
panel1_legend.to_csv(os.path.join(output_directory, fund_name + '_panel1_legend.csv'), sep = ',')
# Out:
# C:\Users\jjanko\Desktop\wei_mutual_fund_project\output\working

# %%
panel1_legend.loc[:,'restricted'] = 'no'

panel1_legend.loc[panel1_legend['code'].str.contains("restrict") | panel1_legend['code'].str.contains("level 3 security") \
              | panel1_legend['code'].str.contains("exempt from registration") |panel1_legend['code'].str.contains("private placement") , 'restricted'] = 'yes'

restricted = panel1_legend.loc[panel1_legend['restricted'].str.contains("yes")]

restricted.to_csv(os.path.join(output_directory, fund_name + '_panel1_restricted_legend.csv'), sep = ',')
print(restricted)

panel1.loc[:,'restricted'] = 'no'

for index, row in restricted.iterrows():
    try:
        panel1.loc[(panel1['identifier'] == row['identifier']) & (panel1['textfile'] == row.textfile) \
                       & (panel1['key'].str.contains(row['symbol'])), 'restricted'] = 'yes'
    except:
        pass
    
restricted_holdings = panel1.loc[(panel1['restricted'] == 'yes')]
restricted_holdings.to_csv(os.path.join(output_directory, fund_name + '_panel1_restricted.csv'), sep = ',')
# Out:
# Empty DataFrame
# Columns: [code, symbol, restricted, identifier, weblink, textfile]
# Index: []
