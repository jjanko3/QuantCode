# %%
import os
import pandas as pd
from lxml import html
import requests
import re
import sys
from datetime import datetime

from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import time
import pickle
import string

# %%
fund_name = 'anchor'


CIK_LIST = ['726735']

# %%
cur_wd = os.getcwd()
if 'trunk' in cur_wd:
    output_directory = os.path.join("\\".join(cur_wd.split('\\')[0:-1]),'output')
else:
    output_directory = os.path.join("\\".join(cur_wd.split('\\')[0:-1]),'output','working')
    
cached_wd = os.path.join("\\".join(cur_wd.split('\\')[0:-1]),'cached_data')
cur_wd = os.path.join("\\".join(cur_wd.split('\\')[0:-1]),'data')
print('data directory')
print(cur_wd)
print('output directory')
print(output_directory)

print('cached data')
print(cached_wd)
# Out:
# data directory
# C:\Users\jjanko\Desktop\wei_mutual_fund_project\data
# output directory
# C:\Users\jjanko\Desktop\wei_mutual_fund_project\output\working
# cached data
# C:\Users\jjanko\Desktop\wei_mutual_fund_project\cached_data

# %%
weblink = {}
txt = []

for CIK in CIK_LIST:
    weblink[CIK]  = []
    txt_files = os.listdir(os.path.join(cur_wd, CIK, 'n-q'))
    for i in txt_files:
        txt.append(i)
        weblink[CIK].append(r"https://www.sec.gov/Archives/edgar/data/" + str(CIK)+r"/"  + i)

# %%
with open(os.path.join(cached_wd, 'errors_dict.pickle'), 'rb') as handle:
    errors = pickle.load(handle)
    
print(errors)
# Out:
# {'867297': ['0001193125-04-202597.txt', '0001193125-05-115532.txt', '0001193125-05-232633.txt'], '1091439': ['0000950152-04-008622.txt', '0000950152-05-004867.txt', '0000950152-05-009599.txt'], '1301708': ['0000950152-05-009600.txt'], '1423227': [], '1098605': ['0000950136-05-006141.txt', '0000950136-04-003174.txt', '0000950136-05-001871.txt'], '1378240': ['0001104659-07-029038.txt', '0001104659-07-077264.txt', '0001104659-08-027201.txt', '0001104659-08-064591.txt'], '726735': ['0000950129-04-009378.txt', '0000950129-05-005810.txt', '0000950129-05-011455.txt'], '844779': ['0001193125-05-039836.txt', '0001193125-05-175146.txt', '0001193125-05-175147.txt', '0001193125-05-175620.txt'], '1398078': [], '774013': ['0001193805-05-000319.txt', '0001193805-05-001781.txt', '0001193805-05-002628.txt', '0001193805-05-002636.txt', '0001193805-05-002638.txt'], '1062806': ['0000900092-04-000310.txt', '0000900092-05-000103.txt', '0000900092-05-000135.txt', '0000900092-05-000453.txt', '0001193805-04-001626.txt', '0001193805-05-002132.txt'], '1026144': ['0001193805-04-001796.txt', '0001193805-04-001803.txt', '0001193805-04-001824.txt', '0001193805-04-001836.txt', '0001193805-05-000898.txt', '0001193805-05-001187.txt', '0001193805-05-001197.txt', '0001193805-05-001217.txt', '0001193805-05-001228.txt', '0001193805-05-002368.txt', '0001193805-05-002374.txt', '0001193805-05-002382.txt', '0001193805-05-002390.txt'], '1062805': ['0000900092-04-000311.txt', '0000900092-05-000104.txt', '0000900092-05-000136.txt', '0000900092-05-000454.txt', '0001193805-04-001628.txt', '0001193805-05-000900.txt', '0001193805-05-002134.txt'], '276463': ['0000900092-05-000045.txt', '0000900092-05-000047.txt', '0000900092-05-000052.txt', '0000900092-05-000113.txt', '0000900092-05-000374.txt', '0000900092-05-000376.txt', '0000900092-05-000377.txt'], '1097077': ['0001193805-04-001466.txt', '0001193805-04-001490.txt', '0001193805-04-001495.txt', '0001193805-05-000623.txt', '0001193805-05-000639.txt', '0001193805-05-000651.txt', '0001193805-05-001991.txt', '0001193805-05-001995.txt', '0001193805-05-001999.txt'], '1137391': ['0000891092-13-005525.txt', '0000891092-13-010218.txt', '0000891092-14-004773.txt', '0000891092-14-009551.txt', '0000891092-15-005304.txt', '0000930413-04-004580.txt', '0000930413-05-002397.txt', '0000930413-05-006885.txt', '0000930413-06-002593.txt', '0000930413-06-007049.txt', '0000930413-07-002985.txt', '0000930413-07-007633.txt', '0000930413-08-002117.txt', '0000930413-08-007373.txt', '0001171200-09-000395.txt', '0001171200-09-001050.txt', '0001171200-10-000620.txt', '0001171200-10-001195.txt', '0001171200-11-000541.txt', '0001171200-11-001133.txt', '0001171200-12-000586.txt', '0001193125-12-512794.txt', '0001193125-15-410813.txt', '0001193125-16-628998.txt', '0001193125-16-798990.txt', '0001193125-17-210388.txt', '0001193125-17-376378.txt', '0001193125-18-197964.txt', '0001193125-18-356378.txt'], '1160864': ['0000891092-13-000558.txt', '0000891092-13-006494.txt', '0000891092-14-000498.txt', '0000891092-14-005548.txt', '0000891092-15-000459.txt', '0000891092-15-006483.txt', '0000930413-04-004572.txt', '0000930413-05-002392.txt', '0000930413-05-006895.txt', '0000930413-06-002619.txt', '0000930413-06-007033.txt', '0000930413-07-002962.txt', '0000930413-07-007640.txt', '0000930413-08-002102.txt', '0000930413-08-005678.txt', '0000930413-09-000518.txt', '0001171200-09-000501.txt', '0001171200-10-000067.txt', '0001171200-10-000744.txt', '0001171200-11-000053.txt', '0001171200-11-000652.txt', '0001171200-12-000097.txt', '0001171200-12-000716.txt', '0001193125-16-435647.txt', '0001193125-16-658423.txt', '0001193125-17-016352.txt', '0001193125-17-233962.txt', '0001193125-18-016079.txt', '0001193125-18-223365.txt', '0001193125-19-013796.txt'], '1181249': ['0000891092-13-005524.txt', '0000891092-13-010217.txt', '0000891092-14-004774.txt', '0000891092-14-009550.txt', '0000891092-15-005305.txt', '0000930413-04-005417.txt', '0000930413-05-003986.txt', '0000930413-05- ...

# %%
with open(os.path.join(cached_wd, 'panel2.pickle'), 'rb') as handle:
    panel2 = pickle.load(handle)

# %%
panel2 = panel2.loc[panel2['file_read'].isin(txt)]

# %%
print(panel2)
panel2.to_csv(os.path.join(output_directory, fund_name + '_panel2.csv'), sep = ',')
# Out:
#    CLASS-CONTRACT-ID CLASS-CONTRACT-NAME CLASS-CONTRACT-TICKER-SYMBOL  \
# 0         C000021550             Class 3                        STAAA
# 1         C000021551             Class 1                        STAAB
# 2         C000021552             Class 2                        ASCAA
# 3         C000021553             Class 3                        ASCAB
# 4         C000021554             Class 1                        ASGQA
# 5         C000021555             Class 2                        ASGQB
# 6         C000021556             Class 3                        ASGIA
# 7         C000021557             Class 1                        ASGRA
# 8         C000021558             Class 2                        ASGRB
# 9         C000021559             Class 1                        ASMMA
# 10        C000021560             Class 3                        ASMAA
# 11        C000021561             Class 1                        ASNRA
# 12        C000021562             Class 2                        ASNRB
# 13        C000021563             Class 1                        ASTMA
# 14        C000021564             Class 1                         None
# 15        C000021565             Class 3                         None
# 16        C000021566             Class 1                         None
# 17        C000021567             Class 2                         None
# 18        C000021568             Class 1                         None
# 0         C000021550             Class 3                        STAAA
# 1         C000021551             Class 1                        STAAB
# 2         C000021552             Class 2                        ASCAA
# 3         C000021553             Class 3                        ASCAB
# 4         C000021554             Class 1                        ASGQA
# 5         C000021555             Class 2                        ASGQB
# 6         C000021556             Class 3                        ASGIA
# 7         C000021557             Class 1                        ASGRA
# 8         C000021558             Class 2                        ASGRB
# 9         C000021559             Class 1                        ASMMA
# 10        C000021560             Class 3                        ASMAA
# ..               ...                 ...                          ...
# 10        C000021560             Class 3                        ASNRA
# 11        C000021561             Class 1                        ASNRB
# 12        C000021562             Class 2                        ASTMA
# 13        C000021564             Class 1                         None
# 14        C000118111             Class 3                         None
# 15        C000021565             Class 3                         None
# 16        C000021566             Class 1                         None
# 17        C000021567             Class 2                         None
# 18        C000021568             Class 1                         None
# 19        C000173074             Class 3                         None
# 0         C000021550             Class 3                        STAAA
# 1         C000021551             Class 1                        STAAB
# 2         C000021552             Class 2                        ASCAA
# 3         C000021553             Class 3                        ASCAB
# 4         C000021554             Class 1                        ASGQA
# 5         C000021555             Class 2                        ASGQB
# 6         C000021556             Class 3                        ASGIA
# 7         C000021557             Class 1                        ASGRA
# 8         C000021558             Class 2                        ASGRB
# 9         C000021559             Class 1                        ASMAA
# 10        C000021560             Class 3                        ASNRA
# 11        C000021561             Class 1                        ASNRB
# 12        C000021562             Class 2                        ASTMA
# 13        C000021564             Class 1                         None
# 14        C000118111             Class 3                         None
# 15        C000021565             Class 3                         None
# 16        C000021566             Class 1                         None
# 17        C000021567             Class 2                         None
# 18        C000021568             Class 1                         None
# 19        C000173074             Class 3                         None
#
#      SERIES-ID   OWNER-CIK                                        SERIES-NAME  \
# 0   S000007948  0000726735                         Asset Allocation Portfolio
# 1   S000007948  0000726735                         Asset Allocation Portfolio
# 2   S000007948  0000726735                         Asset Allocation Portfolio
# 3   S000007949  0000726735                     Capital Appreciation Portfolio
# 4   S000007949  0000726735                     Capital Appreciation Portfolio
# 5   S000007949  0000726735                     Capital Appreciation Portfolio
# 6   S000007950  0000726735              Government and Quality Bond Portfolio
# 7   S000007950  0000726735              Government and Quality Bond Portfolio
# 8   S000007950  0000726735              Government and Quality Bond Portfolio
# 9   S000007951  0000726735                        Growth and Income Portfolio
# 10  S000007952  0000726735                                   Growth Portfolio
# 11  S000007952  0000726735                                   Growth Portfolio
# 12  S000007952  0000726735                                   Growth Portfolio
# 13  S000007953  0000726735                             Money Market Portfolio
# 14  S000007954  0000726735                              Multi-Asset Portfolio
# 15  S000007955  0000726735                        Natural Resources Portfolio
# 16  S000007955  0000726735                        Natural Resources Portfolio
# 17  S000007955  0000726735                        Natural Resources Portfolio
# 18  S000007956  0000726735                    Strategic Multi-Asset Portfolio
# 0   S000007948  0000726735                         Asset Allocation Portfolio
# 1   S000007948  0000726735                         Asset Allocation Portfolio
# 2   S000007948  0000726735                         Asset Allocation Portfolio
# 3   S000007949  0000726735                     Capital Appreciation Portfolio
# 4   S000007949  0000726735                     Capital Appreciation Portfolio
# 5   S000007949  0000726735                     Capital Appreciation Portfolio
# 6   S000007950  0000726735              Government and Quality Bond Portfolio
# 7   0000950123-10-054054.txt   20100528    ANCHOR SERIES TRUST       20100331
# 8   0000950123-10-054054.txt   20100528    ANCHOR SERIES TRUST       20100331
# 9   0000950123-10-054054.txt   20100528    ANCHOR SERIES TRUST       20100331
# 10  0000950123-10-054054.txt   20100528    ANCHOR SERIES TRUST       20100331
# ..                       ...        ...                    ...            ...
# 10  0001193125-18-176521.txt   20180529    ANCHOR SERIES TRUST       20180331
# 11  0001193125-18-176521.txt   20180529    ANCHOR SERIES TRUST       20180331
# 12  0001193125-18-176521.txt   20180529    ANCHOR SERIES TRUST       20180331
# 13  0001193125-18-176521.txt   20180529    ANCHOR SERIES TRUST       20180331
# 14  0001193125-18-176521.txt   20180529    ANCHOR SERIES TRUST       20180331
# 15  0001193125-18-176521.txt   20180529    ANCHOR SERIES TRUST       20180331
# 16  0001193125-18-176521.txt   20180529    ANCHOR SERIES TRUST       20180331
# 17  0001193125-18-176521.txt   20180529    ANCHOR SERIES TRUST       20180331
# 18  0001193125-18-176521.txt   20180529    ANCHOR SERIES TRUST       20180331
# 19  0001193125-18-176521.txt   20180529    ANCHOR SERIES TRUST       20180331
# 0   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 1   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 2   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 3   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 4   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 5   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 6   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 7   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 8   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 9   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 10  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 11  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 12  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 13  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 14  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 15  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 16  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 17  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 18  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 19  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
#
# [498 rows x 10 columns]

# %% [markdown]
# ## Test on One FILE

# %%
CIK  = '726735'
text =  '0001193125-18-336505.txt'

# %%
panel2.loc[panel2['file_read'] == text]
# Out:
#    CLASS-CONTRACT-ID CLASS-CONTRACT-NAME CLASS-CONTRACT-TICKER-SYMBOL  \
# 0         C000021550             Class 3                        STAAA
# 1         C000021551             Class 1                        STAAB
# 2         C000021552             Class 2                        ASCAA
# 3         C000021553             Class 3                        ASCAB
# 4         C000021554             Class 1                        ASGQA
# 5         C000021555             Class 2                        ASGQB
# 6         C000021556             Class 3                        ASGIA
# 7         C000021557             Class 1                        ASGRA
# 8         C000021558             Class 2                        ASGRB
# 9         C000021559             Class 1                        ASMAA
# 10        C000021560             Class 3                        ASNRA
# 11        C000021561             Class 1                        ASNRB
# 12        C000021562             Class 2                        ASTMA
# 13        C000021564             Class 1                         None
# 14        C000118111             Class 3                         None
# 15        C000021565             Class 3                         None
# 16        C000021566             Class 1                         None
# 17        C000021567             Class 2                         None
# 18        C000021568             Class 1                         None
# 19        C000173074             Class 3                         None
#
#      SERIES-ID   OWNER-CIK                                        SERIES-NAME  \
# 0   S000007948  0000726735                  SA PGI Asset Allocation Portfolio
# 1   S000007948  0000726735                  SA PGI Asset Allocation Portfolio
# 2   S000007948  0000726735                  SA PGI Asset Allocation Portfolio
# 3   S000007949  0000726735       SA Wellington Capital Appreciation Portfolio
# 4   S000007949  0000726735       SA Wellington Capital Appreciation Portfolio
# 5   S000007949  0000726735       SA Wellington Capital Appreciation Portfolio
# 6   S000007950  0000726735  SA Wellington Government and Quality Bond Port...
# 7   S000007950  0000726735  SA Wellington Government and Quality Bond Port...
# 8   S000007950  0000726735  SA Wellington Government and Quality Bond Port...
# 9   S000007951  0000726735          SA Wellington Growth and Income Portfolio
# 10  S000007952  0000726735                     SA Wellington Growth Portfolio
# 11  S000007952  0000726735                     SA Wellington Growth Portfolio
# 12  S000007952  0000726735                     SA Wellington Growth Portfolio
# 13  S000007954  0000726735          SA BlackRock Multi-Asset Income Portfolio
# 14  S000007954  0000726735          SA BlackRock Multi-Asset Income Portfolio
# 15  S000007955  0000726735          SA Wellington Natural Resources Portfolio
# 16  S000007955  0000726735          SA Wellington Natural Resources Portfolio
# 17  S000007955  0000726735          SA Wellington Natural Resources Portfolio
# 18  S000007956  0000726735      SA Wellington Strategic Multi-Asset Portfolio
# 19  S000007956  0000726735      SA Wellington Strategic Multi-Asset Portfolio
#
#                    file_read date_filed company conformed name reporting_date
# 0   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 1   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 2   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 3   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 4   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 5   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 6   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 7   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 8   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 9   0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 10  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 11  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 12  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 13  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 14  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 15  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 16  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 17  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 18  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930
# 19  0001193125-18-336505.txt   20181128    ANCHOR SERIES TRUST       20180930

# %%
names = panel2.loc[panel2['file_read'] == text, 'SERIES-NAME']
names = names.unique()
print(names)
# Out:
# ['SA PGI Asset Allocation Portfolio'
#  'SA Wellington Capital Appreciation Portfolio'
#  'SA Wellington Government and Quality Bond Portfolio'
#  'SA Wellington Growth and Income Portfolio'
#  'SA Wellington Growth Portfolio'
#  'SA BlackRock Multi-Asset Income Portfolio'
#  'SA Wellington Natural Resources Portfolio'
#  'SA Wellington Strategic Multi-Asset Portfolio']

# %%
url = r'https://www.sec.gov/Archives/edgar/data/' + CIK + r'/' + text.replace('.txt', '').replace('-','')  + r'/' + text
html_table = urlopen(url).read()
soup = BeautifulSoup(html_table, "html.parser")
tags = soup.find_all(['tr','b'])

# %%
tables = []
iterate = 0

for h in tags:
    if 'series' in str(h).lower() and 'portfolio'  in str(h).lower() and '<b>' in str(h).lower():
        print(str(h).lower())
        
    try:
        df = pd.read_html(str(i), flavor="bs4")
        for j in df:
            if len(j.index) > 0 :
                tables.append(j)
                iterate = iterate + 1
    except:
        pass
# Out:
# <b>anchor series trust sa wellington government and quality bond portfolio </b>
# <b>anchor series trust sa pgi asset allocation portfolio# </b>
# <b>anchor series trust sa wellington growth and income portfolio# </b>
# <b>anchor series trust sa wellington growth portfolio# </b>
# <b>anchor series trust sa wellington capital appreciation portfolio </b>
# <b>anchor series trust sa wellington natural resources portfolio# </b>
# <b>anchor series trust sa blackrock multi-asset income portfolio </b>
# <b>anchor series trust sa wellington strategic multi-asset portfolio# </b>

# %%
def remove_junk(addline):
    addline = re.sub('<[^>]*>', ' ', addline)
    addline = re.sub('&nbsp;', ' ', addline)
    addline = re.sub('&#174;', ' ', addline)
    addline = re.sub('&#8480;', ' ', addline)
    addline = re.sub(r'&reg;',' ',addline)
    addline = re.sub(r'\n', ' ', addline)
    addline = re.sub(r'\t', ' ', addline)
    addline = re.sub('\xa0', ' ', addline)
    return addline

# %%
count = 0
for i in tables:
    s = 'table ' + str(count)
    print(s)
    print(i)
    count = count + 1

# %%
def get_holdings(df):
    filter_names = []
    cleaned_df = pd.DataFrame()
    add =0 
    if len(df.columns) >= 3:
        col_name = 0
        
        df = df.dropna(axis = 0, subset = [df.columns[col_name]])
        df = df.dropna(thresh = 3, axis = 0)

        for count, row in df.iterrows():
            name = str(row[0])
            if name[-1] != r'%' and '(cost' not in name.lower() and 'issuer' not in name.lower() and 'security description' not in name.lower() \
            and 'due' not in name.lower() :
                keys = re.findall(r'\([^()]*\)',name)
                key = ''
                for k in keys:
                    if '-' not in k:
                        key = key + k
                        name = name.replace(k,'')

                strip_punct = '!"#$%&\'()+,-./:;<=>?@[\\]^_`{|}'
                h = re.findall("[^A-Za-z0-9]", name.replace(' ', ''))
                key2 = ''.join(h)
                key2 = key2.strip(strip_punct)
                for c in key2:
                    name = name.replace(c,"")

                
                add = pd.DataFrame(df.loc[count]).dropna()
                add = add[~add.duplicated()]
                add = add.loc[1:]
                if len(add) == 2:
                    add = add.transpose().dropna()
                    add.columns = ['holdings shares', 'holdings value']
                    add['holdings name'] = name
                    add['key'] = key + key2
                    add.loc[0,'holdings shares'] = add.loc[0,'holdings shares'].replace('$','').replace(',','')
                    add.loc[0,'holdings value'] = add.loc[0,'holdings value'].replace('$','').replace(',','')
                    if add.loc[0,'holdings shares'].isdigit() and add.loc[0,'holdings value'].isdigit():
                        cleaned_df = pd.concat([cleaned_df, add], axis = 0, sort=False, ignore_index = True)

                        cleaned_df.index = pd.RangeIndex(len(cleaned_df.index))

    return cleaned_df, add

# %%
def get_legend(df):
    df = df.dropna(axis = 0, how = 'all')
    df = df.dropna(axis = 1, how = 'all')
    legend = pd.DataFrame(columns = ['code', 'symbol', 'restricted'])
    try:
        for count, row in df.iterrows():
            keys = str(row[0])
            code = str(row[1])
            if (keys.strip() != code.strip()) and (code.strip() != ''):
                if (len(keys) == 3 and '(' in keys and ')' in keys) or ((len(keys) == 1) and (keys.isdigit() is False) and (keys.isalpha() is False)):

                    add = pd.DataFrame([code, keys, '']).T
                    add.columns = ['code', 'symbol', 'restricted']
                    if len(legend.index) == 0:
                        legend = add.copy()
                    else:
                        legend = pd.concat([legend, add], axis = 0,ignore_index = True, sort = False)
    except:
        pass

                    
    return legend

# %%
names = panel2.loc[panel2['file_read'] == text, 'SERIES-NAME']
names = names.unique()

holdings = pd.DataFrame()
legend = pd.DataFrame()
fundname = ''

for tr in tags:
    if 'series' in str(tr).lower() and 'portfolio'  in str(tr).lower() and '<b>' in str(tr).lower():
        s = str(tr).replace('&amp','and')
        s = s.replace('  ', '')
        s = s.replace(';','')
        s = remove_junk(s)
        for n in names:
            if n.lower().strip() in str(s).lower().strip():
                fundname = n
                print(fundname)
                
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td]
    row = list(filter(None, row))
    if len(row) == 3:
        add = pd.DataFrame(row).T
        cleaned_df, add1 = get_holdings(add)
        if len(cleaned_df.index) > 0:
            cleaned_df.loc[:, 'fund name'] = fundname
            cleaned_df.loc[:, 'identifier'] = fundname
            if len(holdings.index) > 0:
                holdings = pd.concat([holdings, cleaned_df], axis = 0, sort=False, ignore_index = True)
            else:
                holdings = cleaned_df.copy()
                
    if len(row) == 2:
        add = pd.DataFrame(row).T
        add_legend = get_legend(add)
        if len(add_legend.index) > 0:
            add_legend.loc[:, 'identifier'] = fundname
            if len(legend.index) > 0:
                legend = pd.concat([legend, add_legend], axis = 0 , sort=False, ignore_index = True)
            else:
                legend  = add_legend.copy()
# Out:
# SA Wellington Government and Quality Bond Portfolio
# SA PGI Asset Allocation Portfolio
# SA Wellington Growth and Income Portfolio
# SA Wellington Growth Portfolio
# SA Wellington Capital Appreciation Portfolio
# SA Wellington Natural Resources Portfolio
# SA BlackRock Multi-Asset Income Portfolio
# SA Wellington Strategic Multi-Asset Portfolio

# %%
legend
# Out:
#                                                  code symbol restricted  \
# 0   Securities exempt from registration under Rule...      *
# 1   Certain variable rate securities are not based...    (1)
# 2                  Collateralized Mortgage Obligation    (2)
# 3                      Collateralized Loan Obligation    (3)
# 4                 Commercial Mortgage Backed Security    (4)
# 5   Principal amount of security is adjusted for i...    (5)
# 6   The security or a portion thereof was pledged ...    (6)
# 7   See Note 2 for details of Joint Repurchase Agr...    (7)
# 8                                             516,438      $
# 9   Notational basis refers to the contractual amo...      *
# 10  For a detailed presentation of investments, pl...      *
# 11  Other financial instruments are derivative Ins...      +
# 12  Subsequent to September 30, 2018, the SA Edge ...      #
# 13                      Non-income producing security      †
# 14  Securities exempt from registration under Rule...      *
# 15  Perpetual maturity - maturity date reflects th...    (1)
# 16  Certain variable rate securities are not based...    (2)
# 17                Commercial Mortgage Backed Security    (3)
# 18                 Collateralized Mortgage Obligation    (4)
# 19  PIK (“Payment-in-Kind”) security - Income may ...    (5)
# 20     Securities classified as Level 3 (see Note 1).    (6)
# 21  Illiquid security. At September 30, 2018, the ...    (7)
# 22                                      Interest Only    (8)
# 23                   Security in default of interest.    (9)
# 24  For a detailed presentation of investments, pl...      *
# 25  Subsequent to September 30, 2018, the SA Welli...      #
# 26                      Non-income producing security      †
# 27  Illiquid security. At September 30, 2018, the ...    (1)
# 28     Securities classified as Level 3 (see Note 1).    (2)
# 29  See Note 2 for details of Joint Repurchase Agr...    (3)
# ..                                                ...    ...        ...
# 34  See Note 2 for details of Joint Repurchase Agr...    (1)
# 35  For a detailed presentation of investments, pl...      *
# 36                      Non-income producing security      †
# 37  Illiquid security. At September 30, 2018, the ...    (1)
# 38     Securities classified as Level 3 (see Note 1).    (2)
# 39  Denotes a restricted security that: (a) cannot...    (3)
# 40  See Note 2 for details of Joint Repurchase Agr...    (4)
# 41  For a detailed presentation of investments, pl...      *
# 42  The total change in unrealized appreciation (d...    (1)
# 43  The significant unobservable inputs regarding ...    (1)
# 44  Subsequent to September 30, 2018, the SA Welli...      #
# 45                      Non-income producing security      †
# 46  Illiquid security. At September 30, 2018, the ...    (1)
# 47  See Note 2 for details of Joint Repurchase Agr...    (2)
# 48  For a detailed presentation of investments, pl...      *
# 49                                             49,325      $
# 50  Notional basis refers to the contractual amoun...      *
# 51  For a detailed presentation of investments, pl...      *
# 52  Other financial instruments are derivative ins...      +
# 57      SA Wellington Strategic Multi-Asset Portfolio
# 58      SA Wellington Strategic Multi-Asset Portfolio
# 59      SA Wellington Strategic Multi-Asset Portfolio
# 60      SA Wellington Strategic Multi-Asset Portfolio
# 61      SA Wellington Strategic Multi-Asset Portfolio
# 62      SA Wellington Strategic Multi-Asset Portfolio
# 63      SA Wellington Strategic Multi-Asset Portfolio
#
# [64 rows x 4 columns]

# %%
holdings.to_csv('check.csv')

# %%
holdings['value multiplier'] = ''
holdings['textfile'] = text
holdings['CIK'] = CIK
holdings['date_filed'] = '' 
holdings['company conformed name'] = ''
holdings['reporting_date'] = ''

try:
    date_filed = panel2.loc[panel2['file_read'] == text, 'date_filed'].unique()[0]
    conformed_name = panel2.loc[panel2['file_read'] == text, 'company conformed name'].unique()[0]
    reporting_date = panel2.loc[panel2['file_read'] == text, 'reporting_date'].unique()[0]
except IndexError:
    date_filed = ''
    conformed_name = ''

holdings.loc[:, 'date_filed'] = date_filed
holdings.loc[:, 'company conformed name'] = conformed_name
holdings.loc[:, 'reporting_date'] = reporting_date

holdings.index = pd.RangeIndex(len(holdings.index))
print(holdings)

for z in weblink[CIK]:
    if text in z:
        matching_link = z

holdings['weblink'] = matching_link
legend['weblink'] = matching_link
legend['textfile'] = text
# Out:
#     holdings shares holdings value  \
# 0               495          52688
# 1              1755         556984
# 2             77000         215600
# 3             12194         839679
# 4              5500         439120
# 5              6544         378440
# 6              1273          51047
# 7              2213         206805
# 8             17966        2054771
# 9              2599         354192
# 10             9000         325170
# 11            36000         673380
# 12             2769         107767
# 13             6128         417869
# 14             1878          73824
# 15            11320         981218
# 16             1403          64640
# 17            11693         614233
# 18            70000         441000
# 19            13478         104589
# 20             7139         270996
# 21              414          40274
# 22             5573         582044
# 23            11202         676265
# 24             2560          41395
# 25            38000         492860
# 26             2190         104354
# 27              812          44904
# 28            10431        1420598
# 29             3250         217068
# ..              ...            ...
# 723             635          92710
# 724            4881         125295
# 725            5590         347027
# 726            1400         136279
# 727            4294         157160
# 728            2043         543520
# 729            2058         286309
# 730            1307         199644
# 731             860         116264
# 732            3432         437820
# 733            4465         289480
# 734            1165         132519
# 735            7764         314675
# 736           11100         128038
# 737            1962         395598
# 738            3731         182285
# 739            8344         252949
# 740            6519         327710
# 741            1400         160748
# 742            1033         304528
# 743            4159         307808
# 744           41520         356958
# 745            1264         128561
# 746            1311         132346
# 747            9774         456645
# 748            5173         297551
# 749            6571         486583
# 750             655         105625
# 751             452         539448
# 752            4509         148301
#
#                                          holdings name    key  \
# 0                                     MSA Safety, Inc.
# 1                               Northrop Grumman Corp.
# 2                              Incitec Pivot, Ltd. ADR
# 3                               Alaska Air Group, Inc.
# 4                             Copa Holdings SA, ClassA
# 5                                Delta Air Lines, Inc.
# 6                              Hawaiian Holdings, Inc.
# 7                                             VF Corp.
# 8                                      Microsoft Corp.
# 9                                        Red Hat, Inc.      †
# 10                     Ritchie Bros. Auctioneers, Inc.
# 11                          Nissan Motor Co., Ltd. ADR
# 12                                     NFI Group, Inc.
# 13                                        PACCAR, Inc.
# 14                                          Adient PLC
# 15                                       Autoliv, Inc.
# 16                                       Linamar Corp.
# 17                           Magna International, Inc.
# 18              Banco Bilbao Vizcaya Argentaria SA ADR
# 19   Banco Santander Mexico SA Institucion de Banca...
# 20                                            Bank OZK
# 21                                 BOK Financial Corp.
# 22                          Cullen/Frost Bankers, Inc.
# 23                             East West Bancorp, Inc.
# 24                                  Hope Bancorp, Inc.
# 25                                    ING Groep NV ADR
# 26                                     PacWest Bancorp
# 27                      Washington Trust Bancorp, Inc.
# 28                  PNC Financial Services Group, Inc.
# 29                                SunTrust Banks, Inc.
# ..                                                 ...    ...
# 723                                 Bluebird Bio, Inc.      †
# 724                           Bausch Health Cos., Inc.      †
# 725                           Bristol-Myers Squibb Co.
# 726                                    Eisai Co., Ltd.
# 727                                           Mylan NV      †
# 728                           UnitedHealth Group, Inc.
# 729                               HCA Healthcare, Inc.
# 730                             Concho Resources, Inc.      †
# 731                           Diamondback Energy, Inc.
# 732                                EOG Resources, Inc.
# 733                                           TOTAL SA
# 734                                Valero Energy Corp.
# 735                                    Halliburton Co.
# 736           Sunny Optical Technology Group Co., Ltd.
# 737                                     Public Storage
# 738                                         Vonovia SE
# 739                      Industria de Diseno Textil SA
# 740                                     Tapestry, Inc.
# 741                                   Lowes Cos., Inc.      ’
# 742                                Dominos Pizza, Inc.      ’
# 743    New Oriental Education Technology Group Inc ADR   &,.†
# 744       Taiwan Semiconductor Manufacturing Co., Ltd.
# 745                                   KLA-Tencor Corp.
# 746                               SoftBank Group Corp.
# 747                       British American Tobacco PLC
# 748                                 AerCap Holdings NV      †
# 749                                          CSX Corp.
# 750                    Old Dominion Freight Line, Inc.
# 751                             Alphabet, Inc., ClassC      †
# 752                                  Yandex NV, ClassA      †
#
#                                          fund name  \
# 0                SA PGI Asset Allocation Portfolio
# 1                SA PGI Asset Allocation Portfolio
# 2                SA PGI Asset Allocation Portfolio
# 3                SA PGI Asset Allocation Portfolio
# 4                SA PGI Asset Allocation Portfolio
# 5                SA PGI Asset Allocation Portfolio
# 6                SA PGI Asset Allocation Portfolio
# 7                SA PGI Asset Allocation Portfolio
# 8                SA PGI Asset Allocation Portfolio
# 9                SA PGI Asset Allocation Portfolio
# 10               SA PGI Asset Allocation Portfolio
# 11               SA PGI Asset Allocation Portfolio
# 12               SA PGI Asset Allocation Portfolio
# 13               SA PGI Asset Allocation Portfolio
# 14               SA PGI Asset Allocation Portfolio
# 15               SA PGI Asset Allocation Portfolio
# 16               SA PGI Asset Allocation Portfolio
# 17               SA PGI Asset Allocation Portfolio
# 18               SA PGI Asset Allocation Portfolio
# 19               SA PGI Asset Allocation Portfolio
# 20               SA PGI Asset Allocation Portfolio
# 21               SA PGI Asset Allocation Portfolio
# 22               SA PGI Asset Allocation Portfolio
# 23               SA PGI Asset Allocation Portfolio
# 24               SA PGI Asset Allocation Portfolio
# 25               SA PGI Asset Allocation Portfolio
# 26               SA PGI Asset Allocation Portfolio
# 27               SA PGI Asset Allocation Portfolio
# 28               SA PGI Asset Allocation Portfolio
# 746       20180930
# 747       20180930
# 748       20180930
# 749       20180930
# 750       20180930
# 751       20180930
# 752       20180930
#
# [753 rows x 12 columns]

# %%
legend.loc[:,'restricted'] = 'no'

legend.loc[legend['code'].str.contains("restrict") | legend['code'].str.contains("level 3 security") \
              | legend['code'].str.contains("exempt from registration") |legend['code'].str.contains("private placement") , 'restricted'] = 'yes'

restricted = legend.loc[legend['restricted'].str.contains("yes")]
print(restricted)

holdings.loc[:,'restricted'] = 'no'
# Out:
#                                                  code symbol restricted  \
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
#
#                                            identifier  \
# 0   SA Wellington Government and Quality Bond Port...
# 14                  SA PGI Asset Allocation Portfolio
# 33                     SA Wellington Growth Portfolio
# 39       SA Wellington Capital Appreciation Portfolio
# 55      SA Wellington Strategic Multi-Asset Portfolio
#
#                                               weblink  \
# 0   https://www.sec.gov/Archives/edgar/data/726735...
# 14  https://www.sec.gov/Archives/edgar/data/726735...
# 33  https://www.sec.gov/Archives/edgar/data/726735...
# 39  https://www.sec.gov/Archives/edgar/data/726735...
# 55  https://www.sec.gov/Archives/edgar/data/726735...
#
#                     textfile
# 0   0001193125-18-336505.txt
# 14  0001193125-18-336505.txt
# 33  0001193125-18-336505.txt
# 39  0001193125-18-336505.txt
# 55  0001193125-18-336505.txt

# %%
legend.loc[:,'restricted'] = 'no'

legend.loc[legend['code'].str.contains("restrict") | legend['code'].str.contains("level 3 security") \
              | legend['code'].str.contains("exempt from registration") | legend['code'].str.contains("private placement transaction"), 'restricted'] = 'yes'

restricted = legend.loc[legend['restricted'].str.contains("yes")]
print(restricted)

holdings.loc[:,'restricted'] = 'no'

for index, row in restricted.iterrows():
    holdings.loc[(holdings['identifier'] == row['identifier']) & (holdings['textfile'] == row.textfile) \
                   & (holdings['key'].str.contains(row['symbol'])), 'restricted'] = 'yes'
    
restricted_holdings = holdings.loc[(holdings['restricted'] == 'yes')]
# Out:
#                                                  code symbol restricted  \
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
#
#                                            identifier  \
# 0   SA Wellington Government and Quality Bond Port...
# 14                  SA PGI Asset Allocation Portfolio
# 33                     SA Wellington Growth Portfolio
# 39       SA Wellington Capital Appreciation Portfolio
# 55      SA Wellington Strategic Multi-Asset Portfolio
#
#                                               weblink  \
# 0   https://www.sec.gov/Archives/edgar/data/726735...
# 14  https://www.sec.gov/Archives/edgar/data/726735...
# 33  https://www.sec.gov/Archives/edgar/data/726735...
# 39  https://www.sec.gov/Archives/edgar/data/726735...
# 55  https://www.sec.gov/Archives/edgar/data/726735...
#
#                     textfile
# 0   0001193125-18-336505.txt
# 14  0001193125-18-336505.txt
# 33  0001193125-18-336505.txt
# 39  0001193125-18-336505.txt
# 55  0001193125-18-336505.txt
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-23-b507f3cf4969> in <module>
#      11 for index, row in restricted.iterrows():
#      12     holdings.loc[(holdings['identifier'] == row['identifier']) & (holdings['textfile'] == row.textfile) \
# ---> 13                    & (holdings['key'].str.contains(row['symbol'])), 'restricted'] = 'yes'
#      14
#      15 restricted_holdings = holdings.loc[(holdings['restricted'] == 'yes')]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\strings.py in contains(self, pat, case, flags, na, regex)
#    2521     def contains(self, pat, case=True, flags=0, na=np.nan, regex=True):
#    2522         result = str_contains(self._parent, pat, case=case, flags=flags, na=na,
# -> 2523                               regex=regex)
#    2524         return self._wrap_result(result, fill_value=na)
#    2525
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\strings.py in str_contains(arr, pat, case, flags, na, regex)
#     297             flags |= re.IGNORECASE
#     298
# --> 299         regex = re.compile(pat, flags=flags)
#     300
#     301         if regex.groups > 0:
#
# ~\AppData\Local\Continuum\anaconda3\lib\re.py in compile(pattern, flags)
#     232 def compile(pattern, flags=0):
#     233     "Compile a regular expression pattern, returning a Pattern object."
# --> 234     return _compile(pattern, flags)
#     235
#     236 def purge():
#
# ~\AppData\Local\Continuum\anaconda3\lib\re.py in _compile(pattern, flags)
#     284     if not sre_compile.isstring(pattern):
#     285         raise TypeError("first argument must be string or compiled pattern")
# --> 286     p = sre_compile.compile(pattern, flags)
#     287     if not (flags & DEBUG):
#     288         if len(_cache) >= _MAXCACHE:
#
# ~\AppData\Local\Continuum\anaconda3\lib\sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# --> 764         p = sre_parse.parse(p, flags)
#     765     else:
#     766         pattern = None
#
# ~\AppData\Local\Continuum\anaconda3\lib\sre_parse.py in parse(str, flags, pattern)
#     928
#     929     try:
# --> 930         p = _parse_sub(source, pattern, flags & SRE_FLAG_VERBOSE, 0)
#     931     except Verbose:
#     932         # the VERBOSE flag was switched on inside the pattern.  to be
#
# ~\AppData\Local\Continuum\anaconda3\lib\sre_parse.py in _parse_sub(source, state, verbose, nested)
#     424     while True:
#     425         itemsappend(_parse(source, state, verbose, nested + 1,
# --> 426                            not nested and not items))
#     427         if not sourcematch("|"):
#     428             break
#
# ~\AppData\Local\Continuum\anaconda3\lib\sre_parse.py in _parse(source, state, verbose, nested, first)
#     649             if not item or item[0][0] is AT:
#     650                 raise source.error("nothing to repeat",
# --> 651                                    source.tell() - here + len(this))
#     652             if item[0][0] in _REPEATCODES:
#     653                 raise source.error("multiple repeat",
#
# error: nothing to repeat at position 0

# %%
def getpanel1(CIK, text, panel2):
    names = panel2.loc[panel2['file_read'] == text, 'SERIES-NAME']
    names = names.unique()

    holdings = pd.DataFrame()
    legend = pd.DataFrame()
    fundname = ''

    for tr in tags:
        if 'series' in str(tr).lower() and 'portfolio'  in str(tr).lower() and '<b>' in str(tr).lower():
            s = str(tr).replace('&amp','and')
            s = s.replace('  ', '')
            s = s.replace(';','')
            s = remove_junk(s)
            for n in names:
                if n.lower().strip() in str(s).lower().strip():
                    fundname = n
                    print(fundname)

        td = tr.find_all('td')
        row = [tr.text.strip() for tr in td]
        row = list(filter(None, row))
        if len(row) == 3:
            add = pd.DataFrame(row).T
            cleaned_df, add1 = get_holdings(add)
            if len(cleaned_df.index) > 0:
                cleaned_df.loc[:, 'fund name'] = fundname
                cleaned_df.loc[:, 'identifier'] = fundname
                if len(holdings.index) > 0:
                    holdings = pd.concat([holdings, cleaned_df], axis = 0, sort=False, ignore_index = True)
                else:
                    holdings = cleaned_df.copy()

        if len(row) == 2:
            add = pd.DataFrame(row).T
            add_legend = get_legend(add)
            if len(add_legend.index) > 0:
                add_legend.loc[:, 'identifier'] = fundname
                if len(legend.index) > 0:
                    legend = pd.concat([legend, add_legend], axis = 0 , sort=False, ignore_index = True)
                else:
                    legend  = add_legend.copy()
                    
                    
                    
    holdings['value multiplier'] = ''
    holdings['textfile'] = text
    holdings['CIK'] = CIK
    holdings['date_filed'] = '' 
    holdings['company conformed name'] = ''
    holdings['reporting_date'] = ''

    try:
        date_filed = panel2.loc[panel2['file_read'] == text, 'date_filed'].unique()[0]
        conformed_name = panel2.loc[panel2['file_read'] == text, 'company conformed name'].unique()[0]
        reporting_date = panel2.loc[panel2['file_read'] == text, 'reporting_date'].unique()[0]
    except IndexError:
        date_filed = ''
        conformed_name = ''

    holdings.loc[:, 'date_filed'] = date_filed
    holdings.loc[:, 'company conformed name'] = conformed_name
    holdings.loc[:, 'reporting_date'] = reporting_date

    holdings.index = pd.RangeIndex(len(holdings.index))
    print(holdings)

    for z in weblink[CIK]:
        if text in z:
            matching_link = z

    holdings['weblink'] = matching_link
    legend['weblink'] = matching_link
    legend['textfile'] = text
    
    return holdings, legend

# %%
holdings, legend = getpanel1('726735', '0001193125-15-388874.txt', panel2)
# Out:
# Government and Quality Bond Portfolio
# Asset Allocation Portfolio
# Growth and Income Portfolio
# Growth Portfolio
# Capital Appreciation Portfolio
# Natural Resources Portfolio
# SA BlackRock Multi-Asset Income Portfolio
# Strategic Multi-Asset Portfolio
#     holdings shares holdings value  \
# 0               495          52688
# 1              1755         556984
# 2             77000         215600
# 3             12194         839679
# 4              5500         439120
# 5              6544         378440
# 6              1273          51047
# 7              2213         206805
# 8             17966        2054771
# 9              2599         354192
# 10             9000         325170
# 11            36000         673380
# 12             2769         107767
# 13             6128         417869
# 14             1878          73824
# 15            11320         981218
# 16             1403          64640
# 17            11693         614233
# 18            70000         441000
# 19            13478         104589
# 20             7139         270996
# 21              414          40274
# 22             5573         582044
# 23            11202         676265
# 24             2560          41395
# 25            38000         492860
# 26             2190         104354
# 27              812          44904
# 28            10431        1420598
# 29             3250         217068
# ..              ...            ...
# 723             635          92710
# 724            4881         125295
# 725            5590         347027
# 726            1400         136279
# 727            4294         157160
# 728            2043         543520
# 729            2058         286309
# 730            1307         199644
# 731             860         116264
# 732            3432         437820
# 733            4465         289480
# 734            1165         132519
# 735            7764         314675
# 736           11100         128038
# 737            1962         395598
# 738            3731         182285
# 739            8344         252949
# 740            6519         327710
# 741            1400         160748
# 742            1033         304528
# 743            4159         307808
# 744           41520         356958
# 745            1264         128561
# 746            1311         132346
# 747            9774         456645
# 748            5173         297551
# 749            6571         486583
# 750             655         105625
# 751             452         539448
# 752            4509         148301
#
#                                          holdings name    key  \
# 0                                     MSA Safety, Inc.
# 1                               Northrop Grumman Corp.
# 2                              Incitec Pivot, Ltd. ADR
# 3                               Alaska Air Group, Inc.
# 4                             Copa Holdings SA, ClassA
# 5                                Delta Air Lines, Inc.
# 6                              Hawaiian Holdings, Inc.
# 7                                             VF Corp.
# 8                                      Microsoft Corp.
# 9                                        Red Hat, Inc.      †
# 10                     Ritchie Bros. Auctioneers, Inc.
# 11                          Nissan Motor Co., Ltd. ADR
# 12                                     NFI Group, Inc.
# 13                                        PACCAR, Inc.
# 14                                          Adient PLC
# 15                                       Autoliv, Inc.
# 16                                       Linamar Corp.
# 17                           Magna International, Inc.
# 18              Banco Bilbao Vizcaya Argentaria SA ADR
# 19   Banco Santander Mexico SA Institucion de Banca...
# 20                                            Bank OZK
# 21                                 BOK Financial Corp.
# 22                          Cullen/Frost Bankers, Inc.
# 23                             East West Bancorp, Inc.
# 24                                  Hope Bancorp, Inc.
# 25                                    ING Groep NV ADR
# 26                                     PacWest Bancorp
# 27                      Washington Trust Bancorp, Inc.
# 28                  PNC Financial Services Group, Inc.
# 29                                SunTrust Banks, Inc.
# ..                                                 ...    ...
# 723                                 Bluebird Bio, Inc.      †
# 724                           Bausch Health Cos., Inc.      †
# 725                           Bristol-Myers Squibb Co.
# 726                                    Eisai Co., Ltd.
# 727                                           Mylan NV      †
# 728                           UnitedHealth Group, Inc.
# 729                               HCA Healthcare, Inc.
# 730                             Concho Resources, Inc.      †
# 731                           Diamondback Energy, Inc.
# 732                                EOG Resources, Inc.
# 733                                           TOTAL SA
# 734                                Valero Energy Corp.
# 735                                    Halliburton Co.
# 736           Sunny Optical Technology Group Co., Ltd.
# 737                                     Public Storage
# 738                                         Vonovia SE
# 739                      Industria de Diseno Textil SA
# 740                                     Tapestry, Inc.
# 741                                   Lowes Cos., Inc.      ’
# 742                                Dominos Pizza, Inc.      ’
# 743    New Oriental Education Technology Group Inc ADR   &,.†
# 744       Taiwan Semiconductor Manufacturing Co., Ltd.
# 745                                   KLA-Tencor Corp.
# 746                               SoftBank Group Corp.
# 747                       British American Tobacco PLC
# 748                                 AerCap Holdings NV      †
# 749                                          CSX Corp.
# 750                    Old Dominion Freight Line, Inc.
# 751                             Alphabet, Inc., ClassC      †
# 752                                  Yandex NV, ClassA      †
#
#                            fund name                       identifier  \
# 0         Asset Allocation Portfolio       Asset Allocation Portfolio
# 1         Asset Allocation Portfolio       Asset Allocation Portfolio
# 2         Asset Allocation Portfolio       Asset Allocation Portfolio
# 3         Asset Allocation Portfolio       Asset Allocation Portfolio
# 4         Asset Allocation Portfolio       Asset Allocation Portfolio
# 5         Asset Allocation Portfolio       Asset Allocation Portfolio
# 6         Asset Allocation Portfolio       Asset Allocation Portfolio
# 7         Asset Allocation Portfolio       Asset Allocation Portfolio
# 8         Asset Allocation Portfolio       Asset Allocation Portfolio
# 9         Asset Allocation Portfolio       Asset Allocation Portfolio
# 10        Asset Allocation Portfolio       Asset Allocation Portfolio
# 11        Asset Allocation Portfolio       Asset Allocation Portfolio
# 12        Asset Allocation Portfolio       Asset Allocation Portfolio
# 13        Asset Allocation Portfolio       Asset Allocation Portfolio
# 14        Asset Allocation Portfolio       Asset Allocation Portfolio
# 15        Asset Allocation Portfolio       Asset Allocation Portfolio
# 16        Asset Allocation Portfolio       Asset Allocation Portfolio
# 17        Asset Allocation Portfolio       Asset Allocation Portfolio
# 18        Asset Allocation Portfolio       Asset Allocation Portfolio
# 19        Asset Allocation Portfolio       Asset Allocation Portfolio
# 20        Asset Allocation Portfolio       Asset Allocation Portfolio
# 21        Asset Allocation Portfolio       Asset Allocation Portfolio
# 22        Asset Allocation Portfolio       Asset Allocation Portfolio
# 23        Asset Allocation Portfolio       Asset Allocation Portfolio
# 24        Asset Allocation Portfolio       Asset Allocation Portfolio
# 25        Asset Allocation Portfolio       Asset Allocation Portfolio
# 26        Asset Allocation Portfolio       Asset Allocation Portfolio
# 27        Asset Allocation Portfolio       Asset Allocation Portfolio
# 28        Asset Allocation Portfolio       Asset Allocation Portfolio
# 29        Asset Allocation Portfolio       Asset Allocation Portfolio
# ..                               ...                              ...
# 723  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
#
# 747    ANCHOR SERIES TRUST       20150930
# 748    ANCHOR SERIES TRUST       20150930
# 749    ANCHOR SERIES TRUST       20150930
# 750    ANCHOR SERIES TRUST       20150930
# 751    ANCHOR SERIES TRUST       20150930
# 752    ANCHOR SERIES TRUST       20150930
#
# [753 rows x 12 columns]

# %%
holdings.to_csv(os.path.join(output_directory, fund_name + '_test_holdings2.csv'), sep = ',')
legend.to_csv(os.path.join(output_directory, fund_name + '_test_legend2.csv'), sep = ',')
print(holdings)
# Out:
#     holdings shares holdings value  \
# 0               495          52688
# 1              1755         556984
# 2             77000         215600
# 3             12194         839679
# 4              5500         439120
# 5              6544         378440
# 6              1273          51047
# 7              2213         206805
# 8             17966        2054771
# 9              2599         354192
# 10             9000         325170
# 11            36000         673380
# 12             2769         107767
# 13             6128         417869
# 14             1878          73824
# 15            11320         981218
# 16             1403          64640
# 17            11693         614233
# 18            70000         441000
# 19            13478         104589
# 20             7139         270996
# 21              414          40274
# 22             5573         582044
# 23            11202         676265
# 24             2560          41395
# 25            38000         492860
# 26             2190         104354
# 27              812          44904
# 28            10431        1420598
# 29             3250         217068
# ..              ...            ...
# 723             635          92710
# 724            4881         125295
# 725            5590         347027
# 726            1400         136279
# 727            4294         157160
# 728            2043         543520
# 729            2058         286309
# 730            1307         199644
# 731             860         116264
# 732            3432         437820
# 733            4465         289480
# 734            1165         132519
# 735            7764         314675
# 736           11100         128038
# 737            1962         395598
# 738            3731         182285
# 739            8344         252949
# 740            6519         327710
# 741            1400         160748
# 742            1033         304528
# 743            4159         307808
# 744           41520         356958
# 745            1264         128561
# 746            1311         132346
# 747            9774         456645
# 748            5173         297551
# 749            6571         486583
# 750             655         105625
# 751             452         539448
# 752            4509         148301
#
#                                          holdings name    key  \
# 0                                     MSA Safety, Inc.
# 1                               Northrop Grumman Corp.
# 2                              Incitec Pivot, Ltd. ADR
# 3                               Alaska Air Group, Inc.
# 4                             Copa Holdings SA, ClassA
# 5                                Delta Air Lines, Inc.
# 6                              Hawaiian Holdings, Inc.
# 7                                             VF Corp.
# 8                                      Microsoft Corp.
# 9                                        Red Hat, Inc.      †
# 10                     Ritchie Bros. Auctioneers, Inc.
# 11                          Nissan Motor Co., Ltd. ADR
# 12                                     NFI Group, Inc.
# 13                                        PACCAR, Inc.
# 14                                          Adient PLC
# 15                                       Autoliv, Inc.
# 16                                       Linamar Corp.
# 17                           Magna International, Inc.
# 18              Banco Bilbao Vizcaya Argentaria SA ADR
# 19   Banco Santander Mexico SA Institucion de Banca...
# 20                                            Bank OZK
# 21                                 BOK Financial Corp.
# 22                          Cullen/Frost Bankers, Inc.
# 23                             East West Bancorp, Inc.
# 24                                  Hope Bancorp, Inc.
# 25                                    ING Groep NV ADR
# 26                                     PacWest Bancorp
# 27                      Washington Trust Bancorp, Inc.
# 28                  PNC Financial Services Group, Inc.
# 29                                SunTrust Banks, Inc.
# ..                                                 ...    ...
# 723                                 Bluebird Bio, Inc.      †
# 724                           Bausch Health Cos., Inc.      †
# 725                           Bristol-Myers Squibb Co.
# 726                                    Eisai Co., Ltd.
# 727                                           Mylan NV      †
# 728                           UnitedHealth Group, Inc.
# 729                               HCA Healthcare, Inc.
# 730                             Concho Resources, Inc.      †
# 731                           Diamondback Energy, Inc.
# 732                                EOG Resources, Inc.
# 733                                           TOTAL SA
# 734                                Valero Energy Corp.
# 735                                    Halliburton Co.
# 736           Sunny Optical Technology Group Co., Ltd.
# 737                                     Public Storage
# 738                                         Vonovia SE
# 739                      Industria de Diseno Textil SA
# 740                                     Tapestry, Inc.
# 741                                   Lowes Cos., Inc.      ’
# 742                                Dominos Pizza, Inc.      ’
# 743    New Oriental Education Technology Group Inc ADR   &,.†
# 744       Taiwan Semiconductor Manufacturing Co., Ltd.
# 745                                   KLA-Tencor Corp.
# 746                               SoftBank Group Corp.
# 747                       British American Tobacco PLC
# 748                                 AerCap Holdings NV      †
# 749                                          CSX Corp.
# 750                    Old Dominion Freight Line, Inc.
# 751                             Alphabet, Inc., ClassC      †
# 752                                  Yandex NV, ClassA      †
#
#                            fund name                       identifier  \
# 0         Asset Allocation Portfolio       Asset Allocation Portfolio
# 1         Asset Allocation Portfolio       Asset Allocation Portfolio
# 2         Asset Allocation Portfolio       Asset Allocation Portfolio
# 3         Asset Allocation Portfolio       Asset Allocation Portfolio
# 4         Asset Allocation Portfolio       Asset Allocation Portfolio
# 5         Asset Allocation Portfolio       Asset Allocation Portfolio
# 6         Asset Allocation Portfolio       Asset Allocation Portfolio
# 7         Asset Allocation Portfolio       Asset Allocation Portfolio
# 8         Asset Allocation Portfolio       Asset Allocation Portfolio
# 9         Asset Allocation Portfolio       Asset Allocation Portfolio
# 10        Asset Allocation Portfolio       Asset Allocation Portfolio
# 11        Asset Allocation Portfolio       Asset Allocation Portfolio
# 12        Asset Allocation Portfolio       Asset Allocation Portfolio
# 13        Asset Allocation Portfolio       Asset Allocation Portfolio
# 14        Asset Allocation Portfolio       Asset Allocation Portfolio
# 15        Asset Allocation Portfolio       Asset Allocation Portfolio
# 16        Asset Allocation Portfolio       Asset Allocation Portfolio
# 17        Asset Allocation Portfolio       Asset Allocation Portfolio
# 18        Asset Allocation Portfolio       Asset Allocation Portfolio
# 19        Asset Allocation Portfolio       Asset Allocation Portfolio
# 20        Asset Allocation Portfolio       Asset Allocation Portfolio
# 21        Asset Allocation Portfolio       Asset Allocation Portfolio
# 22        Asset Allocation Portfolio       Asset Allocation Portfolio
# 23        Asset Allocation Portfolio       Asset Allocation Portfolio
# 24        Asset Allocation Portfolio       Asset Allocation Portfolio
# 25        Asset Allocation Portfolio       Asset Allocation Portfolio
# 26        Asset Allocation Portfolio       Asset Allocation Portfolio
# 27        Asset Allocation Portfolio       Asset Allocation Portfolio
# 28        Asset Allocation Portfolio       Asset Allocation Portfolio
# 29        Asset Allocation Portfolio       Asset Allocation Portfolio
# ..                               ...                              ...
# 723  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 724  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 725  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 726  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 727  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 728  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 729  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 730  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 731  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 732  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 733  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 734  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 735  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 736  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 737  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 738  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 739  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 740  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 741  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 742  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 743  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 744  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
#
# 750  https://www.sec.gov/Archives/edgar/data/726735...
# 751  https://www.sec.gov/Archives/edgar/data/726735...
# 752  https://www.sec.gov/Archives/edgar/data/726735...
#
# [753 rows x 13 columns]

# %% [markdown]
# # Run on all CIKs

# %%
panel1 = pd.DataFrame()


panel1 = pd.DataFrame()
panel1_legend = pd.DataFrame()
error_panel1 = []
no_holdings = {}

CIK_LIST = ['726735']

for CIK in CIK_LIST:
    no_holdings[CIK] = []
    txt_files = os.listdir(os.path.join(cur_wd, CIK, 'n-q'))
    for i in txt_files:
        if '.csv' not in i and i not in errors[CIK]:
            holdings, legend = getpanel1(str(CIK), str(i), panel2)
            print(holdings)
            if len(holdings) == 0:
                no_holdings[CIK].append(i)

            if panel1.empty:
                panel1 = holdings.copy()
                panel1_legend = legend.copy()
            else:
                panel1 = pd.concat([panel1, holdings], axis = 0, sort = False)
                panel1_legend = pd.concat([panel1_legend , legend], axis = 0, sort = False)

            panel1.index = pd.RangeIndex(len(panel1.index))
# Out:
# Government and Quality Bond Portfolio
# Asset Allocation Portfolio
# Growth and Income Portfolio
# Growth Portfolio
# Capital Appreciation Portfolio
# Natural Resources Portfolio
# Multi-Asset Portfolio
# Strategic Multi-Asset Portfolio
#     holdings shares holdings value  \
# 0               495          52688
# 1              1755         556984
# 2             77000         215600
# 3             12194         839679
# 4              5500         439120
# 5              6544         378440
# 6              1273          51047
# 7              2213         206805
# 8             17966        2054771
# 9              2599         354192
# 10             9000         325170
# 11            36000         673380
# 12             2769         107767
# 13             6128         417869
# 14             1878          73824
# 15            11320         981218
# 16             1403          64640
# 17            11693         614233
# 18            70000         441000
# 19            13478         104589
# 20             7139         270996
# 21              414          40274
# 22             5573         582044
# 23            11202         676265
# 24             2560          41395
# 25            38000         492860
# 26             2190         104354
# 27              812          44904
# 28            10431        1420598
# 29             3250         217068
# ..              ...            ...
# 723             635          92710
# 724            4881         125295
# 725            5590         347027
# 726            1400         136279
# 727            4294         157160
# 728            2043         543520
# 729            2058         286309
# 730            1307         199644
# 731             860         116264
# 732            3432         437820
# 733            4465         289480
# 734            1165         132519
# 735            7764         314675
# 736           11100         128038
# 737            1962         395598
# 738            3731         182285
# 739            8344         252949
# 740            6519         327710
# 741            1400         160748
# 742            1033         304528
# 743            4159         307808
# 744           41520         356958
# 745            1264         128561
# 746            1311         132346
# 747            9774         456645
# 748            5173         297551
# 749            6571         486583
# 750             655         105625
# 751             452         539448
# 752            4509         148301
#
#                                          holdings name    key  \
# 0                                     MSA Safety, Inc.
# 1                               Northrop Grumman Corp.
# 2                              Incitec Pivot, Ltd. ADR
# 3                               Alaska Air Group, Inc.
# 4                             Copa Holdings SA, ClassA
# 5                                Delta Air Lines, Inc.
# 6                              Hawaiian Holdings, Inc.
# 7                                             VF Corp.
# 8                                      Microsoft Corp.
# 9                                        Red Hat, Inc.      †
# 10                     Ritchie Bros. Auctioneers, Inc.
# 11                          Nissan Motor Co., Ltd. ADR
# 12                                     NFI Group, Inc.
# 13                                        PACCAR, Inc.
# 14                                          Adient PLC
# 15                                       Autoliv, Inc.
# 16                                       Linamar Corp.
# 17                           Magna International, Inc.
# 18              Banco Bilbao Vizcaya Argentaria SA ADR
# 19   Banco Santander Mexico SA Institucion de Banca...
# 20                                            Bank OZK
# 21                                 BOK Financial Corp.
# 22                          Cullen/Frost Bankers, Inc.
# 23                             East West Bancorp, Inc.
# 24                                  Hope Bancorp, Inc.
# 25                                    ING Groep NV ADR
# 26                                     PacWest Bancorp
# 27                      Washington Trust Bancorp, Inc.
# 28                  PNC Financial Services Group, Inc.
# 29                                SunTrust Banks, Inc.
# ..                                                 ...    ...
# 723                                 Bluebird Bio, Inc.      †
# 724                           Bausch Health Cos., Inc.      †
# 725                           Bristol-Myers Squibb Co.
# 726                                    Eisai Co., Ltd.
# 727                                           Mylan NV      †
# 728                           UnitedHealth Group, Inc.
# 729                               HCA Healthcare, Inc.
# 730                             Concho Resources, Inc.      †
# 731                           Diamondback Energy, Inc.
# 732                                EOG Resources, Inc.
# 733                                           TOTAL SA
# 734                                Valero Energy Corp.
# 735                                    Halliburton Co.
# 736           Sunny Optical Technology Group Co., Ltd.
# 737                                     Public Storage
# 738                                         Vonovia SE
# 739                      Industria de Diseno Textil SA
# 740                                     Tapestry, Inc.
# 741                                   Lowes Cos., Inc.      ’
# 742                                Dominos Pizza, Inc.      ’
# 743    New Oriental Education Technology Group Inc ADR   &,.†
# 744       Taiwan Semiconductor Manufacturing Co., Ltd.
# 745                                   KLA-Tencor Corp.
# 746                               SoftBank Group Corp.
# 747                       British American Tobacco PLC
# 748                                 AerCap Holdings NV      †
# 749                                          CSX Corp.
# 750                    Old Dominion Freight Line, Inc.
# 751                             Alphabet, Inc., ClassC      †
# 752                                  Yandex NV, ClassA      †
#
#                            fund name                       identifier  \
# 0         Asset Allocation Portfolio       Asset Allocation Portfolio
# 1         Asset Allocation Portfolio       Asset Allocation Portfolio
# 2         Asset Allocation Portfolio       Asset Allocation Portfolio
# 3         Asset Allocation Portfolio       Asset Allocation Portfolio
# 4         Asset Allocation Portfolio       Asset Allocation Portfolio
# 5         Asset Allocation Portfolio       Asset Allocation Portfolio
# 6         Asset Allocation Portfolio       Asset Allocation Portfolio
# 7         Asset Allocation Portfolio       Asset Allocation Portfolio
# 8         Asset Allocation Portfolio       Asset Allocation Portfolio
# 9         Asset Allocation Portfolio       Asset Allocation Portfolio
# 10        Asset Allocation Portfolio       Asset Allocation Portfolio
# 11        Asset Allocation Portfolio       Asset Allocation Portfolio
# 12        Asset Allocation Portfolio       Asset Allocation Portfolio
# 13        Asset Allocation Portfolio       Asset Allocation Portfolio
# 14        Asset Allocation Portfolio       Asset Allocation Portfolio
# 15        Asset Allocation Portfolio       Asset Allocation Portfolio
# 16        Asset Allocation Portfolio       Asset Allocation Portfolio
# 17        Asset Allocation Portfolio       Asset Allocation Portfolio
# 18        Asset Allocation Portfolio       Asset Allocation Portfolio
# 19        Asset Allocation Portfolio       Asset Allocation Portfolio
# 20        Asset Allocation Portfolio       Asset Allocation Portfolio
# 21        Asset Allocation Portfolio       Asset Allocation Portfolio
# 22        Asset Allocation Portfolio       Asset Allocation Portfolio
# 743    ANCHOR SERIES TRUST       20090930
# 744    ANCHOR SERIES TRUST       20090930
# 745    ANCHOR SERIES TRUST       20090930
# 746    ANCHOR SERIES TRUST       20090930
# 747    ANCHOR SERIES TRUST       20090930
# 748    ANCHOR SERIES TRUST       20090930
# 749    ANCHOR SERIES TRUST       20090930
# 750    ANCHOR SERIES TRUST       20090930
# 751    ANCHOR SERIES TRUST       20090930
# 752    ANCHOR SERIES TRUST       20090930
#
# [753 rows x 12 columns]
#     holdings shares holdings value  \
# 0               495          52688
# 1              1755         556984
# 2             77000         215600
# 3             12194         839679
# 4              5500         439120
# 5              6544         378440
# 6              1273          51047
# 7              2213         206805
# 8             17966        2054771
# 9              2599         354192
# 10             9000         325170
# 11            36000         673380
# 12             2769         107767
# 13             6128         417869
# 14             1878          73824
# 15            11320         981218
# 16             1403          64640
# 17            11693         614233
# 18            70000         441000
# 19            13478         104589
# 20             7139         270996
# 21              414          40274
# 22             5573         582044
# 23            11202         676265
# 24             2560          41395
# 25            38000         492860
# 26             2190         104354
# 27              812          44904
# 28            10431        1420598
# 29             3250         217068
# ..              ...            ...
# 723             635          92710
# 724            4881         125295
# 725            5590         347027
# 726            1400         136279
# 727            4294         157160
# 728            2043         543520
# 729            2058         286309
# 730            1307         199644
# 731             860         116264
# 732            3432         437820
# 733            4465         289480
# 734            1165         132519
# 735            7764         314675
# 736           11100         128038
# 737            1962         395598
# 738            3731         182285
# 739            8344         252949
# 740            6519         327710
# 741            1400         160748
# 742            1033         304528
# 743            4159         307808
# 744           41520         356958
# 745            1264         128561
# 746            1311         132346
# 747            9774         456645
# 748            5173         297551
# 749            6571         486583
# 750             655         105625
# 751             452         539448
# 752            4509         148301
#
#                                          holdings name    key  \
# 0                                     MSA Safety, Inc.
# 1                               Northrop Grumman Corp.
# 2                              Incitec Pivot, Ltd. ADR
# 3                               Alaska Air Group, Inc.
# 4                             Copa Holdings SA, ClassA
# 5                                Delta Air Lines, Inc.
# 6                              Hawaiian Holdings, Inc.
# 7                                             VF Corp.
# 8                                      Microsoft Corp.
# 9                                        Red Hat, Inc.      †
# 10                     Ritchie Bros. Auctioneers, Inc.
# 11                          Nissan Motor Co., Ltd. ADR
# 12                                     NFI Group, Inc.
# 13                                        PACCAR, Inc.
# 14                                          Adient PLC
# 15                                       Autoliv, Inc.
# 16                                       Linamar Corp.
# 17                           Magna International, Inc.
# 18              Banco Bilbao Vizcaya Argentaria SA ADR
# 19   Banco Santander Mexico SA Institucion de Banca...
# 20                                            Bank OZK
# 21                                 BOK Financial Corp.
# 22                          Cullen/Frost Bankers, Inc.
# 23                             East West Bancorp, Inc.
# 24                                  Hope Bancorp, Inc.
# 25                                    ING Groep NV ADR
# 26                                     PacWest Bancorp
# 27                      Washington Trust Bancorp, Inc.
# 28                  PNC Financial Services Group, Inc.
# 29                                SunTrust Banks, Inc.
# ..                                                 ...    ...
# 723                                 Bluebird Bio, Inc.      †
# 724                           Bausch Health Cos., Inc.      †
# 725                           Bristol-Myers Squibb Co.
# 726                                    Eisai Co., Ltd.
# 727                                           Mylan NV      †
# 728                           UnitedHealth Group, Inc.
# 729                               HCA Healthcare, Inc.
# 730                             Concho Resources, Inc.      †
# 731                           Diamondback Energy, Inc.
# 732                                EOG Resources, Inc.
# 733                                           TOTAL SA
# 734                                Valero Energy Corp.
# 735                                    Halliburton Co.
# 736           Sunny Optical Technology Group Co., Ltd.
# 737                                     Public Storage
# 738                                         Vonovia SE
# 739                      Industria de Diseno Textil SA
# 740                                     Tapestry, Inc.
# 741                                   Lowes Cos., Inc.      ’
# 742                                Dominos Pizza, Inc.      ’
# 743    New Oriental Education Technology Group Inc ADR   &,.†
# 744       Taiwan Semiconductor Manufacturing Co., Ltd.
# 745                                   KLA-Tencor Corp.
# 746                               SoftBank Group Corp.
# 747                       British American Tobacco PLC
# 748                                 AerCap Holdings NV      †
# 749                                          CSX Corp.
# 750                    Old Dominion Freight Line, Inc.
# 751                             Alphabet, Inc., ClassC      †
# 752                                  Yandex NV, ClassA      †
#
#                            fund name                       identifier  \
# 0         Asset Allocation Portfolio       Asset Allocation Portfolio
# 1         Asset Allocation Portfolio       Asset Allocation Portfolio
# 2         Asset Allocation Portfolio       Asset Allocation Portfolio
# 3         Asset Allocation Portfolio       Asset Allocation Portfolio
# 4         Asset Allocation Portfolio       Asset Allocation Portfolio
# 5         Asset Allocation Portfolio       Asset Allocation Portfolio
# 6         Asset Allocation Portfolio       Asset Allocation Portfolio
# 7         Asset Allocation Portfolio       Asset Allocation Portfolio
# 8         Asset Allocation Portfolio       Asset Allocation Portfolio
# 9         Asset Allocation Portfolio       Asset Allocation Portfolio
# 10        Asset Allocation Portfolio       Asset Allocation Portfolio
# 11        Asset Allocation Portfolio       Asset Allocation Portfolio
# 12        Asset Allocation Portfolio       Asset Allocation Portfolio
# 13        Asset Allocation Portfolio       Asset Allocation Portfolio
# 14        Asset Allocation Portfolio       Asset Allocation Portfolio
# 15        Asset Allocation Portfolio       Asset Allocation Portfolio
# 16        Asset Allocation Portfolio       Asset Allocation Portfolio
# 17        Asset Allocation Portfolio       Asset Allocation Portfolio
# 18        Asset Allocation Portfolio       Asset Allocation Portfolio
# 19        Asset Allocation Portfolio       Asset Allocation Portfolio
# 20        Asset Allocation Portfolio       Asset Allocation Portfolio
# 21        Asset Allocation Portfolio       Asset Allocation Portfolio
# 22        Asset Allocation Portfolio       Asset Allocation Portfolio
# 23        Asset Allocation Portfolio       Asset Allocation Portfolio
# 24        Asset Allocation Portfolio       Asset Allocation Portfolio
# 25        Asset Allocation Portfolio       Asset Allocation Portfolio
# 26        Asset Allocation Portfolio       Asset Allocation Portfolio
# 27        Asset Allocation Portfolio       Asset Allocation Portfolio
# 28        Asset Allocation Portfolio       Asset Allocation Portfolio
# 29        Asset Allocation Portfolio       Asset Allocation Portfolio
# ..                               ...                              ...
# 723  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 724  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 725  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 726  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 727  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 728  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 729  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 730  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 731  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 732  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 733  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 734  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 735  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 736  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 737  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 738  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 739  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 740  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 741  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 742  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 743  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 744  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 745  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 746  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 747  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 748  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 749  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 750  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 751  Strategic Multi-Asset Portfolio  Strategic Multi-Asset Portfolio
# 728                           UnitedHealth Group, Inc.
# 729                               HCA Healthcare, Inc.
# 730                             Concho Resources, Inc.      †
# 731                           Diamondback Energy, Inc.
# 732                                EOG Resources, Inc.
# 733                                           TOTAL SA
# 734                                Valero Energy Corp.
# 735                                    Halliburton Co.
# 736           Sunny Optical Technology Group Co., Ltd.
# 737                                     Public Storage
# 738                                         Vonovia SE
# 739                      Industria de Diseno Textil SA
# 740                                     Tapestry, Inc.
# 741                                   Lowes Cos., Inc.      ’
# 742                                Dominos Pizza, Inc.      ’
# 743    New Oriental Education Technology Group Inc ADR   &,.†
# 744       Taiwan Semiconductor Manufacturing Co., Ltd.
# 745                                   KLA-Tencor Corp.
# 746                               SoftBank Group Corp.
# 747                       British American Tobacco PLC
# 748                                 AerCap Holdings NV      †
# 749                                          CSX Corp.
# 750                    Old Dominion Freight Line, Inc.
# 751                             Alphabet, Inc., ClassC      †
# 752                                  Yandex NV, ClassA      †
#
#                            fund name                       identifier  \
# 0         Asset Allocation Portfolio       Asset Allocation Portfolio
# 1         Asset Allocation Portfolio       Asset Allocation Portfolio
# 2         Asset Allocation Portfolio       Asset Allocation Portfolio
# 3         Asset Allocation Portfolio       Asset Allocation Portfolio
# 4         Asset Allocation Portfolio       Asset Allocation Portfolio
# 5         Asset Allocation Portfolio       Asset Allocation Portfolio
# 6         Asset Allocation Portfolio       Asset Allocation Portfolio
# 7         Asset Allocation Portfolio       Asset Allocation Portfolio
# 8         Asset Allocation Portfolio       Asset Allocation Portfolio
# 9         Asset Allocation Portfolio       Asset Allocation Portfolio
# 10        Asset Allocation Portfolio       Asset Allocation Portfolio
# 11        Asset Allocation Portfolio       Asset Allocation Portfolio
# 12        Asset Allocation Portfolio       Asset Allocation Portfolio
# 13        Asset Allocation Portfolio       Asset Allocation Portfolio
# 14        Asset Allocation Portfolio       Asset Allocation Portfolio
# 15        Asset Allocation Portfolio       Asset Allocation Portfolio
# 16        Asset Allocation Portfolio       Asset Allocation Portfolio
# 17        Asset Allocation Portfolio       Asset Allocation Portfolio
# 18        Asset Allocation Portfolio       Asset Allocation Portfolio
# 19        Asset Allocation Portfolio       Asset Allocation Portfolio
# 20        Asset Allocation Portfolio       Asset Allocation Portfolio
# ...
# 16               SA PGI Asset Allocation Portfolio
# 17               SA PGI Asset Allocation Portfolio
# 18               SA PGI Asset Allocation Portfolio
# 19               SA PGI Asset Allocation Portfolio
# 20               SA PGI Asset Allocation Portfolio
# 21               SA PGI Asset Allocation Portfolio
# 22               SA PGI Asset Allocation Portfolio
# 23               SA PGI Asset Allocation Portfolio
# 24               SA PGI Asset Allocation Portfolio
# 25               SA PGI Asset Allocation Portfolio
# 26               SA PGI Asset Allocation Portfolio
# 27               SA PGI Asset Allocation Portfolio
# 28               SA PGI Asset Allocation Portfolio
# 29               SA PGI Asset Allocation Portfolio
# ..                                             ...
# 723  SA Wellington Strategic Multi-Asset Portfolio
# 724  SA Wellington Strategic Multi-Asset Portfolio
# 725  SA Wellington Strategic Multi-Asset Portfolio
# 726  SA Wellington Strategic Multi-Asset Portfolio
# 728  SA Wellington Strategic Multi-Asset Portfolio
# 729  SA Wellington Strategic Multi-Asset Portfolio
# 730  SA Wellington Strategic Multi-Asset Portfolio
# 731  SA Wellington Strategic Multi-Asset Portfolio
# 732  SA Wellington Strategic Multi-Asset Portfolio
# 733  SA Wellington Strategic Multi-Asset Portfolio
# 734  SA Wellington Strategic Multi-Asset Portfolio
# 735  SA Wellington Strategic Multi-Asset Portfolio
# 736  SA Wellington Strategic Multi-Asset Portfolio
# 737  SA Wellington Strategic Multi-Asset Portfolio
# 738  SA Wellington Strategic Multi-Asset Portfolio
# 739  SA Wellington Strategic Multi-Asset Portfolio
# 740  SA Wellington Strategic Multi-Asset Portfolio
# 741  SA Wellington Strategic Multi-Asset Portfolio
# 742  SA Wellington Strategic Multi-Asset Portfolio
# 743  SA Wellington Strategic Multi-Asset Portfolio
# 744  SA Wellington Strategic Multi-Asset Portfolio
# 745  SA Wellington Strategic Multi-Asset Portfolio
# 746  SA Wellington Strategic Multi-Asset Portfolio
# 747  SA Wellington Strategic Multi-Asset Portfolio
# 748  SA Wellington Strategic Multi-Asset Portfolio
# 749  SA Wellington Strategic Multi-Asset Portfolio
# 750  SA Wellington Strategic Multi-Asset Portfolio
# 751  SA Wellington Strategic Multi-Asset Portfolio
# 752  SA Wellington Strategic Multi-Asset Portfolio
#
#                      textfile     CIK date_filed company conformed name  \
# 0    0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 1    0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 2    0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 3    0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 4    0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 5    0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 6    0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 7    0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 8    0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 9    0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 10   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 11   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 12   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 13   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 14   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 15   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 16   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 17   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 18   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 19   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 20   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 21   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 22   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 23   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 24   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 25   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 26   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 27   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 28   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 29   0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# ..                        ...     ...        ...                    ...
# 723  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 724  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 725  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 726  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 727  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 728  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 729  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 730  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 731  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 732  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 733  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 734  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 735  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 736  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 737  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 738  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 739  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 740  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 741  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 742  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 743  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 744  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 745  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 746  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 747  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 748  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 749  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 750  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 751  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
# 752  0001193125-18-336505.txt  726735   20181128    ANCHOR SERIES TRUST
#
#     reporting_date                                            weblink
# 0         20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 1         20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 2         20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 3         20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 4         20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 5         20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 6         20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 7         20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 8         20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 9         20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 10        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 11        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 12        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 13        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 14        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 15        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 16        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 17        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 18        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 19        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 20        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 21        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 22        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 23        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 24        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 25        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 26        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 27        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 28        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 29        20180930  https://www.sec.gov/Archives/edgar/data/726735...
# ..             ...                                                ...
# 723       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 724       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 725       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 726       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 727       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 728       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 729       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 730       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 731       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 732       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 733       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 734       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 735       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 736       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 737       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 738       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 739       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 740       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 741       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 742       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 743       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 744       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 745       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 746       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 747       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 748       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 749       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 750       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 751       20180930  https://www.sec.gov/Archives/edgar/data/726735...
# 752       20180930  https://www.sec.gov/Archives/edgar/data/726735...
#
# [753 rows x 13 columns]

# %%
panel1.loc[:,'acq name'] = ''
panel1.loc[:,'acq date'] = ''
panel1.loc[:,'acq cost'] = ''
print(output_directory)
panel1.to_csv(os.path.join(output_directory, fund_name + '_panel1.csv'), sep = ',')
panel1_legend.to_csv(os.path.join(output_directory, fund_name + '_panel1_legend.csv'), sep = ',')
# Out:
# C:\Users\jjanko\Desktop\wei_mutual_fund_project\output\working

# %%
panel1_legend.loc[:,'restricted'] = 'no'

panel1_legend.loc[panel1_legend['code'].str.contains("restrict") | panel1_legend['code'].str.contains("level 3 security") \
              | panel1_legend['code'].str.contains("exempt from registration") |panel1_legend['code'].str.contains("private placement") , 'restricted'] = 'yes'

restricted = panel1_legend.loc[panel1_legend['restricted'].str.contains("yes")]

restricted.to_csv(os.path.join(output_directory, fund_name + '_panel1_restricted_legend.csv'), sep = ',')
print(restricted)

panel1.loc[:,'restricted'] = 'no'

for index, row in restricted.iterrows():
    try:
        panel1.loc[(panel1['identifier'] == row['identifier']) & (panel1['textfile'] == row.textfile) \
                       & (panel1['key'].str.contains(row['symbol'])), 'restricted'] = 'yes'
    except:
        pass
    
restricted_holdings = panel1.loc[(panel1['restricted'] == 'yes')]
restricted_holdings.to_csv(os.path.join(output_directory, fund_name + '_panel1_restricted.csv'), sep = ',')
# Out:
#                                                  code symbol restricted  \
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
# ..                                                ...    ...        ...
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
# 0   Securities exempt from registration under Rule...      *        yes
# 14  Securities exempt from registration under Rule...      *        yes
# 33  Securities exempt from registration under Rule...      *        yes
# 39  Denotes a restricted security that: (a) cannot...    (3)        yes
# 55  Securities exempt from registration under Rule...      *        yes
#
#                                            identifier  \
# 0               Government and Quality Bond Portfolio
# 14                         Asset Allocation Portfolio
# 33                                   Growth Portfolio
# 39                     Capital Appreciation Portfolio
# 55                    Strategic Multi-Asset Portfolio
# 0               Government and Quality Bond Portfolio
# 14                         Asset Allocation Portfolio
# 33                                   Growth Portfolio
# 39                     Capital Appreciation Portfolio
# 55                    Strategic Multi-Asset Portfolio
# 0               Government and Quality Bond Portfolio
# 14                         Asset Allocation Portfolio
# 33                                   Growth Portfolio
# 39                     Capital Appreciation Portfolio
# 55                    Strategic Multi-Asset Portfolio
# 0               Government and Quality Bond Portfolio
# 14                         Asset Allocation Portfolio
# 33                                   Growth Portfolio
# 39                     Capital Appreciation Portfolio
# 55                    Strategic Multi-Asset Portfolio
# 0               Government and Quality Bond Portfolio
# 14                         Asset Allocation Portfolio
# 33                                   Growth Portfolio
# 39                     Capital Appreciation Portfolio
# 55                    Strategic Multi-Asset Portfolio
# 0               Government and Quality Bond Portfolio
# 14                         Asset Allocation Portfolio
# 33                                   Growth Portfolio
# 39                     Capital Appreciation Portfolio
# 55                    Strategic Multi-Asset Portfolio
# ..                                                ...
# 0               Government and Quality Bond Portfolio
# 14                         Asset Allocation Portfolio
# 33                                   Growth Portfolio
# 39                     Capital Appreciation Portfolio
# 55                    Strategic Multi-Asset Portfolio
# 0               Government and Quality Bond Portfolio
# 14                         Asset Allocation Portfolio
# 33                                   Growth Portfolio
# 39                     Capital Appreciation Portfolio
# 55                    Strategic Multi-Asset Portfolio
# 0               Government and Quality Bond Portfolio
# 14                         Asset Allocation Portfolio
# 33                                   Growth Portfolio
# 39                     Capital Appreciation Portfolio
# 55                    Strategic Multi-Asset Portfolio
# 0   SA Wellington Government and Quality Bond Port...
# 14  SA Wellington Government and Quality Bond Port...
# 33                     SA Wellington Growth Portfolio
